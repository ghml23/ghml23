# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar2/"
use_tfidfvectorizer = False
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 30
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.3.1s"
merge_list = ["t2.3.2", "t2.3.4"]

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.1s.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 218335

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)
# Out:
# t2.3.1s+2.3.2+2.3.4

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.2.pkl
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.4.pkl

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 218335

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 218335
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 14.38103461265564

# %%
word_doc_matrix
# Out:
# <218335x14610 sparse matrix of type '<class 'numpy.int64'>'
# 	with 29660968 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 781 edges.
# It has only fully disconnected 15 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 1h 30min 37s, sys: 1min 29s, total: 1h 32min 6s
# Wall time: 15min 41s

# %%
print(runtime_umap)
# Out:
# 941.3969242572784

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 3h 55min 48s, sys: 14.5 s, total: 3h 56min 3s
# Wall time: 3h 52min 41s

# %%
print(runtime_umap_transform)
# Out:
# 13961.8708319664

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//umap_embedding_t2.3.1s+2.3.2+2.3.4.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//umap_clusterable_embedding_t2.3.1s+2.3.2+2.3.4.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type              testset  version      name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1  ss50cs50            50           50
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
# 5  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs50            50          300
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5  7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
# 5  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs50            50          300
# 6  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs50            50          350
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5  7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6  8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
# 5  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs50            50          300
# 6  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs50            50          350
# 7  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs50            50          400
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5  7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6  8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7  8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
# 5  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs50            50          300
# 6  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs50            50          350
# 7  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs50            50          400
# 8  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs50            50          450
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5  7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6  8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7  8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8  9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#   type              testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs50            50           50
# 1  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs50            50          100
# 2  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs50            50          150
# 3  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs50            50          200
# 4  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs50            50          250
# 5  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs50            50          300
# 6  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs50            50          350
# 7  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs50            50          400
# 8  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs50            50          450
# 9  hdb  t2.3.1s+2.3.2+2.3.4        1  ss50cs100           100           50
#
#     runtime                                                tdf  \
# 0  5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1  5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2  5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3  6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4  6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5  7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6  8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7  8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8  9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9  4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 15  8.277192  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 15  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
# 16  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs100           100          400
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 15  8.277192  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 16  9.165464  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 15  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 16  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
# 16  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs100           100          400
# 17  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs100           100          450
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 15  8.277192  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 16  9.165464  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 17  9.587125  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 15  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 16  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 17  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
# 16  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs100           100          400
# 17  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs100           100          450
# 18  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs150           150           50
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 15  8.277192  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 16  9.165464  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 17  9.587125  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 18  4.921248  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 15  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 16  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 17  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 18  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
# 16  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs100           100          400
# 17  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs100           100          450
# 18  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs150           150           50
# 19  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs150           150          100
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 5   7.546428  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 6   8.173876  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 7   8.719731  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 8   9.590811  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 9   4.608053  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 10  5.079311  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 11  5.714146  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 12  6.939471  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 13  7.100409  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 14  7.590520  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 15  8.277192  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 16  9.165464  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 17  9.587125  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 18  4.921248  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 19  5.082654  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 5   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 6   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 7   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 8   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 9   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 10  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 11  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 12  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 13  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 14  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 15  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 16  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 17  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 18  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 19  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# 5   hdb  t2.3.1s+2.3.2+2.3.4        1   ss300cs50            50          300
# 6   hdb  t2.3.1s+2.3.2+2.3.4        1   ss350cs50            50          350
# 7   hdb  t2.3.1s+2.3.2+2.3.4        1   ss400cs50            50          400
# 8   hdb  t2.3.1s+2.3.2+2.3.4        1   ss450cs50            50          450
# 9   hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs100           100           50
# 10  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs100           100          100
# 11  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs100           100          150
# 12  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs100           100          200
# 13  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs100           100          250
# 14  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs100           100          300
# 15  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs100           100          350
# 16  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs100           100          400
# 17  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs100           100          450
# ...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 70  9.309932  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 71  9.780178  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 72  4.629104  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 73  5.149966  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 74  5.839150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 71  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 72  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 73  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 74  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [75 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 71  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs400           400          450
# 72  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs450           450           50
# 73  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs450           450          100
# 74  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs450           450          150
# 75  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs450           450          200
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 71  9.780178  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 72  4.629104  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 73  5.149966  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 74  5.839150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 75  6.665489  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 72  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 73  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 74  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 75  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [76 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 72  hdb  t2.3.1s+2.3.2+2.3.4        1   ss50cs450           450           50
# 73  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs450           450          100
# 74  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs450           450          150
# 75  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs450           450          200
# 76  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs450           450          250
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 72  4.629104  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 73  5.149966  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 74  5.839150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 75  6.665489  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 76  7.106644  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 73  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 74  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 75  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 76  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [77 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 73  hdb  t2.3.1s+2.3.2+2.3.4        1  ss100cs450           450          100
# 74  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs450           450          150
# 75  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs450           450          200
# 76  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs450           450          250
# 77  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs450           450          300
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 73  5.149966  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 74  5.839150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 75  6.665489  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 76  7.106644  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 77  7.659582  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 74  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 75  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 76  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 77  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [78 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 74  hdb  t2.3.1s+2.3.2+2.3.4        1  ss150cs450           450          150
# 75  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs450           450          200
# 76  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs450           450          250
# 77  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs450           450          300
# 78  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs450           450          350
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 74  5.839150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 75  6.665489  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 76  7.106644  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 77  7.659582  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 78  8.508178  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 75  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 76  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 77  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 78  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [79 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 75  hdb  t2.3.1s+2.3.2+2.3.4        1  ss200cs450           450          200
# 76  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs450           450          250
# 77  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs450           450          300
# 78  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs450           450          350
# 79  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs450           450          400
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 75  6.665489  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 76  7.106644  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 77  7.659582  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 78  8.508178  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 79  9.394099  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 76  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 77  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 78  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 79  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [80 rows x 9 columns]
#    type              testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4        1    ss50cs50            50           50
# 1   hdb  t2.3.1s+2.3.2+2.3.4        1   ss100cs50            50          100
# 2   hdb  t2.3.1s+2.3.2+2.3.4        1   ss150cs50            50          150
# 3   hdb  t2.3.1s+2.3.2+2.3.4        1   ss200cs50            50          200
# 4   hdb  t2.3.1s+2.3.2+2.3.4        1   ss250cs50            50          250
# ..  ...                  ...      ...         ...           ...          ...
# 76  hdb  t2.3.1s+2.3.2+2.3.4        1  ss250cs450           450          250
# 77  hdb  t2.3.1s+2.3.2+2.3.4        1  ss300cs450           450          300
# 78  hdb  t2.3.1s+2.3.2+2.3.4        1  ss350cs450           450          350
# 79  hdb  t2.3.1s+2.3.2+2.3.4        1  ss400cs450           450          400
# 80  hdb  t2.3.1s+2.3.2+2.3.4        1  ss450cs450           450          450
#
#      runtime                                                tdf  \
# 0   5.180614  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 1   5.159362  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 2   5.665150  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 3   6.506882  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 4   6.938706  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# ..       ...                                                ...
# 76  7.106644  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 77  7.659582  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 78  8.508178  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 79  9.394099  rt_vect: 14.38103461265564, min_df: 4, max_df:...
# 80  9.513737  rt_vect: 14.38103461265564, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 1   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 2   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 3   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 4   hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 77  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 78  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 79  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
# 80  hellinger, rt_umap_tf: 13961.8708319664, rt_um...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                  name  ss50cs50  ss100cs50  ss150cs50  \
# 0            technopagan/mss-saliency        74         33         22
# 1          snmnmin12/selective-search       141         82         15
# 2                  google/chaps-linux        -1         -1         22
# 3            lukasolson/speech-router        -1         -1         22
# 4               XavierTecBr/qbr-admin        -1         -1         22
# ...                               ...       ...        ...        ...
# 218330  bhagatabhijeet/bhagatabhijeet        -1         -1         15
# 218331  LandGrey/SpringBootVulExploit        -1         -1         22
# 218332    mucomplex/Pentest_checklist        -1         -1         22
# 218333            bigsen/Vision_Track        -1         -1         15
# 218334             ivanol55/cka-notes       182        148         22
#
#         ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  ss450cs50  ...  \
# 0               9         19         10         -1         -1         -1  ...
# 1              12         13         12          8          8          5  ...
# 2               9         -1         10         11          9          6  ...
# 3               9         -1         10         11          9          6  ...
# 4               9         -1         10         11          9          6  ...
# ...           ...        ...        ...        ...        ...        ...  ...
# 218330         12         -1         -1         -1          7         -1  ...
# 218331          9         -1         -1         -1         -1         -1  ...
# 218332          9         41         10         11          9          6  ...
# 218333         12         13         12          8          8          5  ...
# 218334          9         44         10         11          9          6  ...
#
#         ss450cs400  ss50cs450  ss100cs450  ss150cs450  ss200cs450  ss250cs450  \
# 0               -1          3           5           7           3          -1
# 1                4          4           5           5           6           6
# 2                5          3           5           7           3          13
# 3                5          3           5           7           3          13
# 4                5          3           5           7           3          13
# ...            ...        ...         ...         ...         ...         ...
# 218330          -1          4           5           5          -1          -1
# 218331          -1          3          -1           7           3          -1
# 218332           5          3           5           7           3          13
# 218333           4          4           5           5           6           6
# 218334           5          3           5           7           3          13
#
#         ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0                5          -1          -1          -1
# 1                7           8           6           4
# 2                5           7           7           5
# 3                5           7           7           5
# 4                5           7           7           5
# ...            ...         ...         ...         ...
# 218330          -1          -1           5          -1
# 218331          -1          -1          -1          -1
# 218332           5           7           7           5
# 218333           7           8           6           4
# 218334           5           7           7           5
#
# [218335 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//hdb_labels_results_t2.3.1s+2.3.2+2.3.4.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    16      15   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.599161
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 2  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    16      15   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    19      15   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.599161
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.929457
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 2  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 3  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    16      15   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    19      15   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    22      15   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.599161
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.929457
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  2.498752
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 2  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 3  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 4  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    16      15   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    19      15   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    22      15   22
# 5  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    25      15   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.599161
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.929457
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  2.498752
# 5  rt_vect: 14.38103461265564, min_df: 4, max_df:...  2.815118
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 2  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 3  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 4  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 5  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
#            type              testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    10      15   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    13      15   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    16      15   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    19      15   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    22      15   22
# 5  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    25      15   25
# 6  kmeans-umapt  t2.3.1s+2.3.2+2.3.4        1    28      15   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.155808
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.424268
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.599161
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  1.929457
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  2.498752
# 5  rt_vect: 14.38103461265564, min_df: 4, max_df:...  2.815118
# 6  rt_vect: 14.38103461265564, min_df: 4, max_df:...  3.151958
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 1  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 2  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 3  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 4  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 5  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...
# 6  (hellinger, rt_umap_tf: 13961.8708319664, rt_u...

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28
# 0            technopagan/mss-saliency   9   9   9  14  13  18   2
# 1          snmnmin12/selective-search   0  12  13  13  17   1  21
# 2                  google/chaps-linux   8   0  11  11   2   0   1
# 3            lukasolson/speech-router   9   9   9  14  13  18   2
# 4               XavierTecBr/qbr-admin   8   0   6   6  19   7  23
# ...                               ...  ..  ..  ..  ..  ..  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   0  12  13  13  15  14   6
# 218331  LandGrey/SpringBootVulExploit   1   3   4   2  14  19  15
# 218332    mucomplex/Pentest_checklist   8  11   0  11   2   0   1
# 218333            bigsen/Vision_Track   0  12  13  13  15  14   6
# 218334             ivanol55/cka-notes   1   3  11   3   6   3   4
#
# [218320 rows x 8 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans-umap_labels_results_t2.3.1s+2.3.2+2.3.4.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4        1    16   16
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  232.446999
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4        1    19   19
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  232.446999
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  325.395694
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4        1    22   22
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  232.446999
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  325.395694
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  424.685533
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4        1    22   22
# 5  kmeans  t2.3.1s+2.3.2+2.3.4        1    25   25
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  232.446999
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  325.395694
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  424.685533
# 5  rt_vect: 14.38103461265564, min_df: 4, max_df:...  592.865226
#      type              testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4        1    22   22
# 5  kmeans  t2.3.1s+2.3.2+2.3.4        1    25   25
# 6  kmeans  t2.3.1s+2.3.2+2.3.4        1    28   28
#
#                                                  tdf     runtime
# 0  rt_vect: 14.38103461265564, min_df: 4, max_df:...  119.724823
# 1  rt_vect: 14.38103461265564, min_df: 4, max_df:...  172.084332
# 2  rt_vect: 14.38103461265564, min_df: 4, max_df:...  232.446999
# 3  rt_vect: 14.38103461265564, min_df: 4, max_df:...  325.395694
# 4  rt_vect: 14.38103461265564, min_df: 4, max_df:...  424.685533
# 5  rt_vect: 14.38103461265564, min_df: 4, max_df:...  592.865226
# 6  rt_vect: 14.38103461265564, min_df: 4, max_df:...  643.962121

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28
# 0            technopagan/mss-saliency   8   1   3   9   4  18   7
# 1          snmnmin12/selective-search   9  11  15   2  21   1  20
# 2                  google/chaps-linux   1  12   0  12   2   5   5
# 3            lukasolson/speech-router   9  11  15   2   4  15  11
# 4               XavierTecBr/qbr-admin   9  11  15   2  21   1  20
# ...                               ...  ..  ..  ..  ..  ..  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   9  11  15   2  21   1  20
# 218331  LandGrey/SpringBootVulExploit   8  12   0  12   2   4  12
# 218332    mucomplex/Pentest_checklist   8   1   3  12   2   4  12
# 218333            bigsen/Vision_Track   9  11  15   2  21   1  20
# 218334             ivanol55/cka-notes   5   3   4  10  19  22  16
#
# [218335 rows x 8 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar2//kmeans_labels_results_t2.3.1s+2.3.2+2.3.4.pkl
