# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar3/"
use_tfidfvectorizer = True
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 50
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.3.2"
merge_list = ""

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.2.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 188698

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 188698

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 188698
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 0.9343035221099854

# %%
word_doc_matrix
# Out:
# <188698x6979 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1109657 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 49303 edges.
# It has only fully disconnected 1160 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 54min 15s, sys: 2min 53s, total: 57min 9s
# Wall time: 13min 10s

# %%
print(runtime_umap)
# Out:
# 790.7372522354126

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 7min 4s, sys: 320 ms, total: 7min 4s
# Wall time: 5min 56s

# %%
print(runtime_umap_transform)
# Out:
# 356.2356584072113

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_embedding_t2.3.2.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_clusterable_embedding_t2.3.2.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type testset  version      name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1  ss50cs50            50           50  4.482611
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
# 5  hdb  t2.3.2        1  ss300cs50            50          300  6.464869
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
# 5  hdb  t2.3.2        1  ss300cs50            50          300  6.464869
# 6  hdb  t2.3.2        1  ss350cs50            50          350  7.508262
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
# 5  hdb  t2.3.2        1  ss300cs50            50          300  6.464869
# 6  hdb  t2.3.2        1  ss350cs50            50          350  7.508262
# 7  hdb  t2.3.2        1  ss400cs50            50          400  7.595162
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
# 5  hdb  t2.3.2        1  ss300cs50            50          300  6.464869
# 6  hdb  t2.3.2        1  ss350cs50            50          350  7.508262
# 7  hdb  t2.3.2        1  ss400cs50            50          400  7.595162
# 8  hdb  t2.3.2        1  ss450cs50            50          450  8.139901
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#   type testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.2        1   ss50cs50            50           50  4.482611
# 1  hdb  t2.3.2        1  ss100cs50            50          100  4.256934
# 2  hdb  t2.3.2        1  ss150cs50            50          150  4.888586
# 3  hdb  t2.3.2        1  ss200cs50            50          200  5.307672
# 4  hdb  t2.3.2        1  ss250cs50            50          250  6.091980
# 5  hdb  t2.3.2        1  ss300cs50            50          300  6.464869
# 6  hdb  t2.3.2        1  ss350cs50            50          350  7.508262
# 7  hdb  t2.3.2        1  ss400cs50            50          400  7.595162
# 8  hdb  t2.3.2        1  ss450cs50            50          450  8.139901
# 9  hdb  t2.3.2        1  ss50cs100           100           50  3.931135
#
#                                                  tdf  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
# 16  hdb  t2.3.2        1  ss400cs100           100          400  7.595589
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 16  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 16  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
# 16  hdb  t2.3.2        1  ss400cs100           100          400  7.595589
# 17  hdb  t2.3.2        1  ss450cs100           100          450  8.149807
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 16  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 17  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 16  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 17  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
# 16  hdb  t2.3.2        1  ss400cs100           100          400  7.595589
# 17  hdb  t2.3.2        1  ss450cs100           100          450  8.149807
# 18  hdb  t2.3.2        1   ss50cs150           150           50  3.926576
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 16  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 17  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 18  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 16  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 17  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 18  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
# 16  hdb  t2.3.2        1  ss400cs100           100          400  7.595589
# 17  hdb  t2.3.2        1  ss450cs100           100          450  8.149807
# 18  hdb  t2.3.2        1   ss50cs150           150           50  3.926576
# 19  hdb  t2.3.2        1  ss100cs150           150          100  4.366264
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 16  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 17  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 18  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 19  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 16  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 17  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 18  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 19  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# 5   hdb  t2.3.2        1   ss300cs50            50          300  6.464869
# 6   hdb  t2.3.2        1   ss350cs50            50          350  7.508262
# 7   hdb  t2.3.2        1   ss400cs50            50          400  7.595162
# 8   hdb  t2.3.2        1   ss450cs50            50          450  8.139901
# 9   hdb  t2.3.2        1   ss50cs100           100           50  3.931135
# 10  hdb  t2.3.2        1  ss100cs100           100          100  4.347146
# 11  hdb  t2.3.2        1  ss150cs100           100          150  4.909422
# 12  hdb  t2.3.2        1  ss200cs100           100          200  5.242848
# 13  hdb  t2.3.2        1  ss250cs100           100          250  6.079516
# 14  hdb  t2.3.2        1  ss300cs100           100          300  6.465020
# 15  hdb  t2.3.2        1  ss350cs100           100          350  7.496139
# 16  hdb  t2.3.2        1  ss400cs100           100          400  7.595589
# 17  hdb  t2.3.2        1  ss450cs100           100          450  8.149807
# 18  hdb  t2.3.2        1   ss50cs150           150           50  3.926576
# 19  hdb  t2.3.2        1  ss100cs150           150          100  4.366264
# 20  hdb  t2.3.2        1  ss150cs150           150          150  5.262402
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 14  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 15  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 16  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 17  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 18  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 19  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 20  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 5   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 6   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 7   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 8   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 9   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 10  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 11  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 12  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 13  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 14  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 15  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 16  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 17  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 18  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 19  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 20  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# ...
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 70  hdb  t2.3.2        1  ss400cs400           400          400  7.509400
# 71  hdb  t2.3.2        1  ss450cs400           400          450  8.040851
# 72  hdb  t2.3.2        1   ss50cs450           450           50  3.893986
# 73  hdb  t2.3.2        1  ss100cs450           450          100  4.451092
# 74  hdb  t2.3.2        1  ss150cs450           450          150  5.199192
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 70  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 71  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 72  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 73  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 74  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 71  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 72  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 73  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 74  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [75 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 71  hdb  t2.3.2        1  ss450cs400           400          450  8.040851
# 72  hdb  t2.3.2        1   ss50cs450           450           50  3.893986
# 73  hdb  t2.3.2        1  ss100cs450           450          100  4.451092
# 74  hdb  t2.3.2        1  ss150cs450           450          150  5.199192
# 75  hdb  t2.3.2        1  ss200cs450           450          200  5.487762
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 71  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 72  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 73  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 74  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 75  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 72  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 73  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 74  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 75  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [76 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 72  hdb  t2.3.2        1   ss50cs450           450           50  3.893986
# 73  hdb  t2.3.2        1  ss100cs450           450          100  4.451092
# 74  hdb  t2.3.2        1  ss150cs450           450          150  5.199192
# 75  hdb  t2.3.2        1  ss200cs450           450          200  5.487762
# 76  hdb  t2.3.2        1  ss250cs450           450          250  6.293540
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 72  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 73  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 74  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 75  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 76  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 73  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 74  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 75  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 76  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [77 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 73  hdb  t2.3.2        1  ss100cs450           450          100  4.451092
# 74  hdb  t2.3.2        1  ss150cs450           450          150  5.199192
# 75  hdb  t2.3.2        1  ss200cs450           450          200  5.487762
# 76  hdb  t2.3.2        1  ss250cs450           450          250  6.293540
# 77  hdb  t2.3.2        1  ss300cs450           450          300  7.055748
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 73  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 74  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 75  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 76  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 77  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 74  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 75  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 76  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 77  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [78 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 74  hdb  t2.3.2        1  ss150cs450           450          150  5.199192
# 75  hdb  t2.3.2        1  ss200cs450           450          200  5.487762
# 76  hdb  t2.3.2        1  ss250cs450           450          250  6.293540
# 77  hdb  t2.3.2        1  ss300cs450           450          300  7.055748
# 78  hdb  t2.3.2        1  ss350cs450           450          350  7.366859
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 74  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 75  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 76  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 77  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 78  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 75  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 76  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 77  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 78  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [79 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 75  hdb  t2.3.2        1  ss200cs450           450          200  5.487762
# 76  hdb  t2.3.2        1  ss250cs450           450          250  6.293540
# 77  hdb  t2.3.2        1  ss300cs450           450          300  7.055748
# 78  hdb  t2.3.2        1  ss350cs450           450          350  7.366859
# 79  hdb  t2.3.2        1  ss400cs450           450          400  7.527156
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 75  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 76  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 77  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 78  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 79  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 76  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 77  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 78  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 79  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [80 rows x 9 columns]
#    type testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.2        1    ss50cs50            50           50  4.482611
# 1   hdb  t2.3.2        1   ss100cs50            50          100  4.256934
# 2   hdb  t2.3.2        1   ss150cs50            50          150  4.888586
# 3   hdb  t2.3.2        1   ss200cs50            50          200  5.307672
# 4   hdb  t2.3.2        1   ss250cs50            50          250  6.091980
# ..  ...     ...      ...         ...           ...          ...       ...
# 76  hdb  t2.3.2        1  ss250cs450           450          250  6.293540
# 77  hdb  t2.3.2        1  ss300cs450           450          300  7.055748
# 78  hdb  t2.3.2        1  ss350cs450           450          350  7.366859
# 79  hdb  t2.3.2        1  ss400cs450           450          400  7.527156
# 80  hdb  t2.3.2        1  ss450cs450           450          450  8.161706
#
#                                                   tdf  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...
# ..                                                ...
# 76  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 77  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 78  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 79  rt_vect: 0.9343035221099854, min_df: 4, max_df...
# 80  rt_vect: 0.9343035221099854, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 1   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 2   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 3   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 4   hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 77  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 78  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 79  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
# 80  hellinger, rt_umap_tf: 356.2356584072113, rt_u...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                       name  ss50cs50  ss100cs50  ss150cs50  \
# 0                 technopagan/mss-saliency        -1         -1         -1
# 1                       google/chaps-linux        -1         -1         -1
# 2                 lukasolson/speech-router        -1         -1         -1
# 3                    XavierTecBr/qbr-admin       384        267        209
# 4       HackBulgaria/Programming101-Python        64         32         21
# ...                                    ...       ...        ...        ...
# 188693               MarcoPon/BlockHashLoc       376        261        213
# 188694       bhagatabhijeet/bhagatabhijeet        -1         -1         -1
# 188695       LandGrey/SpringBootVulExploit       384        267        209
# 188696                 bigsen/Vision_Track       303        188        155
# 188697                  ivanol55/cka-notes       178        124         96
#
#         ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  ss450cs50  ...  \
# 0              -1         -1         -1         -1         -1         -1  ...
# 1             177        145        112         99         89         61  ...
# 2              -1         -1         -1         -1         -1         -1  ...
# 3             174         -1         -1         -1         90         61  ...
# 4              18         12          9          8         11          9  ...
# ...           ...        ...        ...        ...        ...        ...  ...
# 188693        177        145        112         99         89         61  ...
# 188694         -1         -1         -1         -1         -1         -1  ...
# 188695        174        150         -1         -1         -1         61  ...
# 188696        123         -1         -1         -1         -1         -1  ...
# 188697         78         55         -1         -1         -1         -1  ...
#
#         ss450cs400  ss50cs450  ss100cs450  ss150cs450  ss200cs450  ss250cs450  \
# 0               22         32          -1          -1          -1          -1
# 1               22         32          -1          61          63          52
# 2               22         32          -1          -1          -1          -1
# 3               22         32          69          61          61          52
# 4                6          8           8           6           7           5
# ...            ...        ...         ...         ...         ...         ...
# 188693          22         32          65          61          63          52
# 188694          22         32          -1          -1          -1          -1
# 188695          22         32          69          61          61          52
# 188696          22         32          45          48          -1          -1
# 188697          -1         32          -1          31          -1          -1
#
#         ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0               24          24          -1          21
# 1               24          24          32          21
# 2               24          24          -1          21
# 3               24          24          32          21
# 4                5           4           7           6
# ...            ...         ...         ...         ...
# 188693          24          24          32          21
# 188694          24          -1          -1          21
# 188695          24          24          32          21
# 188696          24          24          32          21
# 188697          24          24          -1          -1
#
# [188698 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_labels_results_t2.3.2.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
# 5  kmeans-umapt  t2.3.2        1    25    1160   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
# 5  kmeans-umapt  t2.3.2        1    25    1160   25
# 6  kmeans-umapt  t2.3.2        1    28    1160   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
# 5  kmeans-umapt  t2.3.2        1    25    1160   25
# 6  kmeans-umapt  t2.3.2        1    28    1160   28
# 7  kmeans-umapt  t2.3.2        1    31    1160   31
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
# 5  kmeans-umapt  t2.3.2        1    25    1160   25
# 6  kmeans-umapt  t2.3.2        1    28    1160   28
# 7  kmeans-umapt  t2.3.2        1    31    1160   31
# 8  kmeans-umapt  t2.3.2        1    34    1160   34
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#            type testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.2        1    10    1160   10
# 1  kmeans-umapt  t2.3.2        1    13    1160   13
# 2  kmeans-umapt  t2.3.2        1    16    1160   16
# 3  kmeans-umapt  t2.3.2        1    19    1160   19
# 4  kmeans-umapt  t2.3.2        1    22    1160   22
# 5  kmeans-umapt  t2.3.2        1    25    1160   25
# 6  kmeans-umapt  t2.3.2        1    28    1160   28
# 7  kmeans-umapt  t2.3.2        1    31    1160   31
# 8  kmeans-umapt  t2.3.2        1    34    1160   34
# 9  kmeans-umapt  t2.3.2        1    37    1160   37
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
# 9  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.480060
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 9  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#             type testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.2        1    10    1160   10
# 1   kmeans-umapt  t2.3.2        1    13    1160   13
# 2   kmeans-umapt  t2.3.2        1    16    1160   16
# 3   kmeans-umapt  t2.3.2        1    19    1160   19
# 4   kmeans-umapt  t2.3.2        1    22    1160   22
# 5   kmeans-umapt  t2.3.2        1    25    1160   25
# 6   kmeans-umapt  t2.3.2        1    28    1160   28
# 7   kmeans-umapt  t2.3.2        1    31    1160   31
# 8   kmeans-umapt  t2.3.2        1    34    1160   34
# 9   kmeans-umapt  t2.3.2        1    37    1160   37
# 10  kmeans-umapt  t2.3.2        1    40    1160   40
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.480060
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.776271
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 9   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 10  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#             type testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.2        1    10    1160   10
# 1   kmeans-umapt  t2.3.2        1    13    1160   13
# 2   kmeans-umapt  t2.3.2        1    16    1160   16
# 3   kmeans-umapt  t2.3.2        1    19    1160   19
# 4   kmeans-umapt  t2.3.2        1    22    1160   22
# 5   kmeans-umapt  t2.3.2        1    25    1160   25
# 6   kmeans-umapt  t2.3.2        1    28    1160   28
# 7   kmeans-umapt  t2.3.2        1    31    1160   31
# 8   kmeans-umapt  t2.3.2        1    34    1160   34
# 9   kmeans-umapt  t2.3.2        1    37    1160   37
# 10  kmeans-umapt  t2.3.2        1    40    1160   40
# 11  kmeans-umapt  t2.3.2        1    43    1160   43
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.480060
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.776271
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.390567
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 9   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 10  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 11  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#             type testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.2        1    10    1160   10
# 1   kmeans-umapt  t2.3.2        1    13    1160   13
# 2   kmeans-umapt  t2.3.2        1    16    1160   16
# 3   kmeans-umapt  t2.3.2        1    19    1160   19
# 4   kmeans-umapt  t2.3.2        1    22    1160   22
# 5   kmeans-umapt  t2.3.2        1    25    1160   25
# 6   kmeans-umapt  t2.3.2        1    28    1160   28
# 7   kmeans-umapt  t2.3.2        1    31    1160   31
# 8   kmeans-umapt  t2.3.2        1    34    1160   34
# 9   kmeans-umapt  t2.3.2        1    37    1160   37
# 10  kmeans-umapt  t2.3.2        1    40    1160   40
# 11  kmeans-umapt  t2.3.2        1    43    1160   43
# 12  kmeans-umapt  t2.3.2        1    46    1160   46
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.480060
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.776271
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.390567
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.066148
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 9   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 10  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 11  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 12  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
#             type testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.2        1    10    1160   10
# 1   kmeans-umapt  t2.3.2        1    13    1160   13
# 2   kmeans-umapt  t2.3.2        1    16    1160   16
# 3   kmeans-umapt  t2.3.2        1    19    1160   19
# 4   kmeans-umapt  t2.3.2        1    22    1160   22
# 5   kmeans-umapt  t2.3.2        1    25    1160   25
# 6   kmeans-umapt  t2.3.2        1    28    1160   28
# 7   kmeans-umapt  t2.3.2        1    31    1160   31
# 8   kmeans-umapt  t2.3.2        1    34    1160   34
# 9   kmeans-umapt  t2.3.2        1    37    1160   37
# 10  kmeans-umapt  t2.3.2        1    40    1160   40
# 11  kmeans-umapt  t2.3.2        1    43    1160   43
# 12  kmeans-umapt  t2.3.2        1    46    1160   46
# 13  kmeans-umapt  t2.3.2        1    49    1160   49
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.181871
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.279038
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.489902
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...  1.781694
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.172588
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.407152
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.714640
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.102909
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.523384
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.480060
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.776271
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.390567
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.066148
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.856234
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 1   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 2   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 3   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 4   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 5   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 6   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 7   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 8   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 9   (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 10  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 11  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 12  (hellinger, rt_umap_tf: 356.2356584072113, rt_...
# 13  (hellinger, rt_umap_tf: 356.2356584072113, rt_...

# %%
kmeans_labels_results
# Out:
#                                       name  10  13  16  19  22  25  28  31  \
# 0                 technopagan/mss-saliency   3   4  11  14   1  20   9  15
# 1                       google/chaps-linux   0   1   7   9  19  23  25  28
# 2                 lukasolson/speech-router   3   4  11   2   1  20   9  19
# 3                    XavierTecBr/qbr-admin   0   1   7   1  19  19  25  28
# 4       HackBulgaria/Programming101-Python   6   4  11   2  18   1  27   6
# ...                                    ...  ..  ..  ..  ..  ..  ..  ..  ..
# 188693               MarcoPon/BlockHashLoc   6   1   7   9  19  23  27  28
# 188694       bhagatabhijeet/bhagatabhijeet   7   4   4   2  20  17   1  12
# 188695       LandGrey/SpringBootVulExploit   0   1   7   1   6  19  21  28
# 188696                 bigsen/Vision_Track   3   5  12  14  13  20  20  19
# 188697                  ivanol55/cka-notes   7   0   4   5  20  17   1  21
#
#         34  37  40  43  46  49
# 0        0  21   1  26   4  36
# 1       10  14  26  28  45  28
# 2        0  21   1  26   4  36
# 3       31  14  37  28   0  22
# 4       32   0  22  19  38   8
# ...     ..  ..  ..  ..  ..  ..
# 188693  10  14  26  28  45  28
# 188694  20  13   9   5  16  35
# 188695  31  31  37  28   0  22
# 188696   1  25  12  23  14  36
# 188697  20  35   9  14  22  25
#
# [187538 rows x 15 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_labels_results_t2.3.2.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.649043
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
# 5  kmeans  t2.3.2        1    25   25
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.649043
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  6.328335
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
# 5  kmeans  t2.3.2        1    25   25
# 6  kmeans  t2.3.2        1    28   28
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.649043
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  6.328335
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  7.658424
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
# 5  kmeans  t2.3.2        1    25   25
# 6  kmeans  t2.3.2        1    28   28
# 7  kmeans  t2.3.2        1    31   31
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.649043
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  6.328335
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  7.658424
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...  9.791685
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
# 5  kmeans  t2.3.2        1    25   25
# 6  kmeans  t2.3.2        1    28   28
# 7  kmeans  t2.3.2        1    31   31
# 8  kmeans  t2.3.2        1    34   34
#
#                                                  tdf   runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...  2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...  3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...  4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...  5.649043
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...  6.328335
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...  7.658424
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...  9.791685
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...  9.406566
#      type testset  version  size name  \
# 0  kmeans  t2.3.2        1    10   10
# 1  kmeans  t2.3.2        1    13   13
# 2  kmeans  t2.3.2        1    16   16
# 3  kmeans  t2.3.2        1    19   19
# 4  kmeans  t2.3.2        1    22   22
# 5  kmeans  t2.3.2        1    25   25
# 6  kmeans  t2.3.2        1    28   28
# 7  kmeans  t2.3.2        1    31   31
# 8  kmeans  t2.3.2        1    34   34
# 9  kmeans  t2.3.2        1    37   37
#
#                                                  tdf    runtime
# 0  rt_vect: 0.9343035221099854, min_df: 4, max_df...   2.811559
# 1  rt_vect: 0.9343035221099854, min_df: 4, max_df...   3.598481
# 2  rt_vect: 0.9343035221099854, min_df: 4, max_df...   4.507963
# 3  rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.230899
# 4  rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.649043
# 5  rt_vect: 0.9343035221099854, min_df: 4, max_df...   6.328335
# 6  rt_vect: 0.9343035221099854, min_df: 4, max_df...   7.658424
# 7  rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.791685
# 8  rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.406566
# 9  rt_vect: 0.9343035221099854, min_df: 4, max_df...  11.882956
#       type testset  version  size name  \
# 0   kmeans  t2.3.2        1    10   10
# 1   kmeans  t2.3.2        1    13   13
# 2   kmeans  t2.3.2        1    16   16
# 3   kmeans  t2.3.2        1    19   19
# 4   kmeans  t2.3.2        1    22   22
# 5   kmeans  t2.3.2        1    25   25
# 6   kmeans  t2.3.2        1    28   28
# 7   kmeans  t2.3.2        1    31   31
# 8   kmeans  t2.3.2        1    34   34
# 9   kmeans  t2.3.2        1    37   37
# 10  kmeans  t2.3.2        1    40   40
#
#                                                   tdf    runtime
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...   2.811559
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...   3.598481
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...   4.507963
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.230899
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.649043
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...   6.328335
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...   7.658424
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.791685
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.406566
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  11.882956
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  10.947766
#       type testset  version  size name  \
# 0   kmeans  t2.3.2        1    10   10
# 1   kmeans  t2.3.2        1    13   13
# 2   kmeans  t2.3.2        1    16   16
# 3   kmeans  t2.3.2        1    19   19
# 4   kmeans  t2.3.2        1    22   22
# 5   kmeans  t2.3.2        1    25   25
# 6   kmeans  t2.3.2        1    28   28
# 7   kmeans  t2.3.2        1    31   31
# 8   kmeans  t2.3.2        1    34   34
# 9   kmeans  t2.3.2        1    37   37
# 10  kmeans  t2.3.2        1    40   40
# 11  kmeans  t2.3.2        1    43   43
#
#                                                   tdf    runtime
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...   2.811559
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...   3.598481
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...   4.507963
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.230899
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.649043
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...   6.328335
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...   7.658424
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.791685
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.406566
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  11.882956
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  10.947766
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  12.347434
#       type testset  version  size name  \
# 0   kmeans  t2.3.2        1    10   10
# 1   kmeans  t2.3.2        1    13   13
# 2   kmeans  t2.3.2        1    16   16
# 3   kmeans  t2.3.2        1    19   19
# 4   kmeans  t2.3.2        1    22   22
# 5   kmeans  t2.3.2        1    25   25
# 6   kmeans  t2.3.2        1    28   28
# 7   kmeans  t2.3.2        1    31   31
# 8   kmeans  t2.3.2        1    34   34
# 9   kmeans  t2.3.2        1    37   37
# 10  kmeans  t2.3.2        1    40   40
# 11  kmeans  t2.3.2        1    43   43
# 12  kmeans  t2.3.2        1    46   46
#
#                                                   tdf    runtime
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...   2.811559
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...   3.598481
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...   4.507963
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.230899
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.649043
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...   6.328335
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...   7.658424
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.791685
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.406566
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  11.882956
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  10.947766
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  12.347434
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...  13.531772
#       type testset  version  size name  \
# 0   kmeans  t2.3.2        1    10   10
# 1   kmeans  t2.3.2        1    13   13
# 2   kmeans  t2.3.2        1    16   16
# 3   kmeans  t2.3.2        1    19   19
# 4   kmeans  t2.3.2        1    22   22
# 5   kmeans  t2.3.2        1    25   25
# 6   kmeans  t2.3.2        1    28   28
# 7   kmeans  t2.3.2        1    31   31
# 8   kmeans  t2.3.2        1    34   34
# 9   kmeans  t2.3.2        1    37   37
# 10  kmeans  t2.3.2        1    40   40
# 11  kmeans  t2.3.2        1    43   43
# 12  kmeans  t2.3.2        1    46   46
# 13  kmeans  t2.3.2        1    49   49
#
#                                                   tdf    runtime
# 0   rt_vect: 0.9343035221099854, min_df: 4, max_df...   2.811559
# 1   rt_vect: 0.9343035221099854, min_df: 4, max_df...   3.598481
# 2   rt_vect: 0.9343035221099854, min_df: 4, max_df...   4.507963
# 3   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.230899
# 4   rt_vect: 0.9343035221099854, min_df: 4, max_df...   5.649043
# 5   rt_vect: 0.9343035221099854, min_df: 4, max_df...   6.328335
# 6   rt_vect: 0.9343035221099854, min_df: 4, max_df...   7.658424
# 7   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.791685
# 8   rt_vect: 0.9343035221099854, min_df: 4, max_df...   9.406566
# 9   rt_vect: 0.9343035221099854, min_df: 4, max_df...  11.882956
# 10  rt_vect: 0.9343035221099854, min_df: 4, max_df...  10.947766
# 11  rt_vect: 0.9343035221099854, min_df: 4, max_df...  12.347434
# 12  rt_vect: 0.9343035221099854, min_df: 4, max_df...  13.531772
# 13  rt_vect: 0.9343035221099854, min_df: 4, max_df...  13.662512

# %%
kmeans_labels_results
# Out:
#                                       name  10  13  16  19  22  25  28  31  \
# 0                 technopagan/mss-saliency   0   2   3  12   0   5   5   5
# 1                       google/chaps-linux   0   2   3  12   0   5   5   5
# 2                 lukasolson/speech-router   0   2   7  17   0   6   6   6
# 3                    XavierTecBr/qbr-admin   0   2   7  17   0   6   6   6
# 4       HackBulgaria/Programming101-Python   0   2   7   8   3  12  12  12
# ...                                    ...  ..  ..  ..  ..  ..  ..  ..  ..
# 188693               MarcoPon/BlockHashLoc   0   2   5  17   0   2   2   2
# 188694       bhagatabhijeet/bhagatabhijeet   0   2   2  13   4   6   6   6
# 188695       LandGrey/SpringBootVulExploit   0   2   7  17   0   6   6   6
# 188696                 bigsen/Vision_Track   0   2   7  17   0   6   6   4
# 188697                  ivanol55/cka-notes   0   2  13   6   0   6   6   6
#
#         34  37  40  43  46  49
# 0        7  34  11  24  25   7
# 1       32  34  11  24  25   3
# 2       10   5   7   1  21  18
# 3       10  19  21  11   0  18
# 4       10  35   1  30  22  17
# ...     ..  ..  ..  ..  ..  ..
# 188693  10   5   6  40   1  29
# 188694   8   9  36  10   0  25
# 188695  10   5   7   1   0   6
# 188696  21  30   7  34  14  40
# 188697   8   9   7  10   0  25
#
# [188698 rows x 15 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_labels_results_t2.3.2.pkl
