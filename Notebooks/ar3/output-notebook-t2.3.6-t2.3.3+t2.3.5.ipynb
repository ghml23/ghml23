# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar3/"
use_tfidfvectorizer = True
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 50
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.3.6"
merge_list = ["t2.3.3", "t2.3.5"]

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.6.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 28395

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)
# Out:
# t2.3.6+2.3.3+2.3.5

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.3.pkl
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.5.pkl

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 28395

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 28395
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 0.22918415069580078

# %%
word_doc_matrix
# Out:
# <28395x4247 sparse matrix of type '<class 'numpy.float64'>'
# 	with 385877 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 307 edges.
# It has only fully disconnected 5 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 4min 44s, sys: 8.51 s, total: 4min 53s
# Wall time: 1min 37s

# %%
print(runtime_umap)
# Out:
# 97.7764105796814

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 1min 7s, sys: 64.8 ms, total: 1min 7s
# Wall time: 58.7 s

# %%
print(runtime_umap_transform)
# Out:
# 58.670198917388916

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_embedding_t2.3.6+2.3.3+2.3.5.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_clusterable_embedding_t2.3.6+2.3.3+2.3.5.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type             testset  version      name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1  ss50cs50            50           50
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
# 5  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs50            50          300
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5  0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
# 5  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs50            50          300
# 6  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs50            50          350
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5  0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6  0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
# 5  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs50            50          300
# 6  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs50            50          350
# 7  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs50            50          400
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5  0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6  0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7  0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
# 5  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs50            50          300
# 6  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs50            50          350
# 7  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs50            50          400
# 8  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs50            50          450
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5  0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6  0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7  0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8  1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#   type             testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs50            50           50
# 1  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs50            50          100
# 2  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs50            50          150
# 3  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs50            50          200
# 4  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs50            50          250
# 5  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs50            50          300
# 6  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs50            50          350
# 7  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs50            50          400
# 8  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs50            50          450
# 9  hdb  t2.3.6+2.3.3+2.3.5        1  ss50cs100           100           50
#
#     runtime                                                tdf  \
# 0  1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1  0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2  0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3  0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4  0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5  0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6  0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7  0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8  1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9  0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 15  0.914963  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 15  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
# 16  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs100           100          400
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 15  0.914963  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 16  0.986275  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 15  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 16  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
# 16  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs100           100          400
# 17  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs100           100          450
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 15  0.914963  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 16  0.986275  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 17  1.022405  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 15  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 16  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 17  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
# 16  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs100           100          400
# 17  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs100           100          450
# 18  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs150           150           50
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 15  0.914963  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 16  0.986275  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 17  1.022405  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 18  0.438155  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 15  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 16  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 17  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 18  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
# 16  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs100           100          400
# 17  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs100           100          450
# 18  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs150           150           50
# 19  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs150           150          100
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 5   0.813697  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 6   0.916038  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 7   0.966668  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 8   1.072827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 9   0.437428  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 10  0.499232  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 11  0.560752  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 12  0.630824  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 13  0.687461  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 14  0.784385  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 15  0.914963  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 16  0.986275  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 17  1.022405  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 18  0.438155  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 19  0.525406  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 5   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 6   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 7   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 8   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 9   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 10  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 11  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 12  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 13  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 14  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 15  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 16  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 17  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 18  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 19  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# 5   hdb  t2.3.6+2.3.3+2.3.5        1   ss300cs50            50          300
# 6   hdb  t2.3.6+2.3.3+2.3.5        1   ss350cs50            50          350
# 7   hdb  t2.3.6+2.3.3+2.3.5        1   ss400cs50            50          400
# 8   hdb  t2.3.6+2.3.3+2.3.5        1   ss450cs50            50          450
# 9   hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs100           100           50
# 10  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs100           100          100
# 11  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs100           100          150
# 12  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs100           100          200
# 13  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs100           100          250
# 14  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs100           100          300
# 15  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs100           100          350
# 16  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs100           100          400
# 17  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs100           100          450
# 18  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs150           150           50
# 19  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs150           150          100
# 20  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs150           150          150
#
# ...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 70  0.902226  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 71  0.998131  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 72  0.452284  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 73  0.514827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 74  0.586167  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 71  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 72  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 73  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 74  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [75 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 71  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs400           400          450
# 72  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs450           450           50
# 73  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs450           450          100
# 74  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs450           450          150
# 75  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs450           450          200
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 71  0.998131  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 72  0.452284  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 73  0.514827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 74  0.586167  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 75  0.658317  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 72  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 73  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 74  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 75  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [76 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 72  hdb  t2.3.6+2.3.3+2.3.5        1   ss50cs450           450           50
# 73  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs450           450          100
# 74  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs450           450          150
# 75  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs450           450          200
# 76  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs450           450          250
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 72  0.452284  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 73  0.514827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 74  0.586167  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 75  0.658317  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 76  0.690061  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 73  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 74  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 75  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 76  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [77 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 73  hdb  t2.3.6+2.3.3+2.3.5        1  ss100cs450           450          100
# 74  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs450           450          150
# 75  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs450           450          200
# 76  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs450           450          250
# 77  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs450           450          300
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 73  0.514827  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 74  0.586167  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 75  0.658317  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 76  0.690061  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 77  0.763637  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 74  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 75  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 76  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 77  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [78 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 74  hdb  t2.3.6+2.3.3+2.3.5        1  ss150cs450           450          150
# 75  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs450           450          200
# 76  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs450           450          250
# 77  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs450           450          300
# 78  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs450           450          350
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 74  0.586167  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 75  0.658317  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 76  0.690061  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 77  0.763637  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 78  0.870402  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 75  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 76  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 77  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 78  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [79 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 75  hdb  t2.3.6+2.3.3+2.3.5        1  ss200cs450           450          200
# 76  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs450           450          250
# 77  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs450           450          300
# 78  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs450           450          350
# 79  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs450           450          400
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 75  0.658317  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 76  0.690061  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 77  0.763637  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 78  0.870402  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 79  0.910294  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 76  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 77  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 78  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 79  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [80 rows x 9 columns]
#    type             testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.3.6+2.3.3+2.3.5        1    ss50cs50            50           50
# 1   hdb  t2.3.6+2.3.3+2.3.5        1   ss100cs50            50          100
# 2   hdb  t2.3.6+2.3.3+2.3.5        1   ss150cs50            50          150
# 3   hdb  t2.3.6+2.3.3+2.3.5        1   ss200cs50            50          200
# 4   hdb  t2.3.6+2.3.3+2.3.5        1   ss250cs50            50          250
# ..  ...                 ...      ...         ...           ...          ...
# 76  hdb  t2.3.6+2.3.3+2.3.5        1  ss250cs450           450          250
# 77  hdb  t2.3.6+2.3.3+2.3.5        1  ss300cs450           450          300
# 78  hdb  t2.3.6+2.3.3+2.3.5        1  ss350cs450           450          350
# 79  hdb  t2.3.6+2.3.3+2.3.5        1  ss400cs450           450          400
# 80  hdb  t2.3.6+2.3.3+2.3.5        1  ss450cs450           450          450
#
#      runtime                                                tdf  \
# 0   1.073524  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 1   0.502680  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 2   0.567822  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 3   0.688992  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 4   0.763339  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# ..       ...                                                ...
# 76  0.690061  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 77  0.763637  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 78  0.870402  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 79  0.910294  rt_vect: 0.22918415069580078, min_df: 4, max_d...
# 80  0.987735  rt_vect: 0.22918415069580078, min_df: 4, max_d...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 1   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 2   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 3   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 4   hellinger, rt_umap_tf: 58.670198917388916, rt_...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 77  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 78  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 79  hellinger, rt_umap_tf: 58.670198917388916, rt_...
# 80  hellinger, rt_umap_tf: 58.670198917388916, rt_...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                                     name  ss50cs50  ss100cs50  \
# 0                                     google/chaps-linux        74         37
# 1                                     droidefense/engine        -1         15
# 2                                           wdgdc/Jarvis        -1         -1
# 3       PaloAltoNetworks/google-cloud-hub-spoke-tutorial        41         -1
# 4                                     liwenhe1993/charts        -1         -1
# ...                                                  ...       ...        ...
# 28390            sakhnyuk/javascript-interview-questions        -1         -1
# 28391                    mohammaduzair9/Face-Recognition        89         45
# 28392                      deepinx/age-gender-estimation        -1         -1
# 28393  aws-cloudformation/aws-cloudformation-resource...        67         15
# 28394          microsoft/security-devops-actions-toolkit        51         33
#
#        ss150cs50  ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  \
# 0             22         20          6          6          5          5
# 1             12         11          6          6          5          5
# 2              7          5          4          4          3          3
# 3             -1         -1          6          6          5          5
# 4             35         26          6          6          5          5
# ...          ...        ...        ...        ...        ...        ...
# 28390         -1         -1         -1         -1         -1         -1
# 28391         26         18          6          6          5          5
# 28392         -1         -1          6          6          5          5
# 28393         12         11          6          6          5          5
# 28394         14         14          6          6          5          5
#
#        ss450cs50  ...  ss450cs400  ss50cs450  ss100cs450  ss150cs450  \
# 0              5  ...           5          4           5           2
# 1              5  ...           5          4           5           2
# 2              3  ...           3          2           2           2
# 3              5  ...           5          4          -1           2
# 4              5  ...           5          4           5           2
# ...          ...  ...         ...        ...         ...         ...
# 28390         -1  ...          -1         -1          -1           2
# 28391          5  ...           5          4           5           2
# 28392          5  ...           5          4           5           2
# 28393          5  ...           5          4           5           2
# 28394          5  ...           5          4           5           2
#
#        ss200cs450  ss250cs450  ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0               5           5           5           5           5           5
# 1               5           5           5           5           5           5
# 2               3           3           3           3           3           3
# 3               5           5           5           5           5           5
# 4               5           5           5           5           5           5
# ...           ...         ...         ...         ...         ...         ...
# 28390           2          -1          -1          -1          -1          -1
# 28391           5           5           5           5           5           5
# 28392           5           5           5           5           5           5
# 28393           5           5           5           5           5           5
# 28394           5           5           5           5           5           5
#
# [28395 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_labels_results_t2.3.6+2.3.3+2.3.5.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
#
#                                                  tdf  runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...   0.2714
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#            type             testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
# 9  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    37       5   37
#
#                                                  tdf   runtime  \
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
# 9  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.557126
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 9  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#             type             testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
# 9   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    37       5   37
# 10  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    40       5   40
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.557126
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.602245
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 9   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 10  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#             type             testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
# 9   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    37       5   37
# 10  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    40       5   40
# 11  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    43       5   43
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.557126
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.602245
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.609335
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 9   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 10  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 11  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#             type             testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
# 9   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    37       5   37
# 10  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    40       5   40
# 11  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    43       5   43
# 12  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    46       5   46
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.557126
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.602245
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.609335
# 12  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.719571
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 9   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 10  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 11  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 12  (hellinger, rt_umap_tf: 58.670198917388916, rt...
#             type             testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    10       5   10
# 1   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    13       5   13
# 2   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    16       5   16
# 3   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    19       5   19
# 4   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    22       5   22
# 5   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    25       5   25
# 6   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    28       5   28
# 7   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    31       5   31
# 8   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    34       5   34
# 9   kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    37       5   37
# 10  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    40       5   40
# 11  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    43       5   43
# 12  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    46       5   46
# 13  kmeans-umapt  t2.3.6+2.3.3+2.3.5        1    49       5   49
#
#                                                   tdf   runtime  \
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.271400
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.209875
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.247399
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.376683
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.345729
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.412730
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.448476
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.497677
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.520454
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.557126
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.602245
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.609335
# 12  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.719571
# 13  rt_vect: 0.22918415069580078, min_df: 4, max_d...  0.706153
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 1   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 2   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 3   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 4   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 5   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 6   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 7   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 8   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 9   (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 10  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 11  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 12  (hellinger, rt_umap_tf: 58.670198917388916, rt...
# 13  (hellinger, rt_umap_tf: 58.670198917388916, rt...

# %%
kmeans_labels_results
# Out:
#                                                     name  10  13  16  19  22  \
# 0                                     google/chaps-linux   1   2   4   0  12
# 1                                     droidefense/engine   1   0   1  17  10
# 2                                           wdgdc/Jarvis   6   1   3   1  17
# 3       PaloAltoNetworks/google-cloud-hub-spoke-tutorial   1  12   4   0  12
# 4                                     liwenhe1993/charts   1   0   4   0  12
# ...                                                  ...  ..  ..  ..  ..  ..
# 28390            sakhnyuk/javascript-interview-questions   2   8   6  16   5
# 28391                    mohammaduzair9/Face-Recognition   4  11   8  13   6
# 28392                      deepinx/age-gender-estimation   0   2   5   8   6
# 28393  aws-cloudformation/aws-cloudformation-resource...   1   0   1  17  10
# 28394          microsoft/security-devops-actions-toolkit   6   7   3  10  19
#
#        25  28  31  34  37  40  43  46  49
# 0      14  19  13  11   8  14   6  42  12
# 1      11  18  25  26   0   0  41  37  26
# 2      23  14  18  13  11   3  11  18   7
# 3       5  11  14  24  25   8  21  22  22
# 4      17   5   6  11  33  32   1  16  13
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..
# 28390   4   6  27   6   1  11  17  15  43
# 28391  20  25  15  15   5  35  31   2   1
# 28392  20  25  15  15   5   1  12  38  38
# 28393  11  18  25  26   0   0  41  37  26
# 28394   8  27   2  10   4  25  13  14  40
#
# [28390 rows x 15 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_labels_results_t2.3.6+2.3.3+2.3.5.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5  kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5  kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6  kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5  kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6  kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7  kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5  kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6  kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7  kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8  kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
#      type             testset  version  size name  \
# 0  kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1  kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2  kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3  kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4  kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5  kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6  kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7  kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8  kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
# 9  kmeans  t2.3.6+2.3.3+2.3.5        1    37   37
#
#                                                  tdf   runtime
# 0  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3  rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5  rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8  rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
# 9  rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.188998
#       type             testset  version  size name  \
# 0   kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1   kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2   kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3   kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4   kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5   kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6   kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7   kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8   kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
# 9   kmeans  t2.3.6+2.3.3+2.3.5        1    37   37
# 10  kmeans  t2.3.6+2.3.3+2.3.5        1    40   40
#
#                                                   tdf   runtime
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.188998
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.678940
#       type             testset  version  size name  \
# 0   kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1   kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2   kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3   kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4   kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5   kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6   kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7   kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8   kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
# 9   kmeans  t2.3.6+2.3.3+2.3.5        1    37   37
# 10  kmeans  t2.3.6+2.3.3+2.3.5        1    40   40
# 11  kmeans  t2.3.6+2.3.3+2.3.5        1    43   43
#
#                                                   tdf   runtime
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.188998
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.678940
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  5.206023
#       type             testset  version  size name  \
# 0   kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1   kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2   kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3   kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4   kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5   kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6   kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7   kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8   kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
# 9   kmeans  t2.3.6+2.3.3+2.3.5        1    37   37
# 10  kmeans  t2.3.6+2.3.3+2.3.5        1    40   40
# 11  kmeans  t2.3.6+2.3.3+2.3.5        1    43   43
# 12  kmeans  t2.3.6+2.3.3+2.3.5        1    46   46
#
#                                                   tdf   runtime
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.188998
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.678940
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  5.206023
# 12  rt_vect: 0.22918415069580078, min_df: 4, max_d...  5.449605
#       type             testset  version  size name  \
# 0   kmeans  t2.3.6+2.3.3+2.3.5        1    10   10
# 1   kmeans  t2.3.6+2.3.3+2.3.5        1    13   13
# 2   kmeans  t2.3.6+2.3.3+2.3.5        1    16   16
# 3   kmeans  t2.3.6+2.3.3+2.3.5        1    19   19
# 4   kmeans  t2.3.6+2.3.3+2.3.5        1    22   22
# 5   kmeans  t2.3.6+2.3.3+2.3.5        1    25   25
# 6   kmeans  t2.3.6+2.3.3+2.3.5        1    28   28
# 7   kmeans  t2.3.6+2.3.3+2.3.5        1    31   31
# 8   kmeans  t2.3.6+2.3.3+2.3.5        1    34   34
# 9   kmeans  t2.3.6+2.3.3+2.3.5        1    37   37
# 10  kmeans  t2.3.6+2.3.3+2.3.5        1    40   40
# 11  kmeans  t2.3.6+2.3.3+2.3.5        1    43   43
# 12  kmeans  t2.3.6+2.3.3+2.3.5        1    46   46
# 13  kmeans  t2.3.6+2.3.3+2.3.5        1    49   49
#
#                                                   tdf   runtime
# 0   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.437257
# 1   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.670915
# 2   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.729734
# 3   rt_vect: 0.22918415069580078, min_df: 4, max_d...  1.995792
# 4   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.332657
# 5   rt_vect: 0.22918415069580078, min_df: 4, max_d...  2.756663
# 6   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.043608
# 7   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.811321
# 8   rt_vect: 0.22918415069580078, min_df: 4, max_d...  3.926773
# 9   rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.188998
# 10  rt_vect: 0.22918415069580078, min_df: 4, max_d...  4.678940
# 11  rt_vect: 0.22918415069580078, min_df: 4, max_d...  5.206023
# 12  rt_vect: 0.22918415069580078, min_df: 4, max_d...  5.449605
# 13  rt_vect: 0.22918415069580078, min_df: 4, max_d...  6.114364

# %%
kmeans_labels_results
# Out:
#                                                     name  10  13  16  19  22  \
# 0                                     google/chaps-linux   9   2   3  14   5
# 1                                     droidefense/engine   2  11  10  17  15
# 2                                           wdgdc/Jarvis   4   0  11  11   4
# 3       PaloAltoNetworks/google-cloud-hub-spoke-tutorial   0   2   3   0   8
# 4                                     liwenhe1993/charts   0   2   3  14   5
# ...                                                  ...  ..  ..  ..  ..  ..
# 28390            sakhnyuk/javascript-interview-questions   0   2   3   5   8
# 28391                    mohammaduzair9/Face-Recognition   0   9   1  14  16
# 28392                      deepinx/age-gender-estimation   9   2  13  15   1
# 28393  aws-cloudformation/aws-cloudformation-resource...   2  11  12  11  15
# 28394          microsoft/security-devops-actions-toolkit   4   5   6  10  10
#
#        25  28  31  34  37  40  43  46  49
# 0       5  18  25  14  16   5  16   9   4
# 1       3  24   5  12   7  28  26  26  42
# 2      21  16  23   2  33  34  21  44   0
# 3       2  18   4  31  31  16  22  22  32
# 4       2  18  25  14  30   5  28  28  12
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ..
# 28390   2  18   4  33  32  16  22  22  45
# 28391   5  15  11  14  16  27  10  16  12
# 28392  19  10  10  23  12  30  15  15  36
# 28393   3  24   5  12   7  28  26  26  24
# 28394  12  26  29   5  17   2  31  31  34
#
# [28395 rows x 15 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_labels_results_t2.3.6+2.3.3+2.3.5.pkl
