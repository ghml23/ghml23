# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar3/"
use_tfidfvectorizer = True
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 50
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.4.1s"
merge_list = ["t2.4.4"]

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.1s.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 217922

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)
# Out:
# t2.4.1s+2.4.4

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.4.pkl

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 217922

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 217922
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 3.501038074493408

# %%
word_doc_matrix
# Out:
# <217922x740 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6542580 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 585 edges.
# It has only fully disconnected 11 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 41min 24s, sys: 1min 45s, total: 43min 10s
# Wall time: 9min 19s

# %%
print(runtime_umap)
# Out:
# 559.3678381443024

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 24min 31s, sys: 4.1 s, total: 24min 35s
# Wall time: 22min 48s

# %%
print(runtime_umap_transform)
# Out:
# 1368.1599354743958

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_embedding_t2.4.1s+2.4.4.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//umap_clusterable_embedding_t2.4.1s+2.4.4.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type        testset  version      name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.4.1s+2.4.4        1  ss50cs50            50           50  5.108918
#
#                                                  tdf  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
# 5  hdb  t2.4.1s+2.4.4        1  ss300cs50            50          300
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5  8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
# 5  hdb  t2.4.1s+2.4.4        1  ss300cs50            50          300
# 6  hdb  t2.4.1s+2.4.4        1  ss350cs50            50          350
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5  8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6  7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
# 5  hdb  t2.4.1s+2.4.4        1  ss300cs50            50          300
# 6  hdb  t2.4.1s+2.4.4        1  ss350cs50            50          350
# 7  hdb  t2.4.1s+2.4.4        1  ss400cs50            50          400
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5  8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6  7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7  8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
# 5  hdb  t2.4.1s+2.4.4        1  ss300cs50            50          300
# 6  hdb  t2.4.1s+2.4.4        1  ss350cs50            50          350
# 7  hdb  t2.4.1s+2.4.4        1  ss400cs50            50          400
# 8  hdb  t2.4.1s+2.4.4        1  ss450cs50            50          450
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5  8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6  7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7  8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8  8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#   type        testset  version       name  hdb_minclust  hdb_minsamp  \
# 0  hdb  t2.4.1s+2.4.4        1   ss50cs50            50           50
# 1  hdb  t2.4.1s+2.4.4        1  ss100cs50            50          100
# 2  hdb  t2.4.1s+2.4.4        1  ss150cs50            50          150
# 3  hdb  t2.4.1s+2.4.4        1  ss200cs50            50          200
# 4  hdb  t2.4.1s+2.4.4        1  ss250cs50            50          250
# 5  hdb  t2.4.1s+2.4.4        1  ss300cs50            50          300
# 6  hdb  t2.4.1s+2.4.4        1  ss350cs50            50          350
# 7  hdb  t2.4.1s+2.4.4        1  ss400cs50            50          400
# 8  hdb  t2.4.1s+2.4.4        1  ss450cs50            50          450
# 9  hdb  t2.4.1s+2.4.4        1  ss50cs100           100           50
#
#     runtime                                                tdf  \
# 0  5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1  5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2  5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3  6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4  7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5  8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6  7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7  8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8  8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9  3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 15  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
# 16  hdb  t2.4.1s+2.4.4        1  ss400cs100           100          400
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 16  9.627556  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 15  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 16  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
# 16  hdb  t2.4.1s+2.4.4        1  ss400cs100           100          400
# 17  hdb  t2.4.1s+2.4.4        1  ss450cs100           100          450
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 16  9.627556  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 17  9.823869  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 15  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 16  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 17  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
# 16  hdb  t2.4.1s+2.4.4        1  ss400cs100           100          400
# 17  hdb  t2.4.1s+2.4.4        1  ss450cs100           100          450
# 18  hdb  t2.4.1s+2.4.4        1   ss50cs150           150           50
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 16  9.627556  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 17  9.823869  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 18  4.648304  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 15  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 16  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 17  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 18  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
# 16  hdb  t2.4.1s+2.4.4        1  ss400cs100           100          400
# 17  hdb  t2.4.1s+2.4.4        1  ss450cs100           100          450
# 18  hdb  t2.4.1s+2.4.4        1   ss50cs150           150           50
# 19  hdb  t2.4.1s+2.4.4        1  ss100cs150           150          100
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 16  9.627556  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 17  9.823869  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 18  4.648304  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 19  5.017250  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 5   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 6   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 7   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 8   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 9   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 10  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 11  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 12  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 13  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 14  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 15  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 16  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 17  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 18  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 19  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# 5   hdb  t2.4.1s+2.4.4        1   ss300cs50            50          300
# 6   hdb  t2.4.1s+2.4.4        1   ss350cs50            50          350
# 7   hdb  t2.4.1s+2.4.4        1   ss400cs50            50          400
# 8   hdb  t2.4.1s+2.4.4        1   ss450cs50            50          450
# 9   hdb  t2.4.1s+2.4.4        1   ss50cs100           100           50
# 10  hdb  t2.4.1s+2.4.4        1  ss100cs100           100          100
# 11  hdb  t2.4.1s+2.4.4        1  ss150cs100           100          150
# 12  hdb  t2.4.1s+2.4.4        1  ss200cs100           100          200
# 13  hdb  t2.4.1s+2.4.4        1  ss250cs100           100          250
# 14  hdb  t2.4.1s+2.4.4        1  ss300cs100           100          300
# 15  hdb  t2.4.1s+2.4.4        1  ss350cs100           100          350
# 16  hdb  t2.4.1s+2.4.4        1  ss400cs100           100          400
# 17  hdb  t2.4.1s+2.4.4        1  ss450cs100           100          450
# 18  hdb  t2.4.1s+2.4.4        1   ss50cs150           150           50
# 19  hdb  t2.4.1s+2.4.4        1  ss100cs150           150          100
# 20  hdb  t2.4.1s+2.4.4        1  ss150cs150           150          150
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 5   8.009167  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 6   7.979689  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 7   8.236012  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 8   8.280631  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 9   3.873971  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 10  4.438322  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 11  4.879865  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 12  6.021678  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 13  7.093708  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 14  7.989717  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 15  8.637263  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 16  9.627556  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 17  9.823869  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ...
# 73  hdb  t2.4.1s+2.4.4        1  ss100cs450           450          100
# 74  hdb  t2.4.1s+2.4.4        1  ss150cs450           450          150
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 70  8.831098  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 71  8.484683  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 72  3.730912  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 73  4.463344  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 74  5.778081  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 71  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 72  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 73  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 74  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [75 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 71  hdb  t2.4.1s+2.4.4        1  ss450cs400           400          450
# 72  hdb  t2.4.1s+2.4.4        1   ss50cs450           450           50
# 73  hdb  t2.4.1s+2.4.4        1  ss100cs450           450          100
# 74  hdb  t2.4.1s+2.4.4        1  ss150cs450           450          150
# 75  hdb  t2.4.1s+2.4.4        1  ss200cs450           450          200
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 71  8.484683  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 72  3.730912  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 73  4.463344  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 74  5.778081  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 75  5.549249  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 72  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 73  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 74  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 75  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [76 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 72  hdb  t2.4.1s+2.4.4        1   ss50cs450           450           50
# 73  hdb  t2.4.1s+2.4.4        1  ss100cs450           450          100
# 74  hdb  t2.4.1s+2.4.4        1  ss150cs450           450          150
# 75  hdb  t2.4.1s+2.4.4        1  ss200cs450           450          200
# 76  hdb  t2.4.1s+2.4.4        1  ss250cs450           450          250
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 72  3.730912  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 73  4.463344  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 74  5.778081  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 75  5.549249  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 76  6.076916  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 73  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 74  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 75  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 76  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [77 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 73  hdb  t2.4.1s+2.4.4        1  ss100cs450           450          100
# 74  hdb  t2.4.1s+2.4.4        1  ss150cs450           450          150
# 75  hdb  t2.4.1s+2.4.4        1  ss200cs450           450          200
# 76  hdb  t2.4.1s+2.4.4        1  ss250cs450           450          250
# 77  hdb  t2.4.1s+2.4.4        1  ss300cs450           450          300
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 73  4.463344  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 74  5.778081  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 75  5.549249  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 76  6.076916  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 77  6.774937  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 74  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 75  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 76  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 77  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [78 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 74  hdb  t2.4.1s+2.4.4        1  ss150cs450           450          150
# 75  hdb  t2.4.1s+2.4.4        1  ss200cs450           450          200
# 76  hdb  t2.4.1s+2.4.4        1  ss250cs450           450          250
# 77  hdb  t2.4.1s+2.4.4        1  ss300cs450           450          300
# 78  hdb  t2.4.1s+2.4.4        1  ss350cs450           450          350
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 74  5.778081  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 75  5.549249  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 76  6.076916  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 77  6.774937  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 78  7.499976  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 75  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 76  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 77  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 78  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [79 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 75  hdb  t2.4.1s+2.4.4        1  ss200cs450           450          200
# 76  hdb  t2.4.1s+2.4.4        1  ss250cs450           450          250
# 77  hdb  t2.4.1s+2.4.4        1  ss300cs450           450          300
# 78  hdb  t2.4.1s+2.4.4        1  ss350cs450           450          350
# 79  hdb  t2.4.1s+2.4.4        1  ss400cs450           450          400
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 75  5.549249  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 76  6.076916  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 77  6.774937  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 78  7.499976  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 79  8.299739  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 76  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 77  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 78  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 79  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [80 rows x 9 columns]
#    type        testset  version        name  hdb_minclust  hdb_minsamp  \
# 0   hdb  t2.4.1s+2.4.4        1    ss50cs50            50           50
# 1   hdb  t2.4.1s+2.4.4        1   ss100cs50            50          100
# 2   hdb  t2.4.1s+2.4.4        1   ss150cs50            50          150
# 3   hdb  t2.4.1s+2.4.4        1   ss200cs50            50          200
# 4   hdb  t2.4.1s+2.4.4        1   ss250cs50            50          250
# ..  ...            ...      ...         ...           ...          ...
# 76  hdb  t2.4.1s+2.4.4        1  ss250cs450           450          250
# 77  hdb  t2.4.1s+2.4.4        1  ss300cs450           450          300
# 78  hdb  t2.4.1s+2.4.4        1  ss350cs450           450          350
# 79  hdb  t2.4.1s+2.4.4        1  ss400cs450           450          400
# 80  hdb  t2.4.1s+2.4.4        1  ss450cs450           450          450
#
#      runtime                                                tdf  \
# 0   5.108918  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 1   5.425550  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 2   5.733057  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 3   6.574479  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 4   7.132554  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# ..       ...                                                ...
# 76  6.076916  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 77  6.774937  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 78  7.499976  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 79  8.299739  rt_vect: 3.501038074493408, min_df: 4, max_df:...
# 80  8.727339  rt_vect: 3.501038074493408, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 1   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 2   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 3   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 4   hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 77  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 78  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 79  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
# 80  hellinger, rt_umap_tf: 1368.1599354743958, rt_...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                  name  ss50cs50  ss100cs50  ss150cs50  \
# 0            technopagan/mss-saliency        -1          8         43
# 1          snmnmin12/selective-search        -1          8         43
# 2                  google/chaps-linux        -1         -1         -1
# 3            lukasolson/speech-router       139         -1         36
# 4               XavierTecBr/qbr-admin        -1         -1         -1
# ...                               ...       ...        ...        ...
# 217917  bhagatabhijeet/bhagatabhijeet        -1         -1         -1
# 217918  LandGrey/SpringBootVulExploit       165         -1         -1
# 217919    mucomplex/Pentest_checklist       156         73         44
# 217920            bigsen/Vision_Track        -1          8         -1
# 217921             ivanol55/cka-notes       208        111         66
#
#         ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  ss450cs50  ...  \
# 0               5          9          4          6          4          4  ...
# 1               5          9          4          6          4          4  ...
# 2               5          9          4          6          4          4  ...
# 3               5          9          4          6          4          4  ...
# 4               5          9          4          6          4          4  ...
# ...           ...        ...        ...        ...        ...        ...  ...
# 217917          5          9          4          6          4          4  ...
# 217918          5          9          4          6          4          4  ...
# 217919          5          9          4          6          4          4  ...
# 217920          5          9          4          6          4          4  ...
# 217921          5          9          4          6          4          4  ...
#
#         ss450cs400  ss50cs450  ss100cs450  ss150cs450  ss200cs450  ss250cs450  \
# 0                3          7           3           3           3           8
# 1                3          7           3           3           3           8
# 2                3          7           7           3           3           8
# 3                3          7           7           3           3           8
# 4                3          7           7           3           3           8
# ...            ...        ...         ...         ...         ...         ...
# 217917           3          7           7           3           3           8
# 217918           3          7           7           3           3           8
# 217919           3          7           7           3           3           8
# 217920           3          7           3           3           3           8
# 217921           3          7           7           3           3           8
#
#         ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0                3           5           3           3
# 1                3           5           3           3
# 2                3           5           3           3
# 3                3           5           3           3
# 4                3           5           3           3
# ...            ...         ...         ...         ...
# 217917           3           5           3           3
# 217918           3           5           3           3
# 217919           3           5           3           3
# 217920           3           5           3           3
# 217921           3           5           3           3
#
# [217922 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//hdb_labels_results_t2.4.1s+2.4.4.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5  kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5  kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6  kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5  kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6  kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7  kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5  kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6  kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7  kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8  kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#            type        testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1  kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2  kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3  kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4  kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5  kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6  kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7  kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8  kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
# 9  kmeans-umapt  t2.4.1s+2.4.4        1    37      11   37
#
#                                                  tdf   runtime  \
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8  rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
# 9  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.731391
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 9  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#             type        testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1   kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2   kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3   kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4   kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5   kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6   kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7   kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8   kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
# 9   kmeans-umapt  t2.4.1s+2.4.4        1    37      11   37
# 10  kmeans-umapt  t2.4.1s+2.4.4        1    40      11   40
#
#                                                   tdf   runtime  \
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.731391
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.811884
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 9   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 10  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#             type        testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1   kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2   kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3   kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4   kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5   kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6   kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7   kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8   kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
# 9   kmeans-umapt  t2.4.1s+2.4.4        1    37      11   37
# 10  kmeans-umapt  t2.4.1s+2.4.4        1    40      11   40
# 11  kmeans-umapt  t2.4.1s+2.4.4        1    43      11   43
#
#                                                   tdf   runtime  \
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.731391
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.811884
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.857801
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 9   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 10  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 11  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#             type        testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1   kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2   kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3   kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4   kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5   kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6   kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7   kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8   kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
# 9   kmeans-umapt  t2.4.1s+2.4.4        1    37      11   37
# 10  kmeans-umapt  t2.4.1s+2.4.4        1    40      11   40
# 11  kmeans-umapt  t2.4.1s+2.4.4        1    43      11   43
# 12  kmeans-umapt  t2.4.1s+2.4.4        1    46      11   46
#
#                                                   tdf   runtime  \
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.731391
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.811884
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.857801
# 12  rt_vect: 3.501038074493408, min_df: 4, max_df:...  5.215595
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 9   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 10  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 11  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 12  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
#             type        testset  version  size  no_con name  \
# 0   kmeans-umapt  t2.4.1s+2.4.4        1    10      11   10
# 1   kmeans-umapt  t2.4.1s+2.4.4        1    13      11   13
# 2   kmeans-umapt  t2.4.1s+2.4.4        1    16      11   16
# 3   kmeans-umapt  t2.4.1s+2.4.4        1    19      11   19
# 4   kmeans-umapt  t2.4.1s+2.4.4        1    22      11   22
# 5   kmeans-umapt  t2.4.1s+2.4.4        1    25      11   25
# 6   kmeans-umapt  t2.4.1s+2.4.4        1    28      11   28
# 7   kmeans-umapt  t2.4.1s+2.4.4        1    31      11   31
# 8   kmeans-umapt  t2.4.1s+2.4.4        1    34      11   34
# 9   kmeans-umapt  t2.4.1s+2.4.4        1    37      11   37
# 10  kmeans-umapt  t2.4.1s+2.4.4        1    40      11   40
# 11  kmeans-umapt  t2.4.1s+2.4.4        1    43      11   43
# 12  kmeans-umapt  t2.4.1s+2.4.4        1    46      11   46
# 13  kmeans-umapt  t2.4.1s+2.4.4        1    49      11   49
#
#                                                   tdf   runtime  \
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.330701
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.477356
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.708917
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  1.963630
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  2.828465
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.142332
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.239610
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.675555
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  3.857475
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.731391
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.811884
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...  4.857801
# 12  rt_vect: 3.501038074493408, min_df: 4, max_df:...  5.215595
# 13  rt_vect: 3.501038074493408, min_df: 4, max_df:...  5.499153
#
#                                                  umap
# 0   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 1   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 2   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 3   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 4   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 5   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 6   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 7   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 8   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 9   (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 10  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 11  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 12  (hellinger, rt_umap_tf: 1368.1599354743958, rt...
# 13  (hellinger, rt_umap_tf: 1368.1599354743958, rt...

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28  31  34  37  \
# 0            technopagan/mss-saliency   9   9   6   9  16  23  13   1  20  25
# 1          snmnmin12/selective-search   9   9   6  12   1  23  13   1  20  25
# 2                  google/chaps-linux   2   2  14  18   0   1  22  25  10  28
# 3            lukasolson/speech-router   6  10   0  11   4   3   3   9   5   7
# 4               XavierTecBr/qbr-admin   1  12  13  15   9  10  12   2  29  18
# ...                               ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 217917  bhagatabhijeet/bhagatabhijeet   1  12  13  15   9  10  12   2   3  18
# 217918  LandGrey/SpringBootVulExploit   7  11  10   2   2  20   1  10   0  32
# 217919    mucomplex/Pentest_checklist   2   8  14   4  13  17  19  11   6  27
# 217920            bigsen/Vision_Track   9   9   6   9  16  23  13   1  20  25
# 217921             ivanol55/cka-notes   7  11  10   7   7   6  16  10  15  13
#
#         40  43  46  49
# 0        8  30   5  13
# 1        8  30   5  13
# 2       12  16   8   1
# 3        2   8  19  47
# 4       35  35  32  19
# ...     ..  ..  ..  ..
# 217917  35  22  32  26
# 217918  24  15  17  15
# 217919  22  33   0  14
# 217920   8  30   5  28
# 217921   6   2   9  31
#
# [217911 rows x 15 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans-umap_labels_results_t2.4.1s+2.4.4.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
# 5  kmeans  t2.4.1s+2.4.4        1    25   25
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
# 5  kmeans  t2.4.1s+2.4.4        1    25   25
# 6  kmeans  t2.4.1s+2.4.4        1    28   28
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
# 5  kmeans  t2.4.1s+2.4.4        1    25   25
# 6  kmeans  t2.4.1s+2.4.4        1    28   28
# 7  kmeans  t2.4.1s+2.4.4        1    31   31
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
# 5  kmeans  t2.4.1s+2.4.4        1    25   25
# 6  kmeans  t2.4.1s+2.4.4        1    28   28
# 7  kmeans  t2.4.1s+2.4.4        1    31   31
# 8  kmeans  t2.4.1s+2.4.4        1    34   34
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
# 8  rt_vect: 3.501038074493408, min_df: 4, max_df:...  92.186260
#      type        testset  version  size name  \
# 0  kmeans  t2.4.1s+2.4.4        1    10   10
# 1  kmeans  t2.4.1s+2.4.4        1    13   13
# 2  kmeans  t2.4.1s+2.4.4        1    16   16
# 3  kmeans  t2.4.1s+2.4.4        1    19   19
# 4  kmeans  t2.4.1s+2.4.4        1    22   22
# 5  kmeans  t2.4.1s+2.4.4        1    25   25
# 6  kmeans  t2.4.1s+2.4.4        1    28   28
# 7  kmeans  t2.4.1s+2.4.4        1    31   31
# 8  kmeans  t2.4.1s+2.4.4        1    34   34
# 9  kmeans  t2.4.1s+2.4.4        1    37   37
#
#                                                  tdf    runtime
# 0  rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1  rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2  rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3  rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4  rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5  rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6  rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7  rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
# 8  rt_vect: 3.501038074493408, min_df: 4, max_df:...  92.186260
# 9  rt_vect: 3.501038074493408, min_df: 4, max_df:...  68.300273
#       type        testset  version  size name  \
# 0   kmeans  t2.4.1s+2.4.4        1    10   10
# 1   kmeans  t2.4.1s+2.4.4        1    13   13
# 2   kmeans  t2.4.1s+2.4.4        1    16   16
# 3   kmeans  t2.4.1s+2.4.4        1    19   19
# 4   kmeans  t2.4.1s+2.4.4        1    22   22
# 5   kmeans  t2.4.1s+2.4.4        1    25   25
# 6   kmeans  t2.4.1s+2.4.4        1    28   28
# 7   kmeans  t2.4.1s+2.4.4        1    31   31
# 8   kmeans  t2.4.1s+2.4.4        1    34   34
# 9   kmeans  t2.4.1s+2.4.4        1    37   37
# 10  kmeans  t2.4.1s+2.4.4        1    40   40
#
#                                                   tdf    runtime
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  92.186260
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  68.300273
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  67.188604
#       type        testset  version  size name  \
# 0   kmeans  t2.4.1s+2.4.4        1    10   10
# 1   kmeans  t2.4.1s+2.4.4        1    13   13
# 2   kmeans  t2.4.1s+2.4.4        1    16   16
# 3   kmeans  t2.4.1s+2.4.4        1    19   19
# 4   kmeans  t2.4.1s+2.4.4        1    22   22
# 5   kmeans  t2.4.1s+2.4.4        1    25   25
# 6   kmeans  t2.4.1s+2.4.4        1    28   28
# 7   kmeans  t2.4.1s+2.4.4        1    31   31
# 8   kmeans  t2.4.1s+2.4.4        1    34   34
# 9   kmeans  t2.4.1s+2.4.4        1    37   37
# 10  kmeans  t2.4.1s+2.4.4        1    40   40
# 11  kmeans  t2.4.1s+2.4.4        1    43   43
#
#                                                   tdf    runtime
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  92.186260
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  68.300273
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  67.188604
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...  78.096164
#       type        testset  version  size name  \
# 0   kmeans  t2.4.1s+2.4.4        1    10   10
# 1   kmeans  t2.4.1s+2.4.4        1    13   13
# 2   kmeans  t2.4.1s+2.4.4        1    16   16
# 3   kmeans  t2.4.1s+2.4.4        1    19   19
# 4   kmeans  t2.4.1s+2.4.4        1    22   22
# 5   kmeans  t2.4.1s+2.4.4        1    25   25
# 6   kmeans  t2.4.1s+2.4.4        1    28   28
# 7   kmeans  t2.4.1s+2.4.4        1    31   31
# 8   kmeans  t2.4.1s+2.4.4        1    34   34
# 9   kmeans  t2.4.1s+2.4.4        1    37   37
# 10  kmeans  t2.4.1s+2.4.4        1    40   40
# 11  kmeans  t2.4.1s+2.4.4        1    43   43
# 12  kmeans  t2.4.1s+2.4.4        1    46   46
#
#                                                   tdf    runtime
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...  16.704244
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...  19.163295
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...  23.460292
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...  29.513467
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...  41.007453
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...  40.896221
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...  58.381392
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...  53.826186
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...  92.186260
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...  68.300273
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...  67.188604
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...  78.096164
# 12  rt_vect: 3.501038074493408, min_df: 4, max_df:...  90.740786
#       type        testset  version  size name  \
# 0   kmeans  t2.4.1s+2.4.4        1    10   10
# 1   kmeans  t2.4.1s+2.4.4        1    13   13
# 2   kmeans  t2.4.1s+2.4.4        1    16   16
# 3   kmeans  t2.4.1s+2.4.4        1    19   19
# 4   kmeans  t2.4.1s+2.4.4        1    22   22
# 5   kmeans  t2.4.1s+2.4.4        1    25   25
# 6   kmeans  t2.4.1s+2.4.4        1    28   28
# 7   kmeans  t2.4.1s+2.4.4        1    31   31
# 8   kmeans  t2.4.1s+2.4.4        1    34   34
# 9   kmeans  t2.4.1s+2.4.4        1    37   37
# 10  kmeans  t2.4.1s+2.4.4        1    40   40
# 11  kmeans  t2.4.1s+2.4.4        1    43   43
# 12  kmeans  t2.4.1s+2.4.4        1    46   46
# 13  kmeans  t2.4.1s+2.4.4        1    49   49
#
#                                                   tdf     runtime
# 0   rt_vect: 3.501038074493408, min_df: 4, max_df:...   16.704244
# 1   rt_vect: 3.501038074493408, min_df: 4, max_df:...   19.163295
# 2   rt_vect: 3.501038074493408, min_df: 4, max_df:...   23.460292
# 3   rt_vect: 3.501038074493408, min_df: 4, max_df:...   29.513467
# 4   rt_vect: 3.501038074493408, min_df: 4, max_df:...   41.007453
# 5   rt_vect: 3.501038074493408, min_df: 4, max_df:...   40.896221
# 6   rt_vect: 3.501038074493408, min_df: 4, max_df:...   58.381392
# 7   rt_vect: 3.501038074493408, min_df: 4, max_df:...   53.826186
# 8   rt_vect: 3.501038074493408, min_df: 4, max_df:...   92.186260
# 9   rt_vect: 3.501038074493408, min_df: 4, max_df:...   68.300273
# 10  rt_vect: 3.501038074493408, min_df: 4, max_df:...   67.188604
# 11  rt_vect: 3.501038074493408, min_df: 4, max_df:...   78.096164
# 12  rt_vect: 3.501038074493408, min_df: 4, max_df:...   90.740786
# 13  rt_vect: 3.501038074493408, min_df: 4, max_df:...  100.371106

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28  31  34  37  \
# 0            technopagan/mss-saliency   9  12   1  18  17   4  16   6  29  24
# 1          snmnmin12/selective-search   9  12   1  18  17  13  16  29  29   6
# 2                  google/chaps-linux   3   7   8   7  10  20  24   6  11  12
# 3            lukasolson/speech-router   8   5   4   3   6  24   4  26  26  28
# 4               XavierTecBr/qbr-admin   2   1  11   1   3   6   5  25   7   2
# ...                               ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 217917  bhagatabhijeet/bhagatabhijeet   7   3   5  11  14   2  14   7  28  25
# 217918  LandGrey/SpringBootVulExploit   2   2  11   1   3   6   5   8   7   2
# 217919    mucomplex/Pentest_checklist   3   1   3  16  16  18  17   1  19  31
# 217920            bigsen/Vision_Track   6   0   6   9  12  22   1  28  20   6
# 217921             ivanol55/cka-notes   2   2  13  17   4  19  23  12  33  16
#
#         40  43  46  49
# 0       38  40  33  34
# 1       25  40  33  34
# 2       33  17  20  24
# 3        8  22  16  37
# 4        0   4  41   5
# ...     ..  ..  ..  ..
# 217917  12   1  15  22
# 217918   0   9  13   5
# 217919   9   3   3  21
# 217920  24  12  31  33
# 217921  15  39  21  28
#
# [217922 rows x 15 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar3//kmeans_labels_results_t2.4.1s+2.4.4.pkl
