# %%
# replaces Paper-Testset-Data-ANALZE
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator

from IPython.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

pd.set_option('display.max_columns', None)

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
import shared_globals_functions as sgf
# %aimport shared_globals_functions

# %%
# do this only on the first run

def first_run():
    github_data_df = pd.DataFrame()

    json_pattern = os.path.join(github_data_folder,'*.json')
    file_list = glob.glob(json_pattern)

    dfs = [] # an empty list to store the data frames
    for file in file_list:
        data = pd.read_json(file, lines=True) # read data frame from json file
        dfs.append(data) # append the data frame to the list

    github_data_df = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.

    to_disk(github_data_df[['name', 'isfork', 'stars', 'archived', 'commits', 'watcher', 'license',
                   'releases', 'forks', 'pushed', 'created', 'wiki', 'downloads',
                   'open_issues', 'open_issues_s30d', 'open_issues_b30d',
                   'language', 'size', 'url', 'contributors',
                   'content_url', 'crawl_created', 'crawl_last_updated',
                   'crawl_last_spare_req', 'search_queries']], 'init_short') #, 'about_is_english',               'readme_is_english'

    to_disk(github_data_df, 'init')

# %%
github_data_df = from_disk('init')
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/init.pkl

# %%
github_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221971 entries, 0 to 221970
# Data columns (total 31 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   name                  221971 non-null  object
#  1   isfork                221971 non-null  bool
#  2   stars                 221971 non-null  int64
#  3   archived              221971 non-null  bool
#  4   commits               221971 non-null  int64
#  5   watcher               221971 non-null  int64
#  6   license               125322 non-null  object
#  7   releases              221971 non-null  int64
#  8   forks                 221971 non-null  int64
#  9   pushed                221971 non-null  object
#  10  created               221971 non-null  object
#  11  wiki                  221971 non-null  bool
#  12  downloads             221971 non-null  bool
#  13  open_issues           221971 non-null  int64
#  14  open_issues_s30d      221971 non-null  int64
#  15  open_issues_b30d      221971 non-null  int64
#  16  topics                221971 non-null  object
#  17  about                 194881 non-null  object
#  18  language              192428 non-null  object
#  19  languages             221971 non-null  object
#  20  size                  221971 non-null  int64
#  21  url                   221971 non-null  object
#  22  contributors          221971 non-null  int64
#  23  content_url           221971 non-null  object
#  24  readme                221971 non-null  object
#  25  tree                  221971 non-null  object
#  26  crawl_created         221971 non-null  object
#  27  crawl_last_updated    221971 non-null  object
#  28  crawl_last_spare_req  221971 non-null  int64
#  29  search_queries        221971 non-null  object
#  30  readme_clean          219683 non-null  object
# dtypes: bool(4), int64(11), object(16)
# memory usage: 46.6+ MB

# %%
from collections import Counter
topic_counter = Counter(github_data_df['topics'].explode().to_list())

# %%
total_repo_cnt = len(github_data_df)
print(f"Total number of repos {total_repo_cnt}")
# Out:
# Total number of repos 221971

# %%
# percentage of repos with topics
(len(github_data_df[github_data_df['topics'].str.len() > 0])) / total_repo_cnt
# Out:
# 0.31453207851476095

# %%
# number of repos without readme
1-(len(github_data_df['readme'][github_data_df['readme'].str.len() > 0])) / total_repo_cnt
# Out:
# 0.011050993147753485

# %%
# number of repos with about
(len(github_data_df['about'][github_data_df['about'].str.len() > 0])) / total_repo_cnt
# Out:
# 0.8779390100508625

# %%
# number of unique topics
len(topic_counter.keys())
# Out:
# 93055

# %%
total_repos_with_topics=len(github_data_df[github_data_df['topics'].str.len() > 0])

# %%
## we build topics and topics_composite, that are lists of topics which are represented in at least X repositories; this is to reduce topics that are rarely used and to reduce the memory footprint
topic_composite = [] # save topic compositions
topics = []

min_thres=total_repos_with_topics*0.0005 # at least in 5% of the repos
print(f'there are {total_repos_with_topics} repos that have topics, we take topics that are in minimium of {min_thres} in our topic list')

for i in topic_counter.items():
    t = i[0]
    o = i[1]
    if isinstance(t, str):
        if not t.isascii():
            print(f'string is not ascii: {t}')
        if any(not c.isalnum() for c in t):
            #print(f'string contains non alphanumeric values: {t}')
            if o >= min_thres:             
                topic_composite.append(t)
        if o >= min_thres:
                topics.append(t)
# Out:
# there are 69817 repos that have topics, we take topics that are in minimium of 34.908500000000004 in our topic list

# %%
# topics that are at least in X repos
topics
# Out:
# ['wordpress',
#  'wordpress-plugin',
#  'language',
#  'amazon',
#  'chrome-extension',
#  'swift',
#  'ios',
#  'custom',
#  'cnn',
#  'cnn-keras',
#  'tensorflow',
#  'ai',
#  'machine-learning',
#  'android',
#  'security',
#  'malware',
#  'malware-analysis',
#  'trojan',
#  'ransomware',
#  'engine',
#  'static-analysis',
#  'static-code-analysis',
#  'dynamic-analysis',
#  'html5',
#  'css3',
#  'python3',
#  'mongodb',
#  'flask-application',
#  'heroku',
#  'bootstrap4',
#  'landmark-detection',
#  'computer-vision',
#  'pentest',
#  'pentest-tool',
#  'penetration-testing',
#  'bugbounty',
#  'enumeration',
#  'osint',
#  'brute-force',
#  'password',
#  'fast',
#  'raspberry-pi',
#  'media',
#  'docker-compose',
#  'docker',
#  'grafana',
#  'prometheus',
#  'real-time',
#  'instance-segmentation',
#  'mask-rcnn',
#  'webcam',
#  'rcnn',
#  'image-segmentation',
#  'keras',
#  'opencv',
#  'object-detection',
#  'network-analysis',
#  'community-detection',
#  'graph-algorithms',
#  'gcp',
#  'google-cloud',
#  'google-cloud-platform',
#  'terraform',
#  'python',
#  'optimization',
#  'deep-learning',
#  'deeplearning',
#  'nlp',
#  'rust',
#  'reverse-engineering',
#  'game',
#  'flutter',
#  'dart',
#  'php',
#  'iot',
#  'dashboard',
#  'map',
#  'awesome',
#  'awesome-list',
#  'list',
#  'azure',
#  'question-answering',
#  'sql',
#  'csv',
#  'database',
#  'fud',
#  'bypass',
#  'downloader',
#  'windows',
#  'antivirus',
#  'antivirus-evasion',
#  'console',
#  'terminal',
#  'shell',
#  'paper',
#  'redux',
#  'react-redux',
#  'api',
#  'django',
#  'elasticsearch',
#  'privacy',
#  'spark',
#  'etl',
#  'detection',
#  'opencv-python',
#  'mobilenet-ssd',
#  'unet',
#  'pytorch',
#  'papers',
#  'nodejs',
#  'nestjs',
#  'graphql',
#  'clustering',
#  'jupyter-notebook',
#  'machine-learning-algorithms',
#  'neural-network',
#  'numpy',
#  'regression',
#  'reinforcement-learning',
#  'supervised-learning',
#  'unsupervised-learning',
#  'linear-regression',
#  'logistic-regression',
#  'linux',
#  'medical-imaging',
#  'mariadb',
#  'anomaly',
#  'machinelearning',
#  'deep-reinforcement-learning',
#  'meta-learning',
#  'rnn',
#  'julia',
#  'faster-rcnn',
#  'wifi',
#  'wireless',
#  'wifi-security',
#  'audit',
#  'solidity',
#  'forensics',
#  'cryptography',
#  'web',
#  'scss',
#  'bot',
#  'discord-bot',
#  'slack-bot',
#  'telegram',
#  'telegram-bot',
#  'finance',
#  'stocks',
#  'streamlit',
#  'yolov3',
#  'convolutional-neural-networks',
#  'coronavirus',
#  'youtube',
#  'research-paper',
#  'trading',
#  'tradingview',
#  'tool',
#  'alerts',
#  'alert',
#  'notifications',
#  'websocket',
#  'webhook',
#  'arduino',
#  'webserver',
#  'ajax',
#  'html',
#  'javascript',
#  'c-plus-plus',
#  'esp8266',
#  'internet-of-things',
#  'deep-neural-networks',
#  'password-manager',
#  'privacy-protection',
#  'reactjs',
#  'react-native',
#  'robot',
#  'hardware',
#  'ssd',
#  'ocr-recognition',
#  'aws',
#  'best-practices',
#  'sass',
#  'image-processing',
#  'bootstrap',
#  'template',
#  'blockchain',
#  'bitcoin',
#  'cloud',
#  'component',
#  'prettier',
#  'markdown',
#  'node',
#  'code',
#  'cli',
#  'dataset',
#  'go',
#  'sdk',
#  'expressjs',
#  'cqrs',
#  'dotnet-core',
#  'example',
#  'netcore',
#  'hacktoberfest',
#  'uikit',
#  'snippets',
#  'laravel-package',
#  'laravel',
#  'yolov4',
#  'object-tracking',
#  'bioinformatics',
#  'ngs',
#  'firebase',
#  'firebase-auth',
#  'theme',
#  'active-learning',
#  'semi-supervised-learning',
#  'visualization',
#  'java',
#  'desktop',
#  'secure',
#  'sandbox',
#  'sklearn',
#  'svm',
#  'decision-trees',
#  'random-forest',
#  'keras-tensorflow',
#  'neural-networks',
#  'testing',
#  'test-automation',
#  'functional-programming',
#  'orm',
#  'human-pose-estimation',
#  'segmentation',
#  'transfer-learning',
#  'semantic-segmentation',
#  'mongoose',
#  'covid',
#  'app',
#  'depth-estimation',
#  'onnx',
#  'onnxruntime',
#  'yara-rules',
#  'swagger',
#  'openapi',
#  'rest-api',
#  'server',
#  'middleware',
#  'cluster',
#  'ansible-role',
#  'ansible',
#  'debugging',
#  'android-development',
#  'gradle',
#  'full-stack',
#  'react',
#  'drag-and-drop',
#  'jira',
#  'automation',
#  'face-detection',
#  'threat-intelligence',
#  'threat-hunting',
#  'threat-sharing',
#  'reconnaissance',
#  'hacking-tools',
#  'blueteam',
#  'redteam',
#  'redteaming',
#  'yolov2',
#  'darknet',
#  'crud',
#  'restful-api',
#  'spring',
#  'spring-boot',
#  'springboot',
#  'devsecops',
#  'golang',
#  'security-tools',
#  'secrets',
#  'verification',
#  'smart-home',
#  'home-automation',
#  'hardening',
#  'hadoop',
#  'compliance',
#  'natural-language-processing',
#  'ethereum',
#  'config',
#  'protobuf',
#  'grpc',
#  'ruby',
#  'rails',
#  'containers',
#  'vmware',
#  'management',
#  'kubernetes',
#  'openshift',
#  'webview',
#  'science',
#  'physics',
#  'math',
#  'artificial-intelligence',
#  'tutorial',
#  'coursera',
#  'google',
#  'yolov5',
#  'image',
#  'data-science',
#  'community',
#  'image-classification',
#  'devops',
#  'infrastructure-as-code',
#  'network',
#  'proxy',
#  'home-assistant',
#  'home-assistant-config',
#  'alexa',
#  'speech',
#  'cancer',
#  'validation',
#  'camera',
#  'vision',
#  'vuejs',
#  'tensorflowjs',
#  'tensorflow-tutorials',
#  'imagenet',
#  'workshop',
#  'geospatial',
#  'gis',
#  'parsing',
#  'airflow',
#  'data-analysis',
#  'i18n',
#  'caffe',
#  'yara',
#  'webpack',
#  'container',
#  'tor',
#  'ncnn',
#  'facedetection',
#  'classifier',
#  'objectdetection',
#  'encryption',
#  'open-source',
#  'awesome-lists',
#  'tools',
#  'resources',
#  'internet',
#  'kafka',
#  'library',
#  'classification',
#  'c',
#  'game-development',
#  'gamedev',
#  'hacktoberfest2020',
#  'webrtc',
#  'test',
#  'svm-classifier',
#  'lane-detection',
#  'cplusplus',
#  'hough-transform',
#  'extension',
#  'objective-c',
#  'slam',
#  'robotics',
#  'ros',
#  'cpp',
#  'pose-estimation',
#  'mapping',
#  'weakly-supervised-learning',
#  'mediapipe',
#  'tensorflow-lite',
#  'ui-components',
#  'vision-transformer',
#  'facial-recognition',
#  'raspberry-pi-3',
#  'chatgpt',
#  'cybersecurity',
#  'openai',
#  'oss',
#  'corpus',
#  'prompt',
#  'android-application',
#  'kotlin-android',
#  'vpn',
#  'post-exploitation',
#  'hacking',
#  'backdoor',
#  'privilege-escalation',
#  'c2',
#  'persistence',
#  'composer',
#  'siem',
#  'battery',
#  'deepfakes',
#  'kaggle',
#  'deepfake-detection',
#  'offensive-security',
#  'purpleteam',
#  'cti',
#  'ioc',
#  'misp',
#  'protocol',
#  'router',
#  'typescript',
#  'electron',
#  'macos',
#  'distributed-systems',
#  'mvc',
#  'framework',
#  'starter-kit',
#  'web-development',
#  'convolutional-neural-network',
#  'tensorflow2',
#  'vgg16',
#  'project',
#  'nextjs',
#  'clean-architecture',
#  'ddd',
#  'helm',
#  'kibana',
#  'microservices',
#  'rabbitmq',
#  'event-driven',
#  'ssr',
#  'javafx',
#  'image-annotation',
#  'bounding-boxes',
#  'annotation-tool',
#  'material-ui',
#  'data',
#  'notes',
#  'ips',
#  'face-recognition',
#  'recon',
#  'dfir',
#  'forensic-analysis',
#  'video-processing',
#  'image-recognition',
#  'language-model',
#  'yolo',
#  'table',
#  'opencv3',
#  'cv2',
#  'sensors',
#  'documentation',
#  'lstm',
#  'word2vec',
#  'deeplearning-ai',
#  'reverse-proxy',
#  'proxy-server',
#  'microsoft',
#  'csharp',
#  'vue',
#  'vue-components',
#  'redis',
#  'mysql',
#  'xml',
#  'json',
#  'socket',
#  'http',
#  'scheduler',
#  'validator',
#  'regex',
#  'translation',
#  'plugin',
#  'rpi',
#  'temperature',
#  'pcb',
#  'homeassistant',
#  'mqtt',
#  'sensor',
#  'video',
#  'unity',
#  'canvas',
#  'webgl',
#  'data-mining',
#  'graphs',
#  'fake-news',
#  'datasets',
#  'pypi',
#  'algorithms',
#  'text-classification',
#  'material-design',
#  'red-team',
#  'evasion',
#  'emulator',
#  'frontend',
#  'kotlin',
#  'gui',
#  'flask',
#  'deployment',
#  'filter',
#  'hackintosh',
#  'model',
#  'docker-image',
#  'anomaly-detection',
#  'eda',
#  'cve',
#  'vulnerability',
#  'magento2',
#  'spigot',
#  'minecraft',
#  'localization',
#  'metrics',
#  'dnn',
#  'authentication',
#  'authorization',
#  'security-testing',
#  'puppeteer',
#  'rtsp',
#  'learning',
#  'ecommerce',
#  'magento',
#  'monitoring',
#  'vulnerability-scanner',
#  'poc',
#  'translate',
#  'free',
#  'golang-library',
#  'elk',
#  'integration',
#  'lua',
#  'async',
#  'event',
#  'smtp',
#  'mail',
#  'text',
#  'email',
#  'benchmark',
#  'certification',
#  'k8s',
#  'cncf',
#  'kubernetes-cluster',
#  'examples',
#  'pandas',
#  'ecg',
#  'signal-processing',
#  'exploitation',
#  'data-visualization',
#  'sql-injection',
#  'xss',
#  'cpp17',
#  'flutter-examples',
#  'dialog',
#  'blazor',
#  'iphone',
#  'metasploit',
#  'shellcode',
#  'nosql',
#  'health',
#  'streaming',
#  'responsive',
#  'css',
#  'webapp',
#  'ocr',
#  'gke',
#  'spring-cloud',
#  'gateway',
#  'consul',
#  'fuzzing',
#  'pentesting',
#  'stream-processing',
#  'nginx',
#  'owasp',
#  'music',
#  'php7',
#  'socket-io',
#  'vault',
#  'operator',
#  'istio',
#  'angular',
#  'software-engineering',
#  'data-structures',
#  'header-only',
#  'animation',
#  'ffmpeg',
#  'scripting',
#  'rat',
#  'scikit-learn',
#  'control',
#  'stack',
#  'queue',
#  'tree',
#  'graph',
#  'matrix',
#  'unity3d',
#  'stm32',
#  'fingerprint',
#  'module',
#  'tensorflow-examples',
#  'tflite',
#  'serverless',
#  'ibm-cloud',
#  'slack',
#  'powershell',
#  'geolocation',
#  'sql-server',
#  'postgresql',
#  'opentelemetry',
#  'docker-container',
#  'ci',
#  'continuous-integration',
#  'hack',
#  'python-3',
#  'parser',
#  'concurrency',
#  'analysis',
#  'recurrent-neural-networks',
#  'monitor',
#  'traefik',
#  'nextcloud',
#  'maven',
#  'ros2',
#  'simulation',
#  'django-rest-framework',
#  'blue-team',
#  'incident-response',
#  'bash',
#  'tailwindcss',
#  'tailwind',
#  'js',
#  'admin',
#  'admin-dashboard',
#  'arkit',
#  'fingerprinting',
#  'logging',
#  'log',
#  'waf',
#  'hacking-tool',
#  'api-gateway',
#  'jquery',
#  'jquery-plugin',
#  'opengl',
#  'delphi',
#  'car',
#  'traffic',
#  'physics-simulation',
#  'rootkit',
#  'lambda',
#  'aws-lambda',
#  'pwa',
#  'oauth2',
#  'ssl',
#  'rest',
#  'big-data',
#  'telemetry',
#  'scala',
#  'lidar',
#  'point-cloud',
#  'autonomous-driving',
#  'self-driving-car',
#  'bert',
#  'huggingface',
#  'twitter',
#  'udacity-self-driving-car',
#  'udacity-nanodegree',
#  'satellite-imagery',
#  'remote-sensing',
#  'clojure',
#  'messaging',
#  'text-detection',
#  'saas',
#  'paas',
#  'toolbox',
#  'sonarqube',
#  'vim',
#  'encoding',
#  'domain-adaptation',
#  'robustness',
#  'alerting',
#  'reactive',
#  'deprecated',
#  'github',
#  'workflow',
#  'linter',
#  'colab-notebook',
#  'mod',
#  'nlp-machine-learning',
#  'lstm-neural-networks',
#  'sentiment-analysis',
#  'asm',
#  'jetson-nano',
#  'web-scraping',
#  'webscraping',
#  'metadata',
#  'information-extraction',
#  'vehicle-detection',
#  'vehicle-tracking',
#  'license-plate-recognition',
#  'tensorflow-object-detection-api',
#  'mvvm',
#  'angularjs',
#  'cisco',
#  'end-to-end-encryption',
#  'opensource',
#  'scripts',
#  'guide',
#  'statistics',
#  'r',
#  'audio',
#  'speech-recognition',
#  'crypto',
#  'outlier-detection',
#  'python2',
#  'fraud-detection',
#  'autoencoder',
#  'out-of-distribution-detection',
#  'games',
#  'tensorrt',
#  'openpose',
#  'gan',
#  'generative-adversarial-network',
#  'curated-list',
#  'collection',
#  'knowledge-distillation',
#  '3d-object-detection',
#  'gpt',
#  'gpt-4',
#  'scanner',
#  'node-red',
#  'matlab',
#  'research',
#  'appsec',
#  'federated-learning',
#  'distributed-computing',
#  'filesystem',
#  'sdr',
#  'network-monitoring',
#  'network-security',
#  'cocoapods',
#  'carthage',
#  'keycloak',
#  'php-library',
#  'hacktoberfest2021',
#  'ubuntu',
#  'mxnet',
#  'ssh',
#  'osx',
#  'mac',
#  'macosx',
#  'cms',
#  'cheatsheet',
#  'material',
#  'android-library',
#  'android-ui',
#  'command-line',
#  'security-automation',
#  'menu',
#  'links',
#  'steganography',
#  'ethical-hacking',
#  'python-script',
#  'bluetooth-low-energy',
#  'bluetooth',
#  'contrastive-learning',
#  'facial-expression-recognition',
#  'xamarin',
#  'dotnet',
#  'nfc',
#  'mobilenetv2',
#  'efficientnet',
#  'tracking',
#  'arduino-library',
#  'controller',
#  'diy',
#  'augmented-reality',
#  'algorithmic-trading',
#  'trading-strategies',
#  'trading-bot',
#  'gdpr',
#  'analytics',
#  'weather',
#  'webassembly',
#  'search-engine',
#  'vr',
#  'graphics',
#  'virtual-reality',
#  'search',
#  'audio-processing',
#  'audio-analysis',
#  'pascal-voc',
#  'edge-computing',
#  'crawler',
#  'bots',
#  'spider',
#  'logs',
#  'resnet',
#  'ip',
#  'jdbc',
#  'high-performance',
#  'unicode',
#  'svg',
#  'maps',
#  'javascript-library',
#  'processing',
#  'ec2',
#  'pyspark',
#  'bigdata',
#  'autonomous-vehicles',
#  'service-mesh',
#  'windows-10',
#  'windows-11',
#  'stock-market',
#  'sample',
#  'rds',
#  'self-hosted',
#  'hls',
#  'azure-functions',
#  'virtual-machine',
#  'distributed',
#  'obfuscation',
#  'dapp',
#  'wallet',
#  'modal',
#  'emacs',
#  'emacs-lisp',
#  'boilerplate',
#  'mobile',
#  'pytorch-lightning',
#  'drone',
#  'beginner',
#  'computer-science',
#  'programming',
#  'pretrained-models',
#  'quantum-computing',
#  'assembly',
#  'x86',
#  'arm',
#  'kernel',
#  'dark-theme',
#  'node-js',
#  'angular2',
#  'photos',
#  'synthetic-data',
#  'editor',
#  'vscode',
#  'attack',
#  'defi',
#  'exploit',
#  'exploits',
#  'cross-platform',
#  'browser',
#  'optical-character-recognition',
#  'bug-bounty',
#  'scraper',
#  'data-quality',
#  'tweets',
#  'emotion-detection',
#  'letsencrypt',
#  'apache',
#  'https',
#  'github-actions',
#  'utilities',
#  'honeypot',
#  'mtcnn',
#  'inference',
#  'vulnerability-management',
#  'prediction',
#  'healthcare',
#  'android-studio',
#  'debian',
#  'pipeline',
#  'form',
#  'ldap',
#  'active-directory',
#  'popup',
#  'threatintel',
#  'phishing',
#  'jenkins',
#  'git',
#  'anti-spoofing',
#  'liveness-detection',
#  'attention-mechanism',
#  'security-audit',
#  'facial-landmarks',
#  'cryptocurrency',
#  'peer-to-peer',
#  'transformer',
#  'detr',
#  'transformers',
#  'multiplayer',
#  'course',
#  'llm',
#  'vscode-extension',
#  'lists',
#  'mlops',
#  'cloud-security',
#  'express',
#  'website',
#  'information-security',
#  'machine',
#  'chart',
#  'benchmarking',
#  'interpretability',
#  'sound',
#  'sagemaker',
#  'dns',
#  'iptables',
#  'llvm',
#  'bruteforce',
#  'btc',
#  'p2p',
#  'ipfs',
#  'self-supervised-learning',
#  'splunk',
#  'intelligence',
#  'edge',
#  'change-detection',
#  'operating-system',
#  'service-discovery',
#  'nmap',
#  'vulnerability-scanners',
#  'freebsd',
#  'vulnerability-detection',
#  'security-vulnerability',
#  'security-scanner',
#  'security-hardening',
#  'vulnerabilities',
#  'code-quality',
#  'actions',
#  'genomics',
#  'smart-contracts',
#  'openvpn',
#  'firewall',
#  'qt5',
#  'wireguard',
#  'npm',
#  'iot-platform',
#  'openssl',
#  'agent',
#  'ebpf',
#  'ml',
#  'observability',
#  'tracing',
#  'kotlin-library',
#  'radio',
#  'identity',
#  '3d-vision',
#  'ensemble-learning',
#  'kitti-dataset',
#  'sensor-fusion',
#  'kalman-filter',
#  'automl',
#  'collision-detection',
#  'machine-translation',
#  'binance',
#  'asyncio',
#  'expo',
#  'sqlite',
#  'wechat',
#  'terraform-modules',
#  'developer-tools',
#  'react-router',
#  'chrome',
#  'devops-tools',
#  'cdk',
#  'gpu',
#  'cuda',
#  'cv',
#  'manager',
#  'malware-research',
#  'malware-detection',
#  'mining',
#  'eth',
#  'nvidia',
#  'networking',
#  'esp32',
#  'logger',
#  'multithreading',
#  'iot-device',
#  'firmware',
#  'restful',
#  'quantization',
#  'yolox',
#  'ble',
#  'stereo-vision',
#  'symfony',
#  'text-recognition',
#  'oscp',
#  'latex',
#  'hunting',
#  'cyber-security',
#  'styled-components',
#  'upload',
#  'lidar-point-cloud',
#  'radar',
#  'data-engineering',
#  'threat',
#  'memory',
#  'volatility',
#  'front-end',
#  'development',
#  'application',
#  'user-agent',
#  'infosec',
#  'microcontroller',
#  'xgboost',
#  'mobilenet',
#  'xcode',
#  ...]

# %%
# topics compositions that are at least in X repos
topic_composite
# Out:
# ['wordpress-plugin',
#  'chrome-extension',
#  'cnn-keras',
#  'machine-learning',
#  'malware-analysis',
#  'static-analysis',
#  'static-code-analysis',
#  'dynamic-analysis',
#  'flask-application',
#  'landmark-detection',
#  'computer-vision',
#  'pentest-tool',
#  'penetration-testing',
#  'brute-force',
#  'raspberry-pi',
#  'docker-compose',
#  'real-time',
#  'instance-segmentation',
#  'mask-rcnn',
#  'image-segmentation',
#  'object-detection',
#  'network-analysis',
#  'community-detection',
#  'graph-algorithms',
#  'google-cloud',
#  'google-cloud-platform',
#  'deep-learning',
#  'reverse-engineering',
#  'awesome-list',
#  'question-answering',
#  'antivirus-evasion',
#  'react-redux',
#  'opencv-python',
#  'mobilenet-ssd',
#  'jupyter-notebook',
#  'machine-learning-algorithms',
#  'neural-network',
#  'reinforcement-learning',
#  'supervised-learning',
#  'unsupervised-learning',
#  'linear-regression',
#  'logistic-regression',
#  'medical-imaging',
#  'deep-reinforcement-learning',
#  'meta-learning',
#  'faster-rcnn',
#  'wifi-security',
#  'discord-bot',
#  'slack-bot',
#  'telegram-bot',
#  'convolutional-neural-networks',
#  'research-paper',
#  'c-plus-plus',
#  'internet-of-things',
#  'deep-neural-networks',
#  'password-manager',
#  'privacy-protection',
#  'react-native',
#  'ocr-recognition',
#  'best-practices',
#  'image-processing',
#  'dotnet-core',
#  'laravel-package',
#  'object-tracking',
#  'firebase-auth',
#  'active-learning',
#  'semi-supervised-learning',
#  'decision-trees',
#  'random-forest',
#  'keras-tensorflow',
#  'neural-networks',
#  'test-automation',
#  'functional-programming',
#  'human-pose-estimation',
#  'transfer-learning',
#  'semantic-segmentation',
#  'depth-estimation',
#  'yara-rules',
#  'rest-api',
#  'ansible-role',
#  'android-development',
#  'full-stack',
#  'drag-and-drop',
#  'face-detection',
#  'threat-intelligence',
#  'threat-hunting',
#  'threat-sharing',
#  'hacking-tools',
#  'restful-api',
#  'spring-boot',
#  'security-tools',
#  'smart-home',
#  'home-automation',
#  'natural-language-processing',
#  'artificial-intelligence',
#  'data-science',
#  'image-classification',
#  'infrastructure-as-code',
#  'home-assistant',
#  'home-assistant-config',
#  'tensorflow-tutorials',
#  'data-analysis',
#  'open-source',
#  'awesome-lists',
#  'game-development',
#  'svm-classifier',
#  'lane-detection',
#  'hough-transform',
#  'objective-c',
#  'pose-estimation',
#  'weakly-supervised-learning',
#  'tensorflow-lite',
#  'ui-components',
#  'vision-transformer',
#  'facial-recognition',
#  'raspberry-pi-3',
#  'android-application',
#  'kotlin-android',
#  'post-exploitation',
#  'privilege-escalation',
#  'deepfake-detection',
#  'offensive-security',
#  'distributed-systems',
#  'starter-kit',
#  'web-development',
#  'convolutional-neural-network',
#  'clean-architecture',
#  'event-driven',
#  'image-annotation',
#  'bounding-boxes',
#  'annotation-tool',
#  'material-ui',
#  'face-recognition',
#  'forensic-analysis',
#  'video-processing',
#  'image-recognition',
#  'language-model',
#  'deeplearning-ai',
#  'reverse-proxy',
#  'proxy-server',
#  'vue-components',
#  'data-mining',
#  'fake-news',
#  'text-classification',
#  'material-design',
#  'red-team',
#  'docker-image',
#  'anomaly-detection',
#  'security-testing',
#  'vulnerability-scanner',
#  'golang-library',
#  'kubernetes-cluster',
#  'signal-processing',
#  'data-visualization',
#  'sql-injection',
#  'flutter-examples',
#  'spring-cloud',
#  'stream-processing',
#  'socket-io',
#  'software-engineering',
#  'data-structures',
#  'header-only',
#  'scikit-learn',
#  'tensorflow-examples',
#  'ibm-cloud',
#  'sql-server',
#  'docker-container',
#  'continuous-integration',
#  'python-3',
#  'recurrent-neural-networks',
#  'django-rest-framework',
#  'blue-team',
#  'incident-response',
#  'admin-dashboard',
#  'hacking-tool',
#  'api-gateway',
#  'jquery-plugin',
#  'physics-simulation',
#  'aws-lambda',
#  'big-data',
#  'point-cloud',
#  'autonomous-driving',
#  'self-driving-car',
#  'udacity-self-driving-car',
#  'udacity-nanodegree',
#  'satellite-imagery',
#  'remote-sensing',
#  'text-detection',
#  'domain-adaptation',
#  'colab-notebook',
#  'nlp-machine-learning',
#  'lstm-neural-networks',
#  'sentiment-analysis',
#  'jetson-nano',
#  'web-scraping',
#  'information-extraction',
#  'vehicle-detection',
#  'vehicle-tracking',
#  'license-plate-recognition',
#  'tensorflow-object-detection-api',
#  'end-to-end-encryption',
#  'speech-recognition',
#  'outlier-detection',
#  'fraud-detection',
#  'out-of-distribution-detection',
#  'generative-adversarial-network',
#  'curated-list',
#  'knowledge-distillation',
#  '3d-object-detection',
#  'gpt-4',
#  'node-red',
#  'federated-learning',
#  'distributed-computing',
#  'network-monitoring',
#  'network-security',
#  'php-library',
#  'android-library',
#  'android-ui',
#  'command-line',
#  'security-automation',
#  'ethical-hacking',
#  'python-script',
#  'bluetooth-low-energy',
#  'contrastive-learning',
#  'facial-expression-recognition',
#  'arduino-library',
#  'augmented-reality',
#  'algorithmic-trading',
#  'trading-strategies',
#  'trading-bot',
#  'search-engine',
#  'virtual-reality',
#  'audio-processing',
#  'audio-analysis',
#  'pascal-voc',
#  'edge-computing',
#  'high-performance',
#  'javascript-library',
#  'autonomous-vehicles',
#  'service-mesh',
#  'windows-10',
#  'windows-11',
#  'stock-market',
#  'self-hosted',
#  'azure-functions',
#  'virtual-machine',
#  'emacs-lisp',
#  'pytorch-lightning',
#  'computer-science',
#  'pretrained-models',
#  'quantum-computing',
#  'dark-theme',
#  'node-js',
#  'synthetic-data',
#  'cross-platform',
#  'optical-character-recognition',
#  'bug-bounty',
#  'data-quality',
#  'emotion-detection',
#  'github-actions',
#  'vulnerability-management',
#  'android-studio',
#  'active-directory',
#  'anti-spoofing',
#  'liveness-detection',
#  'attention-mechanism',
#  'security-audit',
#  'facial-landmarks',
#  'peer-to-peer',
#  'vscode-extension',
#  'cloud-security',
#  'information-security',
#  'self-supervised-learning',
#  'change-detection',
#  'operating-system',
#  'service-discovery',
#  'vulnerability-scanners',
#  'vulnerability-detection',
#  'security-vulnerability',
#  'security-scanner',
#  'security-hardening',
#  'code-quality',
#  'smart-contracts',
#  'iot-platform',
#  'kotlin-library',
#  '3d-vision',
#  'ensemble-learning',
#  'kitti-dataset',
#  'sensor-fusion',
#  'kalman-filter',
#  'collision-detection',
#  'machine-translation',
#  'terraform-modules',
#  'developer-tools',
#  'react-router',
#  'devops-tools',
#  'malware-research',
#  'malware-detection',
#  'iot-device',
#  'stereo-vision',
#  'text-recognition',
#  'cyber-security',
#  'styled-components',
#  'lidar-point-cloud',
#  'data-engineering',
#  'front-end',
#  'user-agent',
#  'hand-detection',
#  'text-mining',
#  'named-entity-recognition',
#  'information-gathering',
#  'voice-recognition',
#  'eye-detection',
#  'eye-tracking',
#  'anti-virus',
#  'bypass-antivirus',
#  'cnn-classification',
#  'terraform-module',
#  'npm-package',
#  'action-recognition',
#  'deep-learning-tutorial',
#  'face-tracking',
#  'face-mask-detection',
#  'react-hooks',
#  'linux-kernel',
#  'azure-devops',
#  'rust-lang',
#  'rna-seq',
#  'interview-preparation',
#  'interview-questions',
#  'object-recognition',
#  'spring-mvc',
#  'prometheus-exporter',
#  'data-augmentation',
#  'file-upload',
#  'mobile-development',
#  'bash-script',
#  'super-resolution',
#  'microservices-architecture',
#  'asp-net-core',
#  'image-analysis',
#  'support-vector-machines',
#  'intrusion-detection-system',
#  'remote-control',
#  'naive-bayes-classifier',
#  'spam-detection',
#  'adversarial-attacks',
#  'aws-security',
#  'natural-language-understanding',
#  'multi-object-tracking',
#  'web-components',
#  'time-series',
#  'time-series-analysis',
#  '3d-printing',
#  '3d-detection',
#  'cordova-plugin',
#  'path-planning',
#  'tensorflow-models',
#  'ssd-mobilenet',
#  'high-availability',
#  'social-media',
#  'edge-detection',
#  'api-rest',
#  'motion-detection',
#  'voice-activity-detection',
#  'ci-cd',
#  'sample-code',
#  'spring-security',
#  'apache-spark',
#  'optical-flow',
#  'single-cell',
#  'raspberry-pi-4',
#  'speech-to-text',
#  'create-react-app',
#  'monitoring-tool',
#  'push-notifications',
#  'resnet-50',
#  'graph-neural-networks',
#  'covid-19',
#  'api-client',
#  'blockchain-technology',
#  'beginner-friendly',
#  'support-vector-machine',
#  'topic-modeling',
#  'easy-to-use',
#  'image-manipulation',
#  'intrusion-detection',
#  'ros-kinetic',
#  'reverse-shell',
#  'aws-cloudformation',
#  'pytorch-implementation',
#  'language-detection',
#  'haar-cascade-classifier',
#  'cyber-threat-intelligence',
#  'ios-app',
#  'discord-py',
#  'kali-linux',
#  'salient-object-detection',
#  'credit-card',
#  'kaggle-competition',
#  'labeling-tool',
#  'hacktoberfest-accepted',
#  'final-year-project',
#  'reference-implementation',
#  'edge-ai',
#  'live-demo',
#  'spring-data-jpa',
#  'python-library',
#  'canny-edge-detection',
#  'face-alignment',
#  'knowledge-graph',
#  'syntax-highlighting',
#  'http-server',
#  'command-line-tool',
#  '3d-reconstruction',
#  'embedded-systems',
#  'ctf-tools',
#  'shell-script',
#  'bioinformatics-pipeline',
#  'pattern-recognition',
#  'mitre-attack',
#  'digital-forensics',
#  'design-system',
#  'http-client',
#  'explainable-ai',
#  'distributed-tracing',
#  'aws-ec2',
#  'physics-engine',
#  'android-app',
#  'recommender-system',
#  'medical-image-processing',
#  'medical-image-analysis',
#  'cloud-computing',
#  'web-security',
#  'mobile-app',
#  'ios-swift',
#  'amazon-web-services',
#  'social-network',
#  'programming-language',
#  'design-patterns',
#  'few-shot-learning',
#  'mask-detection',
#  'text-to-speech',
#  'image-captioning',
#  'emotion-recognition',
#  'ruby-on-rails',
#  'discord-js',
#  'exploratory-data-analysis',
#  'adversarial-machine-learning',
#  'tesseract-ocr',
#  'feature-extraction',
#  'uptime-monitor',
#  'c-sharp',
#  'haar-cascade',
#  'gpt-3',
#  'cloud-native',
#  'ctf-writeups',
#  'gesture-recognition',
#  'esp32-arduino',
#  'incident-management',
#  'cnn-model',
#  'serverless-framework',
#  'continuous-delivery',
#  'keypoint-detection',
#  'r-package',
#  'elk-stack',
#  'kubernetes-operator',
#  'kubernetes-deployment',
#  'json-schema',
#  'pedestrian-detection',
#  'iot-application',
#  'application-security',
#  'paper-list',
#  'java-8',
#  'docker-swarm',
#  'package-manager',
#  'competitive-programming',
#  'html-css-javascript',
#  'web-application',
#  'grafana-dashboard',
#  'component-library',
#  'kmeans-clustering',
#  'ctf-challenges',
#  'flash-messages',
#  'unit-testing',
#  'ddos-attacks',
#  'esp8266-arduino',
#  'threat-analysis',
#  'log-analysis',
#  'game-engine',
#  'aws-s3',
#  'visual-studio',
#  'phishing-detection',
#  'testing-tools',
#  'speech-processing',
#  'voice-assistant',
#  'hog-features',
#  'powershell-script',
#  'camera-calibration',
#  'cognitive-services',
#  'configuration-management',
#  'travis-ci',
#  'status-page',
#  'artificial-neural-networks',
#  'machine-vision',
#  'feature-detection',
#  'google-colab',
#  'stable-diffusion',
#  'information-retrieval',
#  'fake-news-detection',
#  'browser-extension',
#  'computer-graphics',
#  'representation-learning',
#  'large-language-models',
#  'mysql-database',
#  'background-subtraction',
#  'code-generation',
#  'binary-analysis',
#  'flutter-apps',
#  'penetration-testing-tools',
#  'feature-engineering',
#  'access-control',
#  'selenium-webdriver',
#  'low-code',
#  'awesome-resources',
#  'saliency-detection',
#  'awesome-readme',
#  'forensics-investigations',
#  'homebridge-plugin',
#  'unet-image-segmentation',
#  'heroku-deployment',
#  'react-components',
#  'classification-algorithm',
#  'no-dependencies',
#  'jwt-authentication',
#  'earth-observation',
#  'pentesting-tools',
#  'mit-license']

# %%
len(topics)
# Out:
# 1659

# %%
len(topic_composite)
# Out:
# 538

# %%
# we combine split words to not loose any information
topics_combined = []
for t in topics:
    newt = ''.join(t.split('-'))
    if newt not in topics_combined:
        topics_combined.append(newt)

# %%
# this operation is very intense, run it only once
def clean_readme():
    readme_clean=[]
    for i in github_data_df[['name', 'readme']].itertuples(index=False, name=None):
        try:
            readme_clean.append(clean_text(markdown_to_text(i[1])))
        except Exception as e:
            print(f'{i[0]} has readme f{i[1]}')
            print(e)
            readme_clean.append(np.nan)

    github_data_df['readme_clean'] = readme_clean
    
    to_disk(github_data_df, 'init')

# %%
len(github_data_df[github_data_df['readme_clean'].str.len()>0])
# Out:
# 218425

# %%
len(github_data_df[github_data_df['readme'].str.len()>0])
# Out:
# 219518

# %% [markdown]
# ## Testset 1 (D_T1)
#    * in: name, topics (as list)
#    * out: name, topics (as string)
#    * All Github Data with topics

# %%
topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(x))

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 93053

# %%
to_disk(github_data_wtopic, 't1')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.pkl

# %%
from collections import Counter
word_cnt_t1 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1.update(t.split(' '))


word_cnt_t1.most_common()
# Out:
# [('python', 6323),
#  ('deep-learning', 4953),
#  ('machine-learning', 4521),
#  ('computer-vision', 2953),
#  ('javascript', 2744),
#  ('security', 2656),
#  ('object-detection', 2569),
#  ('pytorch', 2166),
#  ('tensorflow', 2123),
#  ('opencv', 2042),
#  ('hacktoberfest', 2010),
#  ('android', 1676),
#  ('python3', 1660),
#  ('docker', 1656),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1273),
#  ('aws', 1264),
#  ('golang', 1251),
#  ('kubernetes', 1223),
#  ('awesome-list', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('monitoring', 1126),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('image-processing', 986),
#  ('typescript', 971),
#  ('face-detection', 939),
#  ('keras', 871),
#  ('windows', 848),
#  ('nlp', 823),
#  ('api', 800),
#  ('go', 782),
#  ('data-science', 756),
#  ('artificial-intelligence', 733),
#  ('swift', 721),
#  ('convolutional-neural-networks', 704),
#  ('cybersecurity', 694),
#  ('anomaly-detection', 685),
#  ('cnn', 683),
#  ('ai', 672),
#  ('cpp', 660),
#  ('security-tools', 653),
#  ('neural-network', 648),
#  ('automation', 637),
#  ('raspberry-pi', 635),
#  ('face-recognition', 626),
#  ('terraform', 615),
#  ('prometheus', 600),
#  ('dataset', 594),
#  ('azure', 584),
#  ('iot', 580),
#  ('natural-language-processing', 576),
#  ('hacking', 576),
#  ('html', 575),
#  ('rust', 561),
#  ('yolo', 557),
#  ('flask', 547),
#  ('macos', 546),
#  ('deep-neural-networks', 535),
#  ('blockchain', 535),
#  ('css', 527),
#  ('classification', 526),
#  ('reactjs', 519),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 499),
#  ('bot', 498),
#  ('c', 467),
#  ('cli', 464),
#  ('react-native', 463),
#  ('cryptography', 461),
#  ('yolov3', 455),
#  ('opencv-python', 453),
#  ('segmentation', 452),
#  ('csharp', 448),
#  ('open-source', 445),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 430),
#  ('vue', 427),
#  ('spring-boot', 415),
#  ('cloud', 409),
#  ('library', 409),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('image-classification', 404),
#  ('django', 403),
#  ('database', 398),
#  ('game', 394),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('alert', 372),
#  ('ruby', 371),
#  ('cryptocurrency', 370),
#  ('web', 367),
#  ('mongodb', 366),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('neural-networks', 352),
#  ('ocr', 349),
#  ('deeplearning', 347),
#  ('elasticsearch', 342),
#  ('matlab', 334),
#  ('penetration-testing', 333),
#  ('ansible', 330),
#  ('yolov5', 330),
#  ('plugin', 328),
#  ('postgresql', 328),
#  ('bootstrap', 323),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('mysql', 317),
#  ('discord', 316),
#  ('metrics', 315),
#  ('covid-19', 315),
#  ('rest-api', 314),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('reverse-engineering', 309),
#  ('malware-analysis', 308),
#  ('json', 308),
#  ('notifications', 304),
#  ('threat-hunting', 303),
#  ('jupyter-notebook', 302),
#  ('r', 302),
#  ('home-assistant', 301),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('bugbounty', 297),
#  ('threat-intelligence', 297),
#  ('framework', 295),
#  ('incident-response', 291),
#  ('github', 286),
#  ('audio', 284),
#  ('dotnet', 282),
#  ('antivirus', 281),
#  ('firebase', 278),
#  ('time-series', 277),
#  ('osint', 275),
#  ('network', 274),
#  ('docker-compose', 273),
#  ('sql', 273),
#  ('real-time', 272),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('bash', 266),
#  ('transfer-learning', 261),
#  ('visualization', 259),
#  ('c-plus-plus', 258),
#  ('dfir', 257),
#  ('semantic-segmentation', 256),
#  ('encryption', 256),
#  ('html5', 252),
#  ('testing', 252),
#  ('tracking', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 247),
#  ('gui', 245),
#  ('autonomous-driving', 245),
#  ('unity', 244),
#  ('microservices', 243),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('tools', 240),
#  ('lstm', 239),
#  ('list', 238),
#  ('ui', 238),
#  ('redis', 237),
#  ('jquery', 237),
#  ('data-analysis', 235),
#  ('logging', 233),
#  ('algorithms', 231),
#  ('js', 231),
#  ('aws-lambda', 230),
#  ('networking', 229),
#  ('pose-estimation', 226),
#  ('http', 225),
#  ('vuejs', 223),
#  ('alerting', 222),
#  ('home-automation', 221),
#  ('sdk', 220),
#  ('machine-learning-algorithms', 218),
#  ('keras-tensorflow', 217),
#  ('game-development', 217),
#  ('self-driving-car', 214),
#  ('authentication', 209),
#  ('containers', 208),
#  ('tensorflow2', 208),
#  ('ml', 207),
#  ('data-visualization', 206),
#  ('redux', 204),
#  ('clustering', 204),
#  ('scikit-learn', 203),
#  ('telegram-bot', 202),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('image-segmentation', 200),
#  ('dart', 199),
#  ('git', 199),
#  ('paper', 198),
#  ('faster-rcnn', 198),
#  ('scanner', 197),
#  ('spark', 196),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('unsupervised-learning', 194),
#  ('point-cloud', 194),
#  ('ids', 194),
#  ('data', 192),
#  ('transformer', 191),
#  ('express', 191),
#  ('slack', 190),
#  ('mobile', 190),
#  ('graph', 189),
#  ('yolov4', 187),
#  ('github-actions', 187),
#  ('pandas', 186),
#  ('remote-sensing', 186),
#  ('analytics', 186),
#  ('image', 185),
#  ('malware-detection', 184),
#  ('esp8266', 183),
#  ('redteam', 183),
#  ('rest', 183),
#  ('reinforcement-learning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentiment-analysis', 182),
#  ('objective-c', 181),
#  ('slam', 181),
#  ('face', 180),
#  ('image-recognition', 179),
#  ('speech-recognition', 179),
#  ('observability', 179),
#  ('instance-segmentation', 178),
#  ('darknet', 178),
#  ('graphql', 177),
#  ('cross-platform', 177),
#  ('dns', 177),
#  ('resources', 176),
#  ('lidar', 175),
#  ('exploit', 175),
#  ('discord-bot', 174),
#  ('server', 174),
#  ('spring', 174),
#  ('chatgpt', 174),
#  ('chrome-extension', 173),
#  ('devsecops', 173),
#  ('static-analysis', 172),
#  ('yara', 172),
#  ('twitter', 172),
#  ('frontend', 171),
#  ('vulnerability', 171),
#  ('webapp', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('lane-detection', 167),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('data-mining', 165),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('tool', 164),
#  ('opensource', 164),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('medical-imaging', 160),
#  ('signal-processing', 160),
#  ('gan', 160),
#  ('template', 159),
#  ('electron', 159),
#  ('scala', 159),
#  ('chatbot', 159),
#  ('object-tracking', 158),
#  ('autonomous-vehicles', 158),
#  ('security-audit', 158),
#  ('cuda', 157),
#  ('wifi', 156),
#  ('ssd', 156),
#  ('random-forest', 156),
#  ('android-application', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('opengl', 155),
#  ('learning', 154),
#  ('monitor', 154),
#  ('browser', 154),
#  ('homeassistant', 153),
#  ('malware-research', 153),
#  ('trading', 152),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('microservice', 152),
#  ('network-analysis', 151),
#  ('docker-image', 151),
#  ('wordpress-plugin', 150),
#  ('terminal', 150),
#  ('outlier-detection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('onnx', 147),
#  ('email', 147),
#  ('smart-contracts', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('text-classification', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('3d', 146),
#  ('apple', 145),
#  ('selenium', 145),
#  ('machinelearning', 144),
#  ('rails', 144),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('alerts', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('edge-detection', 142),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('fraud-detection', 141),
#  ('css3', 140),
#  ('streaming', 140),
#  ('unity3d', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('intrusion-detection', 138),
#  ('siem', 137),
#  ('generative-adversarial-network', 137),
#  ('phishing', 137),
#  ('game-engine', 137),
#  ('deployment', 136),
#  ('inference', 136),
#  ('cloud-native', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('threatintel', 135),
#  ('heroku', 134),
#  ('command-line', 134),
#  ('realtime', 134),
#  ('swiftui', 134),
#  ('dlib', 134),
#  ('mask-rcnn', 133),
#  ('hacking-tool', 133),
#  ('nlp-machine-learning', 133),
#  ('vision', 132),
#  ('video-processing', 132),
#  ('terraform-module', 132),
#  ('openapi', 131),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('websocket', 130),
#  ('data-structures', 130),
#  ('vscode', 130),
#  ('tailwindcss', 129),
#  ('android-library', 129),
#  ('backup', 129),
#  ('augmented-reality', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheus-exporter', 128),
#  ('alertmanager', 127),
#  ('recognition', 127),
#  ('boilerplate', 126),
#  ('chrome', 126),
#  ('c-sharp', 126),
#  ('hack', 125),
#  ('cyber-security', 125),
#  ('embedded', 125),
#  ('papers', 124),
#  ('blueteam', 124),
#  ('webrtc', 124),
#  ('3d-object-detection', 124),
#  ('benchmark', 123),
#  ('npm', 123),
#  ('client', 123),
#  ('app', 122),
#  ('vim', 122),
#  ('infrastructure', 122),
#  ('cnn-keras', 121),
#  ('expressjs', 121),
#  ('openai', 121),
#  ('ssl', 121),
#  ('distributed-systems', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('jenkins', 120),
#  ('vulnerability-detection', 120),
#  ('tls', 120),
#  ('demo', 120),
#  ('kibana', 119),
#  ('workflow', 119),
#  ('self-supervised-learning', 119),
#  ('graph-neural-networks', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('feature-extraction', 118),
#  ('language', 117),
#  ('bootstrap4', 117),
#  ('web3', 117),
#  ('mediapipe', 116),
#  ('vpn', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('text-detection', 115),
#  ('resnet', 115),
#  ('mlops', 115),
#  ('optimization', 114),
#  ('material-design', 114),
#  ('module', 114),
#  ('programming', 114),
#  ('backend', 114),
#  ('emotion-recognition', 114),
#  ('developer-tools', 113),
#  ('uptime-monitor', 113),
#  ('sklearn', 112),
#  ('bluetooth', 111),
#  ('education', 111),
#  ('dotnet-core', 110),
#  ('autoencoder', 110),
#  ('crawler', 110),
#  ('self-hosted', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfest-accepted', 110),
#  ('streamlit', 109),
#  ('compliance', 109),
#  ('awesome-lists', 109),
#  ('google-cloud', 108),
#  ('spring-cloud', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('hardware', 107),
#  ('cluster', 107),
#  ('translation', 107),
#  ('python-3', 107),
#  ('big-data', 107),
#  ('security-automation', 107),
#  ('windows-10', 107),
#  ('rnn', 106),
#  ('change-detection', 106),
#  ('vulnerabilities', 106),
#  ('community-detection', 105),
#  ('finance', 105),
#  ('gamedev', 105),
#  ('tensorflow-lite', 105),
#  ('pwa', 105),
#  ('webassembly', 105),
#  ('vscode-extension', 105),
#  ('sqlite', 105),
#  ('terraform-modules', 105),
#  ('intel', 105),
#  ('cplusplus', 104),
#  ('network-security', 104),
#  ('vulnerability-scanners', 104),
#  ('collision-detection', 104),
#  ('android-app', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('red-team', 103),
#  ('arduino-library', 103),
#  ('pretrained-models', 103),
#  ('animation', 102),
#  ('vehicle-detection', 102),
#  ('edge-computing', 102),
#  ('push-notifications', 102),
#  ('csv', 101),
#  ('logistic-regression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('best-practices', 101),
#  ('genomics', 101),
#  ('raspberrypi', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('status-page', 101),
#  ('computer-science', 100),
#  ('node-js', 100),
#  ('script', 100),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('search', 99),
#  ('emotion-detection', 99),
#  ('postgres', 99),
#  ('spring-security', 99),
#  ('command-line-tool', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('fastapi', 98),
#  ('satellite-imagery', 97),
#  ('audio-processing', 97),
#  ('cnn-classification', 97),
#  ('infrastructure-as-code', 96),
#  ('tensorflowjs', 96),
#  ('project', 96),
#  ('owasp', 96),
#  ('hacktoberfest2021', 96),
#  ('digital-forensics', 96),
#  ('openshift', 95),
#  ('kotlin-android', 95),
#  ('cocoapods', 95),
#  ('edge', 95),
#  ('nmap', 95),
#  ('smarthome', 95),
#  ('theme', 94),
#  ('validation', 94),
#  ('svm-classifier', 94),
#  ('ui-components', 94),
#  ('mobilenet', 94),
#  ('influxdb', 94),
#  ('interview-questions', 94),
#  ('regression', 93),
#  ('hacking-tools', 93),
#  ('physics', 93),
#  ('hacktoberfest2020', 93),
#  ('async', 93),
#  ('tflite', 93),
#  ('speech', 92),
#  ('imagenet', 92),
#  ('material-ui', 92),
#  ('cv', 92),
#  ('websockets', 92),
#  ('chat', 92),
#  ('google-cloud-platform', 91),
#  ('sass', 91),
#  ('api-gateway', 91),
#  ('gitops', 91),
#  ('api-client', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentest-tool', 90),
#  ('audit', 90),
#  ('yolov2', 90),
#  ('games', 90),
#  ('scraper', 90),
#  ('rstats', 90),
#  ('speech-to-text', 90),
#  ('kali-linux', 90),
#  ('hacktoberfest2022', 90),
#  ('supervised-learning', 89),
#  ('container', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attention-mechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('pytorch-implementation', 88),
#  ('firefox', 88),
#  ('covid19', 88),
#  ('cloudformation', 88),
#  ('tcp', 88),
#  ('coursera', 87),
#  ('wallet', 87),
#  ('motion-detection', 87),
#  ('svelte', 87),
#  ('mitre-attack', 87),
#  ('aws-s3', 87),
#  ('amazon', 86),
#  ('human-pose-estimation', 86),
#  ('middleware', 86),
#  ('xml', 86),
#  ('ecommerce', 86),
#  ('network-monitoring', 86),
#  ('cheatsheet', 86),
#  ('trading-bot', 86),
#  ('bug-bounty', 86),
#  ('security-scanner', 86),
#  ('binance', 86),
#  ('interview', 86),
#  ('bash-script', 86),
#  ('image-analysis', 86),
#  ('coco', 86),
#  ('zabbix', 86),
#  ('grpc', 85),
#  ('clojure', 85),
#  ('honeypot', 85),
#  ('p2p', 85),
#  ('package', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('restful-api', 84),
#  ('extension', 84),
#  ('recurrent-neural-networks', 84),
#  ('filesystem', 84),
#  ('healthcare', 84),
#  ('ctf-writeups', 84),
#  ('cicd', 84),
#  ('uikit', 83),
#  ('springboot', 83),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('information-security', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flask-application', 82),
#  ('webcam', 82),
#  ('i18n', 82),
#  ('guide', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('lightweight', 82),
#  ('blog', 82),
#  ('artificial-neural-networks', 82),
#  ('bypass', 81),
#  ('unet', 81),
#  ('continuous-integration', 81),
#  ('maven', 81),
#  ('mobilenetv2', 81),
#  ('javascript-library', 81),
#  ('logger', 81),
#  ('monitoring-tool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('log', 80),
#  ('development', 80),
#  ('application', 80),
#  ('datascience', 80),
#  ('perl', 80),
#  ('pyqt5', 80),
#  ('gps', 80),
#  ('stream', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graph-algorithms', 79),
#  ('php7', 79),
#  ('attack', 79),
#  ('popup', 79),
#  ('nvidia', 79),
#  ('action-recognition', 79),
#  ('toast', 79),
#  ('language-detection', 79),
#  ('tutorials', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('python-script', 78),
#  ('obfuscation', 78),
#  ('hooks', 78),
#  ('time-series-analysis', 78),
#  ('sms', 78),
#  ('web-application', 78),
#  ('retinanet', 78),
#  ('convolutional-neural-network', 77),
#  ('jetson-nano', 77),
#  ('text-recognition', 77),
#  ('compiler', 77),
#  ('intrusion-detection-system', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('example', 76),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('xgboost', 76),
#  ('python-library', 76),
#  ('ransomware', 75),
#  ('facial-recognition', 75),
#  ('forensic-analysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('data-engineering', 75),
#  ('gplv3', 75),
#  ('coreml', 75),
#  ('cloud-computing', 75),
#  ('suricata', 75),
#  ('training', 75),
#  ('internet-of-things', 74),
#  ('debugging', 74),
#  ('raspberry-pi-3', 74),
#  ('osx', 74),
#  ('editor', 74),
#  ('cache', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('backdoor', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('logs', 73),
#  ('distributed', 73),
#  ('prediction', 73),
#  ('ble', 73),
#  ('npm-package', 73),
#  ('pcap', 73),
#  ('linear-regression', 72),
#  ('yara-rules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('blue-team', 72),
#  ('messaging', 72),
#  ('gpt', 72),
#  ('security-hardening', 72),
#  ('data-augmentation', 72),
#  ('adversarial-attacks', 72),
#  ('programming-language', 72),
#  ('html-css-javascript', 72),
#  ('ajax', 71),
#  ('cti', 71),
#  ('filter', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('mac', 71),
#  ('https', 71),
#  ('llm', 71),
#  ('lidar-point-cloud', 71),
#  ('timeseries', 71),
#  ('cyber-threat-intelligence', 71),
#  ('cpu', 71),
#  ('3d-reconstruction', 71),
#  ('scss', 70),
#  ('sandbox', 70),
#  ('management', 70),
#  ('vision-transformer', 70),
#  ('integration', 70),
#  ('software-engineering', 70),
#  ('stm32', 70),
#  ('jquery-plugin', 70),
#  ('search-engine', 70),
#  ('defi', 70),
#  ('kalman-filter', 70),
#  ('salient-object-detection', 70),
#  ('aws-ec2', 70),
#  ('virus', 70),
#  ('semi-supervised-learning', 69),
#  ('crud', 69),
#  ('test', 69),
#  ('clean-architecture', 69),
#  ('angularjs', 69),
#  ('cms', 69),
#  ('ec2', 69),
#  ('angular2', 69),
#  ('apache', 69),
#  ('radar', 69),
#  ('threejs', 69),
#  ('hash', 69),
#  ('jest', 69),
#  ('offensive-security', 68),
#  ('notes', 68),
#  ('fake-news', 68),
#  ('vault', 68),
#  ('domain-adaptation', 68),
#  ('federated-learning', 68),
#  ('svg', 68),
#  ('operating-system', 68),
#  ('oracle', 68),
#  ('multi-object-tracking', 68),
#  ('ionic', 68),
#  ('facebook', 68),
#  ('vue3', 68),
#  ('amazon-web-services', 68),
#  ('iobroker', 68),
#  ('scraping', 68),
#  ('mongoose', 67),
#  ('ioc', 67),
#  ('bounding-boxes', 67),
#  ('stream-processing', 67),
#  ('graphics', 67),
#  ('virtual-machine', 67),
#  ('drone', 67),
#  ('qt5', 67),
#  ('wrapper', 67),
#  ('utility', 67),
#  ('events', 67),
#  ('facenet', 67),
#  ('widget', 67),
#  ('trojan', 66),
#  ('engine', 66),
#  ('antivirus-evasion', 66),
#  ('etl', 66),
#  ('orm', 66),
#  ('android-development', 66),
#  ('home-assistant-config', 66),
#  ('vgg16', 66),
#  ('emulator', 66),
#  ('rat', 66),
#  ('node-red', 66),
#  ('azure-functions', 66),
#  ('form', 66),
#  ('tracing', 66),
#  ('unix', 66),
#  ('face-alignment', 66),
#  ('configuration', 66),
#  ('navigation', 66),
#  ('software', 66),
#  ('simulator', 66),
#  ('mapping', 65),
#  ('kubernetes-cluster', 65),
#  ('cpp17', 65),
#  ('gateway', 65),
#  ('admin-dashboard', 65),
#  ('collection', 65),
#  ('sdr', 65),
#  ('ethical-hacking', 65),
#  ('embedded-systems', 65),
#  ('pedestrian-detection', 65),
#  ('fast', 64),
#  ('ansible-role', 64),
#  ('gis', 64),
#  ('steganography', 64),
#  ('lists', 64),
#  ('sensor-fusion', 64),
#  ('face-tracking', 64),
#  ('system', 64),
#  ('ios-app', 64),
#  ('forecasting', 64),
#  ('neovim', 64),
#  ('ocr-recognition', 63),
#  ('smart-home', 63),
#  ('community', 63),
#  ('composer', 63),
#  ('cisco', 63),
#  ('bluetooth-low-energy', 63),
#  ('android-studio', 63),
#  ('radio', 63),
#  ('object-recognition', 63),
#  ('tesseract', 63),
#  ('testing-tools', 63),
#  ('smtp', 62),
#  ('active-directory', 62),
#  ('ebpf', 62),
#  ('cdk', 62),
#  ('multithreading', 62),
#  ('interview-preparation', 62),
#  ('usb', 62),
#  ('voice-activity-detection', 62),
#  ('eeg', 62),
#  ('sre', 62),
#  ('text-to-speech', 62),
#  ('service', 62),
#  ('chess', 62),
#  ('cnn-model', 62),
#  ('verilog', 62),
#  ('keyboard', 62),
#  ('cheat', 62),
#  ('pentesting-tools', 62),
#  ('config', 61),
#  ('javafx', 61),
#  ('nosql', 61),
#  ('fingerprint', 61),
#  ('docker-container', 61),
#  ('waf', 61),
#  ('linter', 61),
#  ('mvvm', 61),
#  ('facial-landmarks', 61),
#  ('actions', 61),
#  ('automl', 61),
#  ('react-router', 61),
#  ('face-mask-detection', 61),
#  ('jetson', 61),
#  ('apns', 61),
#  ('kaggle-competition', 61),
#  ('edge-ai', 61),
#  ('virtualization', 61),
#  ('attention', 61),
#  ('productivity', 61),
#  ('protection', 61),
#  ('wireless', 60),
#  ('hardening', 60),
#  ('sensors', 60),
#  ('arkit', 60),
#  ('telemetry', 60),
#  ('deprecated', 60),
#  ('sagemaker', 60),
#  ('memory', 60),
#  ('text-mining', 60),
#  ('osquery', 60),
#  ('linux-kernel', 60),
#  ('rust-lang', 60),
#  ('rna-seq', 60),
#  ('annotations', 60),
#  ('cordova-plugin', 60),
#  ('syntax-highlighting', 60),
#  ('tkinter', 60),
#  ('explainable-ai', 60),
#  ('voice', 60),
#  ('social-network', 60),
#  ('haar-cascade', 60),
#  ('news', 60),
#  ('emotion', 60),
#  ('react-components', 60),
#  ('enumeration', 59),
#  ('redteaming', 59),
#  ('hackintosh', 59),
#  ('tensorflow-object-detection-api', 59),
#  ('agent', 59),
#  ('devops-tools', 59),
#  ('information-gathering', 59),
#  ('bypass-antivirus', 59),
#  ('native', 59),
#  ('eks', 59),
#  ('asp-net-core', 59),
#  ('clamav', 59),
#  ('dockerfile', 59),
#  ('survey', 59),
#  ('md', 59),
#  ('books', 59),
#  ('mask-detection', 59),
#  ('puppet', 59),
#  ('forms', 59),
#  ('cassandra', 59),
#  ('ddos', 59),
#  ('iac', 59),
#  ('portfolio', 59),
#  ('udp', 59),
#  ('mvc', 58),
#  ('web-development', 58),
#  ('graphs', 58),
#  ('iphone', 58),
#  ('socket-io', 58),
#  ('operator', 58),
#  ('lstm-neural-networks', 58),
#  ('stock-market', 58),
#  ('letsencrypt', 58),
#  ('ensemble-learning', 58),
#  ('instagram', 58),
#  ('tracker', 58),
#  ('gitlab', 58),
#  ('ci-cd', 58),
#  ('vagrant', 58),
#  ('salesforce', 58),
#  ('r-package', 58),
#  ('pca', 58),
#  ('cpp11', 58),
#  ('browser-extension', 58),
#  ('opencv3', 57),
#  ('regex', 57),
#  ('consul', 57),
#  ('geolocation', 57),
#  ('mining', 57),
#  ('scanning', 57),
#  ('computervision', 57),
#  ('shell-script', 57),
#  ('alarm', 57),
#  ('medical-image-processing', 57),
#  ('neo4j', 57),
#  ('compression', 57),
#  ('cvpr', 57),
#  ('feature-engineering', 57),
#  ('test-automation', 56),
#  ('science', 56),
#  ('airflow', 56),
#  ('weakly-supervised-learning', 56),
#  ('cv2', 56),
#  ('encoding', 56),
#  ('pyspark', 56),
#  ('sample', 56),
#  ('cloud-security', 56),
#  ('chart', 56),
#  ('named-entity-recognition', 56),
#  ('react-hooks', 56),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 1.1
#    * in: name, topics
#    * out: name, topics(preprocessed, lemmatized)

# %%
sgf.topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(preprocess_text(' '.join(x), lem=True)))

# %%
Counter(sgf.topics_removed).most_common()
# Out:
# [('of', 661),
#  ('to', 578),
#  ('and', 335),
#  ('in', 232),
#  ('for', 228),
#  ('as', 187),
#  ('the', 167),
#  ('on', 155),
#  ('by', 122),
#  ('no', 109),
#  ('few', 103),
#  ('out', 83),
#  ('only', 79),
#  ('a', 64),
#  ('over', 59),
#  ('d', 58),
#  ('re', 57),
#  ('with', 55),
#  ('from', 42),
#  ('t', 36),
#  ('up', 34),
#  ('can', 32),
#  ('it', 32),
#  ('m', 30),
#  ('at', 28),
#  ('all', 24),
#  ('doing', 24),
#  ('i', 23),
#  ('your', 23),
#  ('s', 22),
#  ('now', 19),
#  ('how', 18),
#  ('me', 17),
#  ('not', 17),
#  ('is', 17),
#  ('my', 17),
#  ('after', 14),
#  ('do', 14),
#  ('you', 13),
#  ('off', 11),
#  ('o', 11),
#  ('down', 11),
#  ('ve', 9),
#  ('did', 9),
#  ('other', 9),
#  ('this', 8),
#  ('about', 7),
#  ('who', 7),
#  ('once', 6),
#  ('be', 5),
#  ('under', 5),
#  ('here', 5),
#  ('any', 5),
#  ('an', 5),
#  ('have', 4),
#  ('been', 4),
#  ('own', 4),
#  ('will', 4),
#  ('just', 4),
#  ('through', 3),
#  ('same', 3),
#  ('if', 3),
#  ('what', 3),
#  ('into', 2),
#  ('while', 2),
#  ('then', 2),
#  ('he', 2),
#  ('myself', 2),
#  ('more', 2),
#  ('against', 2),
#  ('am', 2),
#  ('its', 2),
#  ('very', 2),
#  ('between', 2),
#  ('ll', 1),
#  ('nor', 1),
#  ('y', 1),
#  ('we', 1),
#  ('isn', 1),
#  ('haven', 1),
#  ('ain', 1),
#  ('too', 1),
#  ('ma', 1),
#  ('when', 1),
#  ('does', 1),
#  ('some', 1),
#  ('has', 1),
#  ('so', 1),
#  ('why', 1)]

# %%
github_data_wtopic
# Out:
#                                           name  \
# 6               thingsym/multi-device-switcher
# 8       redlink-gmbh/solr-compound-word-filter
# 9         xswlme/Delivery-Availability-Checker
# 10                    eastsss/ErrorDispatching
# 11                       ahmadhuzaifa/skinskan
# ...                                        ...
# 221952                   waqasbhatti/astrobase
# 221955                 hpcc-systems/vscode-ecl
# 221965                   MarcoPon/BlockHashLoc
# 221966           bhagatabhijeet/bhagatabhijeet
# 221967           LandGrey/SpringBootVulExploit
#
#                                                    topics
# 6                              wordpress wordpress plugin
# 8                    solr lucene lucene analyzer language
# 9       amazon chrome extension food delivery grocery ...
# 10      swift ios error handle custom chain responsibi...
# 11      cnn cnn keras skin cancer tensorflow ai machin...
# ...                                                   ...
# 221952         light curve astronomy python variable star
# 221955                vscode typescript ecl hpcc platform
# 221965  bhl recovery hash block metadata undelete unfo...
# 221966  bhagatabhijeet abhijeetbhagat abhijeet bhagat ...
# 221967  springboot springboot actuator rce rce spring ...
#
# [69817 rows x 2 columns]

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 43131

# %%
to_disk(github_data_wtopic, 't1.1')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.1.pkl

# %%
from collections import Counter
word_cnt_t1_1 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1_1.update(t.split(' '))


word_cnt_t1_1.most_common()
# Out:
# [('detection', 13503),
#  ('learn', 13192),
#  ('python', 7897),
#  ('deep', 6053),
#  ('machine', 5861),
#  ('security', 5645),
#  ('network', 5319),
#  ('image', 4566),
#  ('data', 4467),
#  ('object', 3839),
#  ('api', 3718),
#  ('vision', 3611),
#  ('computer', 3399),
#  ('analysis', 3267),
#  ('javascript', 3218),
#  ('android', 3063),
#  ('neural', 3024),
#  ('tool', 3002),
#  ('face', 2934),
#  ('tensorflow', 2893),
#  ('recognition', 2801),
#  ('process', 2793),
#  ('react', 2770),
#  ('awesome', 2753),
#  ('opencv', 2686),
#  ('aws', 2554),
#  ('pytorch', 2516),
#  ('docker', 2462),
#  ('monitor', 2392),
#  ('cloud', 2160),
#  ('hacktoberfest', 2133),
#  ('model', 2017),
#  ('classification', 2012),
#  ('library', 1942),
#  ('plugin', 1902),
#  ('list', 1902),
#  ('java', 1869),
#  ('game', 1732),
#  ('language', 1707),
#  ('test', 1687),
#  ('python3', 1679),
#  ('kubernetes', 1672),
#  ('linux', 1633),
#  ('azure', 1627),
#  ('segmentation', 1614),
#  ('web', 1554),
#  ('bot', 1538),
#  ('server', 1483),
#  ('framework', 1475),
#  ('malware', 1439),
#  ('windows', 1400),
#  ('ios', 1396),
#  ('php', 1361),
#  ('golang', 1361),
#  ('nodejs', 1354),
#  ('automation', 1350),
#  ('keras', 1345),
#  ('hack', 1342),
#  ('intelligence', 1338),
#  ('video', 1304),
#  ('track', 1245),
#  ('ai', 1244),
#  ('dataset', 1219),
#  ('text', 1203),
#  ('spring', 1197),
#  ('code', 1189),
#  ('google', 1189),
#  ('c', 1176),
#  ('science', 1174),
#  ('graph', 1144),
#  ('nlp', 1124),
#  ('cnn', 1116),
#  ('application', 1104),
#  ('management', 1094),
#  ('database', 1077),
#  ('app', 1075),
#  ('service', 1056),
#  ('typescript', 1036),
#  ('terraform', 1033),
#  ('time', 1030),
#  ('alert', 1024),
#  ('script', 1018),
#  ('swift', 974),
#  ('algorithms', 972),
#  ('3d', 969),
#  ('threat', 963),
#  ('engine', 945),
#  ('system', 940),
#  ('iot', 934),
#  ('pi', 926),
#  ('ui', 921),
#  ('convolutional', 912),
#  ('raspberry', 911),
#  ('go', 899),
#  ('project', 898),
#  ('artificial', 895),
#  ('engineer', 881),
#  ('native', 879),
#  ('client', 874),
#  ('prometheus', 872),
#  ('program', 872),
#  ('cluster', 868),
#  ('anomaly', 855),
#  ('forensics', 846),
#  ('arduino', 843),
#  ('css', 841),
#  ('algorithm', 832),
#  ('open', 820),
#  ('home', 808),
#  ('discord', 807),
#  ('development', 807),
#  ('html', 806),
#  ('log', 793),
#  ('drive', 788),
#  ('flask', 776),
#  ('flutter', 776),
#  ('github', 763),
#  ('cpp', 754),
#  ('file', 752),
#  ('cybersecurity', 748),
#  ('extension', 744),
#  ('speech', 740),
#  ('stream', 738),
#  ('vue', 737),
#  ('audio', 733),
#  ('cli', 732),
#  ('vulnerability', 727),
#  ('attack', 724),
#  ('rest', 718),
#  ('camera', 714),
#  ('natural', 713),
#  ('estimation', 705),
#  ('rust', 694),
#  ('blockchain', 693),
#  ('design', 685),
#  ('js', 683),
#  ('source', 677),
#  ('angular', 676),
#  ('self', 672),
#  ('yolo', 670),
#  ('platform', 669),
#  ('laravel', 668),
#  ('devops', 659),
#  ('package', 657),
#  ('plus', 652),
#  ('sdk', 650),
#  ('node', 646),
#  ('scanner', 643),
#  ('search', 641),
#  ('feature', 629),
#  ('telegram', 621),
#  ('trade', 617),
#  ('module', 615),
#  ('edge', 610),
#  ('macos', 609),
#  ('paper', 603),
#  ('django', 602),
#  ('filter', 601),
#  ('kotlin', 598),
#  ('components', 587),
#  ('architecture', 586),
#  ('visualization', 584),
#  ('research', 578),
#  ('multi', 576),
#  ('ocr', 575),
#  ('action', 575),
#  ('template', 572),
#  ('cryptography', 572),
#  ('notifications', 565),
#  ('control', 559),
#  ('sql', 553),
#  ('wordpress', 551),
#  ('pose', 549),
#  ('assistant', 545),
#  ('series', 543),
#  ('privacy', 542),
#  ('ros', 535),
#  ('reactjs', 531),
#  ('boot', 529),
#  ('json', 529),
#  ('tutorial', 528),
#  ('autonomous', 528),
#  ('proxy', 526),
#  ('compute', 525),
#  ('mobile', 525),
#  ('pentesting', 524),
#  ('encryption', 520),
#  ('yolov3', 519),
#  ('ethereum', 518),
#  ('metrics', 514),
#  ('manager', 510),
#  ('generator', 506),
#  ('point', 505),
#  ('robotics', 504),
#  ('dashboard', 504),
#  ('ansible', 504),
#  ('analytics', 504),
#  ('kafka', 501),
#  ('systems', 493),
#  ('detector', 493),
#  ('ruby', 492),
#  ('firebase', 491),
#  ('lambda', 491),
#  ('map', 490),
#  ('component', 488),
#  ('reverse', 484),
#  ('csharp', 479),
#  ('interview', 477),
#  ('bootstrap', 474),
#  ('notebook', 470),
#  ('covid', 470),
#  ('grafana', 468),
#  ('ctf', 468),
#  ('shell', 465),
#  ('powershell', 462),
#  ('software', 459),
#  ('response', 457),
#  ('r', 456),
#  ('command', 456),
#  ('antivirus', 451),
#  ('supervise', 447),
#  ('line', 447),
#  ('penetration', 446),
#  ('classifier', 444),
#  ('serverless', 444),
#  ('information', 443),
#  ('jupyter', 443),
#  ('rcnn', 442),
#  ('amazon', 441),
#  ('dotnet', 440),
#  ('mine', 440),
#  ('remote', 440),
#  ('mysql', 436),
#  ('semantic', 435),
#  ('http', 435),
#  ('ml', 433),
#  ('incident', 433),
#  ('cryptocurrency', 433),
#  ('chrome', 432),
#  ('car', 429),
#  ('hunt', 429),
#  ('authentication', 427),
#  ('medical', 426),
#  ('matlab', 425),
#  ('mongodb', 423),
#  ('sensor', 421),
#  ('bitcoin', 420),
#  ('real', 418),
#  ('signal', 417),
#  ('visual', 416),
#  ('extraction', 416),
#  ('mask', 415),
#  ('pipeline', 412),
#  ('team', 412),
#  ('gui', 410),
#  ('browser', 407),
#  ('prediction', 404),
#  ('embed', 402),
#  ('music', 401),
#  ('smart', 401),
#  ('elasticsearch', 398),
#  ('adversarial', 396),
#  ('generation', 395),
#  ('theme', 395),
#  ('deeplearning', 394),
#  ('distribute', 393),
#  ('performance', 391),
#  ('parser', 390),
#  ('dns', 386),
#  ('lstm', 385),
#  ('tree', 384),
#  ('material', 384),
#  ('voice', 383),
#  ('simulation', 381),
#  ('transfer', 381),
#  ('cve', 380),
#  ('bash', 380),
#  ('pattern', 379),
#  ('storage', 379),
#  ('emotion', 379),
#  ('social', 378),
#  ('core', 377),
#  ('transformer', 377),
#  ('event', 376),
#  ('postgresql', 376),
#  ('digital', 375),
#  ('regression', 375),
#  ('osint', 374),
#  ('function', 374),
#  ('base', 374),
#  ('crypto', 365),
#  ('19', 364),
#  ('jquery', 362),
#  ('message', 360),
#  ('free', 359),
#  ('cross', 357),
#  ('audit', 356),
#  ('resources', 356),
#  ('scan', 356),
#  ('bugbounty', 355),
#  ('human', 354),
#  ('optimization', 353),
#  ('wifi', 353),
#  ('lane', 353),
#  ('unity', 351),
#  ('anti', 350),
#  ('microsoft', 350),
#  ('compose', 349),
#  ('yolov5', 349),
#  ('redux', 348),
#  ('net', 347),
#  ('bioinformatics', 345),
#  ('lidar', 343),
#  ('static', 339),
#  ('yara', 339),
#  ('virtual', 339),
#  ('microservices', 337),
#  ('inference', 337),
#  ('3', 336),
#  ('structure', 336),
#  ('cyber', 336),
#  ('traffic', 335),
#  ('redis', 335),
#  ('ip', 333),
#  ('esp32', 333),
#  ('motion', 333),
#  ('infosec', 331),
#  ('deployment', 330),
#  ('custom', 327),
#  ('form', 327),
#  ('email', 326),
#  ('sample', 324),
#  ('mqtt', 323),
#  ('xss', 323),
#  ('train', 323),
#  ('gateway', 322),
#  ('html5', 319),
#  ('configuration', 319),
#  ('password', 318),
#  ('kernel', 318),
#  ('facial', 316),
#  ('desktop', 315),
#  ('spark', 309),
#  ('label', 309),
#  ('website', 305),
#  ('sentiment', 304),
#  ('injection', 304),
#  ('admin', 304),
#  ('rule', 303),
#  ('protocol', 303),
#  ('tracker', 302),
#  ('minecraft', 302),
#  ('twitter', 302),
#  ('firewall', 302),
#  ('ssd', 301),
#  ('exploit', 299),
#  ('config', 298),
#  ('container', 298),
#  ('demo', 297),
#  ('pentest', 296),
#  ('infrastructure', 296),
#  ('slack', 295),
#  ('jwt', 292),
#  ('nginx', 290),
#  ('translation', 290),
#  ('community', 288),
#  ('random', 288),
#  ('page', 288),
#  ('memory', 286),
#  ('hook', 286),
#  ('end', 286),
#  ('detect', 285),
#  ('instance', 284),
#  ('question', 283),
#  ('bypass', 283),
#  ('generative', 283),
#  ('stack', 282),
#  ('editor', 282),
#  ('driver', 282),
#  ('vehicle', 281),
#  ('user', 280),
#  ('red', 280),
#  ('gpu', 280),
#  ('robot', 277),
#  ('physics', 277),
#  ('controller', 275),
#  ('dfir', 275),
#  ('attention', 275),
#  ('quality', 275),
#  ('intrusion', 273),
#  ('s3', 272),
#  ('svm', 271),
#  ('phishing', 270),
#  ('graphql', 269),
#  ('domain', 269),
#  ('vscode', 269),
#  ('dynamic', 268),
#  ('unsupervised', 268),
#  ('integration', 267),
#  ('reinforcement', 266),
#  ('cancer', 265),
#  ('agent', 265),
#  ('git', 265),
#  ('yolov4', 263),
#  ('forest', 263),
#  ('contract', 263),
#  ('report', 263),
#  ('fraud', 262),
#  ('numpy', 261),
#  ('exporter', 261),
#  ('developer', 260),
#  ('change', 259),
#  ('challenge', 258),
#  ('express', 257),
#  ('bluetooth', 255),
#  ('apps', 254),
#  ('notification', 254),
#  ('stock', 253),
#  ('studio', 253),
#  ('flow', 252),
#  ('device', 251),
#  ('news', 251),
#  ('swagger', 250),
#  ('realtime', 249),
#  ('esp8266', 248),
#  ('task', 248),
#  ('color', 247),
#  ('terminal', 246),
#  ('cod', 245),
#  ('backup', 245),
#  ('knowledge', 243),
#  ('shoot', 243),
#  ('protection', 242),
#  ('rail', 242),
#  ('jetson', 242),
#  ('documentation', 241),
#  ('weather', 241),
#  ('license', 240),
#  ('frontend', 240),
#  ('single', 240),
#  ('selenium', 240),
#  ('ids', 240),
#  ('dialog', 239),
#  ('slam', 238),
#  ('hardware', 238),
#  ('kaggle', 238),
#  ('localization', 238),
#  ('cordova', 238),
#  ('containers', 237),
#  ('lua', 237),
#  ('key', 236),
#  ('vuejs', 236),
#  ('card', 234),
#  ('hash', 234),
#  ('bug', 234),
#  ('scikit', 233),
#  ('host', 233),
#  ('darknet', 232),
#  ('sense', 232),
#  ('reality', 232),
#  ('practice', 231),
#  ('fingerprint', 231),
#  ('low', 231),
#  ('fake', 230),
#  ('ssh', 230),
#  ('plugins', 230),
#  ('markdown', 229),
#  ('light', 228),
#  ('faster', 228),
#  ('validation', 227),
#  ('sequence', 227),
#  ('datasets', 227),
#  ('apache', 227),
#  ('exploitation', 226),
#  ('health', 226),
#  ('chatgpt', 226),
#  ('apple', 226),
#  ('2d', 226),
#  ('router', 225),
#  ('graphics', 225),
#  ('resnet', 224),
#  ('k8s', 224),
#  ('ubuntu', 224),
#  ('chat', 224),
#  ('dart', 223),
#  ('support', 223),
#  ('modules', 222),
#  ('redteam', 221),
#  ('ci', 221),
#  ('annotation', 220),
#  ('certificate', 218),
#  ('forecast', 218),
#  ('sign', 218),
#  ('webapp', 217),
#  ('gpt', 217),
#  ('jenkins', 217),
#  ('npm', 217),
#  ('token', 217),
#  ('solidity', 216),
#  ('electron', 216),
#  ('tensorflow2', 216),
#  ('pandas', 216),
#  ('link', 215),
#  ('gin', 214),
#  ('high', 214),
#  ('ddos', 214),
#  ('vpn', 213),
#  ('udacity', 213),
#  ('media', 212),
#  ('mobilenet', 212),
#  ('ssl', 212),
#  ('market', 212),
#  ('workflow', 211),
#  ('boilerplate', 210),
#  ('cache', 210),
#  ('document', 209),
#  ('statistics', 208),
#  ('solutions', 208),
#  ('bert', 208),
#  ('hand', 208),
#  ('objective', 207),
#  ('binary', 206),
#  ('plate', 206),
#  ('youtube', 205),
#  ('helm', 205),
#  ('entity', 204),
#  ('profile', 204),
#  ('2', 203),
#  ('mod', 203),
#  ('chart', 203),
#  ('parse', 202),
#  ('box', 202),
#  ('modal', 202),
#  ('heroku', 201),
#  ('share', 201),
#  ('continuous', 201),
#  ('observability', 201),
#  ('backend', 200),
#  ('chatbot', 200),
#  ('wallet', 199),
#  ('match', 199),
#  ('tutorials', 198),
#  ('energy', 198),
#  ('state', 198),
#  ('online', 197),
#  ('activity', 196),
#  ('pdf', 196),
#  ('kit', 195),
#  ('examples', 195),
#  ('spam', 195),
#  ('openapi', 194),
#  ('check', 194),
#  ('discovery', 193),
#  ('distance', 193),
#  ('addon', 193),
#  ('4', 193),
#  ('auto', 193),
#  ('websocket', 192),
#  ('devsecops', 192),
#  ('vector', 192),
#  ('trace', 192),
#  ('tls', 192),
#  ('outlier', 191),
#  ('virus', 191),
#  ('push', 191),
#  ('microservice', 191),
#  ('homeassistant', 190),
#  ('cell', 190),
#  ('guide', 189),
#  ('transformers', 189),
#  ('style', 189),
#  ('coronavirus', 188),
#  ('identification', 188),
#  ('build', 188),
#  ('scene', 188),
#  ('applications', 187),
#  ('gcp', 186),
#  ('secure', 186),
#  ('satellite', 186),
#  ('active', 185),
#  ('collision', 185),
#  ('mvc', 184),
#  ('openai', 184),
#  ('player', 184),
#  ('vehicles', 184),
#  ('access', 184),
#  ('disease', 184),
#  ('events', 184),
#  ('templates', 183),
#  ('course', 183),
#  ('opengl', 183),
#  ('dlib', 183),
#  ('radio', 183),
#  ('verification', 182),
#  ('wrapper', 182),
#  ('opensource', 182),
#  ('eye', 182),
#  ('openvino', 182),
#  ('cuda', 181),
#  ('call', 180),
#  ('example', 179),
#  ('benchmark', 179),
#  ('intel', 179),
#  ('puppet', 179),
#  ('collection', 178),
#  ('firefox', 178),
#  ('stealer', 178),
#  ('internet', 177),
#  ('vim', 177),
#  ('tensorrt', 177),
#  ('swiftui', 177),
#  ('policy', 177),
#  ('webrtc', 176),
#  ('site', 176),
#  ('capture', 176),
#  ('ibm', 176),
#  ('autoencoder', 176),
#  ('error', 175),
#  ('scala', 175),
#  ('os', 174),
#  ('table', 174),
#  ('harden', 174),
#  ('webpack', 174),
#  ('cms', 174),
#  ('crawler', 174),
#  ('coco', 174),
#  ('unet', 173),
#  ('ec2', 173),
#  ('linear', 172),
#  ('zero', 172),
#  ('gesture', 172),
#  ('seq', 172),
#  ('book', 172),
#  ('sms', 171),
#  ('scrap', 171),
#  ('clean', 171),
#  ('colab', 171),
#  ('oracle', 171),
#  ('webhook', 170),
#  ('onnx', 170),
#  ('starter', 170),
#  ('nextjs', 170),
#  ('socket', 170),
#  ('live', 169),
#  ('debug', 169),
#  ('note', 169),
#  ('chain', 168),
#  ('machinelearning', 168),
#  ('caffe', 168),
#  ('ffmpeg', 168),
#  ('scraper', 168),
#  ('kali', 168),
#  ('mediapipe', 167),
#  ('arm', 167),
#  ('debian', 167),
#  ('matrix', 166),
#  ('big', 166),
#  ('toolkit', 166),
#  ('environment', 166),
#  ('upload', 166),
#  ('simulator', 166),
#  ('alertmanager', 166),
#  ('cloudformation', 166),
#  ('analyzer', 165),
#  ('emacs', 165),
#  ('zabbix', 165),
#  ('cheat', 165),
#  ('10', 164),
#  ('unity3d', 164),
#  ('usb', 164),
#  ('oauth2', 164),
#  ('nvidia', 164),
#  ('implementation', 164),
#  ('word', 163),
#  ('transform', 163),
#  ('interface', 163),
#  ('exchange', 163),
#  ('csv', 162),
#  ('job', 162),
#  ('lite', 162),
#  ('mesh', 162),
#  ('animation', 162),
#  ('uptime', 162),
#  ('evasion', 161),
#  ('sort', 161),
#  ('restful', 161),
#  ('type', 161),
#  ('blog', 161),
#  ('fusion', 161),
#  ('elixir', 161),
#  ('university', 160),
#  ('rat', 160),
#  ('tag', 160),
#  ('operator', 159),
#  ('pool', 159),
#  ('alignment', 159),
#  ('tcp', 159),
#  ('cascade', 158),
#  ('rnn', 157),
#  ('mode', 157),
#  ('spoof', 157),
#  ('firmware', 157),
#  ('finance', 156),
#  ('crud', 156),
#  ('request', 156),
#  ('augment', 156),
#  ('augmentation', 156),
#  ('plan', 155),
#  ('status', 155),
#  ('education', 155),
#  ('ransomware', 154),
#  ('expression', 154),
#  ('streamlit', 153),
#  ('distribution', 153),
#  ('css3', 152),
#  ('coursera', 152),
#  ('builder', 151),
#  ('retrieval', 151),
#  ('tailwindcss', 151),
#  ('gender', 151),
#  ('genomics', 151),
#  ('assembly', 150),
#  ('vault', 149),
#  ('schema', 149),
#  ('saliency', 149),
#  ('imagery', 148),
#  ('binance', 148),
#  ('compliance', 147),
#  ('ng', 147),
#  ('batch', 147),
#  ('navigation', 147),
#  ('query', 146),
#  ('count', 145),
#  ('use', 145),
#  ('render', 145),
#  ('writeups', 145),
#  ('payment', 144),
#  ('depth', 144),
#  ('grid', 144),
#  ('async', 144),
#  ('art', 144),
#  ('best', 143),
#  ('pretrained', 143),
#  ('identity', 142),
#  ('cloudflare', 142),
#  ('skin', 141),
#  ('gps', 141),
#  ('mitre', 141),
#  ('reconstruction', 141),
#  ('lightning', 141),
#  ('nmap', 141),
#  ('twitch', 141),
#  ('eeg', 141),
#  ('first', 140),
#  ('ecg', 140),
#  ('background', 140),
#  ('logger', 140),
#  ('siem', 139),
#  ('quantum', 139),
#  ('manipulation', 139),
#  ('optical', 139),
#  ('popup', 139),
#  ('store', 138),
#  ('kibana', 138),
#  ('character', 138),
#  ('calibration', 138),
#  ('evaluation', 137),
#  ('drone', 137),
#  ('directory', 137),
#  ('lang', 137),
#  ('instagram', 137),
#  ('facebook', 137),
#  ('compression', 136),
#  ('widget', 136),
#  ('cv', 136),
#  ('sqlite', 136),
#  ('similarity', 136),
#  ('view', 136),
#  ('asp', 136),
#  ('toast', 136),
#  ('crack', 136),
#  ('fuzzing', 135),
#  ('io', 135),
#  ('threatintel', 135),
#  ('cpu', 135),
#  ('surveillance', 134),
#  ('loss', 134),
#  ('owasp', 134),
#  ('bounty', 134),
#  ('sharp', 134),
#  ('ecommerce', 133),
#  ('mtcnn', 133),
#  ('login', 133),
#  ('compiler', 133),
#  ('rna', 133),
#  ('one', 133),
#  ('checker', 132),
#  ('number', 132),
#  ('forensic', 132),
#  ('string', 132),
#  ('methods', 132),
#  ('star', 132),
#  ('grpc', 131),
#  ('mac', 131),
#  ('mlops', 131),
#  ('splunk', 131),
#  ('dependency', 131),
#  ('multimodal', 130),
#  ('embeddings', 130),
#  ('ensemble', 130),
#  ('format', 129),
#  ('syntax', 129),
#  ('vulnerabilities', 129),
#  ('web3', 129),
#  ('es6', 128),
#  ('load', 128),
#  ('sagemaker', 128),
#  ('x', 128),
#  ('understand', 128),
#  ('temporal', 128),
#  ('prompt', 127),
#  ('queue', 127),
#  ('metadata', 127),
#  ('tune', 127),
#  ('packet', 127),
#  ('alarm', 127),
#  ('accept', 127),
#  ('covid19', 127),
#  ('tesseract', 127),
#  ('fast', 126),
#  ('sklearn', 126),
#  ('decision', 126),
#  ('middleware', 126),
#  ('reconnaissance', 126),
#  ('blueteam', 126),
#  ('secrets', 126),
#  ('dom', 126),
#  ('elk', 126),
#  ('haar', 126),
#  ('ionic', 126),
#  ('healthcare', 126),
#  ('symfony', 126),
#  ('connect', 126),
#  ('utility', 126),
#  ('ecs', 126),
#  ('location', 125),
#  ('wireless', 125),
#  ('nano', 125),
#  ('name', 125),
#  ('space', 125),
#  ('hackathon', 124),
#  ('imagenet', 124),
#  ('extensions', 124),
#  ('scanners', 124),
#  ('cloudwatch', 124),
#  ('tkinter', 124),
#  ('signature', 124),
#  ('trojan', 123),
#  ('converter', 123),
#  ('private', 123),
#  ('authorization', 123),
#  ('xamarin', 123),
#  ('reader', 123),
#  ('technology', 123),
#  ('content', 123),
#  ('expressjs', 122),
#  ('bind', 122),
#  ('tflite', 122),
#  ('price', 122),
#  ('thread', 122),
#  ('landmark', 121),
#  ('xml', 121),
#  ('whatsapp', 121),
#  ('automate', 121),
#  ('webassembly', 121),
#  ('2021', 121),
#  ('registry', 121),
#  ('bootstrap4', 120),
#  ('webcam', 120),
#  ('battery', 120),
#  ('pwa', 120),
#  ('port', 120),
#  ('communication', 120),
#  ('timeseries', 120),
#  ('representation', 120),
#  ('downloader', 119),
#  ('blazor', 119),
#  ('tiny', 119),
#  ('console', 118),
#  ('sandbox', 118),
#  ('sound', 118),
#  ('mvvm', 118),
#  ('https', 118),
#  ('reference', 118),
#  ('keyboard', 118),
#  ('grabber', 118),
#  ('theory', 117),
#  ('group', 117),
#  ('sensors', 117),
#  ('webgl', 117),
#  ('safety', 117),
#  ('review', 117),
#  ('competition', 117),
#  ('devices', 117),
#  ('path', 117),
#  ('postgres', 117),
#  ('swarm', 117),
#  ('highlight', 117),
#  ('computational', 117),
#  ('radar', 116),
#  ('5', 116),
#  ('cookie', 116),
#  ('gradient', 116),
#  ('account', 115),
#  ('cplusplus', 115),
#  ('bound', 115),
#  ('rate', 115),
#  ('orient', 115),
#  ('svelte', 115),
#  ('url', 114),
#  ('study', 114),
#  ('encode', 114),
#  ('barcode', 114),
#  ('astronomy', 114),
#  ('operate', 114),
#  ('kitti', 114),
#  ('id', 114),
#  ('person', 114),
#  ('class', 113),
#  ('workshop', 113),
#  ('gamedev', 113),
#  ('emulator', 113),
#  ('channel', 113),
#  ('pedestrian', 113),
#  ('neovim', 113),
#  ('chess', 113),
#  ('pcap', 113),
#  ('public', 112),
#  ('openshift', 112),
#  ('recurrent', 112),
#  ('filesystem', 112),
#  ('liven', 112),
#  ('peer', 112),
#  ('qrcode', 112),
#  ('matplotlib', 112),
#  ('wasm', 112),
#  ('orm', 111),
#  ('gradle', 111),
#  ('auth', 110),
#  ('recon', 110),
#  ('canvas', 110),
#  ('non', 110),
#  ('xray', 110),
#  ('resource', 110),
#  ('logistic', 109),
#  ('window', 109),
#  ('offensive', 109),
#  ('icons', 109),
#  ('side', 109),
#  ('ros2', 109),
#  ('landmarks', 109),
#  ('automatic', 109),
#  ('enterprise', 109),
#  ('scale', 109),
#  ('power', 109),
#  ('sass', 108),
#  ('bots', 108),
#  ('pascal', 108),
#  ('jpa', 108),
#  ('cognitive', 108),
#  ('delivery', 107),
#  ('etl', 107),
#  ('diffusion', 107),
#  ('prevention', 107),
#  ('e', 107),
#  ('steam', 107),
#  ('yaml', 107),
#  ('aes', 107),
#  ('salesforce', 107),
#  ('readme', 107),
#  ('leetcode', 107),
#  ('telemetry', 106),
#  ('age', 106),
#  ('cheatsheet', 106),
#  ('interaction', 106),
#  ('dark', 106),
#  ('p2p', 106),
#  ('gather', 106),
#  ('bayesian', 106),
#  ('update', 106),
#  ('portfolio', 106),
#  ('ajax', 105),
#  ('hide', 105),
#  ('backdoor', 105),
#  ('level', 105),
#  ('hackintosh', 105),
#  ('reactive', 105),
#  ('cdk', 105),
#  ('payload', 105),
#  ('leak', 105),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 1.2 (D_T3)
# ```
# in: name, topics
# out: name, topics (tokeinzed not lematized)
# ```

# %%
sgf.topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(preprocess_text(' '.join(x), lem=False)))

# %%
Counter(sgf.topics_removed).most_common()
# Out:
# [('of', 661),
#  ('to', 578),
#  ('and', 335),
#  ('in', 232),
#  ('for', 228),
#  ('as', 187),
#  ('the', 167),
#  ('on', 155),
#  ('by', 122),
#  ('no', 109),
#  ('few', 103),
#  ('out', 83),
#  ('only', 79),
#  ('a', 64),
#  ('over', 59),
#  ('d', 58),
#  ('re', 57),
#  ('with', 55),
#  ('from', 42),
#  ('t', 36),
#  ('up', 34),
#  ('can', 32),
#  ('it', 32),
#  ('m', 30),
#  ('at', 28),
#  ('all', 24),
#  ('doing', 24),
#  ('i', 23),
#  ('your', 23),
#  ('s', 22),
#  ('now', 19),
#  ('how', 18),
#  ('me', 17),
#  ('not', 17),
#  ('is', 17),
#  ('my', 17),
#  ('after', 14),
#  ('do', 14),
#  ('you', 13),
#  ('off', 11),
#  ('o', 11),
#  ('down', 11),
#  ('ve', 9),
#  ('did', 9),
#  ('other', 9),
#  ('this', 8),
#  ('about', 7),
#  ('who', 7),
#  ('once', 6),
#  ('be', 5),
#  ('under', 5),
#  ('here', 5),
#  ('any', 5),
#  ('an', 5),
#  ('have', 4),
#  ('been', 4),
#  ('own', 4),
#  ('will', 4),
#  ('just', 4),
#  ('through', 3),
#  ('same', 3),
#  ('if', 3),
#  ('what', 3),
#  ('into', 2),
#  ('while', 2),
#  ('then', 2),
#  ('he', 2),
#  ('myself', 2),
#  ('more', 2),
#  ('against', 2),
#  ('am', 2),
#  ('its', 2),
#  ('very', 2),
#  ('between', 2),
#  ('ll', 1),
#  ('nor', 1),
#  ('y', 1),
#  ('we', 1),
#  ('isn', 1),
#  ('haven', 1),
#  ('ain', 1),
#  ('too', 1),
#  ('ma', 1),
#  ('when', 1),
#  ('does', 1),
#  ('some', 1),
#  ('has', 1),
#  ('so', 1),
#  ('why', 1)]

# %%
github_data_wtopic
# Out:
#                                           name  \
# 6               thingsym/multi-device-switcher
# 8       redlink-gmbh/solr-compound-word-filter
# 9         xswlme/Delivery-Availability-Checker
# 10                    eastsss/ErrorDispatching
# 11                       ahmadhuzaifa/skinskan
# ...                                        ...
# 221952                   waqasbhatti/astrobase
# 221955                 hpcc-systems/vscode-ecl
# 221965                   MarcoPon/BlockHashLoc
# 221966           bhagatabhijeet/bhagatabhijeet
# 221967           LandGrey/SpringBootVulExploit
#
#                                                    topics
# 6                              wordpress wordpress plugin
# 8                    solr lucene lucene analyzer language
# 9       amazon chrome extension food delivery grocery ...
# 10      swift ios error handling custom chain responsi...
# 11      cnn cnn keras skin cancer tensorflow ai machin...
# ...                                                   ...
# 221952       light curves astronomy python variable stars
# 221955                vscode typescript ecl hpcc platform
# 221965  bhl recovery hash block metadata undelete unfo...
# 221966  bhagatabhijeet abhijeetbhagat abhijeet bhagat ...
# 221967  springboot springboot actuator rce rce spring ...
#
# [69817 rows x 2 columns]

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 44924

# %%
to_disk(github_data_wtopic, 't1.2')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.2.pkl

# %%
from collections import Counter
word_cnt_t1_2 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1_2.update(t.split(' '))


word_cnt_t1_2.most_common()
# Out:
# [('detection', 13503),
#  ('learning', 12881),
#  ('python', 7897),
#  ('deep', 6053),
#  ('machine', 5800),
#  ('security', 5645),
#  ('data', 4467),
#  ('image', 3795),
#  ('object', 3785),
#  ('api', 3718),
#  ('vision', 3611),
#  ('computer', 3399),
#  ('analysis', 3267),
#  ('javascript', 3218),
#  ('android', 3063),
#  ('neural', 3024),
#  ('tensorflow', 2893),
#  ('face', 2878),
#  ('recognition', 2801),
#  ('react', 2770),
#  ('awesome', 2753),
#  ('opencv', 2686),
#  ('network', 2587),
#  ('processing', 2563),
#  ('aws', 2554),
#  ('pytorch', 2516),
#  ('docker', 2462),
#  ('networks', 2454),
#  ('hacktoberfest', 2133),
#  ('cloud', 2131),
#  ('classification', 2012),
#  ('library', 1942),
#  ('plugin', 1902),
#  ('java', 1869),
#  ('monitoring', 1847),
#  ('tools', 1839),
#  ('language', 1707),
#  ('list', 1688),
#  ('python3', 1679),
#  ('kubernetes', 1672),
#  ('linux', 1633),
#  ('azure', 1627),
#  ('segmentation', 1614),
#  ('web', 1554),
#  ('bot', 1538),
#  ('game', 1490),
#  ('server', 1483),
#  ('framework', 1475),
#  ('malware', 1439),
#  ('windows', 1400),
#  ('ios', 1396),
#  ('php', 1361),
#  ('golang', 1361),
#  ('nodejs', 1354),
#  ('automation', 1350),
#  ('keras', 1345),
#  ('intelligence', 1338),
#  ('video', 1304),
#  ('testing', 1257),
#  ('ai', 1244),
#  ('dataset', 1219),
#  ('tracking', 1216),
#  ('text', 1203),
#  ('spring', 1197),
#  ('code', 1189),
#  ('google', 1189),
#  ('c', 1176),
#  ('science', 1174),
#  ('nlp', 1124),
#  ('cnn', 1116),
#  ('tool', 1112),
#  ('application', 1104),
#  ('hacking', 1098),
#  ('management', 1094),
#  ('database', 1077),
#  ('app', 1075),
#  ('model', 1074),
#  ('typescript', 1036),
#  ('terraform', 1033),
#  ('graph', 1024),
#  ('time', 1001),
#  ('swift', 974),
#  ('algorithms', 972),
#  ('3d', 969),
#  ('threat', 963),
#  ('engine', 945),
#  ('system', 940),
#  ('iot', 934),
#  ('pi', 926),
#  ('ui', 921),
#  ('convolutional', 912),
#  ('raspberry', 911),
#  ('go', 897),
#  ('artificial', 895),
#  ('native', 879),
#  ('client', 874),
#  ('prometheus', 872),
#  ('anomaly', 855),
#  ('forensics', 846),
#  ('arduino', 843),
#  ('css', 841),
#  ('algorithm', 832),
#  ('engineering', 825),
#  ('open', 817),
#  ('home', 807),
#  ('development', 807),
#  ('html', 806),
#  ('discord', 806),
#  ('programming', 779),
#  ('flask', 776),
#  ('flutter', 776),
#  ('github', 763),
#  ('project', 754),
#  ('cpp', 754),
#  ('cybersecurity', 748),
#  ('extension', 744),
#  ('speech', 740),
#  ('vue', 737),
#  ('audio', 733),
#  ('cli', 732),
#  ('vulnerability', 727),
#  ('service', 724),
#  ('rest', 717),
#  ('camera', 714),
#  ('natural', 713),
#  ('estimation', 705),
#  ('rust', 694),
#  ('blockchain', 693),
#  ('models', 687),
#  ('js', 683),
#  ('angular', 676),
#  ('self', 672),
#  ('design', 670),
#  ('yolo', 670),
#  ('platform', 669),
#  ('laravel', 668),
#  ('devops', 659),
#  ('plus', 652),
#  ('sdk', 650),
#  ('node', 646),
#  ('scanner', 643),
#  ('source', 641),
#  ('script', 633),
#  ('search', 624),
#  ('telegram', 621),
#  ('module', 615),
#  ('macos', 609),
#  ('django', 602),
#  ('kotlin', 598),
#  ('edge', 596),
#  ('alert', 587),
#  ('components', 587),
#  ('architecture', 586),
#  ('visualization', 584),
#  ('trading', 581),
#  ('driving', 580),
#  ('research', 578),
#  ('multi', 576),
#  ('ocr', 575),
#  ('template', 572),
#  ('cryptography', 572),
#  ('notifications', 565),
#  ('package', 561),
#  ('sql', 553),
#  ('wordpress', 551),
#  ('pose', 549),
#  ('assistant', 545),
#  ('series', 543),
#  ('privacy', 542),
#  ('ros', 535),
#  ('control', 533),
#  ('reactjs', 531),
#  ('monitor', 530),
#  ('boot', 529),
#  ('json', 529),
#  ('tutorial', 528),
#  ('autonomous', 528),
#  ('proxy', 526),
#  ('mobile', 525),
#  ('pentesting', 524),
#  ('encryption', 520),
#  ('yolov3', 519),
#  ('ethereum', 518),
#  ('metrics', 514),
#  ('manager', 510),
#  ('generator', 506),
#  ('robotics', 504),
#  ('dashboard', 504),
#  ('ansible', 504),
#  ('analytics', 504),
#  ('images', 502),
#  ('kafka', 501),
#  ('systems', 493),
#  ('detector', 493),
#  ('ruby', 492),
#  ('firebase', 491),
#  ('lambda', 491),
#  ('component', 488),
#  ('csharp', 479),
#  ('bootstrap', 474),
#  ('computing', 473),
#  ('notebook', 470),
#  ('covid', 470),
#  ('grafana', 468),
#  ('ctf', 468),
#  ('reverse', 462),
#  ('powershell', 462),
#  ('shell', 460),
#  ('point', 460),
#  ('software', 459),
#  ('response', 457),
#  ('r', 456),
#  ('file', 454),
#  ('antivirus', 451),
#  ('clustering', 449),
#  ('supervised', 447),
#  ('penetration', 446),
#  ('classifier', 444),
#  ('serverless', 444),
#  ('information', 443),
#  ('jupyter', 443),
#  ('rcnn', 442),
#  ('amazon', 441),
#  ('dotnet', 440),
#  ('remote', 440),
#  ('mysql', 436),
#  ('semantic', 435),
#  ('http', 435),
#  ('mining', 435),
#  ('interview', 434),
#  ('ml', 433),
#  ('incident', 433),
#  ('cryptocurrency', 433),
#  ('chrome', 432),
#  ('feature', 432),
#  ('paper', 431),
#  ('car', 429),
#  ('authentication', 427),
#  ('medical', 426),
#  ('matlab', 425),
#  ('attack', 425),
#  ('mongodb', 423),
#  ('sensor', 421),
#  ('bitcoin', 420),
#  ('real', 418),
#  ('visual', 416),
#  ('extraction', 416),
#  ('pipeline', 412),
#  ('gui', 410),
#  ('filter', 408),
#  ('browser', 407),
#  ('prediction', 404),
#  ('music', 401),
#  ('hunting', 400),
#  ('smart', 400),
#  ('elasticsearch', 398),
#  ('adversarial', 396),
#  ('generation', 395),
#  ('deeplearning', 394),
#  ('distributed', 392),
#  ('performance', 391),
#  ('parser', 390),
#  ('dns', 386),
#  ('lstm', 385),
#  ('material', 384),
#  ('command', 383),
#  ('simulation', 381),
#  ('cluster', 380),
#  ('cve', 380),
#  ('bash', 380),
#  ('storage', 379),
#  ('emotion', 379),
#  ('social', 378),
#  ('voice', 378),
#  ('transformer', 377),
#  ('event', 376),
#  ('transfer', 376),
#  ('postgresql', 376),
#  ('digital', 375),
#  ('regression', 375),
#  ('osint', 374),
#  ('core', 370),
#  ('mask', 367),
#  ('crypto', 365),
#  ('19', 364),
#  ('streaming', 363),
#  ('jquery', 362),
#  ('line', 360),
#  ('free', 359),
#  ('resources', 356),
#  ('bugbounty', 355),
#  ('human', 354),
#  ('optimization', 353),
#  ('wifi', 353),
#  ('lane', 353),
#  ('unity', 351),
#  ('anti', 350),
#  ('microsoft', 350),
#  ('cross', 350),
#  ('yolov5', 349),
#  ('compose', 348),
#  ('redux', 348),
#  ('test', 346),
#  ('bioinformatics', 345),
#  ('lidar', 343),
#  ('theme', 341),
#  ('signal', 341),
#  ('static', 339),
#  ('yara', 339),
#  ('virtual', 339),
#  ('microservices', 337),
#  ('inference', 337),
#  ('3', 336),
#  ('log', 336),
#  ('cyber', 336),
#  ('net', 335),
#  ('redis', 335),
#  ('traffic', 334),
#  ('ip', 333),
#  ('esp32', 333),
#  ('motion', 333),
#  ('services', 332),
#  ('infosec', 331),
#  ('deployment', 330),
#  ('custom', 327),
#  ('based', 326),
#  ('mqtt', 323),
#  ('xss', 323),
#  ('gateway', 322),
#  ('functions', 321),
#  ('html5', 319),
#  ('configuration', 319),
#  ('password', 318),
#  ('kernel', 318),
#  ('facial', 316),
#  ('team', 316),
#  ('logging', 316),
#  ('desktop', 315),
#  ('spark', 309),
#  ('audit', 305),
#  ('website', 305),
#  ('sentiment', 304),
#  ('injection', 304),
#  ('admin', 304),
#  ('protocol', 303),
#  ('tracker', 302),
#  ('learn', 302),
#  ('minecraft', 302),
#  ('twitter', 302),
#  ('firewall', 302),
#  ('ssd', 301),
#  ('email', 300),
#  ('config', 298),
#  ('container', 298),
#  ('attacks', 298),
#  ('pentest', 296),
#  ('infrastructure', 296),
#  ('files', 295),
#  ('slack', 295),
#  ('jwt', 292),
#  ('nginx', 290),
#  ('translation', 290),
#  ('actions', 289),
#  ('community', 288),
#  ('random', 288),
#  ('memory', 286),
#  ('action', 286),
#  ('end', 284),
#  ('generative', 283),
#  ('demo', 282),
#  ('editor', 282),
#  ('driver', 282),
#  ('tree', 281),
#  ('vehicle', 281),
#  ('user', 280),
#  ('red', 280),
#  ('gpu', 280),
#  ('stream', 279),
#  ('embedded', 278),
#  ('robot', 277),
#  ('physics', 277),
#  ('networking', 276),
#  ('controller', 275),
#  ('dfir', 275),
#  ('attention', 275),
#  ('scripts', 275),
#  ('quality', 275),
#  ('intrusion', 273),
#  ('s3', 272),
#  ('svm', 271),
#  ('phishing', 270),
#  ('graphql', 269),
#  ('domain', 269),
#  ('vscode', 269),
#  ('dynamic', 268),
#  ('bypass', 268),
#  ('unsupervised', 268),
#  ('imaging', 268),
#  ('integration', 267),
#  ('reinforcement', 266),
#  ('cancer', 265),
#  ('agent', 265),
#  ('git', 265),
#  ('yolov4', 263),
#  ('fraud', 262),
#  ('numpy', 261),
#  ('exporter', 261),
#  ('developer', 260),
#  ('forest', 258),
#  ('express', 257),
#  ('instance', 256),
#  ('bluetooth', 255),
#  ('apps', 254),
#  ('notification', 254),
#  ('studio', 253),
#  ('device', 251),
#  ('news', 251),
#  ('swagger', 250),
#  ('realtime', 249),
#  ('esp8266', 248),
#  ('terminal', 246),
#  ('training', 246),
#  ('backup', 245),
#  ('stack', 244),
#  ('knowledge', 243),
#  ('protection', 242),
#  ('jetson', 242),
#  ('flow', 242),
#  ('documentation', 241),
#  ('weather', 241),
#  ('frontend', 240),
#  ('single', 240),
#  ('selenium', 240),
#  ('ids', 240),
#  ('dialog', 239),
#  ('slam', 238),
#  ('hardware', 238),
#  ('rules', 238),
#  ('kaggle', 238),
#  ('localization', 238),
#  ('cordova', 238),
#  ('containers', 237),
#  ('lua', 237),
#  ('vuejs', 236),
#  ('rails', 234),
#  ('scikit', 233),
#  ('shot', 233),
#  ('darknet', 232),
#  ('reality', 232),
#  ('low', 231),
#  ('exploit', 231),
#  ('ssh', 230),
#  ('alerting', 230),
#  ('plugins', 230),
#  ('markdown', 229),
#  ('change', 229),
#  ('page', 229),
#  ('faster', 228),
#  ('validation', 227),
#  ('datasets', 227),
#  ('apache', 227),
#  ('exploitation', 226),
#  ('health', 226),
#  ('chatgpt', 226),
#  ('apple', 226),
#  ('2d', 226),
#  ('router', 225),
#  ('graphics', 225),
#  ('resnet', 224),
#  ('k8s', 224),
#  ('ubuntu', 224),
#  ('fake', 223),
#  ('detect', 222),
#  ('modules', 222),
#  ('chat', 222),
#  ('redteam', 221),
#  ('ci', 221),
#  ('annotation', 220),
#  ('dart', 217),
#  ('webapp', 217),
#  ('gpt', 217),
#  ('jenkins', 217),
#  ('npm', 217),
#  ('token', 217),
#  ('pattern', 216),
#  ('solidity', 216),
#  ('electron', 216),
#  ('tensorflow2', 216),
#  ('pandas', 216),
#  ('sensing', 216),
#  ('bug', 216),
#  ('modeling', 215),
#  ('high', 214),
#  ('ddos', 214),
#  ('vpn', 213),
#  ('udacity', 213),
#  ('media', 212),
#  ('mobilenet', 212),
#  ('ssl', 212),
#  ('workflow', 211),
#  ('boilerplate', 210),
#  ('statistics', 208),
#  ('solutions', 208),
#  ('bert', 208),
#  ('alerts', 207),
#  ('color', 207),
#  ('objective', 207),
#  ('binary', 206),
#  ('plate', 206),
#  ('youtube', 205),
#  ('helm', 205),
#  ('support', 205),
#  ('entity', 204),
#  ('2', 203),
#  ('mod', 203),
#  ('license', 202),
#  ('hack', 202),
#  ('modal', 202),
#  ('heroku', 201),
#  ('continuous', 201),
#  ('stock', 201),
#  ('observability', 201),
#  ('backend', 200),
#  ('chatbot', 200),
#  ('wallet', 199),
#  ('map', 198),
#  ('form', 198),
#  ('tutorials', 198),
#  ('lists', 198),
#  ('energy', 198),
#  ('online', 197),
#  ('key', 196),
#  ('scanning', 196),
#  ('activity', 196),
#  ('pdf', 196),
#  ('card', 195),
#  ('examples', 195),
#  ('openapi', 194),
#  ('spam', 194),
#  ('discovery', 193),
#  ('addon', 193),
#  ('4', 193),
#  ('questions', 193),
#  ('auto', 193),
#  ('websocket', 192),
#  ('devsecops', 192),
#  ('vector', 192),
#  ('kit', 192),
#  ('process', 192),
#  ('tls', 192),
#  ('state', 191),
#  ('outlier', 191),
#  ('virus', 191),
#  ('push', 191),
#  ('microservice', 191),
#  ('homeassistant', 190),
#  ('gan', 190),
#  ('cell', 190),
#  ('sample', 189),
#  ('features', 189),
#  ('transformers', 189),
#  ('contracts', 189),
#  ('coronavirus', 188),
#  ('identification', 188),
#  ('scene', 188),
#  ('applications', 187),
#  ('gcp', 186),
#  ('active', 185),
#  ('collision', 185),
#  ('mvc', 184),
#  ('openai', 184),
#  ('player', 184),
#  ('vehicles', 184),
#  ('structures', 184),
#  ('disease', 184),
#  ('events', 184),
#  ('templates', 183),
#  ('access', 183),
#  ('opengl', 183),
#  ('dlib', 183),
#  ('verification', 182),
#  ('wrapper', 182),
#  ('opensource', 182),
#  ('radio', 182),
#  ('openvino', 182),
#  ('cuda', 181),
#  ('secure', 180),
#  ('example', 179),
#  ('benchmark', 179),
#  ('intel', 179),
#  ('puppet', 179),
#  ('satellite', 178),
#  ('collection', 178),
#  ('firefox', 178),
#  ('stealer', 178),
#  ('internet', 177),
#  ('vim', 177),
#  ('games', 177),
#  ('tensorrt', 177),
#  ('swiftui', 177),
#  ('policy', 177),
#  ('webrtc', 176),
#  ('site', 176),
#  ('ibm', 176),
#  ('autoencoder', 176),
#  ('error', 175),
#  ('scala', 175),
#  ('hand', 175),
#  ('task', 175),
#  ('os', 174),
#  ('webpack', 174),
#  ('cms', 174),
#  ('crawler', 174),
#  ('coco', 174),
#  ('unet', 173),
#  ('ec2', 173),
#  ('papers', 172),
#  ('linear', 172),
#  ('zero', 172),
#  ('hooks', 172),
#  ('seq', 172),
#  ('sms', 171),
#  ('matching', 171),
#  ('colab', 171),
#  ('oracle', 171),
#  ('cache', 171),
#  ('webhook', 170),
#  ('onnx', 170),
#  ('starter', 170),
#  ('nextjs', 170),
#  ('socket', 170),
#  ('document', 170),
#  ('capture', 169),
#  ('machinelearning', 168),
#  ('caffe', 168),
#  ('ffmpeg', 168),
#  ('scraper', 168),
#  ('eye', 168),
#  ('kali', 168),
#  ('mediapipe', 167),
#  ('debian', 167),
#  ('matrix', 166),
#  ('hardening', 166),
#  ('guide', 166),
#  ('big', 166),
#  ('toolkit', 166),
#  ('environment', 166),
#  ('simulator', 166),
#  ('alertmanager', 166),
#  ('cloudformation', 166),
#  ('analyzer', 165),
#  ('live', 165),
#  ('coding', 165),
#  ('maps', 165),
#  ('emacs', 165),
#  ('sign', 165),
#  ('zabbix', 165),
#  ('10', 164),
#  ('unity3d', 164),
#  ('usb', 164),
#  ('oauth2', 164),
#  ('nvidia', 164),
#  ('implementation', 164),
#  ('interface', 163),
#  ('csv', 162),
#  ('lite', 162),
#  ('animation', 162),
#  ('patterns', 162),
#  ('uptime', 162),
#  ('evasion', 161),
#  ('restful', 161),
#  ('fusion', 161),
#  ('elixir', 161),
#  ('university', 160),
#  ('operator', 159),
#  ('alignment', 159),
#  ('tcp', 159),
#  ('forecasting', 159),
#  ('transform', 158),
#  ('chain', 157),
#  ('rnn', 157),
#  ('mode', 157),
#  ('arm', 157),
#  ('firmware', 157),
#  ('crud', 156),
#  ('augmentation', 156),
#  ('status', 155),
#  ('education', 155),
#  ('ransomware', 154),
#  ('scraping', 154),
#  ('mesh', 154),
#  ('expression', 154),
#  ('upload', 154),
#  ('finance', 153),
#  ('streamlit', 153),
#  ('distribution', 153),
#  ('css3', 152),
#  ('coursera', 152),
#  ('augmented', 152),
#  ('builder', 151),
#  ('retrieval', 151),
#  ('notes', 151),
#  ('tailwindcss', 151),
#  ('gender', 151),
#  ('genomics', 151),
#  ('assembly', 150),
#  ('table', 149),
#  ('light', 149),
#  ('vault', 149),
#  ('schema', 149),
#  ('course', 149),
#  ('saliency', 149),
#  ('imagery', 148),
#  ('binance', 148),
#  ('compliance', 147),
#  ('cascade', 147),
#  ('labeling', 147),
#  ('ng', 147),
#  ('navigation', 147),
#  ('driven', 146),
#  ('distance', 146),
#  ('hash', 145),
#  ('build', 145),
#  ('writeups', 145),
#  ('payment', 144),
#  ('depth', 144),
#  ('grid', 144),
#  ('async', 144),
#  ('certificate', 144),
#  ('projects', 144),
#  ('fingerprint', 144),
#  ('batch', 144),
#  ('art', 144),
#  ('best', 143),
#  ('pretrained', 143),
#  ('cheat', 143),
#  ('identity', 142),
#  ('cloudflare', 142),
#  ('market', 142),
#  ('gps', 141),
#  ('mitre', 141),
#  ('reconstruction', 141),
#  ('lightning', 141),
#  ('nmap', 141),
#  ('twitch', 141),
#  ('eeg', 141),
#  ('first', 140),
#  ('parsing', 140),
#  ('ecg', 140),
#  ('logs', 140),
#  ('logger', 140),
#  ('gesture', 140),
#  ('siem', 139),
#  ('quantum', 139),
#  ('manipulation', 139),
#  ('pool', 139),
#  ('optical', 139),
#  ('popup', 139),
#  ('kibana', 138),
#  ('blog', 138),
#  ('background', 138),
#  ('tracing', 138),
#  ('calibration', 138),
#  ('message', 137),
#  ('evaluation', 137),
#  ('directory', 137),
#  ('lang', 137),
#  ('instagram', 137),
#  ('facebook', 137),
#  ('compression', 136),
#  ('widget', 136),
#  ('cv', 136),
#  ('sqlite', 136),
#  ('similarity', 136),
#  ('asp', 136),
#  ('fuzzing', 135),
#  ('io', 135),
#  ('threatintel', 135),
#  ('cpu', 135),
#  ('skin', 134),
#  ('surveillance', 134),
#  ('loss', 134),
#  ('owasp', 134),
#  ('bounty', 134),
#  ('sharp', 134),
#  ('ecommerce', 133),
#  ('mtcnn', 133),
#  ('login', 133),
#  ('compiler', 133),
#  ('rna', 133),
#  ('one', 133),
#  ('challenge', 132),
#  ('forensic', 132),
#  ('messaging', 132),
#  ('methods', 132),
#  ('planning', 132),
#  ('grpc', 131),
#  ('mac', 131),
#  ('mlops', 131),
#  ('splunk', 131),
#  ('reporting', 131),
#  ('dependency', 131),
#  ('multimodal', 130),
#  ('embeddings', 130),
#  ('ensemble', 130),
#  ('toast', 130),
#  ('sharing', 129),
#  ('clean', 129),
#  ('syntax', 129),
#  ('forms', 129),
#  ('vulnerabilities', 129),
#  ('web3', 129),
#  ('es6', 128),
#  ('sagemaker', 128),
#  ('x', 128),
#  ('exchange', 128),
#  ('scan', 128),
#  ('temporal', 128),
#  ('checker', 127),
#  ('store', 127),
#  ('metadata', 127),
#  ('packet', 127),
#  ('covid19', 127),
#  ('tesseract', 127),
#  ('fast', 126),
#  ('sklearn', 126),
#  ('decision', 126),
#  ('middleware', 126),
#  ('reconnaissance', 126),
#  ('blueteam', 126),
#  ('secrets', 126),
#  ('dom', 126),
#  ('elk', 126),
#  ('haar', 126),
#  ('ionic', 126),
#  ('healthcare', 126),
#  ('spoofing', 126),
#  ('symfony', 126),
#  ('utility', 126),
#  ('ecs', 126),
#  ('location', 125),
#  ('wireless', 125),
#  ('practices', 125),
#  ('mapping', 125),
#  ('chart', 125),
#  ('nano', 125),
#  ('understanding', 125),
#  ('challenges', 125),
#  ('hackathon', 124),
#  ('imagenet', 124),
#  ('extensions', 124),
#  ('scanners', 124),
#  ('view', 124),
#  ('cloudwatch', 124),
#  ('tkinter', 124),
#  ('signature', 124),
#  ('trojan', 123),
#  ('converter', 123),
#  ('call', 123),
#  ('private', 123),
#  ('authorization', 123),
#  ('xamarin', 123),
#  ('reader', 123),
#  ('technology', 123),
#  ('expressjs', 122),
#  ('tflite', 122),
#  ('accepted', 122),
#  ('landmark', 121),
#  ('word', 121),
#  ('xml', 121),
#  ('whatsapp', 121),
#  ('webassembly', 121),
#  ('2021', 121),
#  ('registry', 121),
#  ('bootstrap4', 120),
#  ('webcam', 120),
#  ('battery', 120),
#  ('pwa', 120),
#  ('communication', 120),
#  ('timeseries', 120),
#  ('representation', 120),
#  ('downloader', 119),
#  ('counting', 119),
#  ('debugging', 119),
#  ('blazor', 119),
#  ('tuning', 119),
#  ('hosted', 119),
#  ('tiny', 119),
#  ('content', 119),
#  ('console', 118),
#  ('sandbox', 118),
#  ('mvvm', 118),
#  ('https', 118),
#  ('keyboard', 118),
#  ('grabber', 118),
#  ('theory', 117),
#  ('sensors', 117),
#  ('character', 117),
#  ('webgl', 117),
#  ('safety', 117),
#  ('rendering', 117),
#  ('competition', 117),
#  ('devices', 117),
#  ('path', 117),
#  ('postgres', 117),
#  ('computational', 117),
#  ('radar', 116),
#  ('5', 116),
#  ('style', 116),
#  ('cookie', 116),
#  ('gradient', 116),
#  ('cplusplus', 115),
#  ('filtering', 115),
#  ('sound', 115),
#  ('rate', 115),
#  ('oriented', 115),
#  ('swarm', 115),
#  ('svelte', 115),
#  ('graphs', 114),
#  ('url', 114),
#  ('barcode', 114),
#  ('astronomy', 114),
#  ('kitti', 114),
#  ('id', 114),
#  ('person', 114),
#  ('query', 113),
#  ('workshop', 113),
#  ('gamedev', 113),
#  ('emulator', 113),
#  ('pedestrian', 113),
#  ('neovim', 113),
#  ('chess', 113),
#  ('pcap', 113),
#  ('public', 112),
#  ('openshift', 112),
#  ('recurrent', 112),
#  ('filesystem', 112),
#  ('box', 112),
#  ('liveness', 112),
#  ('qrcode', 112),
#  ('matplotlib', 112),
#  ('wasm', 112),
#  ('orm', 111),
#  ('gradle', 111),
#  ('operating', 111),
#  ('auth', 110),
#  ('prompt', 110),
#  ('recon', 110),
#  ('canvas', 110),
#  ('scripting', 110),
#  ('non', 110),
#  ('xray', 110),
#  ('resource', 110),
#  ('logistic', 109),
#  ('window', 109),
#  ('offensive', 109),
#  ('bounding', 109),
#  ('icons', 109),
#  ('number', 109),
#  ('side', 109),
#  ('rat', 109),
#  ('queue', 109),
#  ('ros2', 109),
#  ('landmarks', 109),
#  ('automatic', 109),
#  ('enterprise', 109),
#  ('sass', 108),
#  ('bots', 108),
#  ('pascal', 108),
#  ('jpa', 108),
#  ('cognitive', 108),
#  ('delivery', 107),
#  ('etl', 107),
#  ('diffusion', 107),
#  ('prevention', 107),
#  ('string', 107),
#  ('e', 107),
#  ('check', 107),
#  ('connect', 107),
#  ('yaml', 107),
#  ('aes', 107),
#  ('salesforce', 107),
#  ('readme', 107),
#  ('leetcode', 107),
#  ('power', 107),
#  ('telemetry', 106),
#  ('cheatsheet', 106),
#  ('interaction', 106),
#  ('dark', 106),
#  ('peer', 106),
#  ('p2p', 106),
#  ('gathering', 106),
#  ('practice', 106),
#  ('bayesian', 106),
#  ('portfolio', 106),
#  ('ajax', 105),
#  ('backdoor', 105),
#  ('hackintosh', 105),
#  ('reactive', 105),
#  ('cdk', 105),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 1.3.1 (D_T4)
# ```
# in: name, topics
# out: name, topics (tokeinzed not lematized, but w composition)
#
# there was an error 1.3 shouldnt be lematized, so 1.3 is now saved as lemmatized and 1.3.1 is not lemma
# ```

# %%
sgf.topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(preprocess_text(' '.join(x), lem=False, do_composition=True)))

# %%
Counter(sgf.topics_removed).most_common()
# Out:
# [('d', 10),
#  ('can', 9),
#  ('did', 9),
#  ('re', 7),
#  ('it', 7),
#  ('i', 5),
#  ('a', 5),
#  ('all', 4),
#  ('up', 4),
#  ('and', 4),
#  ('will', 4),
#  ('for', 4),
#  ('this', 3),
#  ('of', 3),
#  ('who', 3),
#  ('s', 3),
#  ('from', 2),
#  ('about', 2),
#  ('myself', 2),
#  ('the', 2),
#  ('its', 2),
#  ('same', 2),
#  ('any', 2),
#  ('is', 2),
#  ('m', 2),
#  ('to', 2),
#  ('other', 2),
#  ('now', 2),
#  ('ll', 1),
#  ('nor', 1),
#  ('y', 1),
#  ('them', 1),
#  ('over', 1),
#  ('down', 1),
#  ('more', 1),
#  ('isn', 1),
#  ('at', 1),
#  ('your', 1),
#  ('with', 1),
#  ('on', 1),
#  ('off', 1),
#  ('t', 1),
#  ('what', 1),
#  ('does', 1),
#  ('an', 1),
#  ('my', 1),
#  ('ve', 1),
#  ('do', 1),
#  ('no', 1),
#  ('here', 1),
#  ('why', 1)]

# %%
github_data_wtopic
# Out:
#                                           name  \
# 6               thingsym/multi-device-switcher
# 8       redlink-gmbh/solr-compound-word-filter
# 9         xswlme/Delivery-Availability-Checker
# 10                    eastsss/ErrorDispatching
# 11                       ahmadhuzaifa/skinskan
# ...                                        ...
# 221952                   waqasbhatti/astrobase
# 221955                 hpcc-systems/vscode-ecl
# 221965                   MarcoPon/BlockHashLoc
# 221966           bhagatabhijeet/bhagatabhijeet
# 221967           LandGrey/SpringBootVulExploit
#
#                                                    topics
# 6                               wordpress wordpressplugin
# 8                     solr lucene luceneanalyzer language
# 9       amazon chromeextension fooddelivery grocerydel...
# 10      swift ios errorhandling custom chainofresponsi...
# 11      cnn cnnkeras skincancer tensorflow ai machinel...
# ...                                                   ...
# 221952         lightcurves astronomy python variablestars
# 221955                 vscode typescript ecl hpccplatform
# 221965  bhl recovery hash block metadata undelete unfo...
# 221966  bhagatabhijeet abhijeetbhagat abhijeetbhagat s...
# 221967  springboot springbootactuatorrce rce springboo...
#
# [69817 rows x 2 columns]

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 89406

# %%
github_data_wtopic[github_data_wtopic['topics'].str.len() > 0]
# Out:
#                                           name  \
# 6               thingsym/multi-device-switcher
# 8       redlink-gmbh/solr-compound-word-filter
# 9         xswlme/Delivery-Availability-Checker
# 10                    eastsss/ErrorDispatching
# 11                       ahmadhuzaifa/skinskan
# ...                                        ...
# 221952                   waqasbhatti/astrobase
# 221955                 hpcc-systems/vscode-ecl
# 221965                   MarcoPon/BlockHashLoc
# 221966           bhagatabhijeet/bhagatabhijeet
# 221967           LandGrey/SpringBootVulExploit
#
#                                                    topics
# 6                               wordpress wordpressplugin
# 8                     solr lucene luceneanalyzer language
# 9       amazon chromeextension fooddelivery grocerydel...
# 10      swift ios errorhandling custom chainofresponsi...
# 11      cnn cnnkeras skincancer tensorflow ai machinel...
# ...                                                   ...
# 221952         lightcurves astronomy python variablestars
# 221955                 vscode typescript ecl hpccplatform
# 221965  bhl recovery hash block metadata undelete unfo...
# 221966  bhagatabhijeet abhijeetbhagat abhijeetbhagat s...
# 221967  springboot springbootactuatorrce rce springboo...
#
# [69812 rows x 2 columns]

# %%
to_disk(github_data_wtopic, 't1.3.1')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.3.1.pkl

# %%
from collections import Counter
word_cnt_t1_2 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1_2.update(t.split(' '))


word_cnt_t1_2.most_common()
# Out:
# [('python', 6323),
#  ('deeplearning', 5300),
#  ('machinelearning', 4665),
#  ('computervision', 3010),
#  ('javascript', 2744),
#  ('security', 2657),
#  ('objectdetection', 2617),
#  ('pytorch', 2166),
#  ('tensorflow', 2125),
#  ('opencv', 2055),
#  ('hacktoberfest', 2010),
#  ('python3', 1781),
#  ('android', 1676),
#  ('docker', 1658),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1373),
#  ('aws', 1264),
#  ('golang', 1252),
#  ('kubernetes', 1223),
#  ('awesomelist', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('monitoring', 1126),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('imageprocessing', 1000),
#  ('facedetection', 987),
#  ('typescript', 971),
#  ('keras', 871),
#  ('windows', 848),
#  ('datascience', 836),
#  ('nlp', 823),
#  ('cybersecurity', 819),
#  ('api', 802),
#  ('go', 782),
#  ('artificialintelligence', 738),
#  ('anomalydetection', 738),
#  ('raspberrypi', 736),
#  ('swift', 721),
#  ('convolutionalneuralnetworks', 704),
#  ('cnn', 698),
#  ('ai', 672),
#  ('cpp', 660),
#  ('neuralnetwork', 653),
#  ('securitytools', 653),
#  ('facerecognition', 647),
#  ('automation', 637),
#  ('terraform', 615),
#  ('opensource', 609),
#  ('prometheus', 600),
#  ('dataset', 598),
#  ('azure', 584),
#  ('iot', 580),
#  ('naturallanguageprocessing', 579),
#  ('hacking', 576),
#  ('html', 575),
#  ('csharp', 574),
#  ('rust', 561),
#  ('yolo', 557),
#  ('macos', 551),
#  ('flask', 547),
#  ('deepneuralnetworks', 538),
#  ('blockchain', 536),
#  ('css', 527),
#  ('classification', 526),
#  ('reactjs', 520),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 501),
#  ('bot', 498),
#  ('springboot', 498),
#  ('reactnative', 483),
#  ('c', 469),
#  ('cli', 464),
#  ('cryptography', 461),
#  ('yolov3', 457),
#  ('homeassistant', 454),
#  ('opencvpython', 453),
#  ('segmentation', 452),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 432),
#  ('vue', 427),
#  ('library', 415),
#  ('imageclassification', 412),
#  ('cloud', 409),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('realtime', 406),
#  ('django', 403),
#  ('covid19', 403),
#  ('database', 399),
#  ('game', 394),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('bugbounty', 383),
#  ('mongodb', 372),
#  ('alert', 372),
#  ('cryptocurrency', 372),
#  ('ruby', 371),
#  ('web', 367),
#  ('cplusplus', 365),
#  ('neuralnetworks', 360),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('ocr', 349),
#  ('timeseries', 348),
#  ('elasticsearch', 344),
#  ('matlab', 334),
#  ('penetrationtesting', 333),
#  ('yolov5', 331),
#  ('ansible', 330),
#  ('threathunting', 330),
#  ('plugin', 329),
#  ('postgresql', 328),
#  ('restapi', 326),
#  ('bootstrap', 323),
#  ('malwareanalysis', 321),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('antivirus', 319),
#  ('mysql', 317),
#  ('discord', 316),
#  ('metrics', 315),
#  ('reverseengineering', 311),
#  ('threatintelligence', 311),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('json', 308),
#  ('notifications', 304),
#  ('r', 303),
#  ('jupyternotebook', 302),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('dotnet', 297),
#  ('framework', 295),
#  ('incidentresponse', 292),
#  ('redteam', 286),
#  ('github', 286),
#  ('audio', 284),
#  ('firebase', 278),
#  ('network', 276),
#  ('osint', 275),
#  ('dockercompose', 274),
#  ('sql', 273),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('transferlearning', 267),
#  ('bash', 266),
#  ('visualization', 259),
#  ('semanticsegmentation', 257),
#  ('dfir', 257),
#  ('encryption', 256),
#  ('testing', 253),
#  ('html5', 252),
#  ('tracking', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 248),
#  ('microservices', 246),
#  ('gui', 245),
#  ('autonomousdriving', 245),
#  ('homeautomation', 244),
#  ('dataanalysis', 244),
#  ('unity', 244),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('tools', 240),
#  ('lstm', 239),
#  ('ui', 239),
#  ('list', 238),
#  ('jquery', 238),
#  ('redis', 237),
#  ('pointcloud', 236),
#  ('logging', 233),
#  ('algorithms', 231),
#  ('js', 231),
#  ('awslambda', 231),
#  ('networking', 229),
#  ('vuejs', 227),
#  ('poseestimation', 227),
#  ('http', 225),
#  ('alerting', 222),
#  ('sdk', 221),
#  ('gamedevelopment', 221),
#  ('machinelearningalgorithms', 219),
#  ('frontend', 219),
#  ('kerastensorflow', 217),
#  ('tensorflow2', 217),
#  ('datavisualization', 215),
#  ('selfdrivingcar', 215),
#  ('fasterrcnn', 212),
#  ('imagesegmentation', 210),
#  ('telegrambot', 209),
#  ('authentication', 209),
#  ('containers', 208),
#  ('ml', 207),
#  ('redux', 204),
#  ('clustering', 204),
#  ('scikitlearn', 203),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('dart', 199),
#  ('git', 199),
#  ('paper', 198),
#  ('objectivec', 197),
#  ('webapp', 197),
#  ('scanner', 197),
#  ('spark', 196),
#  ('blueteam', 196),
#  ('unsupervisedlearning', 195),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('data', 194),
#  ('ids', 194),
#  ('githubactions', 193),
#  ('transformer', 191),
#  ('express', 191),
#  ('discordbot', 190),
#  ('slack', 190),
#  ('remotesensing', 190),
#  ('mobile', 190),
#  ('yolov4', 189),
#  ('graph', 189),
#  ('pandas', 186),
#  ('analytics', 186),
#  ('crossplatform', 186),
#  ('esp8266', 185),
#  ('image', 185),
#  ('speechrecognition', 185),
#  ('malwaredetection', 185),
#  ('datamining', 183),
#  ('rest', 183),
#  ('reinforcementlearning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentimentanalysis', 182),
#  ('slam', 181),
#  ('imagerecognition', 181),
#  ('face', 180),
#  ('observability', 179),
#  ('instancesegmentation', 178),
#  ('darknet', 178),
#  ('chatgpt', 178),
#  ('graphql', 177),
#  ('wifi', 177),
#  ('resources', 177),
#  ('dns', 177),
#  ('staticanalysis', 176),
#  ('lidar', 175),
#  ('exploit', 175),
#  ('server', 174),
#  ('spring', 174),
#  ('chromeextension', 173),
#  ('devsecops', 173),
#  ('yara', 172),
#  ('twitter', 172),
#  ('vulnerability', 171),
#  ('lanedetection', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('chatbot', 168),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('tool', 164),
#  ('objecttracking', 163),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('signalprocessing', 161),
#  ('medicalimaging', 160),
#  ('template', 160),
#  ('gan', 160),
#  ('cloudnative', 160),
#  ('electron', 159),
#  ('scala', 159),
#  ('smarthome', 158),
#  ('autonomousvehicles', 158),
#  ('securityaudit', 158),
#  ('randomforest', 157),
#  ('androidapplication', 157),
#  ('cuda', 157),
#  ('maskrcnn', 156),
#  ('ssd', 156),
#  ('learning', 156),
#  ('email', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('tailwindcss', 155),
#  ('opengl', 155),
#  ('commandline', 155),
#  ('monitor', 154),
#  ('bigdata', 154),
#  ('browser', 154),
#  ('smartcontracts', 154),
#  ('microservice', 154),
#  ('malwareresearch', 153),
#  ('trading', 152),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('wordpressplugin', 151),
#  ('networkanalysis', 151),
#  ('dockerimage', 151),
#  ('terminal', 150),
#  ('unity3d', 149),
#  ('outlierdetection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('textclassification', 148),
#  ('3d', 148),
#  ('onnx', 147),
#  ('threatintel', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('expressjs', 145),
#  ('apple', 145),
#  ('selenium', 145),
#  ('rails', 144),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('edgedetection', 144),
#  ('alerts', 143),
#  ('dotnetcore', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('datastructures', 143),
#  ('frauddetection', 143),
#  ('cicd', 142),
#  ('css3', 141),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('streaming', 140),
#  ('gameengine', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('windows10', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('intrusiondetection', 138),
#  ('openapi', 137),
#  ('siem', 137),
#  ('generativeadversarialnetwork', 137),
#  ('phishing', 137),
#  ('deployment', 136),
#  ('hackingtool', 136),
#  ('inference', 136),
#  ('swiftui', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('heroku', 134),
#  ('videoprocessing', 134),
#  ('dlib', 134),
#  ('nlpmachinelearning', 133),
#  ('selfhosted', 133),
#  ('websocket', 132),
#  ('vision', 132),
#  ('vscode', 132),
#  ('terraformmodule', 132),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('springcloud', 130),
#  ('androidlibrary', 130),
#  ('augmentedreality', 129),
#  ('backup', 129),
#  ('bootstrap4', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheusexporter', 128),
#  ('alertmanager', 128),
#  ('boilerplate', 127),
#  ('recognition', 127),
#  ('chrome', 126),
#  ('openai', 125),
#  ('hack', 125),
#  ('embedded', 125),
#  ('papers', 124),
#  ('webrtc', 124),
#  ('tensorflowlite', 124),
#  ('3dobjectdetection', 124),
#  ('npm', 124),
#  ('client', 124),
#  ('benchmark', 123),
#  ('app', 122),
#  ('gamedev', 122),
#  ('textdetection', 122),
#  ('vim', 122),
#  ('backend', 122),
#  ('infrastructure', 122),
#  ('statuspage', 122),
#  ('cnnkeras', 121),
#  ('distributedsystems', 121),
#  ('ssl', 121),
#  ('autoencoder', 121),
#  ('jenkins', 121),
#  ('kibana', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('vulnerabilitydetection', 120),
#  ('tls', 120),
#  ('demo', 120),
#  ('workflow', 119),
#  ('selfsupervisedlearning', 119),
#  ('graphneuralnetworks', 119),
#  ('featureextraction', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('mlops', 118),
#  ('language', 117),
#  ('tensorflowjs', 117),
#  ('mediapipe', 117),
#  ('materialdesign', 117),
#  ('ecommerce', 117),
#  ('web3', 117),
#  ('vpn', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('resnet', 115),
#  ('optimization', 114),
#  ('unet', 114),
#  ('module', 114),
#  ('programming', 114),
#  ('changedetection', 114),
#  ('emotionrecognition', 114),
#  ('googlecloud', 113),
#  ('pushnotifications', 113),
#  ('developertools', 113),
#  ('uptimemonitor', 113),
#  ('uikit', 112),
#  ('sklearn', 112),
#  ('networksecurity', 111),
#  ('bluetooth', 111),
#  ('digitalforensics', 111),
#  ('education', 111),
#  ('crawler', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfestaccepted', 110),
#  ('streamlit', 109),
#  ('compliance', 109),
#  ('awesomelists', 109),
#  ('webassembly', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('hardware', 107),
#  ('cluster', 107),
#  ('translation', 107),
#  ('securityautomation', 107),
#  ('package', 107),
#  ('androidapp', 107),
#  ('rnn', 106),
#  ('vulnerabilities', 106),
#  ('communitydetection', 105),
#  ('finance', 105),
#  ('bestpractices', 105),
#  ('hackingtools', 105),
#  ('pwa', 105),
#  ('vscodeextension', 105),
#  ('sqlite', 105),
#  ('terraformmodules', 105),
#  ('springsecurity', 105),
#  ('intel', 105),
#  ('apigateway', 104),
#  ('vehicledetection', 104),
#  ('arduinolibrary', 104),
#  ('vulnerabilityscanners', 104),
#  ('collisiondetection', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('computerscience', 103),
#  ('pretrainedmodels', 103),
#  ('aspnetcore', 103),
#  ('animation', 102),
#  ('edgecomputing', 102),
#  ('csv', 101),
#  ('logisticregression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('genomics', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('script', 100),
#  ('commandlinetool', 100),
#  ('googlecloudplatform', 99),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('search', 99),
#  ('emotiondetection', 99),
#  ('postgres', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('hacktoberfest2021', 98),
#  ('fastapi', 98),
#  ('infrastructureascode', 97),
#  ('satelliteimagery', 97),
#  ('cheatsheet', 97),
#  ('audioprocessing', 97),
#  ('cnnclassification', 97),
#  ('project', 96),
#  ('owasp', 96),
#  ('kalilinux', 96),
#  ('openshift', 95),
#  ('hacktoberfest2020', 95),
#  ('kotlinandroid', 95),
#  ('facemaskdetection', 95),
#  ('cocoapods', 95),
#  ('edge', 95),
#  ('nmap', 95),
#  ('mobilenet', 95),
#  ('timeseriesanalysis', 95),
#  ('theme', 94),
#  ('yolov2', 94),
#  ('validation', 94),
#  ('svmclassifier', 94),
#  ('uicomponents', 94),
#  ('materialui', 94),
#  ('tflite', 94),
#  ('influxdb', 94),
#  ('interviewquestions', 94),
#  ('regression', 93),
#  ('physics', 93),
#  ('imagenet', 93),
#  ('async', 93),
#  ('filesystem', 93),
#  ('websockets', 93),
#  ('rstats', 93),
#  ('hacktoberfest2022', 93),
#  ('speech', 92),
#  ('mobilenetv2', 92),
#  ('cv', 92),
#  ('gitops', 92),
#  ('chat', 92),
#  ('sass', 91),
#  ('apiclient', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentesttool', 90),
#  ('audit', 90),
#  ('games', 90),
#  ('service', 90),
#  ('scraper', 90),
#  ('speechtotext', 90),
#  ('webapplication', 90),
#  ('supervisedlearning', 89),
#  ('container', 89),
#  ('cloudformation', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attentionmechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('motiondetection', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('tradingbot', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('imageanalysis', 88),
#  ('pytorchimplementation', 88),
#  ('firefox', 88),
#  ('tcp', 88),
#  ('coursera', 87),
#  ('extension', 87),
#  ('wallet', 87),
#  ('coco', 87),
#  ('svelte', 87),
#  ('mitreattack', 87),
#  ('awss3', 87),
#  ('amazon', 86),
#  ('humanposeestimation', 86),
#  ('middleware', 86),
#  ('webdevelopment', 86),
#  ('xml', 86),
#  ('networkmonitoring', 86),
#  ('informationsecurity', 86),
#  ('securityscanner', 86),
#  ('binance', 86),
#  ('interview', 86),
#  ('bashscript', 86),
#  ('zabbix', 86),
#  ('grpc', 85),
#  ('sqlserver', 85),
#  ('clojure', 85),
#  ('webscraping', 85),
#  ('honeypot', 85),
#  ('healthcare', 85),
#  ('activedirectory', 85),
#  ('p2p', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('redteaming', 84),
#  ('restfulapi', 84),
#  ('recurrentneuralnetworks', 84),
#  ('lightweight', 84),
#  ('coreml', 84),
#  ('ctfwriteups', 84),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flaskapplication', 82),
#  ('webcam', 82),
#  ('homeassistantconfig', 82),
#  ('i18n', 82),
#  ('guide', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('cloudcomputing', 82),
#  ('retinanet', 82),
#  ('blog', 82),
#  ('artificialneuralnetworks', 82),
#  ('bypass', 81),
#  ('continuousintegration', 81),
#  ('maven', 81),
#  ('javascriptlibrary', 81),
#  ('popup', 81),
#  ('logger', 81),
#  ('textrecognition', 81),
#  ('monitoringtool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('fakenews', 80),
#  ('php7', 80),
#  ('log', 80),
#  ('jetsonnano', 80),
#  ('dataengineering', 80),
#  ('development', 80),
#  ('application', 80),
#  ('perl', 80),
#  ('pyqt5', 80),
#  ('cyberthreatintelligence', 80),
#  ('gps', 80),
#  ('stream', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graphalgorithms', 79),
#  ('fullstack', 79),
#  ('angular2', 79),
#  ('attack', 79),
#  ('nvidia', 79),
#  ('actionrecognition', 79),
#  ('webcomponents', 79),
#  ('toast', 79),
#  ('languagedetection', 79),
#  ('tutorials', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('pythonscript', 78),
#  ('obfuscation', 78),
#  ('hooks', 78),
#  ('threejs', 78),
#  ('sms', 78),
#  ('internetofthings', 77),
#  ('example', 77),
#  ('convolutionalneuralnetwork', 77),
#  ('xgboost', 77),
#  ('compiler', 77),
#  ('intrusiondetectionsystem', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('nodered', 76),
#  ('searchengine', 76),
#  ('windows11', 76),
#  ('qrcode', 76),
#  ('pythonlibrary', 76),
#  ('ransomware', 75),
#  ('facialrecognition', 75),
#  ('raspberrypi3', 75),
#  ('forensicanalysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('osx', 75),
#  ('cloudsecurity', 75),
#  ('gplv3', 75),
#  ('suricata', 75),
#  ('training', 75),
#  ('linearregression', 74),
#  ('debugging', 74),
#  ('backdoor', 74),
#  ('editor', 74),
#  ('cache', 74),
#  ('dataaugmentation', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('bruteforce', 73),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('cleanarchitecture', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('logs', 73),
#  ('distributed', 73),
#  ('prediction', 73),
#  ('androidstudio', 73),
#  ('ble', 73),
#  ('npmpackage', 73),
#  ('gpt3', 73),
#  ('pcap', 73),
#  ('semisupervisedlearning', 72),
#  ('yararules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('messaging', 72),
#  ('gpt', 72),
#  ('securityhardening', 72),
#  ('lidarpointcloud', 72),
#  ('adversarialattacks', 72),
#  ('3dreconstruction', 72),
#  ('programminglanguage', 72),
#  ('htmlcssjavascript', 72),
#  ('ajax', 71),
#  ('offensivesecurity', 71),
#  ('cti', 71),
#  ('filter', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('softwareengineering', 71),
#  ('jqueryplugin', 71),
#  ('mac', 71),
#  ('ethicalhacking', 71),
#  ('https', 71),
#  ('llm', 71),
#  ('multithreading', 71),
#  ('rustlang', 71),
#  ('multiobjecttracking', 71),
#  ('cpu', 71),
#  ('scss', 70),
#  ('deepsort', 70),
#  ('sandbox', 70),
#  ('androiddevelopment', 70),
#  ('management', 70),
#  ('visiontransformer', 70),
#  ('integration', 70),
#  ('stm32', 70),
#  ('defi', 70),
#  ('kalmanfilter', 70),
#  ('salientobjectdetection', 70),
#  ('facealignment', 70),
#  ('awsec2', 70),
#  ('virus', 70),
#  ('crud', 69),
#  ('test', 69),
#  ('angularjs', 69),
#  ('cms', 69),
#  ('ec2', 69),
#  ('azurefunctions', 69),
#  ('virtualmachine', 69),
#  ('apache', 69),
#  ('radar', 69),
#  ('rnaseq', 69),
#  ('vue3', 69),
#  ('hash', 69),
#  ('haarcascade', 69),
#  ('jest', 69),
#  ('vgg16', 68),
#  ('notes', 68),
#  ('streamprocessing', 68),
#  ('vault', 68),
#  ('domainadaptation', 68),
#  ('federatedlearning', 68),
#  ('svg', 68),
#  ('operatingsystem', 68),
#  ('oracle', 68),
#  ('ionic', 68),
#  ('facebook', 68),
#  ('amazonwebservices', 68),
#  ('iobroker', 68),
#  ('scraping', 68),
#  ('mongoose', 67),
#  ('ioc', 67),
#  ('boundingboxes', 67),
#  ('emulator', 67),
#  ('gpt4', 67),
#  ('graphics', 67),
#  ('drone', 67),
#  ('qt5', 67),
#  ('automl', 67),
#  ('wrapper', 67),
#  ('utility', 67),
#  ('events', 67),
#  ('facenet', 67),
#  ('widget', 67),
#  ('simulator', 67),
#  ('trojan', 66),
#  ('engine', 66),
#  ('antivirusevasion', 66),
#  ('etl', 66),
#  ('orm', 66),
#  ('cpp17', 66),
#  ('socketio', 66),
#  ('rat', 66),
#  ('form', 66),
#  ('tracing', 66),
#  ('sensorfusion', 66),
#  ('unix', 66),
#  ('texttospeech', 66),
#  ('configuration', 66),
#  ('navigation', 66),
#  ('pedestriandetection', 66),
#  ('software', 66),
#  ('mapping', 65),
#  ('kubernetescluster', 65),
#  ('gateway', 65),
#  ('admindashboard', 65),
#  ('collection', 65),
#  ('sdr', 65),
#  ('letsencrypt', 65),
#  ('textmining', 65),
#  ('facetracking', 65),
#  ('edgeai', 65),
#  ('embeddedsystems', 65),
#  ('rpackage', 65),
#  ('googlecolab', 65),
#  ('fast', 64),
#  ('webserver', 64),
#  ('ansiblerole', 64),
#  ('gis', 64),
#  ('steganography', 64),
#  ('lists', 64),
#  ('bypassantivirus', 64),
#  ('system', 64),
#  ('iosapp', 64),
#  ('shellscript', 64),
#  ('websecurity', 64),
#  ('forecasting', 64),
#  ('neovim', 64),
#  ('bootstrap5', 64),
#  ('ocrrecognition', 63),
#  ('community', 63),
#  ('composer', 63),
#  ('nosql', 63),
#  ('python2', 63),
#  ('cisco', 63),
#  ('bluetoothlowenergy', 63),
#  ('radio', 63),
#  ('objectrecognition', 63),
#  ('archlinux', 63),
#  ('maskdetection', 63),
#  ('tesseract', 63),
#  ('paperlist', 63),
#  ('testingtools', 63),
#  ('smtp', 62),
#  ('ebpf', 62),
#  ('cdk', 62),
#  ('interviewpreparation', 62),
#  ('usb', 62),
#  ('voiceactivitydetection', 62),
#  ('eeg', 62),
#  ('sre', 62),
#  ('java8', 62),
#  ('chess', 62),
#  ('cnnmodel', 62),
#  ('verilog', 62),
#  ('keyboard', 62),
#  ('cheat', 62),
#  ('pentestingtools', 62),
#  ('config', 61),
#  ('javafx', 61),
#  ('fingerprint', 61),
#  ('dockercontainer', 61),
#  ('waf', 61),
#  ('telemetry', 61),
#  ('linter', 61),
#  ('mvvm', 61),
#  ('faciallandmarks', 61),
#  ('actions', 61),
#  ('reactrouter', 61),
#  ('anticheat', 61),
#  ('jetson', 61),
#  ('socialmedia', 61),
#  ('apns', 61),
#  ('kagglecompetition', 61),
#  ('virtualization', 61),
#  ('kmeansclustering', 61),
#  ('attention', 61),
#  ('productivity', 61),
#  ('protection', 61),
#  ('wireless', 60),
#  ('hardening', 60),
#  ('sensors', 60),
#  ('arkit', 60),
#  ('deprecated', 60),
#  ('sagemaker', 60),
#  ('memory', 60),
#  ('informationgathering', 60),
#  ('osquery', 60),
#  ('linuxkernel', 60),
#  ('annotations', 60),
#  ('cordovaplugin', 60),
#  ('resnet50', 60),
#  ('virustotal', 60),
#  ('syntaxhighlighting', 60),
#  ('tkinter', 60),
#  ('explainableai', 60),
#  ('voice', 60),
#  ('socialnetwork', 60),
#  ('news', 60),
#  ('emotion', 60),
#  ('reactcomponents', 60),
#  ('enumeration', 59),
#  ('purpleteam', 59),
#  ('hackintosh', 59),
#  ('tensorflowobjectdetectionapi', 59),
#  ('agent', 59),
#  ('devopstools', 59),
#  ('native', 59),
#  ('eks', 59),
#  ('clamav', 59),
#  ('dockerfile', 59),
#  ('survey', 59),
#  ('md', 59),
#  ('books', 59),
#  ('puppet', 59),
#  ('forms', 59),
#  ('cassandra', 59),
#  ('ddos', 59),
#  ('iac', 59),
#  ('cpp11', 59),
#  ('browserextension', 59),
#  ('portfolio', 59),
#  ('udp', 59),
#  ('rcnn', 58),
#  ('onnxruntime', 58),
#  ('mvc', 58),
#  ('graphs', 58),
#  ('iphone', 58),
#  ('operator', 58),
#  ('lstmneuralnetworks', 58),
#  ('stockmarket', 58),
#  ('ensemblelearning', 58),
#  ('multimodal', 58),
#  ('instagram', 58),
#  ('tracker', 58),
#  ('gitlab', 58),
#  ('vagrant', 58),
#  ('designpatterns', 58),
#  ('salesforce', 58),
#  ('pca', 58),
#  ('testautomation', 57),
#  ('opencv3', 57),
#  ('regex', 57),
#  ('consul', 57),
#  ('geolocation', 57),
#  ('mining', 57),
#  ('eyetracking', 57),
#  ('scanning', 57),
#  ('3dprinting', 57),
#  ('alarm', 57),
#  ('medicalimageprocessing', 57),
#  ('neo4j', 57),
#  ('compression', 57),
#  ('dotfiles', 57),
#  ('cvpr', 57),
#  ('featureengineering', 57),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 1.3 (D_T5)
# ```
# in: name, topics
# out: name, topics (tokeinzed not lematized, but w composition)
#
# there was an error 1.3 shouldnt be lematized, so 1.3 is now saved as lemmatized and 1.3.1 is not lemma
# ```

# %%
sgf.topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(preprocess_text(' '.join(x), lem=True, do_composition=True)))

# %%
Counter(sgf.topics_removed).most_common()
# Out:
# [('d', 10),
#  ('can', 9),
#  ('did', 9),
#  ('re', 7),
#  ('it', 7),
#  ('i', 5),
#  ('a', 5),
#  ('all', 4),
#  ('up', 4),
#  ('and', 4),
#  ('will', 4),
#  ('for', 4),
#  ('this', 3),
#  ('of', 3),
#  ('who', 3),
#  ('s', 3),
#  ('from', 2),
#  ('about', 2),
#  ('myself', 2),
#  ('the', 2),
#  ('its', 2),
#  ('same', 2),
#  ('any', 2),
#  ('is', 2),
#  ('m', 2),
#  ('to', 2),
#  ('other', 2),
#  ('now', 2),
#  ('ll', 1),
#  ('nor', 1),
#  ('y', 1),
#  ('them', 1),
#  ('over', 1),
#  ('down', 1),
#  ('more', 1),
#  ('isn', 1),
#  ('at', 1),
#  ('your', 1),
#  ('with', 1),
#  ('on', 1),
#  ('off', 1),
#  ('t', 1),
#  ('what', 1),
#  ('does', 1),
#  ('an', 1),
#  ('my', 1),
#  ('ve', 1),
#  ('do', 1),
#  ('no', 1),
#  ('here', 1),
#  ('why', 1)]

# %%
github_data_wtopic
# Out:
#                                           name  \
# 6               thingsym/multi-device-switcher
# 8       redlink-gmbh/solr-compound-word-filter
# 9         xswlme/Delivery-Availability-Checker
# 10                    eastsss/ErrorDispatching
# 11                       ahmadhuzaifa/skinskan
# ...                                        ...
# 221952                   waqasbhatti/astrobase
# 221955                 hpcc-systems/vscode-ecl
# 221965                   MarcoPon/BlockHashLoc
# 221966           bhagatabhijeet/bhagatabhijeet
# 221967           LandGrey/SpringBootVulExploit
#
#                                                    topics
# 6                               wordpress wordpressplugin
# 8                     solr lucene luceneanalyzer language
# 9       amazon chromeextension fooddelivery grocerydel...
# 10      swift ios errorhandling custom chainofresponsi...
# 11      cnn cnnkeras skincancer tensorflow ai machinel...
# ...                                                   ...
# 221952         lightcurves astronomy python variablestars
# 221955                 vscode typescript ecl hpccplatform
# 221965  bhl recovery hash block metadata undelete unfo...
# 221966  bhagatabhijeet abhijeetbhagat abhijeetbhagat s...
# 221967  springboot springbootactuatorrce rce springboo...
#
# [69817 rows x 2 columns]

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 88364

# %%
to_disk(github_data_wtopic, 't1.3')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.3.pkl

# %%
from collections import Counter
word_cnt_t1_2 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1_2.update(t.split(' '))


word_cnt_t1_2.most_common()
# Out:
# [('python', 6323),
#  ('deeplearning', 5300),
#  ('machinelearning', 4665),
#  ('computervision', 3010),
#  ('javascript', 2744),
#  ('security', 2657),
#  ('objectdetection', 2617),
#  ('pytorch', 2166),
#  ('tensorflow', 2125),
#  ('opencv', 2055),
#  ('hacktoberfest', 2010),
#  ('python3', 1781),
#  ('android', 1676),
#  ('docker', 1658),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1373),
#  ('monitor', 1285),
#  ('aws', 1264),
#  ('golang', 1252),
#  ('kubernetes', 1223),
#  ('awesomelist', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('imageprocessing', 1000),
#  ('facedetection', 987),
#  ('typescript', 971),
#  ('keras', 871),
#  ('windows', 848),
#  ('datascience', 836),
#  ('nlp', 823),
#  ('cybersecurity', 819),
#  ('api', 802),
#  ('go', 783),
#  ('artificialintelligence', 738),
#  ('anomalydetection', 738),
#  ('alert', 737),
#  ('raspberrypi', 736),
#  ('hack', 727),
#  ('swift', 721),
#  ('convolutionalneuralnetworks', 704),
#  ('cnn', 698),
#  ('ai', 672),
#  ('cpp', 660),
#  ('neuralnetwork', 653),
#  ('securitytools', 653),
#  ('facerecognition', 647),
#  ('automation', 637),
#  ('terraform', 615),
#  ('opensource', 609),
#  ('prometheus', 600),
#  ('dataset', 598),
#  ('azure', 584),
#  ('iot', 580),
#  ('naturallanguageprocessing', 579),
#  ('html', 575),
#  ('csharp', 574),
#  ('rust', 561),
#  ('yolo', 557),
#  ('macos', 551),
#  ('flask', 547),
#  ('network', 541),
#  ('deepneuralnetworks', 538),
#  ('blockchain', 536),
#  ('css', 527),
#  ('classification', 526),
#  ('game', 522),
#  ('reactjs', 520),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 501),
#  ('bot', 498),
#  ('springboot', 498),
#  ('reactnative', 483),
#  ('c', 469),
#  ('cli', 464),
#  ('cryptography', 461),
#  ('yolov3', 457),
#  ('homeassistant', 454),
#  ('opencvpython', 453),
#  ('segmentation', 452),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 432),
#  ('vue', 427),
#  ('library', 415),
#  ('tool', 414),
#  ('imageclassification', 412),
#  ('cloud', 411),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('realtime', 406),
#  ('django', 403),
#  ('covid19', 403),
#  ('database', 399),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('log', 387),
#  ('bugbounty', 383),
#  ('mongodb', 372),
#  ('cryptocurrency', 372),
#  ('ruby', 371),
#  ('web', 367),
#  ('cplusplus', 365),
#  ('neuralnetworks', 360),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('ocr', 349),
#  ('timeseries', 348),
#  ('elasticsearch', 344),
#  ('matlab', 334),
#  ('penetrationtesting', 333),
#  ('test', 331),
#  ('yolov5', 331),
#  ('ansible', 330),
#  ('threathunting', 330),
#  ('plugin', 329),
#  ('postgresql', 328),
#  ('restapi', 326),
#  ('bootstrap', 323),
#  ('paper', 322),
#  ('malwareanalysis', 321),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('antivirus', 319),
#  ('cluster', 319),
#  ('mysql', 317),
#  ('discord', 317),
#  ('metrics', 315),
#  ('reverseengineering', 311),
#  ('threatintelligence', 311),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('json', 308),
#  ('list', 305),
#  ('notifications', 304),
#  ('r', 303),
#  ('jupyternotebook', 302),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('dotnet', 297),
#  ('framework', 295),
#  ('incidentresponse', 292),
#  ('redteam', 286),
#  ('github', 286),
#  ('audio', 284),
#  ('firebase', 278),
#  ('osint', 275),
#  ('dockercompose', 274),
#  ('sql', 273),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('transferlearning', 267),
#  ('bash', 266),
#  ('visualization', 259),
#  ('track', 259),
#  ('semanticsegmentation', 257),
#  ('dfir', 257),
#  ('encryption', 256),
#  ('graph', 253),
#  ('html5', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 248),
#  ('microservices', 246),
#  ('image', 245),
#  ('gui', 245),
#  ('autonomousdriving', 245),
#  ('homeautomation', 244),
#  ('dataanalysis', 244),
#  ('unity', 244),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('lstm', 239),
#  ('ui', 239),
#  ('jquery', 238),
#  ('redis', 237),
#  ('stream', 236),
#  ('pointcloud', 236),
#  ('algorithms', 231),
#  ('js', 231),
#  ('awslambda', 231),
#  ('vuejs', 227),
#  ('poseestimation', 227),
#  ('http', 225),
#  ('exploit', 225),
#  ('sdk', 221),
#  ('gamedevelopment', 221),
#  ('machinelearningalgorithms', 219),
#  ('frontend', 219),
#  ('kerastensorflow', 217),
#  ('tensorflow2', 217),
#  ('datavisualization', 215),
#  ('selfdrivingcar', 215),
#  ('fasterrcnn', 212),
#  ('imagesegmentation', 210),
#  ('telegrambot', 209),
#  ('authentication', 209),
#  ('containers', 208),
#  ('ml', 207),
#  ('redux', 204),
#  ('scikitlearn', 203),
#  ('dart', 202),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('git', 199),
#  ('objectivec', 197),
#  ('webapp', 197),
#  ('scanner', 197),
#  ('spark', 196),
#  ('blueteam', 196),
#  ('unsupervisedlearning', 195),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('data', 194),
#  ('face', 194),
#  ('ids', 194),
#  ('learn', 193),
#  ('githubactions', 193),
#  ('script', 192),
#  ('transformer', 191),
#  ('express', 191),
#  ('discordbot', 190),
#  ('slack', 190),
#  ('remotesensing', 190),
#  ('mobile', 190),
#  ('yolov4', 189),
#  ('pandas', 186),
#  ('analytics', 186),
#  ('crossplatform', 186),
#  ('esp8266', 185),
#  ('speechrecognition', 185),
#  ('malwaredetection', 185),
#  ('datamining', 183),
#  ('rest', 183),
#  ('reinforcementlearning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentimentanalysis', 182),
#  ('slam', 181),
#  ('imagerecognition', 181),
#  ('observability', 179),
#  ('instancesegmentation', 178),
#  ('darknet', 178),
#  ('chatgpt', 178),
#  ('gin', 178),
#  ('graphql', 177),
#  ('wifi', 177),
#  ('resources', 177),
#  ('dns', 177),
#  ('staticanalysis', 176),
#  ('trade', 176),
#  ('lidar', 175),
#  ('server', 174),
#  ('spring', 174),
#  ('chromeextension', 173),
#  ('devsecops', 173),
#  ('yara', 172),
#  ('twitter', 172),
#  ('vulnerability', 171),
#  ('lanedetection', 170),
#  ('email', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('chatbot', 168),
#  ('map', 167),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('objecttracking', 163),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('signalprocessing', 161),
#  ('medicalimaging', 160),
#  ('template', 160),
#  ('cloudnative', 160),
#  ('electron', 159),
#  ('scala', 159),
#  ('smarthome', 158),
#  ('autonomousvehicles', 158),
#  ('securityaudit', 158),
#  ('randomforest', 157),
#  ('androidapplication', 157),
#  ('cuda', 157),
#  ('maskrcnn', 156),
#  ('ssd', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('tailwindcss', 155),
#  ('opengl', 155),
#  ('commandline', 155),
#  ('bigdata', 154),
#  ('browser', 154),
#  ('smartcontracts', 154),
#  ('microservice', 154),
#  ('malwareresearch', 153),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('wordpressplugin', 151),
#  ('networkanalysis', 151),
#  ('dockerimage', 151),
#  ('terminal', 150),
#  ('unity3d', 149),
#  ('outlierdetection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('textclassification', 148),
#  ('3d', 148),
#  ('onnx', 147),
#  ('threatintel', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('expressjs', 145),
#  ('apple', 145),
#  ('selenium', 145),
#  ('rail', 144),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('edgedetection', 144),
#  ('dotnetcore', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('datastructures', 143),
#  ('frauddetection', 143),
#  ('embed', 143),
#  ('cicd', 142),
#  ('css3', 141),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('hook', 140),
#  ('gameengine', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('windows10', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('package', 138),
#  ('intrusiondetection', 138),
#  ('openapi', 137),
#  ('siem', 137),
#  ('generativeadversarialnetwork', 137),
#  ('phishing', 137),
#  ('project', 136),
#  ('deployment', 136),
#  ('hackingtool', 136),
#  ('inference', 136),
#  ('swiftui', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('heroku', 134),
#  ('videoprocessing', 134),
#  ('dlib', 134),
#  ('nlpmachinelearning', 133),
#  ('selfhosted', 133),
#  ('websocket', 132),
#  ('vision', 132),
#  ('vscode', 132),
#  ('terraformmodule', 132),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('springcloud', 130),
#  ('androidlibrary', 130),
#  ('augmentedreality', 129),
#  ('backup', 129),
#  ('bootstrap4', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheusexporter', 128),
#  ('alertmanager', 128),
#  ('boilerplate', 127),
#  ('recognition', 127),
#  ('chrome', 126),
#  ('openai', 125),
#  ('form', 125),
#  ('demo', 125),
#  ('webrtc', 124),
#  ('tensorflowlite', 124),
#  ('3dobjectdetection', 124),
#  ('npm', 124),
#  ('client', 124),
#  ('audit', 123),
#  ('theme', 123),
#  ('benchmark', 123),
#  ('app', 122),
#  ('gamedev', 122),
#  ('filter', 122),
#  ('textdetection', 122),
#  ('vim', 122),
#  ('backend', 122),
#  ('infrastructure', 122),
#  ('statuspage', 122),
#  ('cnnkeras', 121),
#  ('distributedsystems', 121),
#  ('ssl', 121),
#  ('autoencoder', 121),
#  ('program', 121),
#  ('jenkins', 121),
#  ('kibana', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('service', 120),
#  ('vulnerabilitydetection', 120),
#  ('tls', 120),
#  ('workflow', 119),
#  ('selfsupervisedlearning', 119),
#  ('graphneuralnetworks', 119),
#  ('featureextraction', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('mlops', 118),
#  ('language', 117),
#  ('tensorflowjs', 117),
#  ('mediapipe', 117),
#  ('materialdesign', 117),
#  ('ecommerce', 117),
#  ('web3', 117),
#  ('vpn', 116),
#  ('model', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('resnet', 115),
#  ('optimization', 114),
#  ('unet', 114),
#  ('module', 114),
#  ('changedetection', 114),
#  ('book', 114),
#  ('emotionrecognition', 114),
#  ('googlecloud', 113),
#  ('pushnotifications', 113),
#  ('developertools', 113),
#  ('scan', 113),
#  ('uptimemonitor', 113),
#  ('uikit', 112),
#  ('sklearn', 112),
#  ('networksecurity', 111),
#  ('bluetooth', 111),
#  ('digitalforensics', 111),
#  ('education', 111),
#  ('crawler', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfestaccepted', 110),
#  ('streamlit', 109),
#  ('debug', 109),
#  ('compliance', 109),
#  ('awesomelists', 109),
#  ('webassembly', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('finance', 107),
#  ('hardware', 107),
#  ('translation', 107),
#  ('securityautomation', 107),
#  ('hash', 107),
#  ('androidapp', 107),
#  ('rnn', 106),
#  ('vulnerabilities', 106),
#  ('communitydetection', 105),
#  ('bestpractices', 105),
#  ('hackingtools', 105),
#  ('message', 105),
#  ('pwa', 105),
#  ('search', 105),
#  ('vscodeextension', 105),
#  ('sqlite', 105),
#  ('terraformmodules', 105),
#  ('springsecurity', 105),
#  ('intel', 105),
#  ('apigateway', 104),
#  ('vehicledetection', 104),
#  ('arduinolibrary', 104),
#  ('vulnerabilityscanners', 104),
#  ('collisiondetection', 104),
#  ('cache', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('fingerprint', 103),
#  ('computerscience', 103),
#  ('pretrainedmodels', 103),
#  ('aspnetcore', 103),
#  ('animation', 102),
#  ('edgecomputing', 102),
#  ('csv', 101),
#  ('logisticregression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('edge', 101),
#  ('genomics', 101),
#  ('trace', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('blog', 100),
#  ('attack', 100),
#  ('commandlinetool', 100),
#  ('googlecloudplatform', 99),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('emotiondetection', 99),
#  ('postgres', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('hacktoberfest2021', 98),
#  ('drone', 98),
#  ('fastapi', 98),
#  ('infrastructureascode', 97),
#  ('satelliteimagery', 97),
#  ('cheatsheet', 97),
#  ('audioprocessing', 97),
#  ('cnnclassification', 97),
#  ('interview', 97),
#  ('owasp', 96),
#  ('kalilinux', 96),
#  ('openshift', 95),
#  ('hacktoberfest2020', 95),
#  ('kotlinandroid', 95),
#  ('facemaskdetection', 95),
#  ('cocoapods', 95),
#  ('sample', 95),
#  ('nmap', 95),
#  ('mobilenet', 95),
#  ('timeseriesanalysis', 95),
#  ('yolov2', 94),
#  ('validation', 94),
#  ('svmclassifier', 94),
#  ('uicomponents', 94),
#  ('materialui', 94),
#  ('tflite', 94),
#  ('influxdb', 94),
#  ('interviewquestions', 94),
#  ('regression', 93),
#  ('physics', 93),
#  ('imagenet', 93),
#  ('async', 93),
#  ('filesystem', 93),
#  ('websockets', 93),
#  ('rstats', 93),
#  ('hacktoberfest2022', 93),
#  ('speech', 92),
#  ('mobilenetv2', 92),
#  ('cv', 92),
#  ('gitops', 92),
#  ('chat', 92),
#  ('sass', 91),
#  ('apiclient', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentesttool', 90),
#  ('guide', 90),
#  ('scraper', 90),
#  ('speechtotext', 90),
#  ('webapplication', 90),
#  ('supervisedlearning', 89),
#  ('container', 89),
#  ('cloudformation', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attentionmechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('motiondetection', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('tradingbot', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('action', 88),
#  ('imageanalysis', 88),
#  ('pytorchimplementation', 88),
#  ('firefox', 88),
#  ('tcp', 88),
#  ('bypass', 87),
#  ('coursera', 87),
#  ('extension', 87),
#  ('wallet', 87),
#  ('chart', 87),
#  ('coco', 87),
#  ('svelte', 87),
#  ('mitreattack', 87),
#  ('awss3', 87),
#  ('amazon', 86),
#  ('humanposeestimation', 86),
#  ('middleware', 86),
#  ('webdevelopment', 86),
#  ('xml', 86),
#  ('networkmonitoring', 86),
#  ('informationsecurity', 86),
#  ('securityscanner', 86),
#  ('binance', 86),
#  ('bashscript', 86),
#  ('zabbix', 86),
#  ('train', 86),
#  ('grpc', 85),
#  ('sqlserver', 85),
#  ('clojure', 85),
#  ('webscraping', 85),
#  ('honeypot', 85),
#  ('healthcare', 85),
#  ('activedirectory', 85),
#  ('p2p', 85),
#  ('toast', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('redteaming', 84),
#  ('restfulapi', 84),
#  ('parse', 84),
#  ('recurrentneuralnetworks', 84),
#  ('lightweight', 84),
#  ('coreml', 84),
#  ('ctfwriteups', 84),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flaskapplication', 82),
#  ('webcam', 82),
#  ('homeassistantconfig', 82),
#  ('i18n', 82),
#  ('rat', 82),
#  ('process', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('cloudcomputing', 82),
#  ('retinanet', 82),
#  ('artificialneuralnetworks', 82),
#  ('continuousintegration', 81),
#  ('maven', 81),
#  ('javascriptlibrary', 81),
#  ('popup', 81),
#  ('logger', 81),
#  ('textrecognition', 81),
#  ('monitoringtool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('fakenews', 80),
#  ('php7', 80),
#  ('jetsonnano', 80),
#  ('dataengineering', 80),
#  ('development', 80),
#  ('application', 80),
#  ('file', 80),
#  ('perl', 80),
#  ('forecast', 80),
#  ('pyqt5', 80),
#  ('cyberthreatintelligence', 80),
#  ('gps', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graphalgorithms', 79),
#  ('fullstack', 79),
#  ('angular2', 79),
#  ('nvidia', 79),
#  ('actionrecognition', 79),
#  ('webcomponents', 79),
#  ('languagedetection', 79),
#  ('tutorials', 79),
#  ('cheat', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('pythonscript', 78),
#  ('obfuscation', 78),
#  ('threejs', 78),
#  ('sms', 78),
#  ('internetofthings', 77),
#  ('example', 77),
#  ('convolutionalneuralnetwork', 77),
#  ('certificate', 77),
#  ('xgboost', 77),
#  ('compiler', 77),
#  ('intrusiondetectionsystem', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('nodered', 76),
#  ('searchengine', 76),
#  ('windows11', 76),
#  ('qrcode', 76),
#  ('pythonlibrary', 76),
#  ('scrap', 76),
#  ('ransomware', 75),
#  ('facialrecognition', 75),
#  ('raspberrypi3', 75),
#  ('forensicanalysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('osx', 75),
#  ('cloudsecurity', 75),
#  ('gplv3', 75),
#  ('suricata', 75),
#  ('linearregression', 74),
#  ('backdoor', 74),
#  ('distribute', 74),
#  ('editor', 74),
#  ('dataaugmentation', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('bruteforce', 73),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('cleanarchitecture', 73),
#  ('note', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('prediction', 73),
#  ('androidstudio', 73),
#  ('ble', 73),
#  ('npmpackage', 73),
#  ('gpt3', 73),
#  ('pcap', 73),
#  ('semisupervisedlearning', 72),
#  ('yararules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('gpt', 72),
#  ('securityhardening', 72),
#  ('report', 72),
#  ('lidarpointcloud', 72),
#  ('adversarialattacks', 72),
#  ('3dreconstruction', 72),
#  ('programminglanguage', 72),
#  ('htmlcssjavascript', 72),
#  ('ajax', 71),
#  ('offensivesecurity', 71),
#  ('cti', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('softwareengineering', 71),
#  ('jqueryplugin', 71),
#  ('mac', 71),
#  ('ethicalhacking', 71),
#  ('https', 71),
#  ('course', 71),
#  ('llm', 71),
#  ('multithreading', 71),
#  ('rustlang', 71),
#  ('multiobjecttracking', 71),
#  ('cpu', 71),
#  ('scss', 70),
#  ('stock', 70),
#  ('deepsort', 70),
#  ('sandbox', 70),
#  ('androiddevelopment', 70),
#  ('management', 70),
#  ('visiontransformer', 70),
#  ('integration', 70),
#  ('stm32', 70),
#  ('defi', 70),
#  ('kalmanfilter', 70),
#  ('salientobjectdetection', 70),
#  ('facealignment', 70),
#  ('awsec2', 70),
#  ('virus', 70),
#  ('crud', 69),
#  ('angularjs', 69),
#  ('cms', 69),
#  ('ec2', 69),
#  ('azurefunctions', 69),
#  ('virtualmachine', 69),
#  ('apache', 69),
#  ('radar', 69),
#  ('rnaseq', 69),
#  ('vue3', 69),
#  ('haarcascade', 69),
#  ('jest', 69),
#  ('vgg16', 68),
#  ('streamprocessing', 68),
#  ('vault', 68),
#  ('domainadaptation', 68),
#  ('federatedlearning', 68),
#  ('svg', 68),
#  ('operatingsystem', 68),
#  ('oracle', 68),
#  ('ionic', 68),
#  ('facebook', 68),
#  ('amazonwebservices', 68),
#  ('iobroker', 68),
#  ('control', 67),
#  ('mongoose', 67),
#  ('ioc', 67),
#  ('boundingboxes', 67),
#  ('emulator', 67),
#  ('gpt4', 67),
#  ('graphics', 67),
#  ('qt5', 67),
#  ('automl', 67),
#  ('wrapper', 67),
#  ('utility', 67),
#  ('events', 67),
#  ('facenet', 67),
#  ('promise', 67),
#  ('widget', 67),
#  ('simulator', 67),
#  ('engineer', 66),
#  ('trojan', 66),
#  ('engine', 66),
#  ('antivirusevasion', 66),
#  ('etl', 66),
#  ('orm', 66),
#  ('cpp17', 66),
#  ('socketio', 66),
#  ('encode', 66),
#  ('sensorfusion', 66),
#  ('unix', 66),
#  ('texttospeech', 66),
#  ('configuration', 66),
#  ('navigation', 66),
#  ('article', 66),
#  ('pedestriandetection', 66),
#  ('software', 66),
#  ('gi', 65),
#  ('kubernetescluster', 65),
#  ('gateway', 65),
#  ('admindashboard', 65),
#  ('collection', 65),
#  ('sdr', 65),
#  ('letsencrypt', 65),
#  ('textmining', 65),
#  ('facetracking', 65),
#  ('sort', 65),
#  ('profile', 65),
#  ('edgeai', 65),
#  ('embeddedsystems', 65),
#  ('alarm', 65),
#  ('rpackage', 65),
#  ('googlecolab', 65),
#  ('fast', 64),
#  ('webserver', 64),
#  ('ansiblerole', 64),
#  ('harden', 64),
#  ('steganography', 64),
#  ('bypassantivirus', 64),
#  ('survey', 64),
#  ('system', 64),
#  ('iosapp', 64),
#  ('shellscript', 64),
#  ('websecurity', 64),
#  ('neovim', 64),
#  ('bootstrap5', 64),
#  ('ocrrecognition', 63),
#  ('community', 63),
#  ('composer', 63),
#  ('nosql', 63),
#  ('python2', 63),
#  ('cisco', 63),
#  ('bluetoothlowenergy', 63),
#  ('radio', 63),
#  ('objectrecognition', 63),
#  ('archlinux', 63),
#  ('voice', 63),
#  ('maskdetection', 63),
#  ('tesseract', 63),
#  ('paperlist', 63),
#  ('testingtools', 63),
#  ('prompt', 62),
#  ('label', 62),
#  ('smtp', 62),
#  ('ebpf', 62),
#  ('cdk', 62),
#  ('interviewpreparation', 62),
#  ('usb', 62),
#  ('voiceactivitydetection', 62),
#  ('eeg', 62),
#  ('sre', 62),
#  ('java8', 62),
#  ('chess', 62),
#  ('cnnmodel', 62),
#  ('verilog', 62),
#  ('keyboard', 62),
#  ('pentestingtools', 62),
#  ('config', 61),
#  ('javafx', 61),
#  ('dockercontainer', 61),
#  ('waf', 61),
#  ('telemetry', 61),
#  ('deprecate', 61),
#  ('linter', 61),
#  ('mvvm', 61),
#  ('faciallandmarks', 61),
#  ('reactrouter', 61),
#  ('mine', 61),
#  ('anticheat', 61),
#  ('jetson', 61),
#  ('socialmedia', 61),
#  ('apns', 61),
#  ('kagglecompetition', 61),
#  ('virtualization', 61),
#  ('kmeansclustering', 61),
#  ('attention', 61),
#  ('productivity', 61),
#  ('protection', 61),
#  ('wireless', 60),
#  ('sensors', 60),
#  ('arkit', 60),
#  ('sagemaker', 60),
#  ('memory', 60),
#  ('informationgathering', 60),
#  ('osquery', 60),
#  ('linuxkernel', 60),
#  ('annotations', 60),
#  ('cordovaplugin', 60),
#  ('resnet50', 60),
#  ('virustotal', 60),
#  ('syntaxhighlighting', 60),
#  ('tkinter', 60),
#  ('explainableai', 60),
#  ('socialnetwork', 60),
#  ('color', 60),
#  ('news', 60),
#  ('emotion', 60),
#  ('reactcomponents', 60),
#  ('enumeration', 59),
#  ('purpleteam', 59),
#  ('hackintosh', 59),
#  ('tensorflowobjectdetectionapi', 59),
#  ('agent', 59),
#  ('devopstools', 59),
#  ('native', 59),
#  ('eks', 59),
#  ('clamav', 59),
#  ('dockerfile', 59),
#  ('md', 59),
#  ('puppet', 59),
#  ('cassandra', 59),
#  ('ddos', 59),
#  ('iac', 59),
#  ('cpp11', 59),
#  ('browserextension', 59),
#  ('portfolio', 59),
#  ('udp', 59),
#  ('rcnn', 58),
#  ('onnxruntime', 58),
#  ('mvc', 58),
#  ('iphone', 58),
#  ('operator', 58),
#  ('lstmneuralnetworks', 58),
#  ('stockmarket', 58),
#  ('ensemblelearning', 58),
#  ('multimodal', 58),
#  ('instagram', 58),
#  ('tracker', 58),
#  ('gitlab', 58),
#  ('vagrant', 58),
#  ('designpatterns', 58),
#  ('salesforce', 58),
#  ('pca', 58),
#  ('secure', 57),
#  ('testautomation', 57),
#  ('opencv3', 57),
#  ('regex', 57),
#  ('consul', 57),
#  ('tree', 57),
#  ('geolocation', 57),
#  ('hunt', 57),
#  ('eyetracking', 57),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 1.4 (D_T6)
# ```
# in: name, topics
# out: name, topics (tokeinzed not lematized, but w composition and filter)
# ```

# %%
sgf.topics_removed = []
github_data_wtopic = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()

# %%
github_data_wtopic['topics'] = github_data_wtopic['topics'].apply(lambda x: ' '.join(preprocess_text(' '.join(x), lem=True, do_composition=True, token_list=topics_combined)))

# %%
Counter(sgf.topics_removed).most_common()
# Out:
# [('d', 10),
#  ('can', 9),
#  ('did', 9),
#  ('re', 7),
#  ('it', 7),
#  ('i', 5),
#  ('a', 5),
#  ('all', 4),
#  ('up', 4),
#  ('and', 4),
#  ('will', 4),
#  ('for', 4),
#  ('this', 3),
#  ('of', 3),
#  ('who', 3),
#  ('s', 3),
#  ('from', 2),
#  ('about', 2),
#  ('myself', 2),
#  ('the', 2),
#  ('its', 2),
#  ('same', 2),
#  ('any', 2),
#  ('is', 2),
#  ('m', 2),
#  ('to', 2),
#  ('other', 2),
#  ('now', 2),
#  ('ll', 1),
#  ('nor', 1),
#  ('y', 1),
#  ('them', 1),
#  ('over', 1),
#  ('down', 1),
#  ('more', 1),
#  ('isn', 1),
#  ('at', 1),
#  ('your', 1),
#  ('with', 1),
#  ('on', 1),
#  ('off', 1),
#  ('t', 1),
#  ('what', 1),
#  ('does', 1),
#  ('an', 1),
#  ('my', 1),
#  ('ve', 1),
#  ('do', 1),
#  ('no', 1),
#  ('here', 1),
#  ('why', 1)]

# %%
github_data_wtopic[github_data_wtopic['topics'].str.len() == 0]
# Out:
#                                     name topics
# 42                   LuisKay/Spec_ResNet
# 57             robo-ai/roboai-python-cli
# 93      ivankunyankin/intent_suggestions
# 211      usnistgov/PrivacyEngCollabSpace
# 248      MadDeCoDeR/Classic-RBDOOM-3-BFG
# ...                                  ...    ...
# 221897              HAC-2020/Cookie-Army
# 221904           Snausage0x45/KapeStrike
# 221909                     lupyuen/nuttx
# 221936            cenidetiot/ngsi-parser
# 221966     bhagatabhijeet/bhagatabhijeet
#
# [6508 rows x 2 columns]

# %%
github_data_wtopic = github_data_wtopic[github_data_wtopic['topics'].str.len() > 0]

# %%
len(set(github_data_wtopic['topics'].apply(lambda x: x.split(' ')).explode()))
# Out:
# 1567

# %%
to_disk(github_data_wtopic, 't1.4')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t1.4.pkl

# %%
from collections import Counter
word_cnt_t1_2 = Counter()
i = 0
for t in github_data_wtopic['topics']:
    i += 1
    word_cnt_t1_2.update(t.split(' '))


word_cnt_t1_2.most_common()
# Out:
# [('python', 6323),
#  ('deeplearning', 5300),
#  ('machinelearning', 4665),
#  ('computervision', 3010),
#  ('javascript', 2744),
#  ('security', 2657),
#  ('objectdetection', 2617),
#  ('pytorch', 2166),
#  ('tensorflow', 2125),
#  ('opencv', 2055),
#  ('hacktoberfest', 2010),
#  ('python3', 1781),
#  ('android', 1676),
#  ('docker', 1658),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1373),
#  ('monitor', 1285),
#  ('aws', 1264),
#  ('golang', 1252),
#  ('kubernetes', 1223),
#  ('awesomelist', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('imageprocessing', 1000),
#  ('facedetection', 987),
#  ('typescript', 971),
#  ('keras', 871),
#  ('windows', 848),
#  ('datascience', 836),
#  ('nlp', 823),
#  ('cybersecurity', 819),
#  ('api', 802),
#  ('go', 783),
#  ('artificialintelligence', 738),
#  ('anomalydetection', 738),
#  ('alert', 737),
#  ('raspberrypi', 736),
#  ('hack', 727),
#  ('swift', 721),
#  ('convolutionalneuralnetworks', 704),
#  ('cnn', 698),
#  ('ai', 672),
#  ('cpp', 660),
#  ('neuralnetwork', 653),
#  ('securitytools', 653),
#  ('facerecognition', 647),
#  ('automation', 637),
#  ('terraform', 615),
#  ('opensource', 609),
#  ('prometheus', 600),
#  ('dataset', 598),
#  ('azure', 584),
#  ('iot', 580),
#  ('naturallanguageprocessing', 579),
#  ('html', 575),
#  ('csharp', 574),
#  ('rust', 561),
#  ('yolo', 557),
#  ('macos', 551),
#  ('flask', 547),
#  ('network', 541),
#  ('deepneuralnetworks', 538),
#  ('blockchain', 536),
#  ('css', 527),
#  ('classification', 526),
#  ('game', 522),
#  ('reactjs', 520),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 501),
#  ('bot', 498),
#  ('springboot', 498),
#  ('reactnative', 483),
#  ('c', 469),
#  ('cli', 464),
#  ('cryptography', 461),
#  ('yolov3', 457),
#  ('homeassistant', 454),
#  ('opencvpython', 453),
#  ('segmentation', 452),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 432),
#  ('vue', 427),
#  ('library', 415),
#  ('tool', 414),
#  ('imageclassification', 412),
#  ('cloud', 411),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('realtime', 406),
#  ('django', 403),
#  ('covid19', 403),
#  ('database', 399),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('log', 387),
#  ('bugbounty', 383),
#  ('mongodb', 372),
#  ('cryptocurrency', 372),
#  ('ruby', 371),
#  ('web', 367),
#  ('cplusplus', 365),
#  ('neuralnetworks', 360),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('ocr', 349),
#  ('timeseries', 348),
#  ('elasticsearch', 344),
#  ('matlab', 334),
#  ('penetrationtesting', 333),
#  ('test', 331),
#  ('yolov5', 331),
#  ('ansible', 330),
#  ('threathunting', 330),
#  ('plugin', 329),
#  ('postgresql', 328),
#  ('restapi', 326),
#  ('bootstrap', 323),
#  ('paper', 322),
#  ('malwareanalysis', 321),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('antivirus', 319),
#  ('cluster', 319),
#  ('mysql', 317),
#  ('discord', 317),
#  ('metrics', 315),
#  ('reverseengineering', 311),
#  ('threatintelligence', 311),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('json', 308),
#  ('list', 305),
#  ('notifications', 304),
#  ('r', 303),
#  ('jupyternotebook', 302),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('dotnet', 297),
#  ('framework', 295),
#  ('incidentresponse', 292),
#  ('redteam', 286),
#  ('github', 286),
#  ('audio', 284),
#  ('firebase', 278),
#  ('osint', 275),
#  ('dockercompose', 274),
#  ('sql', 273),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('transferlearning', 267),
#  ('bash', 266),
#  ('visualization', 259),
#  ('semanticsegmentation', 257),
#  ('dfir', 257),
#  ('encryption', 256),
#  ('graph', 253),
#  ('html5', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 248),
#  ('microservices', 246),
#  ('image', 245),
#  ('gui', 245),
#  ('autonomousdriving', 245),
#  ('homeautomation', 244),
#  ('dataanalysis', 244),
#  ('unity', 244),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('lstm', 239),
#  ('ui', 239),
#  ('jquery', 238),
#  ('redis', 237),
#  ('stream', 236),
#  ('pointcloud', 236),
#  ('algorithms', 231),
#  ('js', 231),
#  ('awslambda', 231),
#  ('vuejs', 227),
#  ('poseestimation', 227),
#  ('http', 225),
#  ('exploit', 225),
#  ('sdk', 221),
#  ('gamedevelopment', 221),
#  ('machinelearningalgorithms', 219),
#  ('frontend', 219),
#  ('kerastensorflow', 217),
#  ('tensorflow2', 217),
#  ('datavisualization', 215),
#  ('selfdrivingcar', 215),
#  ('fasterrcnn', 212),
#  ('imagesegmentation', 210),
#  ('telegrambot', 209),
#  ('authentication', 209),
#  ('containers', 208),
#  ('ml', 207),
#  ('redux', 204),
#  ('scikitlearn', 203),
#  ('dart', 202),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('git', 199),
#  ('objectivec', 197),
#  ('webapp', 197),
#  ('scanner', 197),
#  ('spark', 196),
#  ('blueteam', 196),
#  ('unsupervisedlearning', 195),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('data', 194),
#  ('face', 194),
#  ('ids', 194),
#  ('githubactions', 193),
#  ('script', 192),
#  ('transformer', 191),
#  ('express', 191),
#  ('discordbot', 190),
#  ('slack', 190),
#  ('remotesensing', 190),
#  ('mobile', 190),
#  ('yolov4', 189),
#  ('pandas', 186),
#  ('analytics', 186),
#  ('crossplatform', 186),
#  ('esp8266', 185),
#  ('speechrecognition', 185),
#  ('malwaredetection', 185),
#  ('datamining', 183),
#  ('rest', 183),
#  ('reinforcementlearning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentimentanalysis', 182),
#  ('slam', 181),
#  ('imagerecognition', 181),
#  ('observability', 179),
#  ('instancesegmentation', 178),
#  ('darknet', 178),
#  ('chatgpt', 178),
#  ('graphql', 177),
#  ('wifi', 177),
#  ('resources', 177),
#  ('dns', 177),
#  ('staticanalysis', 176),
#  ('lidar', 175),
#  ('server', 174),
#  ('spring', 174),
#  ('chromeextension', 173),
#  ('devsecops', 173),
#  ('yara', 172),
#  ('twitter', 172),
#  ('vulnerability', 171),
#  ('lanedetection', 170),
#  ('email', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('chatbot', 168),
#  ('map', 167),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('objecttracking', 163),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('signalprocessing', 161),
#  ('medicalimaging', 160),
#  ('template', 160),
#  ('cloudnative', 160),
#  ('electron', 159),
#  ('scala', 159),
#  ('smarthome', 158),
#  ('autonomousvehicles', 158),
#  ('securityaudit', 158),
#  ('randomforest', 157),
#  ('androidapplication', 157),
#  ('cuda', 157),
#  ('maskrcnn', 156),
#  ('ssd', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('tailwindcss', 155),
#  ('opengl', 155),
#  ('commandline', 155),
#  ('bigdata', 154),
#  ('browser', 154),
#  ('smartcontracts', 154),
#  ('microservice', 154),
#  ('malwareresearch', 153),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('wordpressplugin', 151),
#  ('networkanalysis', 151),
#  ('dockerimage', 151),
#  ('terminal', 150),
#  ('unity3d', 149),
#  ('outlierdetection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('textclassification', 148),
#  ('3d', 148),
#  ('onnx', 147),
#  ('threatintel', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('expressjs', 145),
#  ('apple', 145),
#  ('selenium', 145),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('edgedetection', 144),
#  ('dotnetcore', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('datastructures', 143),
#  ('frauddetection', 143),
#  ('cicd', 142),
#  ('css3', 141),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('hook', 140),
#  ('gameengine', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('windows10', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('package', 138),
#  ('intrusiondetection', 138),
#  ('openapi', 137),
#  ('siem', 137),
#  ('generativeadversarialnetwork', 137),
#  ('phishing', 137),
#  ('project', 136),
#  ('deployment', 136),
#  ('hackingtool', 136),
#  ('inference', 136),
#  ('swiftui', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('heroku', 134),
#  ('videoprocessing', 134),
#  ('dlib', 134),
#  ('nlpmachinelearning', 133),
#  ('selfhosted', 133),
#  ('websocket', 132),
#  ('vision', 132),
#  ('vscode', 132),
#  ('terraformmodule', 132),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('springcloud', 130),
#  ('androidlibrary', 130),
#  ('augmentedreality', 129),
#  ('backup', 129),
#  ('bootstrap4', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheusexporter', 128),
#  ('alertmanager', 128),
#  ('boilerplate', 127),
#  ('recognition', 127),
#  ('chrome', 126),
#  ('openai', 125),
#  ('form', 125),
#  ('demo', 125),
#  ('webrtc', 124),
#  ('tensorflowlite', 124),
#  ('3dobjectdetection', 124),
#  ('npm', 124),
#  ('client', 124),
#  ('audit', 123),
#  ('theme', 123),
#  ('benchmark', 123),
#  ('app', 122),
#  ('gamedev', 122),
#  ('filter', 122),
#  ('textdetection', 122),
#  ('vim', 122),
#  ('backend', 122),
#  ('infrastructure', 122),
#  ('statuspage', 122),
#  ('cnnkeras', 121),
#  ('distributedsystems', 121),
#  ('ssl', 121),
#  ('autoencoder', 121),
#  ('jenkins', 121),
#  ('kibana', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('service', 120),
#  ('vulnerabilitydetection', 120),
#  ('tls', 120),
#  ('workflow', 119),
#  ('selfsupervisedlearning', 119),
#  ('graphneuralnetworks', 119),
#  ('featureextraction', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('mlops', 118),
#  ('language', 117),
#  ('tensorflowjs', 117),
#  ('mediapipe', 117),
#  ('materialdesign', 117),
#  ('ecommerce', 117),
#  ('web3', 117),
#  ('vpn', 116),
#  ('model', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('resnet', 115),
#  ('optimization', 114),
#  ('unet', 114),
#  ('module', 114),
#  ('changedetection', 114),
#  ('book', 114),
#  ('emotionrecognition', 114),
#  ('googlecloud', 113),
#  ('pushnotifications', 113),
#  ('developertools', 113),
#  ('scan', 113),
#  ('uptimemonitor', 113),
#  ('uikit', 112),
#  ('sklearn', 112),
#  ('networksecurity', 111),
#  ('bluetooth', 111),
#  ('digitalforensics', 111),
#  ('education', 111),
#  ('crawler', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfestaccepted', 110),
#  ('streamlit', 109),
#  ('debug', 109),
#  ('compliance', 109),
#  ('awesomelists', 109),
#  ('webassembly', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('finance', 107),
#  ('hardware', 107),
#  ('translation', 107),
#  ('securityautomation', 107),
#  ('hash', 107),
#  ('androidapp', 107),
#  ('rnn', 106),
#  ('vulnerabilities', 106),
#  ('communitydetection', 105),
#  ('bestpractices', 105),
#  ('hackingtools', 105),
#  ('pwa', 105),
#  ('search', 105),
#  ('vscodeextension', 105),
#  ('sqlite', 105),
#  ('terraformmodules', 105),
#  ('springsecurity', 105),
#  ('intel', 105),
#  ('apigateway', 104),
#  ('vehicledetection', 104),
#  ('arduinolibrary', 104),
#  ('vulnerabilityscanners', 104),
#  ('collisiondetection', 104),
#  ('cache', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('fingerprint', 103),
#  ('computerscience', 103),
#  ('pretrainedmodels', 103),
#  ('aspnetcore', 103),
#  ('animation', 102),
#  ('edgecomputing', 102),
#  ('csv', 101),
#  ('logisticregression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('edge', 101),
#  ('genomics', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('blog', 100),
#  ('attack', 100),
#  ('commandlinetool', 100),
#  ('googlecloudplatform', 99),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('emotiondetection', 99),
#  ('postgres', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('hacktoberfest2021', 98),
#  ('drone', 98),
#  ('fastapi', 98),
#  ('infrastructureascode', 97),
#  ('satelliteimagery', 97),
#  ('cheatsheet', 97),
#  ('audioprocessing', 97),
#  ('cnnclassification', 97),
#  ('interview', 97),
#  ('owasp', 96),
#  ('kalilinux', 96),
#  ('openshift', 95),
#  ('hacktoberfest2020', 95),
#  ('kotlinandroid', 95),
#  ('facemaskdetection', 95),
#  ('cocoapods', 95),
#  ('sample', 95),
#  ('nmap', 95),
#  ('mobilenet', 95),
#  ('timeseriesanalysis', 95),
#  ('yolov2', 94),
#  ('validation', 94),
#  ('svmclassifier', 94),
#  ('uicomponents', 94),
#  ('materialui', 94),
#  ('tflite', 94),
#  ('influxdb', 94),
#  ('interviewquestions', 94),
#  ('regression', 93),
#  ('physics', 93),
#  ('imagenet', 93),
#  ('async', 93),
#  ('filesystem', 93),
#  ('websockets', 93),
#  ('rstats', 93),
#  ('hacktoberfest2022', 93),
#  ('speech', 92),
#  ('mobilenetv2', 92),
#  ('cv', 92),
#  ('gitops', 92),
#  ('chat', 92),
#  ('sass', 91),
#  ('apiclient', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentesttool', 90),
#  ('guide', 90),
#  ('scraper', 90),
#  ('speechtotext', 90),
#  ('webapplication', 90),
#  ('supervisedlearning', 89),
#  ('container', 89),
#  ('cloudformation', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attentionmechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('motiondetection', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('tradingbot', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('imageanalysis', 88),
#  ('pytorchimplementation', 88),
#  ('firefox', 88),
#  ('tcp', 88),
#  ('bypass', 87),
#  ('coursera', 87),
#  ('extension', 87),
#  ('wallet', 87),
#  ('chart', 87),
#  ('coco', 87),
#  ('svelte', 87),
#  ('mitreattack', 87),
#  ('awss3', 87),
#  ('amazon', 86),
#  ('humanposeestimation', 86),
#  ('middleware', 86),
#  ('webdevelopment', 86),
#  ('xml', 86),
#  ('networkmonitoring', 86),
#  ('informationsecurity', 86),
#  ('securityscanner', 86),
#  ('binance', 86),
#  ('bashscript', 86),
#  ('zabbix', 86),
#  ('grpc', 85),
#  ('sqlserver', 85),
#  ('clojure', 85),
#  ('webscraping', 85),
#  ('honeypot', 85),
#  ('healthcare', 85),
#  ('activedirectory', 85),
#  ('p2p', 85),
#  ('toast', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('redteaming', 84),
#  ('restfulapi', 84),
#  ('parse', 84),
#  ('recurrentneuralnetworks', 84),
#  ('lightweight', 84),
#  ('coreml', 84),
#  ('ctfwriteups', 84),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flaskapplication', 82),
#  ('webcam', 82),
#  ('homeassistantconfig', 82),
#  ('i18n', 82),
#  ('rat', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('cloudcomputing', 82),
#  ('retinanet', 82),
#  ('artificialneuralnetworks', 82),
#  ('continuousintegration', 81),
#  ('maven', 81),
#  ('javascriptlibrary', 81),
#  ('popup', 81),
#  ('logger', 81),
#  ('textrecognition', 81),
#  ('monitoringtool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('fakenews', 80),
#  ('php7', 80),
#  ('jetsonnano', 80),
#  ('dataengineering', 80),
#  ('development', 80),
#  ('application', 80),
#  ('file', 80),
#  ('perl', 80),
#  ('pyqt5', 80),
#  ('cyberthreatintelligence', 80),
#  ('gps', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graphalgorithms', 79),
#  ('fullstack', 79),
#  ('angular2', 79),
#  ('nvidia', 79),
#  ('actionrecognition', 79),
#  ('webcomponents', 79),
#  ('languagedetection', 79),
#  ('tutorials', 79),
#  ('cheat', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('pythonscript', 78),
#  ('obfuscation', 78),
#  ('threejs', 78),
#  ('sms', 78),
#  ('internetofthings', 77),
#  ('example', 77),
#  ('convolutionalneuralnetwork', 77),
#  ('certificate', 77),
#  ('xgboost', 77),
#  ('compiler', 77),
#  ('intrusiondetectionsystem', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('nodered', 76),
#  ('searchengine', 76),
#  ('windows11', 76),
#  ('qrcode', 76),
#  ('pythonlibrary', 76),
#  ('ransomware', 75),
#  ('facialrecognition', 75),
#  ('raspberrypi3', 75),
#  ('forensicanalysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('osx', 75),
#  ('cloudsecurity', 75),
#  ('gplv3', 75),
#  ('suricata', 75),
#  ('linearregression', 74),
#  ('backdoor', 74),
#  ('editor', 74),
#  ('dataaugmentation', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('bruteforce', 73),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('cleanarchitecture', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('prediction', 73),
#  ('androidstudio', 73),
#  ('ble', 73),
#  ('npmpackage', 73),
#  ('gpt3', 73),
#  ('pcap', 73),
#  ('semisupervisedlearning', 72),
#  ('yararules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('gpt', 72),
#  ('securityhardening', 72),
#  ('lidarpointcloud', 72),
#  ('adversarialattacks', 72),
#  ('3dreconstruction', 72),
#  ('programminglanguage', 72),
#  ('htmlcssjavascript', 72),
#  ('ajax', 71),
#  ('offensivesecurity', 71),
#  ('cti', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('softwareengineering', 71),
#  ('jqueryplugin', 71),
#  ('mac', 71),
#  ('ethicalhacking', 71),
#  ('https', 71),
#  ('course', 71),
#  ('llm', 71),
#  ('multithreading', 71),
#  ('rustlang', 71),
#  ('multiobjecttracking', 71),
#  ('cpu', 71),
#  ('scss', 70),
#  ('deepsort', 70),
#  ('sandbox', 70),
#  ('androiddevelopment', 70),
#  ('management', 70),
#  ('visiontransformer', 70),
#  ('integration', 70),
#  ('stm32', 70),
#  ('defi', 70),
#  ('kalmanfilter', 70),
#  ('salientobjectdetection', 70),
#  ('facealignment', 70),
#  ('awsec2', 70),
#  ('virus', 70),
#  ('crud', 69),
#  ('angularjs', 69),
#  ('cms', 69),
#  ('ec2', 69),
#  ('azurefunctions', 69),
#  ('virtualmachine', 69),
#  ('apache', 69),
#  ('radar', 69),
#  ('rnaseq', 69),
#  ('vue3', 69),
#  ('haarcascade', 69),
#  ('jest', 69),
#  ('vgg16', 68),
#  ('streamprocessing', 68),
#  ('vault', 68),
#  ('domainadaptation', 68),
#  ('federatedlearning', 68),
#  ('svg', 68),
#  ('operatingsystem', 68),
#  ('oracle', 68),
#  ('ionic', 68),
#  ('facebook', 68),
#  ('amazonwebservices', 68),
#  ('iobroker', 68),
#  ('control', 67),
#  ('mongoose', 67),
#  ('ioc', 67),
#  ('boundingboxes', 67),
#  ('emulator', 67),
#  ('gpt4', 67),
#  ('graphics', 67),
#  ('qt5', 67),
#  ('automl', 67),
#  ('wrapper', 67),
#  ('utility', 67),
#  ('events', 67),
#  ('facenet', 67),
#  ('promise', 67),
#  ('widget', 67),
#  ('simulator', 67),
#  ('trojan', 66),
#  ('engine', 66),
#  ('antivirusevasion', 66),
#  ('etl', 66),
#  ('orm', 66),
#  ('cpp17', 66),
#  ('socketio', 66),
#  ('sensorfusion', 66),
#  ('unix', 66),
#  ('texttospeech', 66),
#  ('configuration', 66),
#  ('navigation', 66),
#  ('article', 66),
#  ('pedestriandetection', 66),
#  ('software', 66),
#  ('kubernetescluster', 65),
#  ('gateway', 65),
#  ('admindashboard', 65),
#  ('collection', 65),
#  ('sdr', 65),
#  ('letsencrypt', 65),
#  ('textmining', 65),
#  ('facetracking', 65),
#  ('sort', 65),
#  ('edgeai', 65),
#  ('embeddedsystems', 65),
#  ('alarm', 65),
#  ('rpackage', 65),
#  ('googlecolab', 65),
#  ('fast', 64),
#  ('webserver', 64),
#  ('ansiblerole', 64),
#  ('steganography', 64),
#  ('bypassantivirus', 64),
#  ('survey', 64),
#  ('system', 64),
#  ('iosapp', 64),
#  ('shellscript', 64),
#  ('websecurity', 64),
#  ('neovim', 64),
#  ('bootstrap5', 64),
#  ('ocrrecognition', 63),
#  ('community', 63),
#  ('composer', 63),
#  ('nosql', 63),
#  ('python2', 63),
#  ('cisco', 63),
#  ('bluetoothlowenergy', 63),
#  ('radio', 63),
#  ('objectrecognition', 63),
#  ('archlinux', 63),
#  ('voice', 63),
#  ('maskdetection', 63),
#  ('tesseract', 63),
#  ('paperlist', 63),
#  ('testingtools', 63),
#  ('prompt', 62),
#  ('smtp', 62),
#  ('ebpf', 62),
#  ('cdk', 62),
#  ('interviewpreparation', 62),
#  ('usb', 62),
#  ('voiceactivitydetection', 62),
#  ('eeg', 62),
#  ('sre', 62),
#  ('java8', 62),
#  ('chess', 62),
#  ('cnnmodel', 62),
#  ('verilog', 62),
#  ('keyboard', 62),
#  ('pentestingtools', 62),
#  ('config', 61),
#  ('javafx', 61),
#  ('dockercontainer', 61),
#  ('waf', 61),
#  ('telemetry', 61),
#  ('linter', 61),
#  ('mvvm', 61),
#  ('faciallandmarks', 61),
#  ('reactrouter', 61),
#  ('anticheat', 61),
#  ('jetson', 61),
#  ('socialmedia', 61),
#  ('apns', 61),
#  ('kagglecompetition', 61),
#  ('virtualization', 61),
#  ('kmeansclustering', 61),
#  ('attention', 61),
#  ('productivity', 61),
#  ('protection', 61),
#  ('wireless', 60),
#  ('sensors', 60),
#  ('arkit', 60),
#  ('sagemaker', 60),
#  ('memory', 60),
#  ('informationgathering', 60),
#  ('osquery', 60),
#  ('linuxkernel', 60),
#  ('annotations', 60),
#  ('cordovaplugin', 60),
#  ('resnet50', 60),
#  ('virustotal', 60),
#  ('syntaxhighlighting', 60),
#  ('tkinter', 60),
#  ('explainableai', 60),
#  ('socialnetwork', 60),
#  ('color', 60),
#  ('news', 60),
#  ('emotion', 60),
#  ('reactcomponents', 60),
#  ('enumeration', 59),
#  ('purpleteam', 59),
#  ('hackintosh', 59),
#  ('tensorflowobjectdetectionapi', 59),
#  ('agent', 59),
#  ('devopstools', 59),
#  ('native', 59),
#  ('eks', 59),
#  ('clamav', 59),
#  ('dockerfile', 59),
#  ('md', 59),
#  ('puppet', 59),
#  ('cassandra', 59),
#  ('ddos', 59),
#  ('iac', 59),
#  ('cpp11', 59),
#  ('browserextension', 59),
#  ('portfolio', 59),
#  ('udp', 59),
#  ('rcnn', 58),
#  ('onnxruntime', 58),
#  ('mvc', 58),
#  ('iphone', 58),
#  ('operator', 58),
#  ('lstmneuralnetworks', 58),
#  ('stockmarket', 58),
#  ('ensemblelearning', 58),
#  ('multimodal', 58),
#  ('instagram', 58),
#  ('tracker', 58),
#  ('gitlab', 58),
#  ('vagrant', 58),
#  ('designpatterns', 58),
#  ('salesforce', 58),
#  ('pca', 58),
#  ('secure', 57),
#  ('testautomation', 57),
#  ('opencv3', 57),
#  ('regex', 57),
#  ('consul', 57),
#  ('tree', 57),
#  ('geolocation', 57),
#  ('eyetracking', 57),
#  ('challenge', 57),
#  ('3dprinting', 57),
#  ('medicalimageprocessing', 57),
#  ('neo4j', 57),
#  ('compression', 57),
#  ('dotfiles', 57),
#  ('cvpr', 57),
#  ('featureengineering', 57),
#  ('netcore', 56),
#  ('science', 56),
#  ('airflow', 56),
#  ('weaklysupervisedlearning', 56),
#  ('cv2', 56),
#  ('stack', 56),
#  ('pyspark', 56),
#  ('namedentityrecognition', 56),
#  ('reacthooks', 56),
#  ('motion', 56),
#  ('microservicesarchitecture', 56),
#  ('spamdetection', 56),
#  ('xray', 56),
#  ('tensorflowmodels', 56),
#  ('raspberry', 56),
#  ('sqlite3', 56),
#  ('cloudwatch', 56),
#  ('addon', 56),
#  ('plugins', 56),
#  ...]

# %%
github_data_wtopic = np.nan

# %% [markdown]
# ## Testset 2.5 (Part of D_C1)
# The best performing 1 set was 1.2; so we do the same we did with 1.2 on readme and about
#
# we set a **min_thres** here, that means this topic has to be at least in 4 repos

# %%
topics_combined_full = []
min_thres = 4
for i in topic_counter.items():
    t = i[0]
    o = i[1]
    t = str(t)
    if t == 'nan':
        continue
    newt = preprocess_text(t, lem=False, do_composition=False)
    if newt not in topics_combined_full:
        if o >= min_thres:
            topics_combined_full+=newt

# %%
len(topics_combined_full)
# Out:
# 23732

# %%
len(set(topics_combined_full))
# Out:
# 9652

# %%
topics_combined_full = list(set(topics_combined_full))

# %%
topics_combined_full
# Out:
# ['cloudrun',
#  'angular8',
#  'icloud',
#  'rabbitmq',
#  'iac',
#  'rpi',
#  'circleci',
#  'manifold',
#  'warframe',
#  'awareness',
#  'fairness',
#  'cmake',
#  'tooltip',
#  'sqlite3',
#  'lane',
#  'capybara',
#  'trading',
#  'java',
#  'gpuimage',
#  'cars',
#  'atomic',
#  'tendermint',
#  'windows11',
#  'postgres',
#  'nim',
#  'factorization',
#  'syn',
#  'sdn',
#  'oidc',
#  'cctv',
#  'listen',
#  'thought',
#  'menubar',
#  'defect',
#  'decryption',
#  'smt',
#  'metatrader',
#  'codereview',
#  'rs485',
#  'godot4',
#  'clahe',
#  'obfuscator',
#  'switzerland',
#  'apikey',
#  'azuread',
#  'husky',
#  'carthage',
#  '064b0s2',
#  'gamepad',
#  'compilers',
#  'elgato',
#  'tinyml',
#  'semgrep',
#  'texttospeech',
#  'm5stack',
#  'neat',
#  'rumor',
#  'apriltag',
#  'gsm',
#  'journey',
#  'assistance',
#  'paddlepaddle',
#  'lemmatizer',
#  'nashorn',
#  'redisai',
#  'fuzzer',
#  'interview',
#  'wisconsin',
#  'e2ee',
#  'callback',
#  'measurement',
#  'feedforward',
#  'invoice',
#  'steganography',
#  'polly',
#  'jsonnet',
#  'res2net',
#  'paint',
#  'stomp',
#  'hana',
#  'garden',
#  'inceptionv2',
#  'abac',
#  'bipartite',
#  'freeswitch',
#  'hci',
#  'counting',
#  'webscraper',
#  'skyrim',
#  'v4l2',
#  'dehazing',
#  'microsoftgraph',
#  'industry',
#  'jq',
#  'geojson',
#  'probot',
#  'socks5',
#  'cvpr2021',
#  'playstore',
#  'webcam',
#  'mobilenet',
#  'nltk',
#  'proto',
#  'phpstorm',
#  'equihash',
#  'diablo2',
#  'seismology',
#  'oculus',
#  'regulations',
#  'charm',
#  'rasa',
#  'axure',
#  'presto',
#  'plsql',
#  'chatbot',
#  'bicep',
#  'curves',
#  'dask',
#  'discord',
#  'minifilter',
#  'multithreaded',
#  'uci',
#  'fork',
#  'lamp',
#  'layers',
#  'hashing',
#  'appdynamics',
#  'hibp',
#  'valorant',
#  'upx',
#  'coordination',
#  'newsapi',
#  'augmented',
#  'opsgenie',
#  'public',
#  'dex',
#  'approximate',
#  'gdi',
#  'factory',
#  'signatures',
#  'onepage',
#  'gmail',
#  'coding',
#  'mlkit',
#  'candlestick',
#  'jwk',
#  'svelte3',
#  'office365',
#  'payment',
#  'leukemia',
#  'livestream',
#  'healing',
#  'facealignment',
#  'tradfri',
#  'readability',
#  'switch',
#  'gadgets',
#  'karaoke',
#  '45105',
#  'dbscan',
#  'music',
#  'conferences',
#  'dla',
#  'servlet',
#  'orm',
#  'ppo',
#  'machinelearning',
#  'sony',
#  'srt',
#  'crdt',
#  'vicuna',
#  'timelapse',
#  'pid',
#  'wns',
#  'cast',
#  'airplay',
#  'portability',
#  'ebay',
#  'portable',
#  'freelancer',
#  'renewable',
#  'competitive',
#  'ghas',
#  'psvita',
#  'notice',
#  'bigquery',
#  'efficiency',
#  'remix',
#  'sentence',
#  'rhythm',
#  'es2015',
#  'imagery',
#  'matlab',
#  'missing',
#  'rstats',
#  'water',
#  'developers',
#  'chemistry',
#  'orchestration',
#  'twc',
#  'germany',
#  'elasticache',
#  'contextmenu',
#  'deeplink',
#  'chef',
#  'ggplot2',
#  'zlib',
#  'rce',
#  'beacons',
#  'p2p',
#  'ziglang',
#  'maximum',
#  'roi',
#  'dcgan',
#  'jetson',
#  'failover',
#  'pipe',
#  'paseto',
#  'adventure',
#  'imitation',
#  'linking',
#  'malaysia',
#  'making',
#  'sur',
#  'topic',
#  'pycbc',
#  'uptimerobot',
#  'tvm',
#  'economics',
#  'summary',
#  'modeling',
#  'housing',
#  'altcoin',
#  'unlimited',
#  'xrp',
#  'ban',
#  'icinga2',
#  'artisan',
#  'bands',
#  'pose',
#  'oss',
#  'managed',
#  'garage',
#  'ii',
#  'spv3',
#  'ctid',
#  'artifactory',
#  'alertscript',
#  'optimization',
#  'fixed',
#  'hiring',
#  'alignment',
#  'randomizer',
#  'bees',
#  'geometry',
#  'androiddevelopment',
#  'fsharp',
#  'pnpm',
#  'circuits',
#  'onewire',
#  'layui',
#  'workers',
#  'duplicates',
#  'ipmi',
#  'idf',
#  'drift',
#  'controls',
#  'colonoscopy',
#  'pthreads',
#  'symbols',
#  'mtproto',
#  'citypersons',
#  'quantification',
#  'opencore',
#  'btrfs',
#  'noty',
#  'aop',
#  'jack',
#  'bbcode',
#  'wled',
#  'amazon',
#  'wine',
#  'orion',
#  'jni',
#  'ds',
#  'aaai2021',
#  'encrypt',
#  'gl',
#  'crowdstrike',
#  'multer',
#  'influxdata',
#  'creation',
#  'smoothing',
#  'homeautomation',
#  'compliance',
#  'soundboard',
#  'attacker',
#  'edi',
#  'emergency',
#  'rectangle',
#  'jpush',
#  'wow',
#  'milvus',
#  'based',
#  'udp',
#  'transliteration',
#  'aqara',
#  'examples',
#  'sidebar',
#  'testnet',
#  'keras',
#  'podcasts',
#  'es7',
#  'serialization',
#  'samd21',
#  'nexus',
#  'bacterial',
#  'monster',
#  'aurora',
#  'filemanager',
#  'libbpf',
#  'npc',
#  'aspnet',
#  'lists',
#  'fakenewsdetection',
#  'nips',
#  'notifier',
#  'secops',
#  'asterisk',
#  'rxjs',
#  'principal',
#  'automotive',
#  'cleaner',
#  'separating',
#  'msbuild',
#  'xps',
#  'glpi',
#  'c3d',
#  'secdevops',
#  'pinia',
#  'fluid',
#  'melodic',
#  'finalyearproject',
#  'bzip2',
#  'emails',
#  'webots',
#  'toolset',
#  'mae',
#  'coraza',
#  'position',
#  'markov',
#  'antivm',
#  'qbus',
#  'prophet',
#  'xarray',
#  'pbr',
#  'snps',
#  'n',
#  'codesigning',
#  'tellodrone',
#  'msi',
#  'siri',
#  'menu',
#  'basketball',
#  'optics',
#  'gateway',
#  'telco',
#  'backtracking',
#  'xception',
#  'dojo',
#  'fft',
#  'cost',
#  'opsec',
#  'arfoundation',
#  'stenciljs',
#  'jade',
#  'neptune',
#  'steps',
#  'consensus',
#  'plasma',
#  'fun',
#  'textpattern',
#  '2022',
#  'final',
#  'minerproxy',
#  'production',
#  'tail',
#  'backpropagation',
#  'reverseshell',
#  'boto',
#  'p4',
#  'ransac',
#  'vnet',
#  'pubnub',
#  'automatic1111',
#  'push',
#  'track',
#  'sde',
#  'drone',
#  'breakpoint',
#  'camerax',
#  'atlas',
#  'vocabulary',
#  'stt',
#  'mp3',
#  'apollo',
#  'radiology',
#  'saml2',
#  'coinmarketcap',
#  'tokens',
#  'i3d',
#  'gpu',
#  'okhttp3',
#  'computervision',
#  'apptemplates',
#  'termux',
#  'code4ro',
#  'hackthebox',
#  'chess',
#  'dataviz',
#  'finger',
#  'blackbox',
#  'snyk',
#  'qrs',
#  'filters',
#  'relay',
#  'hacktoberfest2022',
#  'shufflenetv2',
#  'cip',
#  'markerless',
#  'remoteaccesstrojan',
#  'dvwa',
#  'buildpacks',
#  'pymongo',
#  'deeplearning',
#  'facemask',
#  'indonesia',
#  'pf',
#  'hosts',
#  'annotations',
#  'packet',
#  'biosignals',
#  'daq',
#  'anilist',
#  'ethersjs',
#  'mailbox',
#  'lab',
#  'hackernews',
#  'adc',
#  'zap',
#  'tflearn',
#  'retropie',
#  'carbon',
#  'substrate',
#  'wandb',
#  'anomalies',
#  'delphi',
#  'country',
#  'tf2',
#  'llms',
#  'rnaseq',
#  'styling',
#  'smote',
#  'china',
#  'magisk',
#  'workmanager',
#  'cgal',
#  'racket',
#  'smali',
#  'erlang',
#  'bcrypt',
#  'gitpod',
#  'parallax',
#  'cypress',
#  'pathfinder',
#  'editorjs',
#  'tvos',
#  'renovate',
#  'pacbio',
#  'nvme',
#  'fi',
#  'patients',
#  'siemens',
#  'idm',
#  'kubeflow',
#  'z',
#  'directx',
#  'csf',
#  'apm',
#  'multisig',
#  'pmm',
#  'freak',
#  'socialdistancing',
#  'quake',
#  'nox',
#  'loss',
#  '062s2',
#  'avx',
#  'paper',
#  'ipaddress',
#  'planning',
#  'pulumi',
#  'steal',
#  'store',
#  'marker',
#  'leap',
#  'iclr2020',
#  'b2b',
#  'iframe',
#  'webui',
#  'bioconductor',
#  'todomvc',
#  'rollup',
#  'vuejs',
#  'door',
#  'seanpm2001',
#  'influxdb',
#  'super',
#  'videos',
#  'apache',
#  'drive',
#  'scam',
#  'pagerank',
#  'twemoji',
#  'semeval',
#  'boosting',
#  'eve',
#  'selection',
#  'osm',
#  'tenant',
#  'swift',
#  'antispoofing',
#  'major',
#  'bugbountytips',
#  'prisma',
#  'prisma2',
#  'malicious',
#  'sqli',
#  'lof',
#  'ethicalhacking',
#  'swc',
#  'androidstudio',
#  'teensy41',
#  'vectors',
#  'next',
#  'dns',
#  'dino',
#  'summarization',
#  'cyberattack',
#  '125khz',
#  'cbir',
#  'free',
#  'plants',
#  'mpegts',
#  'tesla',
#  'machinelearningprojects',
#  'timers',
#  'altair',
#  'bookmarklets',
#  'breakout',
#  'anticheat',
#  'icon',
#  'two',
#  'electra',
#  'hibernate',
#  'ethash',
#  'modpack',
#  'bim',
#  'drug',
#  'cube',
#  'sequences',
#  'whisper',
#  'opensea',
#  'newsletter',
#  'nikto',
#  'mybatis',
#  'playgrounds',
#  'gas',
#  'zbar',
#  'administration',
#  'fat32',
#  'sprites',
#  'wrk',
#  'reidentification',
#  'figure',
#  'sol',
#  'space',
#  'draw',
#  'discriminant',
#  'eagle',
#  'iforest',
#  'fullstack',
#  'modularity',
#  'dfu',
#  'amsi',
#  'blood',
#  'coroutines',
#  'wear',
#  'framerate',
#  'phaserjs',
#  'gpt2',
#  'asn',
#  'dbi',
#  'mse',
#  'idle',
#  'pyautogui',
#  'hiding',
#  'cli',
#  'lightgbm',
#  'political',
#  'rnn',
#  'course',
#  'galaxy',
#  'bih',
#  'pigo',
#  'plutus',
#  'rack',
#  'postgraphile',
#  'mq',
#  'soar',
#  'rtl',
#  'gprs',
#  'facebook',
#  'alignments',
#  'napari',
#  'btree',
#  'coredns',
#  'asm',
#  'live',
#  'meltdown',
#  'tuner',
#  'indoor',
#  'zkp',
#  'camelyon16',
#  'uialertview',
#  'flyway',
#  'handshake',
#  'minimalist',
#  'standards',
#  'v2ray',
#  'metagenomics',
#  'components',
#  'employee',
#  'proving',
#  'quasar',
#  'pwa',
#  'autoit',
#  'lzma',
#  'modelling',
#  'ubc',
#  'lyrics',
#  'openra',
#  'cam',
#  'operators',
#  'sharedpreferences',
#  'opendata',
#  'scannet',
#  'work',
#  'fortran',
#  'rundeck',
#  'planner',
#  'visually',
#  'patrowl',
#  'modsecurity',
#  'cncnet',
#  'hmvc',
#  'gan',
#  'doh',
#  'imagesegmentation',
#  'autodesk',
#  'supeng',
#  'electron',
#  'attacks',
#  'foundry',
#  'pythorch',
#  'sysops',
#  'look',
#  'ocaml',
#  'subsystem',
#  'linuxmint',
#  'strongswan',
#  'pfsense',
#  'vlang',
#  'recipes',
#  'sflow',
#  'error',
#  'intel',
#  'opensourceforgood',
#  'deeplabcut',
#  'xlsx',
#  'inspec',
#  'alacritty',
#  'yii',
#  'scipy',
#  'flash',
#  'masscan',
#  'cloudfunctions',
#  'hotkeys',
#  'mql4',
#  'nostr',
#  'enhancement',
#  'limiter',
#  'mosquitto',
#  'pinterest',
#  'rockylinux',
#  'recognition',
#  'torchscript',
#  'keypad',
#  'avx512',
#  'elliptic',
#  'witai',
#  'trends',
#  'usestate',
#  'patches',
#  'terratest',
#  'projection',
#  'less',
#  'scaledyolov4',
#  'conferencing',
#  'commands',
#  'stylus',
#  'idapython',
#  'webcrypto',
#  'clover',
#  'internship',
#  'session',
#  'tx2',
#  'lex',
#  'ff14',
#  'accelerator',
#  'licenses',
#  'lovelace',
#  'fasterrcnn',
#  'organizer',
#  'agile',
#  'xp',
#  'fallback',
#  'retro',
#  'growth',
#  'metro',
#  'handling',
#  'h2',
#  'acme',
#  'repository',
#  'workbench',
#  'wedding',
#  'autograd',
#  'graphx',
#  'group',
#  'xfce4',
#  'cosmosdb',
#  'citrix',
#  'recovering',
#  'wgs',
#  'influence',
#  'smoke',
#  'cloudwatch',
#  'dropdown',
#  'jhipster',
#  'zeromq',
#  'frameworks',
#  'iec60870',
#  'paperlist',
#  'factors',
#  'deserialization',
#  'fetchmail',
#  'signaling',
#  'webdriver',
#  'minor',
#  'ohem',
#  'jobsearch',
#  'ufw',
#  'prompts',
#  'caltech',
#  'hactoberfest2022',
#  'recover',
#  'pairs',
#  'ros2',
#  'mobilenets',
#  'standardization',
#  'hyperloop',
#  'jiguang',
#  'cookies',
#  'dimensional',
#  'stata',
#  'gram',
#  'arcface',
#  'beautifulsoup',
#  'ccdc',
#  'grab',
#  'volumes',
#  'whiteboard',
#  'spoofer',
#  'prefect',
#  'netcat',
#  'kirby',
#  'phoenix',
#  'w',
#  'nvd',
#  'halo',
#  '7zip',
#  'pulseaudio',
#  'testbed',
#  'teachers',
#  'infomap',
#  'spanish',
#  'clipper',
#  'products',
#  'fluxcd',
#  'konami',
#  'lanenet',
#  '365',
#  'honeytoken',
#  'occupancy',
#  'ipados',
#  'roberta',
#  'await',
#  'linkerd',
#  'zelda',
#  'treblle',
#  'webworkers',
#  'gerrit',
#  'sylius',
#  'customelements',
#  'tailwindcss',
#  'spring',
#  'reality',
#  'wi',
#  'train',
#  'emotions',
#  'reproduction',
#  'import',
#  'aiot',
#  'surveys',
#  'activation',
#  'sniper',
#  'kivy',
#  'tpu',
#  'salient',
#  'julialang',
#  'arm64v8',
#  'ros',
#  'ripple',
#  'apn',
#  'oraclelinux',
#  'v',
#  'powerpoint',
#  'jwt',
#  'uwsgi',
#  'cosmology',
#  'python27',
#  'dutch',
#  'angularjs',
#  'brain',
#  'imagej',
#  'bbystealer',
#  'paloaltonetworks',
#  'privatekey',
#  'lingual',
#  'tmux',
#  'yolo9000',
#  'exoplanets',
#  'acap',
#  'datepicker',
#  'dmg',
#  'usenet',
#  'kicad',
#  'openvx',
#  'ekf',
#  'help',
#  'adguard',
#  'nerdpack',
#  'ccna',
#  'nasnetmobile',
#  'coq',
#  'mouse',
#  'hackingtools',
#  'bbs',
#  'sha1',
#  'envoy',
#  'plot',
#  'end',
#  'ether',
#  'hackintosh',
#  'gtfs',
#  'dane',
#  'bootstrap4',
#  'digest',
#  'thefatrat',
#  'scene',
#  'vst3',
#  'multiple',
#  'nix',
#  'multiscale',
#  'kdtree',
#  'snapshot',
#  'janus',
#  'ens',
#  'accident',
#  'snn',
#  'font',
#  'deauth',
#  'wps',
#  'dialogfragment',
#  'spectral',
#  'flare',
#  'sensitive',
#  'ionic4',
#  'lichess',
#  'kubernetes',
#  'nse',
#  'postgis',
#  'portuguese',
#  'rays',
#  'bme280',
#  'sni',
#  'dementia',
#  'stemming',
#  'blueprint',
#  'phantom',
#  'spine',
#  'marathon',
#  'tcp',
#  'systemd',
#  'calculation',
#  'ghostnet',
#  'magento',
#  'andrew',
#  'hassio',
#  'mediawiki',
#  'jellyfin',
#  'padding',
#  'fps',
#  'identityserver4',
#  'internals',
#  'bluepill',
#  'fpc',
#  'validator',
#  'netdata',
#  'board',
#  'midi',
#  'ricing',
#  'cv',
#  'beat',
#  'average',
#  'decorators',
#  'jsp',
#  'rstudio',
#  'feather',
#  'apfs',
#  'lipidomics',
#  'verify',
#  'signlanguage',
#  'eyetracking',
#  'adxl345',
#  'rsync',
#  'sheets',
#  'heartbleed',
#  'aac',
#  'as3',
#  'nestjs',
#  'regression',
#  'degoogling',
#  'virtualization',
#  'airbnb',
#  'uml',
#  'filebeat',
#  'contest',
#  'binance',
#  '2017',
#  'tweaks',
#  'toml',
#  'protect',
#  'rich',
#  'journald',
#  'jira',
#  'finding',
#  'imageprocessing',
#  'jmeter',
#  'reputation',
#  'govuk',
#  'instructions',
#  'yarn',
#  'ksuid',
#  'fresh',
#  'deepfakes',
#  'kind',
#  'pushnotification',
#  'picodet',
#  'pwntools',
#  'changepoint',
#  'putty',
#  'printer',
#  'druid',
#  'astrophotography',
#  'drupal',
#  'opa',
#  'net',
#  'score',
#  'histopathology',
#  ...]

# %%
def myclnfunction(x):
    return preprocess_text(x, lem=False, token_list = topics_combined_full, do_composition=False)

# %%
t1 = github_data_df['name'].apply(lambda x: myclnfunction(x))

# %%
t1_cnt = Counter(t1.explode())
t1_cnt.most_common()
# Out:
# [(nan, 87911),
#  ('detection', 10383),
#  ('awesome', 5841),
#  ('aws', 2876),
#  ('learning', 2736),
#  ('react', 2658),
#  ('project', 1840),
#  ('python', 1762),
#  ('js', 1753),
#  ('plugin', 1666),
#  ('using', 1625),
#  ('object', 1518),
#  ('face', 1479),
#  ('security', 1464),
#  ('api', 1410),
#  ('app', 1390),
#  ('deep', 1389),
#  ('ai', 1374),
#  ('data', 1347),
#  ('samples', 1308),
#  ('android', 1276),
#  ('docker', 1261),
#  ('system', 1173),
#  ('machine', 1161),
#  ('native', 1139),
#  ('ibm', 1134),
#  ('image', 1097),
#  ('recognition', 1060),
#  ('interview', 1028),
#  ('node', 987),
#  ('azure', 955),
#  ('pytorch', 933),
#  ('web', 932),
#  ('demo', 916),
#  ('cloud', 914),
#  ('lab', 890),
#  ('detector', 876),
#  ('io', 876),
#  ('tools', 866),
#  ('code', 859),
#  ('terraform', 831),
#  ('sdk', 819),
#  ('ml', 803),
#  ('github', 799),
#  ('alert', 798),
#  ('vision', 785),
#  ('google', 771),
#  ('go', 762),
#  ('analysis', 761),
#  ('ios', 755),
#  ('opencv', 744),
#  ('php', 725),
#  ('dev', 705),
#  ('server', 688),
#  ('microsoft', 686),
#  ('java', 680),
#  ('based', 662),
#  ('bot', 660),
#  ('network', 656),
#  ('open', 654),
#  ('example', 627),
#  ('client', 623),
#  ('cordova', 615),
#  ('papers', 613),
#  ('iot', 611),
#  ('anomaly', 603),
#  ('boot', 596),
#  ('tensorflow', 588),
#  ('jquery', 579),
#  ('resources', 573),
#  ('spring', 569),
#  ('1', 561),
#  ('ui', 561),
#  ('net', 556),
#  ('guide', 546),
#  ('javascript', 544),
#  ('vue', 525),
#  ('monitor', 518),
#  ('tracking', 510),
#  ('video', 498),
#  ('dataset', 494),
#  ('community', 490),
#  ('laravel', 489),
#  ('workshop', 485),
#  ('classification', 485),
#  ('computer', 481),
#  ('monitoring', 478),
#  ('angular', 474),
#  ('ansible', 474),
#  ('amazon', 472),
#  ('labs', 470),
#  ('time', 470),
#  ('2', 469),
#  ('university', 464),
#  ('cnn', 463),
#  ('segmentation', 456),
#  ('questions', 454),
#  ('projects', 454),
#  ('list', 452),
#  ('research', 452),
#  ('x', 450),
#  ('design', 447),
#  ('yolo', 444),
#  ('team', 444),
#  ('examples', 440),
#  ('kubernetes', 435),
#  ('core', 433),
#  ('smart', 431),
#  ('bootstrap', 431),
#  ('prometheus', 427),
#  ('u', 412),
#  ('tutorial', 410),
#  ('linux', 408),
#  ('3d', 405),
#  ('text', 404),
#  ('service', 399),
#  ('detect', 392),
#  ('django', 390),
#  ('simple', 388),
#  ('template', 387),
#  ('public', 386),
#  ('mobile', 385),
#  ('coding', 382),
#  ('model', 381),
#  ('malware', 380),
#  ('multi', 377),
#  ('developer', 373),
#  ('cli', 369),
#  ('nlp', 367),
#  ('fraud', 366),
#  ('sample', 366),
#  ('real', 364),
#  ('scripts', 362),
#  ('red', 362),
#  ('framework', 359),
#  ('science', 357),
#  ('vehicle', 350),
#  ('plugins', 349),
#  ('mask', 347),
#  ('hacking', 341),
#  ('notes', 336),
#  ('starter', 335),
#  ('windows', 331),
#  ('alerts', 330),
#  ('group', 330),
#  ('r', 330),
#  ('py', 330),
#  ('ids', 328),
#  ('devops', 328),
#  ('paper', 326),
#  ('lane', 326),
#  ('covid', 326),
#  ('edge', 323),
#  ('tool', 320),
#  ('traffic', 319),
#  ('generator', 316),
#  ('dashboard', 312),
#  ('nodejs', 312),
#  ('cve', 309),
#  ('action', 306),
#  ('processing', 302),
#  ('end', 301),
#  ('manager', 299),
#  ('custom', 298),
#  ('rcnn', 296),
#  ('advanced', 295),
#  ('git', 293),
#  ('game', 293),
#  ('wp', 292),
#  ('home', 291),
#  ('library', 290),
#  ('c', 289),
#  ('cv', 288),
#  ('tech', 287),
#  ('management', 287),
#  ('keras', 286),
#  ('intel', 283),
#  ('org', 283),
#  ('test', 281),
#  ('2022', 280),
#  ('frontend', 277),
#  ('platform', 277),
#  ('graph', 276),
#  ('2020', 275),
#  ('software', 273),
#  ('2019', 273),
#  ('source', 272),
#  ('ng', 272),
#  ('pi', 269),
#  ('toolkit', 268),
#  ('facial', 267),
#  ('auto', 266),
#  ('scanner', 266),
#  ('car', 265),
#  ('vim', 265),
#  ('yolov3', 265),
#  ('config', 264),
#  ('attack', 261),
#  ('archive', 260),
#  ('fake', 260),
#  ('language', 260),
#  ('self', 260),
#  ('camera', 260),
#  ('challenge', 258),
#  ('news', 256),
#  ('images', 255),
#  ('apps', 255),
#  ('2021', 255),
#  ('prediction', 254),
#  ('neural', 252),
#  ('serverless', 252),
#  ('cpp', 251),
#  ('free', 250),
#  ('twitter', 250),
#  ('solutions', 246),
#  ('automation', 246),
#  ('event', 243),
#  ('extension', 243),
#  ('emotion', 243),
#  ('unity', 242),
#  ('docs', 242),
#  ('cheat', 241),
#  ('analytics', 239),
#  ('stack', 235),
#  ('engine', 232),
#  ('yolov5', 231),
#  ('human', 231),
#  ('tracker', 231),
#  ('control', 231),
#  ('3', 230),
#  ('application', 229),
#  ('swift', 229),
#  ('best', 228),
#  ('kit', 227),
#  ('proxy', 227),
#  ('ruby', 227),
#  ('threat', 226),
#  ('v2', 223),
#  ('module', 222),
#  ('vscode', 221),
#  ('arduino', 221),
#  ('card', 220),
#  ('ctf', 219),
#  ('grafana', 219),
#  ('learn', 218),
#  ('rest', 218),
#  ('driver', 217),
#  ('19', 217),
#  ('datasets', 217),
#  ('forensics', 217),
#  ('course', 216),
#  ('dotnet', 216),
#  ('driving', 216),
#  ('training', 215),
#  ('digital', 214),
#  ('discord', 212),
#  ('lambda', 210),
#  ('networks', 210),
#  ('crypto', 208),
#  ('intelligence', 208),
#  ('models', 208),
#  ('pipeline', 208),
#  ('admin', 207),
#  ('yara', 206),
#  ('file', 206),
#  ('boilerplate', 205),
#  ('kafka', 205),
#  ('engineering', 205),
#  ('faster', 203),
#  ('flutter', 201),
#  ('build', 201),
#  ('disease', 201),
#  ('search', 200),
#  ('speech', 200),
#  ('social', 200),
#  ('ocr', 200),
#  ('hunting', 199),
#  ('k8s', 199),
#  ('tutorials', 198),
#  ('front', 198),
#  ('pentest', 197),
#  ('services', 197),
#  ('hub', 196),
#  ('pro', 196),
#  ('e', 195),
#  ('sheet', 195),
#  ('assistant', 195),
#  ('cybersecurity', 194),
#  ('remote', 193),
#  ('microservices', 193),
#  ('cyber', 192),
#  ('sign', 192),
#  ('log', 192),
#  ('blockchain', 191),
#  ('browser', 191),
#  ('tf', 191),
#  ('algorithms', 191),
#  ('pose', 190),
#  ('newrelic', 189),
#  ('secure', 189),
#  ('redux', 189),
#  ('fast', 188),
#  ('cluster', 187),
#  ('carnd', 187),
#  ('rs', 187),
#  ('rust', 186),
#  ('website', 186),
#  ('visual', 186),
#  ('estimation', 185),
#  ('chat', 185),
#  ('cancer', 185),
#  ('integration', 184),
#  ('dl', 184),
#  ('intrusion', 183),
#  ('notification', 183),
#  ('robot', 183),
#  ('exporter', 183),
#  ('device', 182),
#  ('pool', 182),
#  ('agent', 182),
#  ('splunk', 182),
#  ('master', 182),
#  ('cs', 181),
#  ('4', 181),
#  ('robotics', 181),
#  ('script', 181),
#  ('development', 181),
#  ('zabbix', 180),
#  ('ros', 180),
#  ('audio', 179),
#  ('id', 179),
#  ('line', 179),
#  ('media', 177),
#  ('ssd', 175),
#  ('ips', 175),
#  ('rules', 175),
#  ('benchmark', 175),
#  ('motion', 175),
#  ('operator', 175),
#  ('telegram', 174),
#  ('testing', 173),
#  ('algorithm', 173),
#  ('deploy', 173),
#  ('plate', 172),
#  ('controller', 172),
#  ('slack', 172),
#  ('online', 171),
#  ('deeplearning', 171),
#  ('apis', 170),
#  ('rails', 170),
#  ('flask', 169),
#  ('study', 169),
#  ('wordpress', 169),
#  ('book', 169),
#  ('kaggle', 168),
#  ('capstone', 168),
#  ('collection', 167),
#  ('meteor', 167),
#  ('check', 166),
#  ('reading', 165),
#  ('feature', 164),
#  ('classifier', 163),
#  ('cheatsheet', 163),
#  ('apache', 163),
#  ('plus', 163),
#  ('auth', 162),
#  ('credit', 161),
#  ('sagemaker', 161),
#  ('push', 161),
#  ('ipsum', 160),
#  ('point', 160),
#  ('spark', 160),
#  ('contrib', 159),
#  ('json', 158),
#  ('change', 158),
#  ('sensor', 158),
#  ('setup', 158),
#  ('2023', 157),
#  ('nginx', 157),
#  ('2018', 157),
#  ('ts', 155),
#  ('oracle', 154),
#  ('systems', 154),
#  ('material', 153),
#  ('http', 153),
#  ('raspberry', 152),
#  ('anti', 152),
#  ('ad', 152),
#  ('blog', 152),
#  ('roadmap', 151),
#  ('hack', 151),
#  ('automatic', 151),
#  ('modules', 150),
#  ('box', 150),
#  ('filter', 149),
#  ('solution', 149),
#  ('one', 149),
#  ('email', 149),
#  ('map', 148),
#  ('autonomous', 148),
#  ('fusion', 148),
#  ('components', 147),
#  ('programming', 147),
#  ('coursera', 147),
#  ('live', 147),
#  ('semantic', 147),
#  ('sql', 146),
#  ('architecture', 146),
#  ('realtime', 145),
#  ('form', 144),
#  ('templates', 144),
#  ('base', 144),
#  ('knowledge', 144),
#  ('top', 144),
#  ('v', 143),
#  ('matlab', 142),
#  ('bug', 142),
#  ('utils', 141),
#  ('lite', 141),
#  ('openshift', 141),
#  ('transformer', 140),
#  ('puppet', 140),
#  ('yolov4', 139),
#  ('sec', 139),
#  ('hackathon', 139),
#  ('user', 139),
#  ('editor', 138),
#  ('html', 138),
#  ('backend', 138),
#  ('checker', 137),
#  ('light', 137),
#  ('component', 137),
#  ('gateway', 137),
#  ('ar', 137),
#  ('defect', 135),
#  ('poc', 135),
#  ('brain', 135),
#  ('chrome', 135),
#  ('full', 135),
#  ('wallet', 135),
#  ('hand', 134),
#  ('checklist', 133),
#  ('road', 133),
#  ('os', 132),
#  ('theme', 132),
#  ('series', 132),
#  ('status', 131),
#  ('n', 131),
#  ('notifications', 131),
#  ('parser', 131),
#  ('courses', 130),
#  ('patterns', 130),
#  ('oss', 130),
#  ('backup', 130),
#  ('k', 130),
#  ('phonegap', 130),
#  ('lib', 129),
#  ('elasticsearch', 128),
#  ('gui', 128),
#  ('style', 128),
#  ('xss', 128),
#  ('days', 127),
#  ('iobroker', 126),
#  ('eye', 125),
#  ('wifi', 125),
#  ('ngx', 125),
#  ('ember', 125),
#  ('bridge', 124),
#  ('express', 124),
#  ('ip', 124),
#  ('homebridge', 124),
#  ('attention', 123),
#  ('metrics', 123),
#  ('stream', 123),
#  ('dialog', 122),
#  ('gan', 121),
#  ('ethereum', 121),
#  ('esp32', 121),
#  ('reactjs', 121),
#  ('flow', 120),
#  ('facedetection', 120),
#  ('health', 120),
#  ('yii2', 120),
#  ('2017', 120),
#  ('infrastructure', 120),
#  ('notebooks', 119),
#  ('firebase', 119),
#  ('response', 119),
#  ('db', 119),
#  ('udacity', 119),
#  ('protocol', 119),
#  ('dynamic', 119),
#  ('ecs', 119),
#  ('slam', 118),
#  ('scan', 118),
#  ('role', 117),
#  ('easy', 117),
#  ('login', 117),
#  ('spam', 117),
#  ('deployment', 117),
#  ('s3', 117),
#  ('mongodb', 116),
#  ('vault', 115),
#  ('license', 115),
#  ('typescript', 115),
#  ('view', 115),
#  ('pedestrian', 115),
#  ('audit', 114),
#  ('developers', 114),
#  ('z', 114),
#  ('cpuminer', 113),
#  ('localization', 113),
#  ('container', 113),
#  ('toolbox', 113),
#  ('co', 113),
#  ('connect', 113),
#  ('final', 112),
#  ('bitcoin', 112),
#  ('notify', 112),
#  ('lua', 112),
#  ('weather', 112),
#  ('mysql', 112),
#  ('chinese', 112),
#  ('ipsec', 111),
#  ('validator', 111),
#  ('css', 111),
#  ('resource', 111),
#  ('domain', 111),
#  ('googlecloudplatform', 111),
#  ('lidar', 111),
#  ('chatgpt', 111),
#  ('events', 110),
#  ('table', 110),
#  ('analyzer', 110),
#  ('books', 110),
#  ('ci', 110),
#  ('voice', 110),
#  ('actions', 110),
#  ('antivirus', 109),
#  ('fire', 109),
#  ('task', 109),
#  ('virtual', 108),
#  ('clone', 108),
#  ('firmware', 108),
#  ('medical', 108),
#  ('satellite', 108),
#  ('color', 108),
#  ('content', 108),
#  ('covid19', 108),
#  ('modal', 108),
#  ('b', 108),
#  ('class', 107),
#  ('cookbook', 107),
#  ('notifier', 107),
#  ('target', 107),
#  ('sap', 107),
#  ('studio', 107),
#  ('transfer', 107),
#  ('webhook', 107),
#  ('vmware', 106),
#  ('fault', 106),
#  ('mtcnn', 106),
#  ('provider', 106),
#  ('lstm', 106),
#  ('nagios', 106),
#  ('nvidia', 105),
#  ('arm', 105),
#  ('elastic', 105),
#  ('art', 105),
#  ('music', 105),
#  ('trading', 105),
#  ('identification', 105),
#  ('mining', 105),
#  ('5', 105),
#  ('mqtt', 104),
#  ('connector', 104),
#  ('power', 104),
#  ('ionic', 104),
#  ('hands', 104),
#  ('repo', 103),
#  ('shot', 103),
#  ('reference', 103),
#  ('phishing', 103),
#  ('practices', 103),
#  ('command', 103),
#  ('fall', 103),
#  ('darknet', 102),
#  ('gesture', 102),
#  ('attendance', 102),
#  ('codacy', 102),
#  ('links', 102),
#  ('automated', 102),
#  ('mozilla', 102),
#  ('router', 101),
#  ('reverse', 101),
#  ('esp', 101),
#  ('eks', 101),
#  ('quickstart', 101),
#  ('gcp', 101),
#  ('redis', 101),
#  ('kernel', 101),
#  ('foundation', 101),
#  ('people', 100),
#  ('basic', 100),
#  ('sms', 100),
#  ('local', 100),
#  ('supervised', 100),
#  ('review', 100),
#  ('extraction', 100),
#  ('artificial', 100),
#  ('tiny', 99),
#  ('activity', 99),
#  ('incident', 99),
#  ('state', 98),
#  ('drone', 98),
#  ('url', 98),
#  ('rpi', 98),
#  ('safe', 98),
#  ('signal', 98),
#  ('edition', 97),
#  ('graphql', 97),
#  ('sentiment', 97),
#  ('adversarial', 97),
#  ('shell', 97),
#  ('builder', 97),
#  ('building', 97),
#  ('single', 97),
#  ('osquery', 96),
#  ('document', 96),
#  ('legacy', 96),
#  ('jenkins', 96),
#  ('streaming', 96),
#  ('markdown', 95),
#  ('tree', 95),
#  ('extensions', 95),
#  ('100', 95),
#  ('ddos', 95),
#  ('logger', 95),
#  ('database', 95),
#  ('misp', 95),
#  ('html5', 95),
#  ('bounty', 95),
#  ('gpu', 94),
#  ('collision', 94),
#  ('swagger', 94),
#  ('stars', 94),
#  ('crud', 94),
#  ('secret', 94),
#  ('center', 94),
#  ('upload', 93),
#  ('viewer', 93),
#  ('counter', 93),
#  ('scraper', 93),
#  ('kube', 93),
#  ('enterprise', 93),
#  ('datadog', 93),
#  ('meta', 93),
#  ('certified', 92),
#  ('programmer', 92),
#  ('space', 92),
#  ('alertmanager', 92),
#  ('snippets', 92),
#  ('plant', 92),
#  ('uboot', 92),
#  ('scene', 92),
#  ('vpn', 92),
#  ('update', 92),
#  ('privacy', 91),
#  ('next', 91),
#  ('radar', 91),
#  ('skin', 90),
#  ('zero', 90),
#  ('desktop', 90),
#  ('7', 90),
#  ('caffe', 90),
#  ('info', 90),
#  ('10', 90),
#  ('charts', 89),
#  ('active', 89),
#  ('osint', 89),
#  ('sensu', 89),
#  ('dns', 89),
#  ('playground', 89),
#  ('intro', 89),
#  ('macos', 89),
#  ('portal', 88),
#  ('websites', 88),
#  ('sh', 88),
#  ('performance', 88),
#  ('practice', 88),
#  ('beta', 88),
#  ('create', 88),
#  ('generation', 88),
#  ('get', 88),
#  ('owasp', 88),
#  ('number', 88),
#  ('sentinel', 87),
#  ('player', 87),
#  ('collector', 87),
#  ('facebook', 87),
#  ('ms', 87),
#  ('teams', 87),
#  ('jetson', 86),
#  ('matrix', 86),
#  ('job', 86),
#  ('store', 86),
#  ('mr', 86),
#  ('mac', 86),
#  ('authentication', 86),
#  ('applications', 86),
#  ('opensource', 86),
#  ('eth', 86),
#  ('counting', 85),
#  ('simulator', 85),
#  ('mirror', 85),
#  ('f', 85),
#  ('saliency', 84),
#  ('common', 84),
#  ('inference', 84),
#  ('6', 84),
#  ('token', 84),
#  ('ec2', 84),
#  ('big', 84),
#  ('electron', 84),
#  ('world', 83),
#  ('stock', 83),
#  ('detecting', 83),
#  ('use', 83),
#  ('powershell', 83),
#  ('helper', 83),
#  ('installer', 83),
#  ('mod', 83),
#  ('ds', 83),
#  ('cdk', 83),
#  ('drowsiness', 83),
#  ('product', 82),
#  ('ssh', 82),
#  ('v3', 82),
#  ('cloudflare', 82),
#  ('policy', 82),
#  ('ops', 82),
#  ('salesforce', 82),
#  ('helm', 82),
#  ('documentation', 82),
#  ('cell', 82),
#  ('objectdetection', 82),
#  ('release', 81),
#  ('sync', 81),
#  ('site', 81),
#  ('apple', 81),
#  ('multiple', 81),
#  ('discovery', 80),
#  ('widget', 80),
#  ('2d', 80),
#  ('implementation', 80),
#  ('ct', 80),
#  ('ecg', 79),
#  ('picker', 79),
#  ('ubuntu', 79),
#  ('loader', 79),
#  ('method', 79),
#  ('youtube', 79),
#  ('finder', 79),
#  ('lung', 79),
#  ('ray', 78),
#  ('path', 78),
#  ('technologies', 78),
#  ('csharp', 78),
#  ('lang', 77),
#  ('forms', 77),
#  ('uploader', 77),
#  ('chef', 77),
#  ('openpilot', 77),
#  ('unsupervised', 77),
#  ('nft', 76),
#  ('nativescript', 76),
#  ('cert', 76),
#  ('kotlin', 76),
#  ('titanium', 76),
#  ('key', 76),
#  ('cam', 75),
#  ('forensic', 75),
#  ('static', 75),
#  ('defense', 75),
#  ('heroku', 75),
#  ('gender', 75),
#  ('vulnerability', 75),
#  ('tumor', 75),
#  ('chain', 75),
#  ('storage', 75),
#  ('features', 75),
#  ('crack', 75),
#  ('demos', 75),
#  ('ajax', 75),
#  ('bypass', 74),
#  ('beginners', 74),
#  ('breast', 74),
#  ('hackintosh', 74),
#  ('transformers', 74),
#  ('files', 74),
#  ('person', 74),
#  ('backbone', 74),
#  ('infosec', 74),
#  ('bundle', 74),
#  ('flash', 74),
#  ('webapp', 74),
#  ('devsecops', 74),
#  ('portfolio', 74),
#  ('survey', 73),
#  ('hacker', 73),
#  ('support', 73),
#  ('exploit', 73),
#  ('information', 73),
#  ('alarm', 73),
#  ('convolutional', 73),
#  ('functions', 73),
#  ('retinanet', 73),
#  ('games', 73),
#  ('hate', 73),
#  ('zone', 73),
#  ('page', 72),
#  ('fpga', 72),
#  ('cloudfoundry', 72),
#  ('exam', 72),
#  ('suite', 72),
#  ('snyk', 72),
#  ('black', 72),
#  ('microservice', 72),
#  ('sandbox', 72),
#  ('clustering', 72),
#  ('bookmarks', 72),
#  ('thesis', 72),
#  ('ca', 72),
#  ('openstack', 72),
#  ('openapi', 72),
#  ('twilio', 71),
#  ('tips', 71),
#  ('context', 71),
#  ('aks', 71),
#  ('async', 71),
#  ('contracts', 71),
#  ('extended', 71),
#  ('wiki', 70),
#  ('grid', 70),
#  ('multimodal', 70),
#  ('compose', 70),
#  ('shopify', 70),
#  ('mini', 70),
#  ('binance', 70),
#  ('scratch', 70),
#  ('price', 70),
#  ('redhat', 70),
#  ('stanford', 70),
#  ('mono', 69),
#  ('cisco', 69),
#  ('landmark', 69),
#  ('explorer', 69),
#  ('101', 69),
#  ('emacs', 69),
#  ('wazuh', 69),
#  ('angularjs', 69),
#  ('call', 69),
#  ('menu', 69),
#  ('head', 69),
#  ('iris', 69),
#  ('cross', 69),
#  ('watcher', 69),
#  ('background', 69),
#  ('chart', 69),
#  ('nano', 68),
#  ('chest', 68),
#  ('install', 68),
#  ('global', 68),
#  ('uav', 68),
#  ('report', 68),
#  ('hunter', 68),
#  ('parse', 68),
#  ('8', 68),
#  ('engineer', 68),
#  ('nasa', 68),
#  ('official', 68),
#  ('level', 68),
#  ('anomalydetection', 67),
#  ('watch', 67),
#  ('dnn', 67),
#  ('maskrcnn', 67),
#  ('scale', 67),
#  ('label', 67),
#  ('private', 67),
#  ('mit', 67),
#  ('runner', 67),
#  ('scala', 67),
#  ('package', 67),
#  ('bro', 67),
#  ('ssl', 67),
#  ('usb', 67),
#  ('todo', 67),
#  ('dark', 67),
#  ('bootcamp', 67),
#  ('exercises', 67),
#  ('safety', 67),
#  ('cloudformation', 67),
#  ('baseline', 66),
#  ('apns', 66),
#  ('mediapipe', 66),
#  ('dotfiles', 66),
#  ('identity', 66),
#  ('age', 66),
#  ('zeek', 66),
#  ('account', 66),
#  ('springboot', 66),
#  ('step', 66),
#  ('socket', 66),
#  ('access', 66),
#  ('leaf', 66),
#  ('input', 66),
#  ('sensing', 66),
#  ('svm', 66),
#  ('barcode', 66),
#  ('random', 66),
#  ('parking', 66),
#  ('getting', 66),
#  ('copy', 65),
#  ('networking', 65),
#  ('mlops', 65),
#  ('cat', 65),
#  ('magento', 65),
#  ('surveillance', 65),
#  ('sound', 65),
#  ('link', 65),
#  ('rds', 65),
#  ('fastapi', 65),
#  ('quality', 65),
#  ('alexa', 65),
#  ('speed', 65),
#  ('hello', 65),
#  ('tflite', 65),
#  ('svelte', 65),
#  ('cloudwatch', 65),
#  ('modern', 65),
#  ('elk', 65),
#  ('exploitation', 65),
#  ('suricata', 65),
#  ('eslint', 65),
#  ('heart', 65),
#  ('bert', 65),
#  ('block', 64),
#  ('lines', 64),
#  ('password', 64),
#  ('teaming', 64),
#  ('cti', 64),
#  ('clamav', 64),
#  ('instance', 64),
#  ('deepfake', 64),
#  ('computing', 64),
#  ('graylog', 64),
#  ('mode', 63),
#  ('siem', 63),
#  ('wrapper', 63),
#  ('forest', 63),
#  ('webrtc', 63),
#  ('distributed', 63),
#  ('tests', 63),
#  ('embedded', 63),
#  ('tradingview', 63),
#  ('universal', 63),
#  ('finance', 63),
#  ('datascience', 63),
#  ('homeassistant', 63),
#  ('addon', 63),
#  ('pattern', 63),
#  ('handler', 63),
#  ('sysadmin', 63),
#  ('chess', 63),
#  ('perception', 63),
#  ('vad', 63),
#  ('angular2', 62),
#  ('workflow', 62),
#  ('bash', 62),
#  ('production', 62),
#  ('vagrant', 62),
#  ('pdf', 62),
#  ('prep', 62),
#  ('handbook', 62),
#  ('videos', 62),
#  ('detr', 62),
#  ('super', 62),
#  ('cognitive', 62),
#  ('word', 61),
#  ('distance', 61),
#  ('quick', 61),
#  ('extractor', 61),
#  ('financial', 61),
#  ('snap', 61),
#  ('translate', 61),
#  ('selfhosted', 61),
#  ('patch', 61),
#  ('cache', 61),
#  ('navigation', 61),
#  ('spoofing', 61),
#  ...]

# %%
t2 = github_data_df['topics'].apply(lambda x: myclnfunction(x))

# %%
t2_cnt = Counter(t2.explode())
t2_cnt.most_common()
# Out:
# [(nan, 152648),
#  ('detection', 13503),
#  ('learning', 12881),
#  ('python', 7897),
#  ('deep', 6053),
#  ('machine', 5800),
#  ('security', 5645),
#  ('data', 4467),
#  ('image', 3795),
#  ('object', 3785),
#  ('api', 3718),
#  ('vision', 3611),
#  ('computer', 3399),
#  ('analysis', 3267),
#  ('javascript', 3218),
#  ('android', 3063),
#  ('neural', 3024),
#  ('tensorflow', 2893),
#  ('face', 2878),
#  ('recognition', 2801),
#  ('react', 2770),
#  ('awesome', 2753),
#  ('opencv', 2686),
#  ('network', 2587),
#  ('processing', 2563),
#  ('aws', 2554),
#  ('pytorch', 2516),
#  ('docker', 2462),
#  ('networks', 2454),
#  ('hacktoberfest', 2133),
#  ('cloud', 2131),
#  ('classification', 2012),
#  ('library', 1942),
#  ('plugin', 1902),
#  ('java', 1869),
#  ('monitoring', 1847),
#  ('tools', 1839),
#  ('language', 1707),
#  ('list', 1688),
#  ('python3', 1679),
#  ('kubernetes', 1672),
#  ('linux', 1633),
#  ('azure', 1627),
#  ('segmentation', 1614),
#  ('web', 1554),
#  ('bot', 1538),
#  ('game', 1490),
#  ('server', 1483),
#  ('framework', 1475),
#  ('malware', 1439),
#  ('windows', 1400),
#  ('ios', 1396),
#  ('php', 1361),
#  ('golang', 1361),
#  ('nodejs', 1354),
#  ('automation', 1350),
#  ('keras', 1345),
#  ('intelligence', 1338),
#  ('video', 1304),
#  ('testing', 1257),
#  ('ai', 1244),
#  ('dataset', 1219),
#  ('tracking', 1216),
#  ('text', 1203),
#  ('spring', 1197),
#  ('code', 1189),
#  ('google', 1189),
#  ('c', 1176),
#  ('science', 1174),
#  ('nlp', 1124),
#  ('cnn', 1116),
#  ('tool', 1112),
#  ('application', 1104),
#  ('hacking', 1098),
#  ('management', 1094),
#  ('database', 1077),
#  ('app', 1075),
#  ('model', 1074),
#  ('typescript', 1036),
#  ('terraform', 1033),
#  ('graph', 1024),
#  ('time', 1001),
#  ('swift', 974),
#  ('algorithms', 972),
#  ('3d', 969),
#  ('threat', 963),
#  ('engine', 945),
#  ('system', 940),
#  ('iot', 934),
#  ('pi', 926),
#  ('ui', 921),
#  ('convolutional', 912),
#  ('raspberry', 911),
#  ('go', 897),
#  ('artificial', 895),
#  ('native', 879),
#  ('client', 874),
#  ('prometheus', 872),
#  ('anomaly', 855),
#  ('forensics', 846),
#  ('arduino', 843),
#  ('css', 841),
#  ('algorithm', 832),
#  ('engineering', 825),
#  ('open', 817),
#  ('home', 807),
#  ('development', 807),
#  ('html', 806),
#  ('discord', 806),
#  ('programming', 779),
#  ('flask', 776),
#  ('flutter', 776),
#  ('github', 763),
#  ('project', 754),
#  ('cpp', 754),
#  ('cybersecurity', 748),
#  ('extension', 744),
#  ('speech', 740),
#  ('vue', 737),
#  ('audio', 733),
#  ('cli', 732),
#  ('vulnerability', 727),
#  ('service', 724),
#  ('rest', 717),
#  ('camera', 714),
#  ('natural', 713),
#  ('estimation', 705),
#  ('rust', 694),
#  ('blockchain', 693),
#  ('models', 687),
#  ('js', 683),
#  ('angular', 676),
#  ('self', 672),
#  ('design', 670),
#  ('yolo', 670),
#  ('platform', 669),
#  ('laravel', 668),
#  ('devops', 659),
#  ('plus', 652),
#  ('sdk', 650),
#  ('node', 646),
#  ('scanner', 643),
#  ('source', 641),
#  ('script', 633),
#  ('search', 624),
#  ('telegram', 621),
#  ('module', 615),
#  ('macos', 609),
#  ('django', 602),
#  ('kotlin', 598),
#  ('edge', 596),
#  ('alert', 587),
#  ('components', 587),
#  ('architecture', 586),
#  ('visualization', 584),
#  ('trading', 581),
#  ('driving', 580),
#  ('research', 578),
#  ('multi', 576),
#  ('ocr', 575),
#  ('template', 572),
#  ('cryptography', 572),
#  ('notifications', 565),
#  ('package', 561),
#  ('sql', 553),
#  ('wordpress', 551),
#  ('pose', 549),
#  ('assistant', 545),
#  ('series', 543),
#  ('privacy', 542),
#  ('ros', 535),
#  ('control', 533),
#  ('reactjs', 531),
#  ('monitor', 530),
#  ('boot', 529),
#  ('json', 529),
#  ('tutorial', 528),
#  ('autonomous', 528),
#  ('proxy', 526),
#  ('mobile', 525),
#  ('pentesting', 524),
#  ('encryption', 520),
#  ('yolov3', 519),
#  ('ethereum', 518),
#  ('metrics', 514),
#  ('manager', 510),
#  ('generator', 506),
#  ('robotics', 504),
#  ('dashboard', 504),
#  ('ansible', 504),
#  ('analytics', 504),
#  ('images', 502),
#  ('kafka', 501),
#  ('systems', 493),
#  ('detector', 493),
#  ('ruby', 492),
#  ('firebase', 491),
#  ('lambda', 491),
#  ('component', 488),
#  ('csharp', 479),
#  ('bootstrap', 474),
#  ('computing', 473),
#  ('notebook', 470),
#  ('covid', 470),
#  ('grafana', 468),
#  ('ctf', 468),
#  ('reverse', 462),
#  ('powershell', 462),
#  ('shell', 460),
#  ('point', 460),
#  ('software', 459),
#  ('response', 457),
#  ('r', 456),
#  ('file', 454),
#  ('antivirus', 451),
#  ('clustering', 449),
#  ('supervised', 447),
#  ('penetration', 446),
#  ('classifier', 444),
#  ('serverless', 444),
#  ('information', 443),
#  ('jupyter', 443),
#  ('rcnn', 442),
#  ('amazon', 441),
#  ('dotnet', 440),
#  ('remote', 440),
#  ('mysql', 436),
#  ('semantic', 435),
#  ('http', 435),
#  ('mining', 435),
#  ('interview', 434),
#  ('ml', 433),
#  ('incident', 433),
#  ('cryptocurrency', 433),
#  ('chrome', 432),
#  ('feature', 432),
#  ('paper', 431),
#  ('car', 429),
#  ('authentication', 427),
#  ('medical', 426),
#  ('matlab', 425),
#  ('attack', 425),
#  ('mongodb', 423),
#  ('sensor', 421),
#  ('bitcoin', 420),
#  ('real', 418),
#  ('visual', 416),
#  ('extraction', 416),
#  ('pipeline', 412),
#  ('gui', 410),
#  ('filter', 408),
#  ('browser', 407),
#  ('prediction', 404),
#  ('music', 401),
#  ('hunting', 400),
#  ('smart', 400),
#  ('elasticsearch', 398),
#  ('adversarial', 396),
#  ('generation', 395),
#  ('deeplearning', 394),
#  ('distributed', 392),
#  ('performance', 391),
#  ('parser', 390),
#  ('dns', 386),
#  ('lstm', 385),
#  ('material', 384),
#  ('command', 383),
#  ('simulation', 381),
#  ('cluster', 380),
#  ('cve', 380),
#  ('bash', 380),
#  ('storage', 379),
#  ('emotion', 379),
#  ('social', 378),
#  ('voice', 378),
#  ('transformer', 377),
#  ('event', 376),
#  ('transfer', 376),
#  ('postgresql', 376),
#  ('digital', 375),
#  ('regression', 375),
#  ('osint', 374),
#  ('core', 370),
#  ('mask', 367),
#  ('crypto', 365),
#  ('19', 364),
#  ('streaming', 363),
#  ('jquery', 362),
#  ('line', 360),
#  ('free', 359),
#  ('resources', 356),
#  ('bugbounty', 355),
#  ('human', 354),
#  ('optimization', 353),
#  ('wifi', 353),
#  ('lane', 353),
#  ('unity', 351),
#  ('anti', 350),
#  ('microsoft', 350),
#  ('cross', 350),
#  ('yolov5', 349),
#  ('compose', 348),
#  ('redux', 348),
#  ('test', 346),
#  ('bioinformatics', 345),
#  ('lidar', 343),
#  ('theme', 341),
#  ('signal', 341),
#  ('static', 339),
#  ('yara', 339),
#  ('virtual', 339),
#  ('microservices', 337),
#  ('inference', 337),
#  ('3', 336),
#  ('log', 336),
#  ('cyber', 336),
#  ('net', 335),
#  ('redis', 335),
#  ('traffic', 334),
#  ('ip', 333),
#  ('esp32', 333),
#  ('motion', 333),
#  ('services', 332),
#  ('infosec', 331),
#  ('deployment', 330),
#  ('custom', 327),
#  ('based', 326),
#  ('mqtt', 323),
#  ('xss', 323),
#  ('gateway', 322),
#  ('functions', 321),
#  ('html5', 319),
#  ('configuration', 319),
#  ('password', 318),
#  ('kernel', 318),
#  ('facial', 316),
#  ('team', 316),
#  ('logging', 316),
#  ('desktop', 315),
#  ('spark', 309),
#  ('audit', 305),
#  ('website', 305),
#  ('sentiment', 304),
#  ('injection', 304),
#  ('admin', 304),
#  ('protocol', 303),
#  ('tracker', 302),
#  ('learn', 302),
#  ('minecraft', 302),
#  ('twitter', 302),
#  ('firewall', 302),
#  ('ssd', 301),
#  ('email', 300),
#  ('config', 298),
#  ('container', 298),
#  ('attacks', 298),
#  ('pentest', 296),
#  ('infrastructure', 296),
#  ('files', 295),
#  ('slack', 295),
#  ('jwt', 292),
#  ('nginx', 290),
#  ('translation', 290),
#  ('actions', 289),
#  ('community', 288),
#  ('random', 288),
#  ('memory', 286),
#  ('action', 286),
#  ('end', 284),
#  ('generative', 283),
#  ('demo', 282),
#  ('editor', 282),
#  ('driver', 282),
#  ('tree', 281),
#  ('vehicle', 281),
#  ('user', 280),
#  ('red', 280),
#  ('gpu', 280),
#  ('stream', 279),
#  ('embedded', 278),
#  ('robot', 277),
#  ('physics', 277),
#  ('networking', 276),
#  ('controller', 275),
#  ('dfir', 275),
#  ('attention', 275),
#  ('scripts', 275),
#  ('quality', 275),
#  ('intrusion', 273),
#  ('s3', 272),
#  ('svm', 271),
#  ('phishing', 270),
#  ('graphql', 269),
#  ('domain', 269),
#  ('vscode', 269),
#  ('dynamic', 268),
#  ('bypass', 268),
#  ('unsupervised', 268),
#  ('imaging', 268),
#  ('integration', 267),
#  ('reinforcement', 266),
#  ('cancer', 265),
#  ('agent', 265),
#  ('git', 265),
#  ('yolov4', 263),
#  ('fraud', 262),
#  ('numpy', 261),
#  ('exporter', 261),
#  ('developer', 260),
#  ('forest', 258),
#  ('express', 257),
#  ('instance', 256),
#  ('bluetooth', 255),
#  ('apps', 254),
#  ('notification', 254),
#  ('studio', 253),
#  ('device', 251),
#  ('news', 251),
#  ('swagger', 250),
#  ('realtime', 249),
#  ('esp8266', 248),
#  ('terminal', 246),
#  ('training', 246),
#  ('backup', 245),
#  ('stack', 244),
#  ('knowledge', 243),
#  ('protection', 242),
#  ('jetson', 242),
#  ('flow', 242),
#  ('documentation', 241),
#  ('weather', 241),
#  ('frontend', 240),
#  ('single', 240),
#  ('selenium', 240),
#  ('ids', 240),
#  ('dialog', 239),
#  ('slam', 238),
#  ('hardware', 238),
#  ('rules', 238),
#  ('kaggle', 238),
#  ('localization', 238),
#  ('cordova', 238),
#  ('containers', 237),
#  ('lua', 237),
#  ('vuejs', 236),
#  ('rails', 234),
#  ('scikit', 233),
#  ('shot', 233),
#  ('darknet', 232),
#  ('reality', 232),
#  ('low', 231),
#  ('exploit', 231),
#  ('ssh', 230),
#  ('alerting', 230),
#  ('plugins', 230),
#  ('markdown', 229),
#  ('change', 229),
#  ('page', 229),
#  ('faster', 228),
#  ('validation', 227),
#  ('datasets', 227),
#  ('apache', 227),
#  ('exploitation', 226),
#  ('health', 226),
#  ('chatgpt', 226),
#  ('apple', 226),
#  ('2d', 226),
#  ('router', 225),
#  ('graphics', 225),
#  ('resnet', 224),
#  ('k8s', 224),
#  ('ubuntu', 224),
#  ('fake', 223),
#  ('detect', 222),
#  ('modules', 222),
#  ('chat', 222),
#  ('redteam', 221),
#  ('ci', 221),
#  ('annotation', 220),
#  ('dart', 217),
#  ('webapp', 217),
#  ('gpt', 217),
#  ('jenkins', 217),
#  ('npm', 217),
#  ('token', 217),
#  ('pattern', 216),
#  ('solidity', 216),
#  ('electron', 216),
#  ('tensorflow2', 216),
#  ('pandas', 216),
#  ('sensing', 216),
#  ('bug', 216),
#  ('modeling', 215),
#  ('high', 214),
#  ('ddos', 214),
#  ('vpn', 213),
#  ('udacity', 213),
#  ('media', 212),
#  ('mobilenet', 212),
#  ('ssl', 212),
#  ('workflow', 211),
#  ('boilerplate', 210),
#  ('statistics', 208),
#  ('solutions', 208),
#  ('bert', 208),
#  ('alerts', 207),
#  ('color', 207),
#  ('objective', 207),
#  ('binary', 206),
#  ('plate', 206),
#  ('youtube', 205),
#  ('helm', 205),
#  ('support', 205),
#  ('entity', 204),
#  ('2', 203),
#  ('mod', 203),
#  ('license', 202),
#  ('hack', 202),
#  ('modal', 202),
#  ('heroku', 201),
#  ('continuous', 201),
#  ('stock', 201),
#  ('observability', 201),
#  ('backend', 200),
#  ('chatbot', 200),
#  ('wallet', 199),
#  ('map', 198),
#  ('form', 198),
#  ('tutorials', 198),
#  ('lists', 198),
#  ('energy', 198),
#  ('online', 197),
#  ('key', 196),
#  ('scanning', 196),
#  ('activity', 196),
#  ('pdf', 196),
#  ('card', 195),
#  ('examples', 195),
#  ('openapi', 194),
#  ('spam', 194),
#  ('discovery', 193),
#  ('addon', 193),
#  ('4', 193),
#  ('questions', 193),
#  ('auto', 193),
#  ('websocket', 192),
#  ('devsecops', 192),
#  ('vector', 192),
#  ('kit', 192),
#  ('process', 192),
#  ('tls', 192),
#  ('state', 191),
#  ('outlier', 191),
#  ('virus', 191),
#  ('push', 191),
#  ('microservice', 191),
#  ('homeassistant', 190),
#  ('gan', 190),
#  ('cell', 190),
#  ('sample', 189),
#  ('features', 189),
#  ('transformers', 189),
#  ('contracts', 189),
#  ('coronavirus', 188),
#  ('identification', 188),
#  ('scene', 188),
#  ('applications', 187),
#  ('gcp', 186),
#  ('active', 185),
#  ('collision', 185),
#  ('mvc', 184),
#  ('openai', 184),
#  ('player', 184),
#  ('vehicles', 184),
#  ('structures', 184),
#  ('disease', 184),
#  ('events', 184),
#  ('templates', 183),
#  ('access', 183),
#  ('opengl', 183),
#  ('dlib', 183),
#  ('verification', 182),
#  ('wrapper', 182),
#  ('opensource', 182),
#  ('radio', 182),
#  ('openvino', 182),
#  ('cuda', 181),
#  ('secure', 180),
#  ('example', 179),
#  ('benchmark', 179),
#  ('intel', 179),
#  ('puppet', 179),
#  ('satellite', 178),
#  ('collection', 178),
#  ('firefox', 178),
#  ('stealer', 178),
#  ('internet', 177),
#  ('vim', 177),
#  ('games', 177),
#  ('tensorrt', 177),
#  ('swiftui', 177),
#  ('policy', 177),
#  ('webrtc', 176),
#  ('site', 176),
#  ('ibm', 176),
#  ('autoencoder', 176),
#  ('error', 175),
#  ('scala', 175),
#  ('hand', 175),
#  ('task', 175),
#  ('os', 174),
#  ('webpack', 174),
#  ('cms', 174),
#  ('crawler', 174),
#  ('coco', 174),
#  ('unet', 173),
#  ('ec2', 173),
#  ('papers', 172),
#  ('linear', 172),
#  ('zero', 172),
#  ('hooks', 172),
#  ('seq', 172),
#  ('sms', 171),
#  ('matching', 171),
#  ('colab', 171),
#  ('oracle', 171),
#  ('cache', 171),
#  ('webhook', 170),
#  ('onnx', 170),
#  ('starter', 170),
#  ('nextjs', 170),
#  ('socket', 170),
#  ('document', 170),
#  ('capture', 169),
#  ('machinelearning', 168),
#  ('caffe', 168),
#  ('ffmpeg', 168),
#  ('scraper', 168),
#  ('eye', 168),
#  ('kali', 168),
#  ('mediapipe', 167),
#  ('debian', 167),
#  ('matrix', 166),
#  ('hardening', 166),
#  ('guide', 166),
#  ('big', 166),
#  ('toolkit', 166),
#  ('environment', 166),
#  ('simulator', 166),
#  ('alertmanager', 166),
#  ('cloudformation', 166),
#  ('analyzer', 165),
#  ('live', 165),
#  ('coding', 165),
#  ('maps', 165),
#  ('emacs', 165),
#  ('sign', 165),
#  ('zabbix', 165),
#  ('10', 164),
#  ('unity3d', 164),
#  ('usb', 164),
#  ('oauth2', 164),
#  ('nvidia', 164),
#  ('implementation', 164),
#  ('interface', 163),
#  ('csv', 162),
#  ('lite', 162),
#  ('animation', 162),
#  ('patterns', 162),
#  ('uptime', 162),
#  ('evasion', 161),
#  ('restful', 161),
#  ('fusion', 161),
#  ('elixir', 161),
#  ('university', 160),
#  ('operator', 159),
#  ('alignment', 159),
#  ('tcp', 159),
#  ('forecasting', 159),
#  ('transform', 158),
#  ('chain', 157),
#  ('rnn', 157),
#  ('mode', 157),
#  ('arm', 157),
#  ('firmware', 157),
#  ('crud', 156),
#  ('augmentation', 156),
#  ('status', 155),
#  ('education', 155),
#  ('ransomware', 154),
#  ('scraping', 154),
#  ('mesh', 154),
#  ('expression', 154),
#  ('upload', 154),
#  ('finance', 153),
#  ('streamlit', 153),
#  ('distribution', 153),
#  ('css3', 152),
#  ('coursera', 152),
#  ('augmented', 152),
#  ('builder', 151),
#  ('retrieval', 151),
#  ('notes', 151),
#  ('tailwindcss', 151),
#  ('gender', 151),
#  ('genomics', 151),
#  ('assembly', 150),
#  ('table', 149),
#  ('light', 149),
#  ('vault', 149),
#  ('schema', 149),
#  ('course', 149),
#  ('saliency', 149),
#  ('imagery', 148),
#  ('binance', 148),
#  ('compliance', 147),
#  ('cascade', 147),
#  ('labeling', 147),
#  ('ng', 147),
#  ('navigation', 147),
#  ('driven', 146),
#  ('distance', 146),
#  ('hash', 145),
#  ('build', 145),
#  ('writeups', 145),
#  ('payment', 144),
#  ('depth', 144),
#  ('grid', 144),
#  ('async', 144),
#  ('certificate', 144),
#  ('projects', 144),
#  ('fingerprint', 144),
#  ('batch', 144),
#  ('art', 144),
#  ('best', 143),
#  ('pretrained', 143),
#  ('cheat', 143),
#  ('identity', 142),
#  ('cloudflare', 142),
#  ('market', 142),
#  ('gps', 141),
#  ('mitre', 141),
#  ('reconstruction', 141),
#  ('lightning', 141),
#  ('nmap', 141),
#  ('twitch', 141),
#  ('eeg', 141),
#  ('first', 140),
#  ('parsing', 140),
#  ('ecg', 140),
#  ('logs', 140),
#  ('logger', 140),
#  ('gesture', 140),
#  ('siem', 139),
#  ('quantum', 139),
#  ('manipulation', 139),
#  ('pool', 139),
#  ('optical', 139),
#  ('popup', 139),
#  ('kibana', 138),
#  ('blog', 138),
#  ('background', 138),
#  ('tracing', 138),
#  ('calibration', 138),
#  ('message', 137),
#  ('evaluation', 137),
#  ('directory', 137),
#  ('lang', 137),
#  ('instagram', 137),
#  ('facebook', 137),
#  ('compression', 136),
#  ('widget', 136),
#  ('cv', 136),
#  ('sqlite', 136),
#  ('similarity', 136),
#  ('asp', 136),
#  ('fuzzing', 135),
#  ('io', 135),
#  ('threatintel', 135),
#  ('cpu', 135),
#  ('skin', 134),
#  ('surveillance', 134),
#  ('loss', 134),
#  ('owasp', 134),
#  ('bounty', 134),
#  ('sharp', 134),
#  ('ecommerce', 133),
#  ('mtcnn', 133),
#  ('login', 133),
#  ('compiler', 133),
#  ('rna', 133),
#  ('one', 133),
#  ('challenge', 132),
#  ('forensic', 132),
#  ('messaging', 132),
#  ('methods', 132),
#  ('planning', 132),
#  ('grpc', 131),
#  ('mac', 131),
#  ('mlops', 131),
#  ('splunk', 131),
#  ('reporting', 131),
#  ('dependency', 131),
#  ('multimodal', 130),
#  ('embeddings', 130),
#  ('ensemble', 130),
#  ('toast', 130),
#  ('sharing', 129),
#  ('clean', 129),
#  ('syntax', 129),
#  ('forms', 129),
#  ('vulnerabilities', 129),
#  ('web3', 129),
#  ('es6', 128),
#  ('sagemaker', 128),
#  ('x', 128),
#  ('exchange', 128),
#  ('scan', 128),
#  ('temporal', 128),
#  ('checker', 127),
#  ('store', 127),
#  ('metadata', 127),
#  ('packet', 127),
#  ('covid19', 127),
#  ('tesseract', 127),
#  ('fast', 126),
#  ('sklearn', 126),
#  ('decision', 126),
#  ('middleware', 126),
#  ('reconnaissance', 126),
#  ('blueteam', 126),
#  ('secrets', 126),
#  ('dom', 126),
#  ('elk', 126),
#  ('haar', 126),
#  ('ionic', 126),
#  ('healthcare', 126),
#  ('spoofing', 126),
#  ('symfony', 126),
#  ('utility', 126),
#  ('ecs', 126),
#  ('location', 125),
#  ('wireless', 125),
#  ('practices', 125),
#  ('mapping', 125),
#  ('chart', 125),
#  ('nano', 125),
#  ('understanding', 125),
#  ('challenges', 125),
#  ('hackathon', 124),
#  ('imagenet', 124),
#  ('extensions', 124),
#  ('scanners', 124),
#  ('view', 124),
#  ('cloudwatch', 124),
#  ('tkinter', 124),
#  ('signature', 124),
#  ('trojan', 123),
#  ('converter', 123),
#  ('call', 123),
#  ('private', 123),
#  ('authorization', 123),
#  ('xamarin', 123),
#  ('reader', 123),
#  ('technology', 123),
#  ('expressjs', 122),
#  ('tflite', 122),
#  ('accepted', 122),
#  ('landmark', 121),
#  ('word', 121),
#  ('xml', 121),
#  ('whatsapp', 121),
#  ('webassembly', 121),
#  ('2021', 121),
#  ('registry', 121),
#  ('bootstrap4', 120),
#  ('webcam', 120),
#  ('battery', 120),
#  ('pwa', 120),
#  ('communication', 120),
#  ('timeseries', 120),
#  ('representation', 120),
#  ('downloader', 119),
#  ('counting', 119),
#  ('debugging', 119),
#  ('blazor', 119),
#  ('tuning', 119),
#  ('hosted', 119),
#  ('tiny', 119),
#  ('content', 119),
#  ('console', 118),
#  ('sandbox', 118),
#  ('mvvm', 118),
#  ('https', 118),
#  ('keyboard', 118),
#  ('grabber', 118),
#  ('theory', 117),
#  ('sensors', 117),
#  ('character', 117),
#  ('webgl', 117),
#  ('safety', 117),
#  ('rendering', 117),
#  ('competition', 117),
#  ('devices', 117),
#  ('path', 117),
#  ('postgres', 117),
#  ('computational', 117),
#  ('radar', 116),
#  ('5', 116),
#  ('style', 116),
#  ('cookie', 116),
#  ('gradient', 116),
#  ('cplusplus', 115),
#  ('filtering', 115),
#  ('sound', 115),
#  ('rate', 115),
#  ('oriented', 115),
#  ('swarm', 115),
#  ('svelte', 115),
#  ('graphs', 114),
#  ('url', 114),
#  ('barcode', 114),
#  ('astronomy', 114),
#  ('kitti', 114),
#  ('id', 114),
#  ('person', 114),
#  ('query', 113),
#  ('workshop', 113),
#  ('gamedev', 113),
#  ('emulator', 113),
#  ('pedestrian', 113),
#  ('neovim', 113),
#  ('chess', 113),
#  ('pcap', 113),
#  ('public', 112),
#  ('openshift', 112),
#  ('recurrent', 112),
#  ('filesystem', 112),
#  ('box', 112),
#  ('liveness', 112),
#  ('qrcode', 112),
#  ('matplotlib', 112),
#  ('wasm', 112),
#  ('orm', 111),
#  ('gradle', 111),
#  ('operating', 111),
#  ('auth', 110),
#  ('prompt', 110),
#  ('recon', 110),
#  ('canvas', 110),
#  ('scripting', 110),
#  ('non', 110),
#  ('xray', 110),
#  ('resource', 110),
#  ('logistic', 109),
#  ('window', 109),
#  ('offensive', 109),
#  ('bounding', 109),
#  ('icons', 109),
#  ('number', 109),
#  ('side', 109),
#  ('rat', 109),
#  ('queue', 109),
#  ('ros2', 109),
#  ('landmarks', 109),
#  ('automatic', 109),
#  ('enterprise', 109),
#  ('sass', 108),
#  ('bots', 108),
#  ('pascal', 108),
#  ('jpa', 108),
#  ('cognitive', 108),
#  ('delivery', 107),
#  ('etl', 107),
#  ('diffusion', 107),
#  ('prevention', 107),
#  ('string', 107),
#  ('e', 107),
#  ('check', 107),
#  ('connect', 107),
#  ('yaml', 107),
#  ('aes', 107),
#  ('salesforce', 107),
#  ('readme', 107),
#  ('leetcode', 107),
#  ('power', 107),
#  ('telemetry', 106),
#  ('cheatsheet', 106),
#  ('interaction', 106),
#  ('dark', 106),
#  ('peer', 106),
#  ('p2p', 106),
#  ('gathering', 106),
#  ('practice', 106),
#  ('bayesian', 106),
#  ('portfolio', 106),
#  ('ajax', 105),
#  ('backdoor', 105),
#  ('hackintosh', 105),
#  ('reactive', 105),
#  ...]

# %%
t3 = github_data_df['about'].apply(lambda x: myclnfunction(x))

# %%
t3_cnt = Counter(t3.explode())
t3_cnt.most_common()
# Out:
# [(nan, 32273),
#  ('detection', 26104),
#  ('using', 18121),
#  ('data', 13173),
#  ('based', 11594),
#  ('learning', 10499),
#  ('1', 9512),
#  ('code', 9463),
#  ('project', 8616),
#  ('python', 8263),
#  ('library', 7875),
#  ('list', 7230),
#  ('system', 6696),
#  ('web', 6552),
#  ('set', 6463),
#  ('api', 6438),
#  ('object', 6329),
#  ('2', 6225),
#  ('implementation', 6035),
#  ('tool', 6006),
#  ('app', 5877),
#  ('application', 5587),
#  ('simple', 5552),
#  ('image', 5516),
#  ('use', 5510),
#  ('repository', 5349),
#  ('c', 5316),
#  ('js', 5296),
#  ('source', 5254),
#  ('time', 5226),
#  ('https', 5148),
#  ('open', 5010),
#  ('network', 4975),
#  ('deep', 4941),
#  ('machine', 4722),
#  ('framework', 4701),
#  ('security', 4604),
#  ('plugin', 4600),
#  ('android', 4499),
#  ('model', 4196),
#  ('tools', 4143),
#  ('github', 4092),
#  ('awesome', 3971),
#  ('3', 3957),
#  ('analysis', 3927),
#  ('resources', 3901),
#  ('server', 3898),
#  ('http', 3855),
#  ('class', 3853),
#  ('face', 3801),
#  ('javascript', 3780),
#  ('software', 3736),
#  ('detect', 3642),
#  ('images', 3571),
#  ('text', 3562),
#  ('collection', 3506),
#  ('curated', 3364),
#  ('react', 3325),
#  ('real', 3235),
#  ('paper', 3204),
#  ('user', 3175),
#  ('script', 3103),
#  ('google', 3079),
#  ('files', 3042),
#  ('computer', 2957),
#  ('file', 2954),
#  ('platform', 2935),
#  ('recognition', 2930),
#  ('cloud', 2915),
#  ('windows', 2914),
#  ('module', 2787),
#  ('node', 2781),
#  ('4', 2776),
#  ('dataset', 2765),
#  ('video', 2760),
#  ('aws', 2744),
#  ('ios', 2724),
#  ('go', 2691),
#  ('support', 2688),
#  ('x', 2647),
#  ('client', 2628),
#  ('neural', 2625),
#  ('one', 2552),
#  ('vision', 2534),
#  ('service', 2519),
#  ('tensorflow', 2465),
#  ('opencv', 2424),
#  ('version', 2401),
#  ('create', 2365),
#  ('applications', 2365),
#  ('multi', 2341),
#  ('linux', 2329),
#  ('5', 2326),
#  ('information', 2325),
#  ('monitoring', 2306),
#  ('language', 2304),
#  ('projects', 2299),
#  ('java', 2294),
#  ('function', 2283),
#  ('algorithm', 2269),
#  ('pytorch', 2249),
#  ('alert', 2231),
#  ('models', 2223),
#  ('ai', 2195),
#  ('processing', 2191),
#  ('end', 2180),
#  ('networks', 2169),
#  ('development', 2159),
#  ('package', 2154),
#  ('group', 2151),
#  ('php', 2142),
#  ('build', 2105),
#  ('net', 2085),
#  ('scripts', 2080),
#  ('control', 2077),
#  ('tracking', 2072),
#  ('features', 2037),
#  ('repo', 2009),
#  ('3d', 2009),
#  ('io', 1979),
#  ('easy', 1978),
#  ('native', 1971),
#  ('e', 1954),
#  ('game', 1945),
#  ('management', 1930),
#  ('get', 1914),
#  ('free', 1907),
#  ('browser', 1907),
#  ('bot', 1895),
#  ('help', 1877),
#  ('classification', 1877),
#  ('fast', 1865),
#  ('docker', 1846),
#  ('example', 1804),
#  ('color', 1803),
#  ('engine', 1792),
#  ('custom', 1758),
#  ('mobile', 1746),
#  ('libraries', 1728),
#  ('alerts', 1707),
#  ('work', 1692),
#  ('camera', 1681),
#  ('make', 1680),
#  ('segmentation', 1677),
#  ('command', 1676),
#  ('content', 1675),
#  ('algorithms', 1671),
#  ('type', 1667),
#  ('ui', 1654),
#  ('official', 1652),
#  ('monitor', 1650),
#  ('line', 1644),
#  ('sdk', 1643),
#  ('azure', 1627),
#  ('name', 1623),
#  ('vue', 1622),
#  ('testing', 1621),
#  ('high', 1615),
#  ('multiple', 1581),
#  ('database', 1574),
#  ('r', 1571),
#  ('level', 1549),
#  ('etc', 1543),
#  ('services', 1542),
#  ('interface', 1541),
#  ('anomaly', 1521),
#  ('spring', 1516),
#  ('kubernetes', 1510),
#  ('html', 1508),
#  ('test', 1491),
#  ('self', 1482),
#  ('design', 1474),
#  ('systems', 1470),
#  ('users', 1469),
#  ('detector', 1465),
#  ('8', 1461),
#  ('extension', 1455),
#  ('feature', 1446),
#  ('7', 1442),
#  ('demo', 1436),
#  ('single', 1432),
#  ('course', 1432),
#  ('search', 1431),
#  ('6', 1429),
#  ('apps', 1426),
#  ('b', 1425),
#  ('program', 1409),
#  ('ids', 1403),
#  ('training', 1402),
#  ('detecting', 1396),
#  ('research', 1392),
#  ('papers', 1392),
#  ('device', 1391),
#  ('event', 1391),
#  ('solution', 1390),
#  ('org', 1388),
#  ('run', 1383),
#  ('id', 1375),
#  ('devices', 1367),
#  ('cnn', 1365),
#  ('add', 1355),
#  ('top', 1346),
#  ('human', 1340),
#  ('science', 1340),
#  ('sample', 1339),
#  ('integration', 1333),
#  ('component', 1331),
#  ('n', 1328),
#  ('local', 1325),
#  ('access', 1308),
#  ('small', 1302),
#  ('performance', 1298),
#  ('learn', 1293),
#  ('full', 1292),
#  ('10', 1277),
#  ('automated', 1276),
#  ('wrapper', 1263),
#  ('method', 1262),
#  ('cross', 1259),
#  ('view', 1256),
#  ('automatic', 1248),
#  ('home', 1227),
#  ('online', 1225),
#  ('smart', 1222),
#  ('page', 1219),
#  ('find', 1215),
#  ('process', 1212),
#  ('graph', 1212),
#  ('2020', 1209),
#  ('pi', 1208),
#  ('2021', 1207),
#  ('programming', 1206),
#  ('public', 1200),
#  ('git', 1199),
#  ('input', 1197),
#  ('best', 1192),
#  ('boot', 1185),
#  ('useful', 1184),
#  ('point', 1180),
#  ('malware', 1179),
#  ('remote', 1179),
#  ('visual', 1175),
#  ('style', 1174),
#  ('building', 1173),
#  ('community', 1172),
#  ('website', 1165),
#  ('first', 1159),
#  ('complete', 1156),
#  ('document', 1151),
#  ('methods', 1139),
#  ('series', 1131),
#  ('number', 1130),
#  ('2022', 1125),
#  ('configuration', 1124),
#  ('guide', 1113),
#  ('json', 1113),
#  ('template', 1110),
#  ('world', 1110),
#  ('ml', 1105),
#  ('lightweight', 1102),
#  ('core', 1102),
#  ('audio', 1101),
#  ('css', 1101),
#  ('events', 1100),
#  ('jquery', 1099),
#  ('fork', 1099),
#  ('raspberry', 1098),
#  ('well', 1092),
#  ('check', 1080),
#  ('traffic', 1076),
#  ('2019', 1074),
#  ('environment', 1070),
#  ('examples', 1065),
#  ('people', 1055),
#  ('target', 1055),
#  ('background', 1055),
#  ('u', 1052),
#  ('components', 1051),
#  ('push', 1049),
#  ('state', 1047),
#  ('memory', 1046),
#  ('objects', 1044),
#  ('team', 1043),
#  ('challenge', 1041),
#  ('things', 1040),
#  ('datasets', 1029),
#  ('logo', 1026),
#  ('link', 1017),
#  ('stack', 1016),
#  ('master', 1016),
#  ('pipeline', 1016),
#  ('form', 1015),
#  ('generate', 1013),
#  ('intelligence', 1011),
#  ('edge', 1007),
#  ('right', 1004),
#  ('implemented', 999),
#  ('iot', 998),
#  ('two', 997),
#  ('notifications', 997),
#  ('address', 997),
#  ('basic', 996),
#  ('log', 992),
#  ('box', 992),
#  ('convolutional', 991),
#  ('advanced', 988),
#  ('toolkit', 986),
#  ('fixed', 983),
#  ('prometheus', 982),
#  ('rest', 980),
#  ('auto', 977),
#  ('url', 976),
#  ('functions', 973),
#  ('display', 972),
#  ('driver', 967),
#  ('ip', 959),
#  ('amazon', 958),
#  ('task', 954),
#  ('protocol', 954),
#  ('value', 947),
#  ('email', 945),
#  ('estimation', 935),
#  ('change', 935),
#  ('yolo', 934),
#  ('frameworks', 933),
#  ('architecture', 932),
#  ('block', 927),
#  ('digital', 926),
#  ('key', 921),
#  ('videos', 920),
#  ('status', 919),
#  ('bootstrap', 917),
#  ('ruby', 916),
#  ('path', 916),
#  ('microsoft', 914),
#  ('action', 897),
#  ('secure', 895),
#  ('arduino', 895),
#  ('media', 894),
#  ('domain', 894),
#  ('generation', 892),
#  ('notification', 890),
#  ('wordpress', 889),
#  ('live', 887),
#  ('laravel', 886),
#  ('utility', 886),
#  ('notes', 882),
#  ('keras', 880),
#  ('terraform', 877),
#  ('common', 877),
#  ('large', 872),
#  ('message', 871),
#  ('sensor', 871),
#  ('angular', 870),
#  ('manager', 865),
#  ('twitter', 865),
#  ('cli', 863),
#  ('tutorial', 862),
#  ('scale', 862),
#  ('automation', 862),
#  ('container', 857),
#  ('speech', 849),
#  ('attack', 847),
#  ('facial', 846),
#  ('cluster', 845),
#  ('os', 844),
#  ('car', 843),
#  ('dynamic', 843),
#  ('side', 837),
#  ('study', 836),
#  ('threat', 831),
#  ('rules', 827),
#  ('flex', 826),
#  ('questions', 822),
#  ('driving', 819),
#  ('codes', 815),
#  ('documentation', 813),
#  ('social', 812),
#  ('apis', 811),
#  ('format', 810),
#  ('track', 807),
#  ('mask', 805),
#  ('robot', 804),
#  ('trained', 804),
#  ('links', 803),
#  ('2018', 801),
#  ('generator', 800),
#  ('table', 799),
#  ('post', 799),
#  ('mirror', 798),
#  ('site', 795),
#  ('read', 791),
#  ('swift', 790),
#  ('discord', 785),
#  ('19', 783),
#  ('v', 777),
#  ('ips', 777),
#  ('motion', 774),
#  ('chat', 772),
#  ('sql', 771),
#  ('dashboard', 770),
#  ('messages', 770),
#  ('bee', 770),
#  ('button', 769),
#  ('tutorials', 761),
#  ('pose', 760),
#  ('red', 756),
#  ('matlab', 754),
#  ('active', 753),
#  ('pre', 752),
#  ('non', 751),
#  ('src', 751),
#  ('light', 750),
#  ('solutions', 749),
#  ('tasks', 748),
#  ('proxy', 747),
#  ('store', 746),
#  ('apache', 744),
#  ('admin', 743),
#  ('analytics', 743),
#  ('developers', 741),
#  ('update', 740),
#  ('changes', 740),
#  ('11', 739),
#  ('deploy', 735),
#  ('efficient', 735),
#  ('interview', 735),
#  ('setup', 731),
#  ('macos', 731),
#  ('vehicle', 727),
#  ('university', 726),
#  ('person', 726),
#  ('100', 721),
#  ('us', 719),
#  ('label', 714),
#  ('metrics', 711),
#  ('z', 711),
#  ('engineering', 708),
#  ('response', 708),
#  ('news', 708),
#  ('hunting', 708),
#  ('modern', 707),
#  ('supervised', 706),
#  ('rails', 705),
#  ('distributed', 704),
#  ('ros', 700),
#  ('front', 696),
#  ('account', 695),
#  ('operations', 693),
#  ('error', 684),
#  ('controller', 684),
#  ('django', 683),
#  ('rust', 680),
#  ('personal', 679),
#  ('fully', 678),
#  ('workshop', 678),
#  ('back', 677),
#  ('filter', 676),
#  ('port', 670),
#  ('f', 669),
#  ('low', 668),
#  ('telegram', 667),
#  ('order', 666),
#  ('attacks', 664),
#  ('window', 664),
#  ('default', 664),
#  ('quality', 663),
#  ('works', 662),
#  ('click', 662),
#  ('power', 662),
#  ('2d', 661),
#  ('powershell', 660),
#  ('map', 657),
#  ('virtual', 656),
#  ('cordova', 655),
#  ('faster', 654),
#  ('scanner', 654),
#  ('authentication', 652),
#  ('k', 650),
#  ('hidden', 650),
#  ('modules', 647),
#  ('cvpr', 646),
#  ('assistant', 644),
#  ('mode', 644),
#  ('reference', 643),
#  ('storage', 642),
#  ('base', 642),
#  ('desktop', 639),
#  ('instance', 638),
#  ('material', 638),
#  ('place', 637),
#  ('nlp', 637),
#  ('roblox', 635),
#  ('gui', 634),
#  ('flutter', 634),
#  ('autonomous', 633),
#  ('train', 631),
#  ('engineer', 631),
#  ('chrome', 630),
#  ('knowledge', 630),
#  ('tree', 629),
#  ('01', 629),
#  ('step', 627),
#  ('internet', 626),
#  ('case', 625),
#  ('ansible', 621),
#  ('stream', 621),
#  ('final', 620),
#  ('prediction', 620),
#  ('golang', 620),
#  ('voice', 617),
#  ('svg', 617),
#  ('location', 617),
#  ('blockchain', 616),
#  ('commands', 614),
#  ('menu', 613),
#  ('firmware', 612),
#  ('editor', 611),
#  ('infrastructure', 609),
#  ('download', 609),
#  ('transfer', 608),
#  ('forensics', 607),
#  ('private', 607),
#  ('covid', 604),
#  ('agent', 604),
#  ('facebook', 604),
#  ('day', 603),
#  ('install', 603),
#  ('robust', 603),
#  ('extraction', 602),
#  ('semantic', 600),
#  ('apple', 599),
#  ('vulnerability', 599),
#  ('developer', 595),
#  ('types', 595),
#  ('hardware', 592),
#  ('space', 592),
#  ('lab', 590),
#  ('backend', 590),
#  ('bug', 590),
#  ('static', 587),
#  ('lane', 587),
#  ('pull', 587),
#  ('long', 585),
#  ('fake', 585),
#  ('deployment', 584),
#  ('hacking', 584),
#  ('technology', 583),
#  ('artificial', 580),
#  ('typescript', 579),
#  ('channel', 579),
#  ('kit', 577),
#  ('standard', 577),
#  ('next', 577),
#  ('kernel', 575),
#  ('life', 574),
#  ('reverse', 572),
#  ('music', 570),
#  ('activity', 570),
#  ('mod', 568),
#  ('problem', 566),
#  ('zero', 565),
#  ('card', 564),
#  ('deprecated', 563),
#  ('anti', 562),
#  ('requests', 561),
#  ('lists', 559),
#  ('dns', 556),
#  ('random', 553),
#  ('compatible', 553),
#  ('general', 553),
#  ('servers', 551),
#  ('issues', 550),
#  ('making', 550),
#  ('books', 549),
#  ('blog', 549),
#  ('plugins', 549),
#  ('extract', 548),
#  ('15', 547),
#  ('center', 546),
#  ('communication', 546),
#  ('plan', 546),
#  ('player', 544),
#  ('body', 541),
#  ('navigation', 540),
#  ('shell', 539),
#  ('context', 539),
#  ('games', 539),
#  ('natural', 538),
#  ('signal', 538),
#  ('pdf', 538),
#  ('binary', 537),
#  ('write', 537),
#  ('mining', 536),
#  ('v2', 535),
#  ('streaming', 535),
#  ('position', 534),
#  ('mac', 533),
#  ('structure', 531),
#  ('request', 528),
#  ('attention', 527),
#  ('mysql', 527),
#  ('2017', 527),
#  ('size', 525),
#  ('connect', 525),
#  ('focus', 524),
#  ('hand', 524),
#  ('intrusion', 523),
#  ('unity', 523),
#  ('packages', 522),
#  ('pure', 521),
#  ('interactive', 521),
#  ('logs', 521),
#  ('w', 520),
#  ('password', 519),
#  ('external', 519),
#  ('devops', 518),
#  ('theme', 517),
#  ('report', 516),
#  ('alerting', 516),
#  ('ethereum', 511),
#  ('cyber', 511),
#  ('output', 510),
#  ('reading', 509),
#  ('flask', 508),
#  ('websites', 508),
#  ('flow', 508),
#  ('adversarial', 507),
#  ('suite', 507),
#  ('book', 507),
#  ('art', 507),
#  ('inference', 505),
#  ('tracker', 505),
#  ('disease', 505),
#  ('classifier', 504),
#  ('bitcoin', 504),
#  ('resource', 503),
#  ('good', 503),
#  ('benchmark', 503),
#  ('html5', 502),
#  ('cve', 501),
#  ('query', 500),
#  ('yolov3', 500),
#  ('crypto', 500),
#  ('health', 499),
#  ('clone', 498),
#  ('samples', 498),
#  ('penetration', 498),
#  ('simulation', 498),
#  ('convert', 498),
#  ('faces', 498),
#  ('play', 495),
#  ('job', 495),
#  ('info', 495),
#  ('lidar', 493),
#  ('practices', 493),
#  ('identification', 493),
#  ('visualization', 492),
#  ('toolbox', 492),
#  ('speed', 490),
#  ('tiny', 490),
#  ('usage', 488),
#  ('tests', 487),
#  ('mongodb', 487),
#  ('call', 486),
#  ('documents', 485),
#  ('forensic', 484),
#  ('unsupervised', 484),
#  ('usb', 483),
#  ('fraud', 482),
#  ('scan', 481),
#  ('role', 480),
#  ('load', 479),
#  ('slack', 478),
#  ('pattern', 478),
#  ('dialog', 478),
#  ('quick', 477),
#  ('serverless', 477),
#  ('patterns', 475),
#  ('nodejs', 475),
#  ('aria', 475),
#  ('element', 475),
#  ('license', 474),
#  ('big', 472),
#  ('screen', 471),
#  ('sign', 470),
#  ('localization', 466),
#  ('templates', 465),
#  ('classes', 463),
#  ('actions', 461),
#  ('phone', 461),
#  ('trading', 461),
#  ('road', 460),
#  ('header', 460),
#  ('frontend', 459),
#  ('evaluation', 458),
#  ('malicious', 457),
#  ('shot', 456),
#  ('chain', 455),
#  ('logging', 455),
#  ('utilities', 454),
#  ('word', 453),
#  ('layer', 453),
#  ('progress', 453),
#  ('rule', 453),
#  ('accuracy', 453),
#  ('driven', 451),
#  ('2023', 449),
#  ('distribution', 448),
#  ('emotion', 447),
#  ('intel', 446),
#  ('antivirus', 445),
#  ('directory', 444),
#  ('token', 443),
#  ('gpu', 443),
#  ('board', 443),
#  ('hosted', 441),
#  ('privacy', 441),
#  ('realtime', 441),
#  ('daily', 440),
#  ('gateway', 440),
#  ('automate', 439),
#  ('coding', 439),
#  ('panel', 438),
#  ('production', 438),
#  ('kaggle', 436),
#  ('release', 434),
#  ('scene', 434),
#  ('eye', 434),
#  ('injection', 433),
#  ('aware', 433),
#  ('friendly', 433),
#  ('login', 433),
#  ('safe', 432),
#  ('materials', 431),
#  ('concept', 431),
#  ('capture', 430),
#  ('dev', 428),
#  ('yara', 427),
#  ('satellite', 427),
#  ('incident', 426),
#  ('string', 425),
#  ('studio', 423),
#  ('unofficial', 423),
#  ('customizable', 423),
#  ('kafka', 422),
#  ('youtube', 422),
#  ('global', 422),
#  ('vulnerabilities', 422),
#  ('cell', 422),
#  ('enterprise', 422),
#  ('upload', 420),
#  ('share', 420),
#  ('supported', 419),
#  ('ajax', 419),
#  ('parser', 418),
#  ('scalable', 418),
#  ('pages', 418),
#  ('grafana', 417),
#  ('sound', 417),
#  ('mr', 417),
#  ('proof', 416),
#  ('cmd', 416),
#  ('bypass', 415),
#  ('look', 415),
#  ('config', 414),
#  ('date', 414),
#  ('validation', 413),
#  ('wifi', 412),
#  ('include', 412),
#  ('index', 412),
#  ('experience', 411),
#  ('console', 410),
#  ('collision', 410),
#  ('repositories', 410),
#  ('keycloak', 409),
#  ('sms', 409),
#  ('flexible', 407),
#  ('days', 406),
#  ('reports', 406),
#  ('syntax', 406),
#  ('spark', 405),
#  ('implementations', 403),
#  ('transformer', 403),
#  ('weather', 402),
#  ('checks', 401),
#  ('integrated', 401),
#  ('clustering', 401),
#  ('three', 400),
#  ('star', 400),
#  ('bit', 399),
#  ('mapping', 399),
#  ('embedded', 399),
#  ('students', 398),
#  ('cameras', 398),
#  ('product', 397),
#  ('fusion', 396),
#  ('articles', 396),
#  ('stuff', 395),
#  ('wiki', 394),
#  ('rgb', 394),
#  ('competition', 393),
#  ('bees', 393),
#  ('classify', 392),
#  ('ocr', 392),
#  ('cancer', 390),
#  ('32', 390),
#  ('medical', 390),
#  ('v3', 389),
#  ('applied', 389),
#  ('teams', 388),
#  ('runtime', 388),
#  ('starter', 387),
#  ('sensors', 387),
#  ('webcam', 386),
#  ('plate', 386),
#  ('encryption', 386),
#  ('notebooks', 385),
#  ('operating', 385),
#  ('annotation', 384),
#  ('oriented', 383),
#  ('meta', 383),
#  ('shows', 382),
#  ('profile', 381),
#  ('font', 381),
#  ('ieee', 380),
#  ('transform', 380),
#  ('maps', 380),
#  ('lambda', 380),
#  ('md', 380),
#  ('tech', 379),
#  ('wallet', 379),
#  ('yolov5', 378),
#  ('getting', 378),
#  ('programs', 377),
#  ('phishing', 377),
#  ('save', 377),
#  ('poc', 376),
#  ('scanning', 376),
#  ('copy', 375),
#  ('bash', 375),
#  ('options', 375),
#  ('pro', 374),
#  ('14', 373),
#  ('computing', 373),
#  ('head', 373),
#  ('helper', 372),
#  ('child', 370),
#  ('loss', 368),
#  ('points', 368),
#  ('inline', 368),
#  ('q', 367),
#  ('humans', 367),
#  ('modal', 367),
#  ('matching', 366),
#  ('cpu', 366),
#  ('rate', 365),
#  ('settings', 365),
#  ('drop', 364),
#  ('extensions', 364),
#  ('short', 363),
#  ('xss', 363),
#  ('math', 363),
#  ('chinese', 363),
#  ('products', 362),
#  ('capabilities', 362),
#  ('vehicles', 361),
#  ('workflow', 360),
#  ('updates', 360),
#  ('stock', 358),
#  ('blocks', 357),
#  ('experiments', 357),
#  ('discovery', 356),
#  ('business', 356),
#  ('svm', 356),
#  ('express', 356),
#  ('parsing', 354),
#  ('handling', 353),
#  ('maintained', 353),
#  ('esp32', 353),
#  ('environments', 352),
#  ('pool', 352),
#  ('markdown', 351),
#  ('vector', 350),
#  ('objective', 350),
#  ('handle', 350),
#  ('transactions', 350),
#  ('parse', 348),
#  ('contract', 348),
#  ('experimental', 348),
#  ('shiny', 348),
#  ('terminal', 348),
#  ('seq', 348),
#  ('credit', 346),
#  ('bindings', 345),
#  ('microservices', 345),
#  ('technologies', 344),
#  ('temporal', 344),
#  ('languages', 344),
#  ('behavior', 344),
#  ('stage', 343),
#  ('universal', 342),
#  ('hands', 342),
#  ('lines', 341),
#  ('started', 340),
#  ('mail', 340),
#  ('brain', 339),
#  ('exploit', 339),
#  ('sharing', 338),
#  ('issue', 338),
#  ('lstm', 337),
#  ('tcp', 337),
#  ('udacity', 336),
#  ('finding', 336),
#  ('optimization', 336),
#  ('elasticsearch', 335),
#  ('fire', 335),
#  ('s3', 335),
#  ('tv', 335),
#  ('super', 335),
#  ('signals', 335),
#  ('platforms', 334),
#  ('history', 334),
#  ('range', 334),
#  ('ctf', 334),
#  ('slam', 333),
#  ('ssd', 333),
#  ('simulator', 333),
#  ('depth', 333),
#  ('mqtt', 333),
#  ('arxiv', 333),
#  ('surveillance', 332),
#  ('baseline', 332),
#  ('year', 332),
#  ('urls', 332),
#  ('ssh', 331),
#  ('protection', 330),
#  ('restful', 330),
#  ('flash', 329),
#  ('resolution', 328),
#  ('intelligent', 327),
#  ('prototype', 327),
#  ('regression', 327),
#  ('assets', 327),
#  ('minimal', 326),
#  ('complex', 325),
#  ('streams', 324),
#  ('continuous', 324),
#  ('exploitation', 324),
#  ('radio', 324),
#  ('nginx', 323),
#  ('region', 322),
#  ('robotics', 321),
#  ('redis', 321),
#  ('feed', 320),
#  ('des', 320),
#  ('cheat', 320),
#  ('cms', 320),
#  ('sites', 319),
#  ('keyboard', 319),
#  ('rcnn', 318),
#  ('modular', 318),
#  ('queries', 317),
#  ('micro', 316),
#  ('black', 315),
#  ('forest', 315),
#  ('db', 315),
#  ('technical', 315),
#  ('modeling', 314),
#  ('defined', 314),
#  ('warning', 314),
#  ('imagery', 314),
#  ('xml', 313),
#  ('party', 313),
#  ('interaction', 312),
#  ('router', 312),
#  ('connection', 312),
#  ('optimized', 312),
#  ('introduction', 312),
#  ('session', 312),
#  ('provider', 311),
#  ('understanding', 311),
#  ('import', 311),
#  ('watch', 310),
#  ('lite', 310),
#  ('sequence', 309),
#  ('py', 309),
#  ('boilerplate', 309),
#  ('remove', 309),
#  ('18', 309),
#  ('sentiment', 309),
#  ('spam', 309),
#  ('sensing', 309),
#  ('commit', 309),
#  ('article', 308),
#  ('adaptive', 307),
#  ('backup', 307),
#  ('responsive', 307),
#  ('payload', 306),
#  ('hash', 306),
#  ...]

# %%
t4 = github_data_df['languages'].apply(lambda x: myclnfunction(x))

# %%
t4_cnt = Counter(t4.explode())
t4_cnt.most_common()
# Out:
# [('python', 85119),
#  ('c', 70739),
#  ('shell', 57069),
#  ('javascript', 49677),
#  ('html', 40935),
#  ('css', 29797),
#  (nan, 27217),
#  ('makefile', 24513),
#  ('jupyter', 19789),
#  ('notebook', 19789),
#  ('dockerfile', 19663),
#  ('java', 17412),
#  ('ruby', 10653),
#  ('objective', 10539),
#  ('cmake', 10454),
#  ('php', 9441),
#  ('typescript', 8785),
#  ('go', 8276),
#  ('matlab', 6311),
#  ('perl', 5473),
#  ('powershell', 4618),
#  ('cuda', 4374),
#  ('swift', 3961),
#  ('assembly', 3892),
#  ('scss', 3615),
#  ('r', 3512),
#  ('kotlin', 2567),
#  ('lua', 2543),
#  ('tex', 2374),
#  ('hcl', 2360),
#  ('rust', 2280),
#  ('m4', 2167),
#  ('vue', 1890),
#  ('scala', 1300),
#  ('dart', 1199),
#  ('coffeescript', 1191),
#  ('glsl', 1181),
#  ('groovy', 1175),
#  ('tcl', 1098),
#  ('awk', 1053),
#  ('lisp', 1047),
#  ('script', 958),
#  ('vim', 942),
#  ('jinja', 907),
#  ('lex', 899),
#  ('cython', 895),
#  ('solidity', 839),
#  ('asp', 810),
#  ('less', 810),
#  ('emacs', 769),
#  ('tsql', 760),
#  ('pascal', 718),
#  ('basic', 676),
#  ('gdb', 627),
#  ('visual', 620),
#  ('clojure', 606),
#  ('yara', 582),
#  ('fortran', 565),
#  ('hack', 543),
#  ('mustache', 542),
#  ('gherkin', 526),
#  ('text', 516),
#  ('rich', 515),
#  ('format', 515),
#  ('handlebars', 508),
#  ('sed', 488),
#  ('net', 455),
#  ('arduino', 454),
#  ('verilog', 441),
#  ('hlsl', 431),
#  ('nix', 418),
#  ('ejs', 401),
#  ('haskell', 397),
#  ('elixir', 382),
#  ('prolog', 375),
#  ('language', 374),
#  ('blade', 366),
#  ('processing', 346),
#  ('erlang', 336),
#  ('inno', 334),
#  ('setup', 334),
#  ('julia', 333),
#  ('6', 318),
#  ('swig', 313),
#  ('common', 312),
#  ('qml', 302),
#  ('vbscript', 291),
#  ('plsql', 286),
#  ('puppet', 286),
#  ('gnuplot', 279),
#  ('actionscript', 278),
#  ('digital', 275),
#  ('command', 275),
#  ('scheme', 273),
#  ('sourcepawn', 263),
#  ('protocol', 258),
#  ('buffer', 258),
#  ('ocaml', 251),
#  ('raku', 247),
#  ('mathematica', 245),
#  ('vhdl', 242),
#  ('smpl', 235),
#  ('antlr', 234),
#  ('pug', 228),
#  ('jsonnet', 224),
#  ('asl', 223),
#  ('svelte', 212),
#  ('systemverilog', 203),
#  ('standard', 203),
#  ('ml', 203),
#  ('f', 202),
#  ('40', 193),
#  ('applescript', 184),
#  ('bicep', 183),
#  ('104', 181),
#  ('pawn', 180),
#  ('twig', 173),
#  ('llvm', 169),
#  ('365', 164),
#  ('forth', 164),
#  ('autohotkey', 153),
#  ('gap', 145),
#  ('sass', 145),
#  ('haxe', 142),
#  ('ray', 137),
#  ('sdl', 137),
#  ('ada', 137),
#  ('zeek', 137),
#  ('53', 133),
#  ('nextflow', 131),
#  ('vba', 131),
#  ('1', 130),
#  ('markdown', 129),
#  ('18', 126),
#  ('34', 124),
#  ('module', 123),
#  ('management', 123),
#  ('system', 123),
#  ('42', 122),
#  ('50', 121),
#  ('stylus', 120),
#  ('racket', 117),
#  ('152', 115),
#  ('stata', 115),
#  ('100', 114),
#  ('apex', 111),
#  ('101', 110),
#  ('metal', 109),
#  ('thrift', 105),
#  ('coq', 105),
#  ('mdx', 105),
#  ('yaml', 104),
#  ('19', 103),
#  ('nginx', 103),
#  ('32', 102),
#  ('17', 102),
#  ('360', 100),
#  ('64', 98),
#  ('35', 98),
#  ('gdscript', 97),
#  ('open', 97),
#  ('policy', 97),
#  ('agent', 97),
#  ('cap', 96),
#  ('idl', 94),
#  ('nim', 93),
#  ('json', 93),
#  ('webassembly', 91),
#  ('autoit', 88),
#  ('elm', 88),
#  ('saltstack', 86),
#  ('n', 85),
#  ('proto', 85),
#  ('crystal', 85),
#  ('q', 84),
#  ('robotframework', 79),
#  ('supercollider', 78),
#  ('bro', 77),
#  ('381', 77),
#  ('512', 77),
#  ('256', 76),
#  ('2', 75),
#  ('433', 75),
#  ('14', 72),
#  ('802', 71),
#  ('15', 70),
#  ('code', 69),
#  ('classic', 65),
#  ('3', 60),
#  ('slim', 59),
#  ('renderscript', 59),
#  ('clean', 57),
#  ('vala', 54),
#  ('900', 53),
#  ('rpc', 52),
#  ('p4', 52),
#  ('smali', 49),
#  ('api', 49),
#  ('blueprint', 49),
#  ('vcl', 48),
#  ('eagle', 47),
#  ('zig', 45),
#  ('2017', 43),
#  ('clips', 42),
#  ('v', 41),
#  ('game', 40),
#  ('2020', 40),
#  ('squirrel', 39),
#  ('enterprise', 38),
#  ('7', 38),
#  ('11', 37),
#  ('2022', 37),
#  ('cobol', 35),
#  ('4', 34),
#  ('io', 34),
#  ('mql5', 34),
#  ('mql4', 34),
#  ('workflow', 34),
#  ('2003', 33),
#  ('fluent', 33),
#  ('jq', 31),
#  ('2023', 31),
#  ('stan', 31),
#  ('2019', 31),
#  ('2018', 30),
#  ('hiveql', 29),
#  ('e', 29),
#  ('5', 29),
#  ('peg', 28),
#  ('js', 28),
#  ('2021', 28),
#  ('codeql', 27),
#  ('imagej', 26),
#  ('macro', 26),
#  ('bison', 26),
#  ('xml', 24),
#  ('slash', 24),
#  ('arc', 23),
#  ('4104', 22),
#  ('terra', 21),
#  ('singularity', 21),
#  ('kicad', 21),
#  ('red', 20),
#  ('cypher', 20),
#  ('template', 19),
#  ('flux', 19),
#  ('layout', 19),
#  ('mermaid', 18),
#  ('mcfunction', 18),
#  ('lasso', 18),
#  ('sieve', 18),
#  ('smt', 18),
#  ('8', 18),
#  ('graphviz', 17),
#  ('dot', 17),
#  ('dm', 17),
#  ('sql', 17),
#  ('factor', 17),
#  ('pure', 16),
#  ('data', 16),
#  ('gcc', 16),
#  ('machine', 16),
#  ('modelica', 15),
#  ('mask', 15),
#  ('jetbrains', 15),
#  ('velocity', 15),
#  ('cairo', 15),
#  ('astro', 14),
#  ('click', 14),
#  ('10', 11),
#  ('6502', 11),
#  ('self', 11),
#  ('py', 11),
#  ('ring', 10),
#  ('alloy', 10),
#  ('monkey', 10),
#  ('web', 10),
#  ('ontology', 10),
#  ('pro', 9),
#  ('opa', 8),
#  ('component', 8),
#  ('routeros', 8),
#  ('document', 7),
#  ('closure', 7),
#  ('templates', 7),
#  ('8086', 6),
#  ('parrot', 6),
#  ('move', 6),
#  ('adblock', 6),
#  ('filter', 6),
#  ('list', 6),
#  ('framework', 5),
#  ('slice', 5),
#  ('zap', 5),
#  ('45105', 5),
#  ('pep8', 5),
#  ('21972', 5),
#  ('lean', 5),
#  ('8051', 5),
#  ('ink', 4),
#  ('kit', 4),
#  ('qt', 4),
#  ('diff', 4),
#  ('45046', 3),
#  ('ini', 3),
#  ('polar', 3),
#  ('uno', 2),
#  ('43012', 2),
#  ('cadence', 2),
#  ('score', 2),
#  ('rmarkdown', 2),
#  ('19781', 2),
#  ('riot', 2),
#  ('gettext', 2),
#  ('catalog', 2),
#  ('forms', 1),
#  ('asciidoc', 1),
#  ('60870', 1),
#  ('regular', 1),
#  ('expression', 1),
#  ('44228', 1),
#  ('80211', 1),
#  ('http', 1),
#  ('openapi', 1),
#  ('specification', 1),
#  ('v2', 1)]

# %%
import swifter
t5 = github_data_df['readme_clean'].swifter.apply(lambda x: myclnfunction(x))
# Out:
# Pandas Apply:   0%|          | 0/221971 [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
t5_cnt = Counter(t5.explode())
t5_cnt.most_common()
# Out:
# [('1', 1552767),
#  ('data', 1166646),
#  ('use', 1122852),
#  ('2', 1032918),
#  ('using', 903495),
#  ('code', 868547),
#  ('file', 866248),
#  ('3', 736281),
#  ('run', 649704),
#  ('c', 587146),
#  ('http', 577440),
#  ('set', 563482),
#  ('name', 558450),
#  ('app', 557488),
#  ('python', 531215),
#  ('image', 520149),
#  ('build', 514153),
#  ('example', 503899),
#  ('default', 491547),
#  ('4', 487253),
#  ('server', 486985),
#  ('js', 485992),
#  ('user', 484510),
#  ('project', 482476),
#  ('api', 475479),
#  ('create', 472815),
#  ('react', 458568),
#  ('time', 454617),
#  ('files', 450335),
#  ('x', 447589),
#  ('5', 444194),
#  ('install', 439748),
#  ('function', 438118),
#  ('one', 430118),
#  ('get', 427697),
#  ('source', 422891),
#  ('based', 422627),
#  ('test', 417612),
#  ('add', 415379),
#  ('learning', 411990),
#  ('system', 406250),
#  ('value', 401150),
#  ('support', 382163),
#  ('version', 378021),
#  ('type', 377257),
#  ('web', 374821),
#  ('library', 374242),
#  ('list', 371092),
#  ('model', 369961),
#  ('object', 359431),
#  ('10', 357256),
#  ('open', 357170),
#  ('make', 356344),
#  ('command', 351717),
#  ('e', 350108),
#  ('application', 345387),
#  ('string', 344726),
#  ('detection', 333455),
#  ('javascript', 330612),
#  ('html', 326419),
#  ('network', 318119),
#  ('service', 309881),
#  ('go', 306460),
#  ('number', 304335),
#  ('environment', 297171),
#  ('json', 296431),
#  ('6', 295090),
#  ('text', 294119),
#  ('video', 292574),
#  ('key', 291004),
#  ('first', 288579),
#  ('information', 288024),
#  ('note', 276476),
#  ('py', 270938),
#  ('configuration', 270903),
#  ('path', 265402),
#  ('security', 265187),
#  ('github', 261746),
#  ('8', 259888),
#  ('class', 257809),
#  ('id', 250285),
#  ('import', 248807),
#  ('log', 246637),
#  ('images', 244002),
#  ('node', 243750),
#  ('output', 241251),
#  ('directory', 240918),
#  ('client', 238241),
#  ('script', 238217),
#  ('software', 238166),
#  ('work', 233989),
#  ('npm', 233711),
#  ('7', 232922),
#  ('docker', 232814),
#  ('page', 229638),
#  ('n', 228906),
#  ('config', 228401),
#  ('tool', 228368),
#  ('package', 228218),
#  ('tools', 227797),
#  ('error', 227591),
#  ('simple', 227013),
#  ('machine', 226781),
#  ('linux', 226212),
#  ('paper', 225662),
#  ('line', 220307),
#  ('access', 220196),
#  ('windows', 220186),
#  ('development', 219371),
#  ('address', 213535),
#  ('database', 212765),
#  ('free', 211743),
#  ('public', 210749),
#  ('bash', 210720),
#  ('php', 207790),
#  ('local', 207373),
#  ('end', 206070),
#  ('check', 205813),
#  ('url', 203008),
#  ('method', 202915),
#  ('framework', 202470),
#  ('css', 201934),
#  ('java', 201514),
#  ('process', 200776),
#  ('find', 200570),
#  ('device', 200510),
#  ('git', 197918),
#  ('features', 197555),
#  ('scripts', 197362),
#  ('memory', 195747),
#  ('two', 195647),
#  ('language', 194801),
#  ('read', 193907),
#  ('android', 193406),
#  ('module', 193071),
#  ('mode', 192834),
#  ('sh', 192720),
#  ('r', 192162),
#  ('users', 190144),
#  ('google', 187892),
#  ('input', 187484),
#  ('change', 187052),
#  ('request', 186798),
#  ('state', 185411),
#  ('options', 184595),
#  ('component', 183330),
#  ('models', 182969),
#  ('console', 182105),
#  ('update', 180921),
#  ('boot', 180445),
#  ('pdf', 180412),
#  ('testing', 179404),
#  ('etc', 178853),
#  ('search', 177553),
#  ('license', 174936),
#  ('single', 174478),
#  ('feature', 174296),
#  ('top', 174089),
#  ('aws', 172878),
#  ('message', 172643),
#  ('link', 172258),
#  ('dataset', 171996),
#  ('size', 170803),
#  ('index', 169664),
#  ('src', 168377),
#  ('download', 167820),
#  ('u', 167210),
#  ('analysis', 166974),
#  ('custom', 166501),
#  ('control', 165854),
#  ('content', 165837),
#  ('repository', 164845),
#  ('b', 163690),
#  ('deep', 163516),
#  ('event', 163196),
#  ('11', 163001),
#  ('help', 162823),
#  ('cloud', 162673),
#  ('port', 161040),
#  ('format', 159354),
#  ('back', 159351),
#  ('multiple', 159326),
#  ('view', 158433),
#  ('platform', 157793),
#  ('tests', 157646),
#  ('case', 156188),
#  ('net', 155081),
#  ('plugin', 154912),
#  ('variables', 154239),
#  ('browser', 154078),
#  ('domain', 153836),
#  ('training', 153442),
#  ('interface', 152458),
#  ('design', 151334),
#  ('level', 150906),
#  ('implementation', 150361),
#  ('applications', 148927),
#  ('components', 147357),
#  ('org', 145865),
#  ('order', 145547),
#  ('functions', 144137),
#  ('common', 143058),
#  ('usage', 142799),
#  ('include', 142688),
#  ('networks', 142052),
#  ('changes', 140798),
#  ('resources', 140639),
#  ('point', 140204),
#  ('root', 139870),
#  ('documentation', 139418),
#  ('setup', 139238),
#  ('target', 138731),
#  ('write', 138683),
#  ('instance', 137823),
#  ('ip', 137597),
#  ('performance', 137387),
#  ('load', 137123),
#  ('systems', 136839),
#  ('services', 134591),
#  ('button', 133938),
#  ('well', 133126),
#  ('table', 132805),
#  ('neural', 132765),
#  ('easy', 132667),
#  ('programming', 132318),
#  ('password', 131538),
#  ('ios', 131182),
#  ('array', 131114),
#  ('examples', 129728),
#  ('env', 129103),
#  ('full', 128847),
#  ('settings', 128675),
#  ('step', 128362),
#  ('high', 128272),
#  ('2019', 127363),
#  ('self', 125386),
#  ('methods', 125079),
#  ('click', 124988),
#  ('defined', 124865),
#  ('optional', 124865),
#  ('static', 124658),
#  ('shell', 124428),
#  ('next', 122642),
#  ('management', 122345),
#  ('f', 122172),
#  ('requests', 122137),
#  ('real', 121499),
#  ('alert', 121435),
#  ('io', 121043),
#  ('2020', 120832),
#  ('multi', 120782),
#  ('parameters', 120425),
#  ('supported', 119687),
#  ('computer', 119615),
#  ('post', 119379),
#  ('select', 118441),
#  ('installation', 118143),
#  ('proxy', 117351),
#  ('program', 116963),
#  ('account', 116780),
#  ('commands', 116757),
#  ('call', 116367),
#  ('map', 116350),
#  ('processing', 116173),
#  ('group', 115632),
#  ('native', 115217),
#  ('info', 115145),
#  ('txt', 115104),
#  ('status', 114683),
#  ('core', 112891),
#  ('ui', 112539),
#  ('fast', 112240),
#  ('container', 111711),
#  ('dev', 111552),
#  ('right', 111036),
#  ('form', 110465),
#  ('response', 110010),
#  ('useful', 108721),
#  ('email', 108408),
#  ('arxiv', 108276),
#  ('2018', 107919),
#  ('deploy', 107463),
#  ('building', 107153),
#  ('vue', 106923),
#  ('100', 106816),
#  ('demo', 106774),
#  ('game', 106574),
#  ('generate', 106421),
#  ('issue', 105367),
#  ('copy', 105107),
#  ('release', 105065),
#  ('non', 104961),
#  ('works', 104778),
#  ('color', 104381),
#  ('store', 103968),
#  ('cd', 103932),
#  ('kernel', 103710),
#  ('production', 103391),
#  ('template', 103345),
#  ('graph', 103299),
#  ('2022', 103008),
#  ('algorithm', 102777),
#  ('swift', 102760),
#  ('objects', 102666),
#  ('learn', 102611),
#  ('remote', 102473),
#  ('binary', 102079),
#  ('types', 101933),
#  ('2021', 101838),
#  ('storage', 101812),
#  ('action', 101773),
#  ('projects', 101437),
#  ('us', 101247),
#  ('architecture', 101224),
#  ('display', 101065),
#  ('save', 100802),
#  ('libraries', 100109),
#  ('fixed', 100062),
#  ('15', 99777),
#  ('block', 99768),
#  ('style', 99140),
#  ('document', 99108),
#  ('query', 98159),
#  ('global', 98151),
#  ('v', 98051),
#  ('2017', 98003),
#  ('algorithms', 97808),
#  ('azure', 97662),
#  ('cache', 97167),
#  ('collection', 97073),
#  ('best', 96974),
#  ('awesome', 96906),
#  ('good', 96703),
#  ('guide', 96173),
#  ('clone', 95852),
#  ('window', 95851),
#  ('reference', 95808),
#  ('issues', 95446),
#  ('sample', 94521),
#  ('apps', 94194),
#  ('engine', 94047),
#  ('visual', 93937),
#  ('bin', 93817),
#  ('dependencies', 93635),
#  ('standard', 93550),
#  ('export', 93459),
#  ('events', 93309),
#  ('large', 93261),
#  ('sudo', 93205),
#  ('task', 93092),
#  ('devices', 92897),
#  ('tree', 92882),
#  ('cluster', 92617),
#  ('site', 92287),
#  ('os', 92023),
#  ('stack', 91774),
#  ('solution', 91574),
#  ('resource', 91424),
#  ('location', 91382),
#  ('date', 90771),
#  ('website', 90601),
#  ('editor', 90372),
#  ('token', 89796),
#  ('world', 89554),
#  ('context', 89471),
#  ('apache', 89375),
#  ('3d', 88642),
#  ('mit', 87941),
#  ('pages', 87700),
#  ('repo', 87628),
#  ('print', 87279),
#  ('pre', 87080),
#  ('header', 86823),
#  ('general', 86807),
#  ('remove', 86655),
#  ('basic', 86383),
#  ('01', 86379),
#  ('home', 86198),
#  ('private', 86119),
#  ('fix', 85855),
#  ('look', 85586),
#  ('debug', 85500),
#  ('sql', 85046),
#  ('train', 84738),
#  ('14', 84687),
#  ('controller', 84445),
#  ('rules', 84105),
#  ('bit', 84068),
#  ('deployment', 83749),
#  ('messages', 83584),
#  ('space', 83553),
#  ('bug', 83024),
#  ('delete', 82786),
#  ('small', 82606),
#  ('online', 82507),
#  ('modules', 82094),
#  ('videos', 81705),
#  ('yaml', 81596),
#  ('problem', 81566),
#  ('structure', 81440),
#  ('admin', 80973),
#  ('element', 80788),
#  ('started', 80708),
#  ('dynamic', 80406),
#  ('long', 80333),
#  ('driver', 79809),
#  ('microsoft', 79399),
#  ('cli', 79263),
#  ('mobile', 79083),
#  ('blog', 78971),
#  ('cross', 78850),
#  ('filter', 78800),
#  ('properties', 78763),
#  ('extension', 77949),
#  ('complete', 77937),
#  ('instructions', 77915),
#  ('ai', 77868),
#  ('connection', 77807),
#  ('integration', 77753),
#  ('side', 77388),
#  ('box', 77016),
#  ('requirements', 76664),
#  ('scale', 76493),
#  ('distributed', 76250),
#  ('means', 76244),
#  ('protocol', 76135),
#  ('steps', 76065),
#  ('19', 75912),
#  ('auto', 75324),
#  ('kubernetes', 75317),
#  ('cpu', 75248),
#  ('manager', 75197),
#  ('course', 74749),
#  ('packages', 74698),
#  ('detect', 74664),
#  ('base', 74583),
#  ('xml', 74221),
#  ('recognition', 74018),
#  ('board', 73850),
#  ('keys', 73744),
#  ('18', 73234),
#  ('channel', 73006),
#  ('pass', 72973),
#  ('bootstrap', 72952),
#  ('star', 72894),
#  ('errors', 72861),
#  ('jest', 72815),
#  ('versions', 72719),
#  ('team', 72516),
#  ('amazon', 72227),
#  ('k', 71789),
#  ('screen', 71709),
#  ('property', 71583),
#  ('classification', 71507),
#  ('camera', 71122),
#  ('virtual', 71117),
#  ('connect', 71096),
#  ('flow', 70821),
#  ('research', 70733),
#  ('label', 70554),
#  ('vision', 70473),
#  ('names', 70130),
#  ('face', 69979),
#  ('hardware', 69395),
#  ('audio', 69156),
#  ('render', 69090),
#  ('tag', 69033),
#  ('community', 68854),
#  ('report', 68588),
#  ('active', 68287),
#  ('pull', 68207),
#  ('session', 68200),
#  ('rest', 68166),
#  ('pip', 68087),
#  ('ruby', 68033),
#  ('operations', 67872),
#  ('introduction', 67560),
#  ('17', 67297),
#  ('tasks', 67263),
#  ('notes', 67234),
#  ('classes', 67019),
#  ('layer', 66869),
#  ('authentication', 66851),
#  ('random', 66598),
#  ('advanced', 66548),
#  ('cve', 66517),
#  ('range', 66451),
#  ('localhost', 66250),
#  ('05', 65922),
#  ('pytorch', 65884),
#  ('login', 65819),
#  ('people', 65762),
#  ('speed', 65681),
#  ('syntax', 65438),
#  ('getting', 65242),
#  ('push', 65214),
#  ('developer', 65046),
#  ('developers', 64874),
#  ('low', 64847),
#  ('monitoring', 64840),
#  ('tensorflow', 64728),
#  ('series', 64644),
#  ('32', 63994),
#  ('datasets', 63162),
#  ('sdk', 63148),
#  ('dns', 63129),
#  ('less', 63096),
#  ('things', 63080),
#  ('place', 63060),
#  ('product', 63047),
#  ('day', 62899),
#  ('master', 62507),
#  ('50', 62423),
#  ('tutorial', 62345),
#  ('monitor', 62294),
#  ('job', 62255),
#  ('terminal', 62154),
#  ('university', 62082),
#  ('background', 61589),
#  ('logs', 61539),
#  ('elements', 61258),
#  ('q', 61233),
#  ('ssh', 61193),
#  ('generation', 61133),
#  ('assets', 61109),
#  ('w', 61046),
#  ('segmentation', 60815),
#  ('three', 60407),
#  ('fields', 60397),
#  ('power', 60285),
#  ('count', 60265),
#  ('menu', 60059),
#  ('mac', 59920),
#  ('pattern', 59916),
#  ('servers', 59799),
#  ('db', 59719),
#  ('username', 59659),
#  ('macos', 59364),
#  ('stored', 59013),
#  ('md', 58972),
#  ('router', 58777),
#  ('traffic', 58661),
#  ('csv', 58563),
#  ('stream', 58500),
#  ('exe', 58495),
#  ('share', 58347),
#  ('callback', 58177),
#  ('readme', 58122),
#  ('execution', 58042),
#  ('operation', 57997),
#  ('flash', 57991),
#  ('hash', 57922),
#  ('policy', 57885),
#  ('links', 57149),
#  ('bar', 57059),
#  ('tracking', 57001),
#  ('questions', 56855),
#  ('book', 56779),
#  ('red', 56736),
#  ('docs', 56730),
#  ('backend', 56723),
#  ('external', 56691),
#  ('validation', 56574),
#  ('blocks', 56475),
#  ('metrics', 56442),
#  ('body', 56408),
#  ('future', 56234),
#  ('higher', 56055),
#  ('plugins', 56011),
#  ('spring', 55934),
#  ('implemented', 55745),
#  ('png', 55532),
#  ('writing', 55483),
#  ('dependency', 55398),
#  ('tags', 55358),
#  ('handle', 55233),
#  ('science', 55034),
#  ('argument', 54817),
#  ('tcp', 54578),
#  ('making', 54519),
#  ('knowledge', 54515),
#  ('apis', 54453),
#  ('internet', 54359),
#  ('updates', 54343),
#  ('2023', 54334),
#  ('nodes', 54029),
#  ('engineering', 53961),
#  ('trained', 53665),
#  ('media', 53663),
#  ('runtime', 53659),
#  ('yarn', 53593),
#  ('live', 53537),
#  ('entry', 53156),
#  ('metadata', 53085),
#  ('secure', 52902),
#  ('watch', 52858),
#  ('points', 52630),
#  ('switch', 52571),
#  ('unit', 52551),
#  ('lines', 52196),
#  ('region', 52184),
#  ('void', 51914),
#  ('mysql', 51776),
#  ('frame', 51764),
#  ('facebook', 51737),
#  ('zero', 51691),
#  ('role', 51605),
#  ('actions', 51583),
#  ('logging', 51561),
#  ('worker', 51484),
#  ('s3', 51281),
#  ('bytes', 51258),
#  ('echo', 51219),
#  ('automatic', 51195),
#  ('gpu', 51106),
#  ('named', 51088),
#  ('human', 51061),
#  ('maximum', 51021),
#  ('person', 50993),
#  ('position', 50850),
#  ('trees', 50803),
#  ('profile', 50729),
#  ('pipeline', 50715),
#  ('hello', 50674),
#  ('final', 50599),
#  ('https', 50396),
#  ('history', 50202),
#  ('chrome', 50182),
#  ('generator', 50098),
#  ('lib', 49791),
#  ('interactive', 49383),
#  ('numbers', 49362),
#  ('transfer', 49215),
#  ('twitter', 49168),
#  ('attack', 49045),
#  ('big', 49026),
#  ('studio', 48823),
#  ('efficient', 48795),
#  ('reading', 48714),
#  ('usb', 48682),
#  ('faster', 48451),
#  ('sequence', 48325),
#  ('official', 48183),
#  ('fully', 48078),
#  ('upload', 47910),
#  ('compile', 47839),
#  ('register', 47796),
#  ('ci', 47599),
#  ('quality', 47584),
#  ('commit', 47579),
#  ('init', 47572),
#  ('bot', 47545),
#  ('debugging', 47495),
#  ('review', 47366),
#  ('webpack', 47366),
#  ('agent', 47237),
#  ('buffer', 47211),
#  ('medium', 47190),
#  ('internal', 47148),
#  ('modern', 46904),
#  ('64', 46843),
#  ('secret', 46786),
#  ('rendering', 46699),
#  ('rate', 46559),
#  ('total', 46532),
#  ('record', 46418),
#  ('v2', 46410),
#  ('z', 46354),
#  ('wrapper', 46300),
#  ('sensor', 46248),
#  ('calls', 45970),
#  ('unique', 45964),
#  ('correct', 45919),
#  ('move', 45847),
#  ('scan', 45769),
#  ('zip', 45738),
#  ('launch', 45733),
#  ('contact', 45692),
#  ('warning', 45465),
#  ('shows', 45421),
#  ('sort', 45421),
#  ('play', 45325),
#  ('instances', 45234),
#  ('samples', 45146),
#  ('times', 45102),
#  ('word', 45006),
#  ('icon', 44861),
#  ('yml', 44690),
#  ('loading', 44598),
#  ('apt', 44569),
#  ('lists', 44521),
#  ('i2c', 44464),
#  ('ubuntu', 44440),
#  ('card', 44439),
#  ('connected', 44357),
#  ('raw', 44274),
#  ('player', 44256),
#  ('coding', 44174),
#  ('distribution', 44145),
#  ('experience', 44139),
#  ('short', 44071),
#  ('dom', 44054),
#  ('desktop', 43967),
#  ('edge', 43965),
#  ('handling', 43917),
#  ('year', 43872),
#  ('theme', 43760),
#  ('cvpr', 43741),
#  ('redis', 43700),
#  ('empty', 43544),
#  ('behavior', 43473),
#  ('patterns', 43416),
#  ('processes', 43399),
#  ('quick', 43335),
#  ('credentials', 43236),
#  ('python3', 43233),
#  ('convolutional', 43157),
#  ('lot', 43115),
#  ('disk', 43028),
#  ('notification', 42886),
#  ('nginx', 42882),
#  ('django', 42876),
#  ('jpg', 42802),
#  ('certificate', 42764),
#  ('social', 42753),
#  ('limit', 42715),
#  ('infrastructure', 42696),
#  ('missing', 42591),
#  ('express', 42424),
#  ('operating', 42388),
#  ('shared', 42377),
#  ('extra', 42371),
#  ('flag', 42356),
#  ('prediction', 42198),
#  ('attribute', 42161),
#  ('rule', 42056),
#  ('logic', 42042),
#  ('attacks', 41961),
#  ('firebase', 41689),
#  ('youtube', 41683),
#  ('templates', 41673),
#  ('center', 41564),
#  ('reverse', 41545),
#  ('ssl', 41466),
#  ('minimum', 41432),
#  ('powershell', 41326),
#  ('bundle', 41219),
#  ('strings', 41018),
#  ('smart', 40994),
#  ('evaluation', 40958),
#  ('layout', 40906),
#  ('props', 40805),
#  ('understanding', 40788),
#  ('lightweight', 40725),
#  ('provider', 40697),
#  ('robot', 40664),
#  ('languages', 40605),
#  ('lambda', 40585),
#  ('convert', 40584),
#  ('pi', 40579),
#  ('auth', 40574),
#  ('maps', 40571),
#  ('socket', 40546),
#  ('progress', 40514),
#  ('ms', 40424),
#  ('queue', 40360),
#  ('labels', 40347),
#  ('enzyme', 40313),
#  ('thread', 40250),
#  ('angular', 40147),
#  ('containers', 40117),
#  ('groups', 40064),
#  ('opencv', 39983),
#  ('checks', 39946),
#  ('interview', 39921),
#  ('technology', 39877),
#  ('optimization', 39870),
#  ('analytics', 39847),
#  ('cs', 39735),
#  ('semantic', 39701),
#  ('linear', 39605),
#  ('endpoint', 39583),
#  ('ram', 39505),
#  ('force', 39501),
#  ('patch', 39487),
#  ('light', 39470),
#  ('depth', 39447),
#  ('attributes', 39363),
#  ('fetch', 39339),
#  ('track', 39259),
#  ('structures', 39257),
#  ('mapping', 39256),
#  ('compatible', 39124),
#  ('42', 39044),
#  ('matrix', 39029),
#  ('payload', 39015),
#  ('utility', 39001),
#  ('extract', 38921),
#  ('topic', 38803),
#  ('complex', 38795),
#  ('volume', 38787),
#  ('generic', 38781),
#  ('solutions', 38764),
#  ('party', 38718),
#  ('todo', 38711),
#  ('dashboard', 38616),
#  ('apple', 38607),
#  ('meta', 38542),
#  ('environments', 38501),
#  ('matching', 38428),
#  ('front', 38406),
#  ('resolution', 38380),
#  ('welcome', 38369),
#  ('inference', 38367),
#  ('malware', 38366),
#  ('permissions', 38340),
#  ('gui', 38333),
#  ('loop', 38302),
#  ('automated', 38299),
#  ('objective', 38215),
#  ('vector', 38183),
#  ('schema', 38177),
#  ('serial', 38115),
#  ('business', 37960),
#  ('digital', 37934),
#  ('compiler', 37932),
#  ('async', 37892),
#  ('article', 37889),
#  ('apikey', 37808),
#  ('character', 37797),
#  ('loss', 37733),
#  ('vulnerability', 37649),
#  ('clean', 37560),
#  ('news', 37549),
#  ('hosting', 37486),
#  ('bus', 37236),
#  ('stage', 37166),
#  ('effect', 37163),
#  ('communication', 37009),
#  ('cmd', 37000),
#  ('entity', 36873),
#  ('cnn', 36812),
#  ('score', 36737),
#  ('attention', 36713),
#  ('expression', 36590),
#  ('compose', 36564),
#  ('sub', 36551),
#  ('curl', 36470),
#  ('markdown', 36417),
#  ('copyright', 36410),
#  ('notifications', 36373),
#  ('intel', 36368),
#  ('img', 36339),
#  ('pool', 36271),
#  ('backup', 36248),
#  ('regular', 36216),
#  ('namespace', 36174),
#  ('aware', 36118),
#  ('signal', 36097),
#  ('conference', 36078),
#  ('firmware', 36005),
#  ('ieee', 35977),
#  ('ml', 35959),
#  ('super', 35894),
#  ('sign', 35878),
#  ('natural', 35832),
#  ('representation', 35779),
#  ('toolkit', 35735),
#  ('computing', 35679),
#  ('documents', 35671),
#  ('alerts', 35660),
#  ('batch', 35631),
#  ('adversarial', 35556),
#  ('kind', 35501),
#  ('operator', 35477),
#  ('words', 35414),
#  ('contract', 35398),
#  ('anything', 35397),
#  ('question', 35373),
#  ('cpp', 35372),
#  ('practice', 35358),
#  ('intelligence', 35322),
#  ('programs', 35307),
#  ('accuracy', 35283),
#  ('continuous', 35242),
#  ('manual', 35149),
#  ('coverage', 35126),
#  ('phone', 35098),
#  ('queries', 35067),
#  ('40', 35036),
#  ('xss', 34969),
#  ('weights', 34924),
#  ('extensions', 34923),
#  ('summary', 34881),
#  ('focus', 34846),
#  ('trigger', 34843),
#  ('visualization', 34842),
#  ('estimation', 34808),
#  ('sass', 34795),
#  ('ide', 34656),
#  ('headers', 34648),
#  ('jquery', 34526),
#  ('applied', 34485),
#  ('gnu', 34457),
#  ('conda', 34438),
#  ('detector', 34395),
#  ('workflow', 34366),
#  ('gateway', 34353),
#  ('lecture', 34339),
#  ('injection', 34317),
#  ('typescript', 34265),
#  ('plan', 34253),
#  ('svg', 34247),
#  ('cost', 34245),
#  ('contributing', 34172),
#  ('parser', 34130),
#  ('activity', 34128),
#  ('routing', 34040),
#  ('material', 33996),
#  ('tutorials', 33777),
#  ('selection', 33774),
#  ('characters', 33765),
#  ('prompt', 33756),
#  ('chat', 33738),
#  ('handler', 33727),
#  ('papers', 33712),
#  ('alternative', 33711),
#  ('terraform', 33663),
#  ('head', 33651),
#  ('promise', 33603),
#  ('fine', 33535),
#  ('books', 33526),
#  ('translation', 33511),
#  ('bugs', 33493),
#  ('challenge', 33492),
#  ('black', 33404),
#  ('products', 33360),
#  ('matlab', 33351),
#  ('mail', 33329),
#  ('encryption', 33306),
#  ('comment', 33257),
#  ('fork', 33231),
#  ('transaction', 33097),
#  ('vm', 33053),
#  ('safe', 33011),
#  ('notebook', 32962),
#  ('hub', 32944),
#  ('speech', 32882),
#  ('jsx', 32787),
#  ('rust', 32708),
#  ('split', 32680),
#  ('functional', 32312),
#  ('comments', 32289),
#  ('platforms', 32268),
#  ('creation', 32258),
#  ('supervised', 32243),
#  ('distance', 32164),
#  ('parallel', 32123),
#  ('verify', 32099),
#  ('iot', 31965),
#  ('golang', 31887),
#  ('automation', 31881),
#  ('notice', 31875),
#  ('styles', 31831),
#  ('reports', 31818),
#  ('cell', 31812),
#  ('regression', 31684),
#  ('flexible', 31645),
#  ('await', 31625),
#  ('games', 31607),
#  ('music', 31515),
#  ('heroku', 31512),
#  ('drive', 31511),
#  ('motion', 31502),
#  ('calling', 31487),
#  ('privacy', 31471),
#  ('cause', 31458),
#  ('drop', 31444),
#  ('tables', 31432),
#  ('vim', 31431),
#  ('days', 31364),
#  ('art', 31362),
#  ('permission', 31334),
#  ('databases', 31319),
#  ('53', 31280),
#  ('interfaces', 31220),
#  ('font', 31212),
#  ('connections', 31199),
#  ('conditions', 31197),
#  ('grid', 31162),
#  ('prometheus', 31111),
#  ('idea', 31064),
#  ('lab', 30901),
#  ('feedback', 30888),
#  ('browsers', 30871),
#  ('threshold', 30836),
#  ('hosted', 30831),
#  ('embedded', 30803),
#  ('tls', 30745),
#  ('publish', 30709),
#  ...]

# %%
t6 = github_data_df['tree'].apply(lambda x: myclnfunction(x))

# %%
t6_cnt = Counter(t6.explode())
t6_cnt.most_common()
# Out:
# [('md', 325429),
#  ('readme', 230494),
#  ('py', 158959),
#  ('license', 123935),
#  ('json', 77162),
#  ('txt', 72139),
#  ('yml', 54300),
#  ('js', 48160),
#  ('sh', 45563),
#  ('go', 40093),
#  ('package', 40029),
#  ('src', 39516),
#  ('github', 37108),
#  ('config', 35597),
#  ('c', 35520),
#  ('pdf', 34528),
#  ('png', 32559),
#  ('ipynb', 26794),
#  ('requirements', 25366),
#  ('test', 24770),
#  ('lock', 24198),
#  ('docs', 20499),
#  ('makefile', 19584),
#  ('setup', 19398),
#  ('contributing', 18501),
#  ('data', 18420),
#  ('travis', 18286),
#  ('php', 17592),
#  ('build', 17538),
#  ('cpp', 17525),
#  ('gradle', 17415),
#  ('tests', 17201),
#  ('changelog', 16818),
#  ('yaml', 16394),
#  ('xml', 15856),
#  ('images', 15573),
#  ('html', 15360),
#  ('lib', 14766),
#  ('dockerfile', 14258),
#  ('scripts', 13675),
#  ('index', 13056),
#  ('docker', 12295),
#  ('app', 11872),
#  ('examples', 11669),
#  ('example', 10877),
#  ('1', 10608),
#  ('jpg', 10521),
#  ('utils', 9981),
#  ('editorconfig', 9065),
#  ('tools', 8999),
#  ('bat', 8628),
#  ('assets', 8504),
#  ('cfg', 8470),
#  ('demo', 7533),
#  ('project', 7510),
#  ('bin', 7438),
#  ('2', 7367),
#  ('models', 7273),
#  ('toml', 7260),
#  ('settings', 6973),
#  ('install', 6945),
#  ('compose', 6940),
#  ('csv', 6900),
#  ('manifest', 6872),
#  ('vscode', 6684),
#  ('model', 6157),
#  ('properties', 5981),
#  ('server', 5942),
#  ('api', 5900),
#  ('public', 5897),
#  ('yarn', 5866),
#  ('resources', 5847),
#  ('version', 5844),
#  ('security', 5669),
#  ('tf', 5617),
#  ('train', 5532),
#  ('idea', 5490),
#  ('env', 5422),
#  ('ini', 5326),
#  ('3', 5231),
#  ('img', 5199),
#  ('zip', 4969),
#  ('css', 4875),
#  ('detection', 4815),
#  ('code', 4753),
#  ('mod', 4683),
#  ('composer', 4583),
#  ('r', 4570),
#  ('cmd', 4332),
#  ('include', 4236),
#  ('templates', 4207),
#  ('common', 4121),
#  ('ps1', 4035),
#  ('cs', 3867),
#  ('4', 3717),
#  ('spec', 3693),
#  ('sample', 3651),
#  ('dev', 3580),
#  ('dataset', 3547),
#  ('ts', 3531),
#  ('run', 3504),
#  ('android', 3452),
#  ('commit', 3448),
#  ('gif', 3409),
#  ('pre', 3390),
#  ('client', 3350),
#  ('configs', 3347),
#  ('web', 3343),
#  ('sql', 3316),
#  ('python', 3294),
#  ('core', 3288),
#  ('image', 3271),
#  ('webpack', 3212),
#  ('util', 3180),
#  ('java', 3164),
#  ('5', 3087),
#  ('todo', 3087),
#  ('cmake', 3062),
#  ('log', 2986),
#  ('lua', 2962),
#  ('static', 2907),
#  ('ci', 2897),
#  ('template', 2894),
#  ('service', 2872),
#  ('notice', 2851),
#  ('driver', 2823),
#  ('release', 2798),
#  ('plugin', 2717),
#  ('cargo', 2692),
#  ('circleci', 2613),
#  ('db', 2555),
#  ('screenshots', 2517),
#  ('learning', 2455),
#  ('files', 2413),
#  ('screenshot', 2401),
#  ('11', 2385),
#  ('datasets', 2353),
#  ('logo', 2335),
#  ('ui', 2296),
#  ('source', 2281),
#  ('deploy', 2281),
#  ('cve', 2244),
#  ('samples', 2239),
#  ('modules', 2239),
#  ('ios', 2223),
#  ('notebooks', 2218),
#  ('exe', 2188),
#  ('script', 2162),
#  ('patch', 2141),
#  ('packages', 2125),
#  ('documentation', 2090),
#  ('media', 2080),
#  ('6', 2067),
#  ('environment', 2059),
#  ('git', 2013),
#  ('news', 1998),
#  ('output', 1992),
#  ('format', 1980),
#  ('mp4', 1970),
#  ('cc', 1956),
#  ('bower', 1944),
#  ('jest', 1937),
#  ('10', 1925),
#  ('icon', 1895),
#  ('clang', 1871),
#  ('notes', 1856),
#  ('ml', 1840),
#  ('aws', 1837),
#  ('phpunit', 1835),
#  ('misc', 1815),
#  ('7', 1803),
#  ('changes', 1798),
#  ('8', 1794),
#  ('linux', 1761),
#  ('report', 1755),
#  ('plugins', 1743),
#  ('cli', 1735),
#  ('appveyor', 1729),
#  ('svg', 1708),
#  ('node', 1698),
#  ('metadata', 1695),
#  ('analysis', 1674),
#  ('tox', 1673),
#  ('windows', 1660),
#  ('libs', 1660),
#  ('init', 1643),
#  ('info', 1629),
#  ('net', 1626),
#  ('man', 1621),
#  ('meta', 1619),
#  ('azure', 1619),
#  ('user', 1616),
#  ('pkg', 1610),
#  ('m4', 1602),
#  ('bootstrap', 1601),
#  ('testing', 1596),
#  ('gitlab', 1586),
#  ('spring', 1585),
#  ('library', 1584),
#  ('list', 1584),
#  ('network', 1565),
#  ('database', 1562),
#  ('babel', 1526),
#  ('day', 1512),
#  ('2019', 1511),
#  ('ico', 1489),
#  ('rules', 1489),
#  ('cloud', 1474),
#  ('boot', 1470),
#  ('licence', 1467),
#  ('markdown', 1457),
#  ('ips', 1456),
#  ('video', 1407),
#  ('style', 1384),
#  ('ai', 1379),
#  ('rar', 1368),
#  ('jquery', 1361),
#  ('paper', 1347),
#  ('mit', 1345),
#  ('system', 1345),
#  ('training', 1343),
#  ('msg', 1341),
#  ('module', 1341),
#  ('update', 1337),
#  ('default', 1321),
#  ('history', 1319),
#  ('logs', 1311),
#  ('swift', 1310),
#  ('dll', 1297),
#  ('detect', 1295),
#  ('01', 1283),
#  ('local', 1279),
#  ('design', 1269),
#  ('tslint', 1266),
#  ('file', 1266),
#  ('application', 1265),
#  ('ipset', 1252),
#  ('debug', 1248),
#  ('classification', 1217),
#  ('functions', 1216),
#  ('org', 1215),
#  ('development', 1212),
#  ('final', 1211),
#  ('read', 1210),
#  ('machine', 1196),
#  ('contrib', 1196),
#  ('docx', 1191),
#  ('2020', 1191),
#  ('using', 1187),
#  ('iml', 1178),
#  ('support', 1177),
#  ('object', 1177),
#  ('class', 1176),
#  ('frontend', 1174),
#  ('etc', 1173),
#  ('jenkinsfile', 1168),
#  ('ruby', 1165),
#  ('deep', 1164),
#  ('flake8', 1156),
#  ('backend', 1148),
#  ('licenses', 1147),
#  ('pipelines', 1140),
#  ('dependencies', 1136),
#  ('launch', 1131),
#  ('views', 1123),
#  ('print', 1122),
#  ('deployment', 1117),
#  ('tasks', 1110),
#  ('experiments', 1103),
#  ('workspace', 1093),
#  ('versions', 1089),
#  ('rollup', 1074),
#  ('storage', 1072),
#  ('pro', 1068),
#  ('conduct', 1053),
#  ('eval', 1052),
#  ('internal', 1049),
#  ('namespace', 1048),
#  ('rspec', 1048),
#  ('networks', 1047),
#  ('admin', 1046),
#  ('types', 1046),
#  ('favicon', 1045),
#  ('components', 1045),
#  ('v', 1043),
#  ('xlsx', 1042),
#  ('services', 1040),
#  ('projects', 1035),
#  ('base', 1030),
#  ('gui', 1024),
#  ('debian', 1015),
#  ('variables', 1015),
#  ('vagrantfile', 1015),
#  ('make', 1003),
#  ('yara', 998),
#  ('pytest', 994),
#  ('2018', 993),
#  ('configuration', 992),
#  ('jpeg', 990),
#  ('master', 977),
#  ('tar', 974),
#  ('cache', 967),
#  ('face', 966),
#  ('kubernetes', 965),
#  ('language', 957),
#  ('tutorial', 955),
#  ('karma', 951),
#  ('terraform', 934),
#  ('tree', 932),
#  ('check', 931),
#  ('routes', 926),
#  ('metrics', 925),
#  ('guide', 915),
#  ('search', 912),
#  ('sublime', 911),
#  ('h5', 910),
#  ('create', 910),
#  ('inference', 894),
#  ('external', 894),
#  ('ansible', 894),
#  ('options', 893),
#  ('05', 888),
#  ('features', 866),
#  ('evaluation', 864),
#  ('benchmark', 861),
#  ('icons', 860),
#  ('poetry', 858),
#  ('http', 857),
#  ('monitor', 856),
#  ('sdk', 855),
#  ('custom', 854),
#  ('graph', 853),
#  ('apps', 851),
#  ('yolo', 849),
#  ('husky', 848),
#  ('pc', 847),
#  ('nginx', 843),
#  ('integration', 843),
#  ('2021', 842),
#  ('text', 841),
#  ('page', 840),
#  ('alert', 840),
#  ('tool', 839),
#  ('post', 836),
#  ('neural', 834),
#  ('commands', 833),
#  ('cnn', 832),
#  ('weights', 831),
#  ('board', 829),
#  ('get', 827),
#  ('input', 826),
#  ('mix', 824),
#  ('helpers', 823),
#  ('programming', 823),
#  ('v2', 823),
#  ('apache', 819),
#  ('hooks', 812),
#  ('preprocessing', 812),
#  ('architecture', 807),
#  ('renovate', 806),
#  ('mkdocs', 798),
#  ('drivers', 797),
#  ('gitpod', 792),
#  ('map', 792),
#  ('x', 791),
#  ('detector', 789),
#  ('pipeline', 785),
#  ('14', 783),
#  ('angular', 783),
#  ('control', 775),
#  ('engine', 774),
#  ('rubocop', 773),
#  ('cluster', 773),
#  ('framework', 772),
#  ('google', 771),
#  ('fs', 770),
#  ('runtime', 769),
#  ('fonts', 767),
#  ('translations', 758),
#  ('filter', 756),
#  ('2017', 755),
#  ('presentation', 751),
#  ('content', 750),
#  ('pages', 750),
#  ('15', 746),
#  ('logging', 744),
#  ('bot', 743),
#  ('react', 742),
#  ('rc', 740),
#  ('filters', 737),
#  ('bash', 736),
#  ('pcap', 735),
#  ('summary', 733),
#  ('sbt', 732),
#  ('asm', 732),
#  ('arch', 729),
#  ('classes', 721),
#  ('game', 719),
#  ('dashboard', 719),
#  ('simple', 716),
#  ('shared', 712),
#  ('nix', 712),
#  ('18', 710),
#  ('pack', 710),
#  ('crypto', 708),
#  ('website', 707),
#  ('extension', 705),
#  ('desktop', 703),
#  ('recognition', 703),
#  ('auth', 694),
#  ('installer', 693),
#  ('prediction', 692),
#  ('time', 688),
#  ('phase', 687),
#  ('merge', 684),
#  ('miner', 684),
#  ('action', 683),
#  ('schema', 682),
#  ('jar', 677),
#  ('key', 668),
#  ('monitoring', 666),
#  ('proxy', 664),
#  ('19', 661),
#  ('styles', 660),
#  ('stack', 659),
#  ('wav', 658),
#  ('helper', 658),
#  ('e2e', 654),
#  ('grafana', 654),
#  ('opencv', 652),
#  ('videos', 647),
#  ('header', 647),
#  ('copyright', 647),
#  ('logger', 646),
#  ('contracts', 644),
#  ('utilities', 641),
#  ('process', 638),
#  ('audio', 635),
#  ('prometheus', 634),
#  ('compile', 631),
#  ('backup', 630),
#  ('bmp', 625),
#  ('command', 624),
#  ('tensorflow', 621),
#  ('platform', 620),
#  ('postcss', 619),
#  ('injection', 616),
#  ('generate', 615),
#  ('slides', 614),
#  ('lint', 614),
#  ('generator', 614),
#  ('hack', 613),
#  ('camera', 613),
#  ('global', 612),
#  ('diff', 612),
#  ('cpu', 609),
#  ('apple', 607),
#  ('libraries', 607),
#  ('segmentation', 606),
#  ('native', 606),
#  ('demos', 606),
#  ('download', 601),
#  ('benchmarks', 601),
#  ('shell', 599),
#  ('agent', 596),
#  ('faq', 595),
#  ('pytorch', 594),
#  ('hardware', 589),
#  ('help', 588),
#  ('hacking', 586),
#  ('view', 583),
#  ('controller', 581),
#  ('sub', 576),
#  ('reference', 574),
#  ('mobile', 573),
#  ('17', 571),
#  ('tutorials', 571),
#  ('event', 571),
#  ('state', 570),
#  ('io', 567),
#  ('yolov3', 564),
#  ('events', 563),
#  ('flow', 562),
#  ('site', 562),
#  ('uninstall', 561),
#  ('archive', 561),
#  ('binary', 560),
#  ('nuget', 559),
#  ('processing', 559),
#  ('disk', 559),
#  ('cuda', 559),
#  ('matlab', 558),
#  ('firmware', 558),
#  ('languages', 557),
#  ('add', 556),
#  ('gpu', 555),
#  ('export', 554),
#  ('feature', 554),
#  ('device', 549),
#  ('party', 549),
#  ('cypress', 545),
#  ('malware', 544),
#  ('k', 544),
#  ('classifier', 540),
#  ('ids', 540),
#  ('sha2', 540),
#  ('patches', 539),
#  ('zone', 539),
#  ('notebook', 538),
#  ('migrations', 533),
#  ('parser', 533),
#  ('software', 532),
#  ('documents', 532),
#  ('clean', 532),
#  ('login', 531),
#  ('next', 530),
#  ('algorithm', 529),
#  ('management', 526),
#  ('assignment', 522),
#  ('pnpm', 519),
#  ('wifi', 517),
#  ('directory', 516),
#  ('groovy', 512),
#  ('afl', 511),
#  ('manual', 510),
#  ('kafka', 509),
#  ('multi', 508),
#  ('papers', 507),
#  ('convert', 507),
#  ('os', 506),
#  ('extra', 505),
#  ('vue', 502),
#  ('algorithms', 502),
#  ('k8s', 502),
#  ('program', 501),
#  ('import', 500),
#  ('error', 499),
#  ('gateway', 496),
#  ('bundle', 495),
#  ('win', 494),
#  ('context', 494),
#  ('policy', 494),
#  ('releases', 492),
#  ('tex', 492),
#  ('upload', 491),
#  ('rest', 491),
#  ('store', 491),
#  ('resource', 490),
#  ('extract', 488),
#  ('publish', 487),
#  ('domain', 487),
#  ('jenkins', 487),
#  ('spark', 486),
#  ('lang', 486),
#  ('designer', 482),
#  ('loss', 482),
#  ('references', 482),
#  ('2022', 480),
#  ('reports', 480),
#  ('snapshot', 479),
#  ('javascript', 479),
#  ('lambda', 478),
#  ('basic', 478),
#  ('es', 478),
#  ('arduino', 477),
#  ('number', 476),
#  ('copy', 476),
#  ('preview', 472),
#  ('us', 471),
#  ('vision', 471),
#  ('lab', 471),
#  ('regression', 470),
#  ('use', 469),
#  ('awesome', 469),
#  ('kernel', 469),
#  ('firebase', 467),
#  ('visualization', 466),
#  ('document', 466),
#  ('circle', 466),
#  ('sonar', 465),
#  ('target', 465),
#  ('tracking', 464),
#  ('remote', 462),
#  ('mac', 462),
#  ('touch', 461),
#  ('coffee', 461),
#  ('array', 461),
#  ('objects', 461),
#  ('scrypt', 459),
#  ('status', 457),
#  ('mypy', 457),
#  ('introduction', 453),
#  ('lecture', 453),
#  ('stats', 450),
#  ('roadmap', 450),
#  ('interface', 450),
#  ('100', 448),
#  ('layers', 445),
#  ('scan', 445),
#  ('books', 444),
#  ('browser', 443),
#  ('menu', 442),
#  ('n', 441),
#  ('x64', 441),
#  ('codes', 440),
#  ('editor', 439),
#  ('book', 439),
#  ('mysql', 439),
#  ('sort', 437),
#  ('session', 435),
#  ('open', 434),
#  ('ssh', 433),
#  ('pictures', 433),
#  ('line', 432),
#  ('webapp', 431),
#  ('win32', 431),
#  ('upgrade', 431),
#  ('console', 430),
#  ('table', 429),
#  ('tailwind', 429),
#  ('covid', 429),
#  ('protocol', 428),
#  ('quickstart', 426),
#  ('sycl', 426),
#  ('home', 425),
#  ('props', 424),
#  ('plot', 424),
#  ('extensions', 424),
#  ('vite', 423),
#  ('root', 423),
#  ('building', 422),
#  ('based', 422),
#  ('art', 421),
#  ('screen', 420),
#  ('ar', 420),
#  ('dir', 420),
#  ('apk', 418),
#  ('study', 418),
#  ('advanced', 415),
#  ('missing', 414),
#  ('profile', 411),
#  ('keras', 411),
#  ('ibm', 411),
#  ('themes', 410),
#  ('baseline', 410),
#  ('diagram', 410),
#  ('planning', 410),
#  ('i18n', 409),
#  ('htm', 409),
#  ('set', 409),
#  ('caffe', 409),
#  ('arm', 408),
#  ('darknet', 407),
#  ('keywords', 407),
#  ('svm', 405),
#  ('builder', 404),
#  ('intro', 402),
#  ('macos', 401),
#  ('roles', 400),
#  ('proto', 400),
#  ('container', 400),
#  ('attack', 399),
#  ('path', 399),
#  ('article', 399),
#  ('font', 398),
#  ('secrets', 397),
#  ('hash', 396),
#  ('installation', 393),
#  ('chrome', 392),
#  ('push', 392),
#  ('manager', 390),
#  ('one', 389),
#  ('stream', 389),
#  ('keys', 388),
#  ('alerts', 387),
#  ('find', 386),
#  ('share', 385),
#  ('drone', 384),
#  ('scanner', 383),
#  ('packaging', 382),
#  ('community', 382),
#  ('e', 382),
#  ('background', 382),
#  ('auto', 380),
#  ('utility', 379),
#  ('neon', 376),
#  ('email', 375),
#  ('worker', 375),
#  ('applications', 375),
#  ('wp', 374),
#  ('component', 374),
#  ('s3', 372),
#  ('usage', 372),
#  ('repo', 372),
#  ('trainer', 372),
#  ('3d', 371),
#  ('u', 369),
#  ('lerna', 368),
#  ('loader', 367),
#  ('getting', 367),
#  ('microsoft', 365),
#  ('production', 365),
#  ('rpc', 365),
#  ('string', 365),
#  ('rs', 364),
#  ('stress', 364),
#  ('phpstan', 363),
#  ('snippets', 362),
#  ('tracker', 362),
#  ('link', 360),
#  ('conda', 360),
#  ('computer', 359),
#  ('fuzz', 359),
#  ('course', 359),
#  ('graphics', 359),
#  ('research', 359),
#  ('phpcs', 358),
#  ('overlay', 358),
#  ('color', 357),
#  ('experiment', 357),
#  ('xss', 354),
#  ('banner', 351),
#  ('redis', 351),
#  ('registry', 351),
#  ('case', 351),
#  ('raw', 347),
#  ('started', 347),
#  ('performance', 346),
#  ('block', 346),
#  ('helm', 346),
#  ('perl', 344),
#  ('ops', 344),
#  ('startup', 344),
#  ('labels', 343),
#  ('bro', 343),
#  ('smart', 343),
#  ('infrastructure', 342),
#  ('handlers', 340),
#  ('red', 340),
#  ('ip', 340),
#  ('graphs', 339),
#  ('mask', 339),
#  ('links', 339),
#  ('qemu', 339),
#  ('dubbo', 339),
#  ('discovery', 338),
#  ('robots', 338),
#  ('starter', 337),
#  ('platformio', 336),
#  ('full', 335),
#  ('swagger', 335),
#  ('rust', 334),
#  ('single', 334),
#  ('rcnn', 334),
#  ('x86', 334),
#  ('function', 333),
#  ('parse', 332),
#  ('sync', 331),
#  ('memory', 331),
#  ('rails', 331),
#  ('cpuminer', 331),
#  ('analytics', 330),
#  ('figure', 329),
#  ('validation', 329),
#  ('capture', 329),
#  ('chat', 329),
#  ('names', 328),
#  ('users', 328),
#  ('solutions', 328),
#  ('iot', 327),
#  ('coverage', 327),
#  ('b', 326),
#  ('edge', 326),
#  ('charts', 326),
#  ('linear', 326),
#  ('bench', 325),
#  ('parameters', 325),
#  ('matrix', 325),
#  ('step', 324),
#  ('mining', 324),
#  ('form', 324),
#  ('cheatsheet', 323),
#  ('workflow', 322),
#  ('anomaly', 322),
#  ('coco', 321),
#  ('group', 321),
#  ('connect', 321),
#  ('exporter', 321),
#  ('task', 320),
#  ('theme', 320),
#  ('nlp', 319),
#  ('cdk', 319),
#  ('random', 318),
#  ('clustering', 318),
#  ('url', 318),
#  ('fetch', 318),
#  ('v3', 317),
#  ('asciidoc', 317),
#  ('z', 317),
#  ('serverless', 316),
#  ('fix', 315),
#  ('ubuntu', 314),
#  ('chart', 314),
#  ('https', 313),
#  ('netlify', 312),
#  ('daemon', 312),
#  ('elasticsearch', 311),
#  ('statistics', 311),
#  ('speech', 310),
#  ('jsp', 310),
#  ('storybook', 310),
#  ('instructions', 309),
#  ('id', 309),
#  ('ii', 309),
#  ('twitter', 309),
#  ('runner', 309),
#  ('fast', 309),
#  ('exploit', 306),
#  ('privacy', 305),
#  ('dns', 305),
#  ('rce', 304),
#  ('team', 304),
#  ('compiler', 303),
#  ('private', 303),
#  ('cron', 303),
#  ('card', 302),
#  ('forensics', 302),
#  ('annotations', 301),
#  ('artisan', 301),
#  ('coveralls', 301),
#  ('avi', 300),
#  ('mp3', 300),
#  ('wrapper', 300),
#  ('sol', 300),
#  ('convolutional', 299),
#  ('infra', 299),
#  ('pic', 299),
#  ('robot', 298),
#  ('sheet', 298),
#  ('hello', 297),
#  ('queue', 297),
#  ('visual', 297),
#  ('plots', 297),
#  ('notification', 296),
#  ('vagrant', 296),
#  ('troubleshooting', 296),
#  ('comments', 296),
#  ('actions', 296),
#  ('scss', 295),
#  ('wiki', 295),
#  ('light', 295),
#  ('messages', 294),
#  ('tsv', 294),
#  ('amazon', 293),
#  ('errors', 292),
#  ('cross', 292),
#  ('player', 292),
#  ('engineering', 291),
#  ('collection', 291),
#  ('32', 291),
#  ('provider', 291),
#  ('review', 290),
#  ('recipes', 289),
#  ('cheat', 289),
#  ('dl', 288),
#  ('layout', 287),
#  ('ros', 287),
#  ('vhd', 287),
#  ('textile', 286),
#  ('ssl', 286),
#  ('sound', 286),
#  ('fraud', 286),
#  ('sandbox', 286),
#  ('releaserc', 285),
#  ('slack', 284),
#  ('dataloader', 283),
#  ('spi', 283),
#  ('yolov5', 282),
#  ('playground', 282),
#  ('profiles', 281),
#  ('learn', 281),
#  ('hosts', 281),
#  ('tidy', 281),
#  ('information', 280),
#  ('message', 280),
#  ('transfer', 280),
#  ('best', 279),
#  ('pickle', 279),
#  ('request', 279),
#  ('job', 278),
#  ('audit', 278),
#  ('osx', 277),
#  ('toolchain', 277),
#  ('flake', 277),
#  ('splunk', 276),
#  ('lisp', 275),
#  ('doxygen', 275),
#  ('non', 274),
#  ('edition', 274),
#  ('exercise', 274),
#  ('legacy', 274),
#  ('lstm', 273),
#  ('blog', 273),
#  ('load', 273),
#  ('type', 273),
#  ('popup', 272),
#  ('two', 272),
#  ('npm', 271),
#  ('distribution', 271),
#  ('end', 271),
#  ('split', 270),
#  ('product', 269),
#  ('work', 269),
#  ('cms', 269),
#  ('cv', 269),
#  ('coding', 269),
#  ('real', 269),
#  ('unix', 269),
#  ('change', 268),
#  ('bugs', 268),
#  ('ssd', 267),
#  ('access', 267),
#  ('usb', 267),
#  ('handler', 267),
#  ('jobs', 267),
#  ('inventory', 266),
#  ('syntax', 266),
#  ('questions', 266),
#  ('lane', 265),
#  ('timer', 265),
#  ('sensor', 265),
#  ('wordpress', 264),
#  ('ng', 264),
#  ('asset', 264),
#  ('dashboards', 264),
#  ('level', 264),
#  ('batch', 264),
#  ('power', 264),
#  ('remove', 263),
#  ('record', 263),
#  ('repository', 263),
#  ('kitchen', 262),
#  ('assembly', 262),
#  ('hp', 262),
#  ('reverse', 261),
#  ('traffic', 260),
#  ('graphql', 260),
#  ('pod', 259),
#  ('bt', 259),
#  ('addons', 259),
#  ('egg', 259),
#  ('response', 258),
#  ('social', 258),
#  ('labs', 258),
#  ('rule', 258),
#  ('ocr', 258),
#  ('formatter', 258),
#  ('front', 257),
#  ('flash', 257),
#  ('dump', 256),
#  ('hook', 256),
#  ('nets', 255),
#  ('account', 255),
#  ('ms', 255),
#  ('issues', 254),
#  ('aarch64', 254),
#  ('validate', 254),
#  ('query', 253),
#  ('pods', 253),
#  ('md5', 252),
#  ('interfaces', 252),
#  ('tag', 252),
#  ('f', 252),
#  ('pi', 251),
#  ('car', 251),
#  ('qa', 250),
#  ('cleanup', 250),
#  ('tiny', 249),
#  ('password', 249),
#  ('queries', 248),
#  ('networking', 248),
#  ('live', 248),
#  ('word', 247),
#  ('checkpoint', 247),
#  ('transport', 247),
#  ('science', 246),
#  ('nodejs', 246),
#  ('systems', 245),
#  ('math', 245),
#  ('feed', 245),
#  ('order', 244),
#  ('eclipse', 244),
#  ('unit', 244),
#  ('powershell', 243),
#  ('sqlite3', 242),
#  ('notify', 242),
#  ('antivirus', 242),
#  ('solution', 242),
#  ('operations', 241),
#  ('trace', 241),
#  ...]

# %% [markdown]
# ### testset 2.5.1(s)
# takes all 2.5 readme_clean extracted topics as set

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t5
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.1')
# Out:
# total repos 218378
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.1.pkl

# %%
ghd_exp['topics'] = ghd_exp['topics'].apply(lambda x: ' '.join(set(x)))

# %%
to_disk(ghd_exp, 't2.5.1s')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.1s.pkl

# %% [markdown]
# ### testset 2.5.2
# takes all 2.5 about extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t3 #+t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.2')
# Out:
# total repos 189698
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.2.pkl

# %% [markdown]
# ### testset 2.5.3
# takes all 2.5 tree extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t6
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.3')
# Out:
# total repos 221805
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.3.pkl

# %% [markdown]
# ### testset 2.5.4
# takes all 2.5 topics extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.4')
# Out:
# total repos 69323
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.4.pkl

# %% [markdown]
# ### testset 2.5.5
# takes all 2.5 languages extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t4
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.5')
# Out:
# total repos 194754
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.5.pkl

# %% [markdown]
# ### testset 2.5.6
# takes all 2.5 title extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t1
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.5.6')
# Out:
# total repos 134060
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.5.6.pkl

# %% [markdown]
# ## Testset 2.3 (Part of D_C2)
# The best performing 1 set was 1.2; so we do the same we did with 1.2 on readme and about
#
# we set a **min_thres** here, that means this topic has to be at least in 4 repos

# %%
topics_combined_full = []
min_thres = 4
for i in topic_counter.items():
    t = i[0]
    o = i[1]
    t = str(t)
    if t == 'nan':
        continue
    newt = preprocess_text(t, lem=True, do_composition=True)
    if newt not in topics_combined_full:
        if o >= min_thres:
            topics_combined_full+=newt

# %%
len(topics_combined_full)
# Out:
# 15491

# %%
len(set(topics_combined_full))
# Out:
# 14653

# %%
topics_combined_full = list(set(topics_combined_full))

# %%
topics_combined_full
# Out:
# ['cloudrun',
#  'angular8',
#  'communitydetection',
#  'hadoopecosystem',
#  'eventstream',
#  'icloud',
#  'securityautomation',
#  'rabbitmq',
#  'iac',
#  'confusionmatrix',
#  'rpi',
#  'circleci',
#  'warframe',
#  'awareness',
#  'fairness',
#  'cmake',
#  'antdesignvue',
#  'tooltip',
#  'audiosignalprocessing',
#  'sqlite3',
#  'lane',
#  'capybara',
#  'encryptionalgorithm',
#  'notificationcenter',
#  'contextualdata',
#  'loadtesting',
#  'buildautomation',
#  'java',
#  'gpuimage',
#  'idgenerator',
#  'cars',
#  'atomic',
#  'interpretablemachinelearning',
#  'snstopic',
#  'windows11',
#  'tendermint',
#  'postgres',
#  'nim',
#  'factorization',
#  'stockmarket',
#  'resourceconstrainedml',
#  'opentelemetrycollector',
#  'sdn',
#  'oidc',
#  'cctv',
#  'listen',
#  'dllinjector',
#  'menubar',
#  'dockersecurity',
#  'webaccessibility',
#  'datastreamprocessing',
#  'decryption',
#  'smt',
#  'codereview',
#  'metatrader',
#  'rs485',
#  'peoplecounter',
#  'godot4',
#  'securityscan',
#  'selfdrivingcarengineer',
#  'clahe',
#  'obfuscator',
#  'coroutinesandroid',
#  'rulebased',
#  'switzerland',
#  'apikey',
#  'vulnerabilityanalysis',
#  'azuread',
#  'husky',
#  'carthage',
#  'gamepad',
#  'compilers',
#  'covid19data',
#  'cosinesimilarity',
#  'tinyml',
#  'bedrockedition',
#  'semgrep',
#  'googledrive',
#  'azurekubernetesservices',
#  'imbalancedlearning',
#  'texttospeech',
#  'aistarterkit',
#  'm5stack',
#  'neat',
#  'ociimage',
#  'apriltag',
#  'gsm',
#  'rumor',
#  'udacitydeeplearning',
#  'paddlepaddle',
#  'lemmatizer',
#  'cyw9p62s143012evb01',
#  'studyplan',
#  'nashorn',
#  'redisai',
#  'fuzzer',
#  'interview',
#  'zshtheme',
#  'e2ee',
#  'callback',
#  'measurement',
#  'trojanrat',
#  'timeseriesanalysis',
#  'invoice',
#  'steganography',
#  'polly',
#  'jsonnet',
#  'privatelink',
#  'metasploitframework',
#  'res2net',
#  'paint',
#  'stomp',
#  'lyric',
#  'hana',
#  'garden',
#  'abac',
#  'chaostesting',
#  'servicelevelagreement',
#  'cloudapi',
#  'freeswitch',
#  'hci',
#  'informationhiding',
#  'multifactorauthentication',
#  'fraudprevention',
#  'webscraper',
#  'skyrim',
#  'mitreattack',
#  'v4l2',
#  'dehazing',
#  'microsoftgraph',
#  'industry',
#  'jq',
#  'geojson',
#  'googlecloudrun',
#  'probot',
#  'socks5',
#  'cvpr2021',
#  'blurdetection',
#  'zshplugins',
#  'playstore',
#  'webcam',
#  'mobilenet',
#  'prometheusoperator',
#  'nltk',
#  'proto',
#  'neurips2019',
#  'continuallearning',
#  'movierecommendation',
#  'phpstorm',
#  'equihash',
#  'diablo2',
#  'seismology',
#  'awesomeresources',
#  'oculus',
#  'regulations',
#  'rasa',
#  'axure',
#  'presto',
#  'plsql',
#  'hashicorpterraform',
#  'vaultclient',
#  'chatbot',
#  'packetcapture',
#  'bicep',
#  'coronavirusglobaloutbreak',
#  'dask',
#  'discord',
#  'minifilter',
#  'securitydatasetscanning',
#  'multithreaded',
#  'uci',
#  'fork',
#  'governmentdata',
#  'lamp',
#  'coronavirusdataset',
#  'devicedetector',
#  'kubernetescrd',
#  'fpsgame',
#  'gingonic',
#  'sentenceclassification',
#  'appdynamics',
#  'pythonlibrary',
#  'hibp',
#  'valorant',
#  'upx',
#  'taskrunner',
#  'coordination',
#  'onlineflow',
#  'socialdistancemonitoring',
#  'newsapi',
#  'ddosattacks',
#  'motionprediction',
#  'nanoporesequencing',
#  'azureadb2c',
#  'opsgenie',
#  'openapigenerator',
#  'jarvisai',
#  'public',
#  'dex',
#  'virtualmachines',
#  'ctimages',
#  'factory',
#  'hsvcolordetection',
#  'softwaredevelopment',
#  'signatures',
#  'dimensionalityreduction',
#  'onepage',
#  'eviltwin',
#  'gmail',
#  'mlkit',
#  'prismacloud',
#  'golangcli',
#  'jwk',
#  'svelte3',
#  'office365',
#  'payment',
#  'sagemakerstudio',
#  'multiprocess',
#  'livestream',
#  'slackapi',
#  'scenegraphgeneration',
#  'facealignment',
#  'tradfri',
#  'internetfreedom',
#  'energyconsumption',
#  'cnnforvisualrecognition',
#  'readability',
#  'garagedoor',
#  'occupancygridmap',
#  'switch',
#  'gadgets',
#  'carcounting',
#  'resnet34',
#  'karaoke',
#  'frauddetection',
#  'dbscan',
#  'encoderdecodermodel',
#  'music',
#  'annotationprocessing',
#  'conferences',
#  'dla',
#  'motionsensor',
#  'servlet',
#  'orm',
#  'ppo',
#  'grammarparser',
#  'machinelearning',
#  'sony',
#  'srt',
#  'broids',
#  'dataexfiltration',
#  'crdt',
#  'nvidiajetsonnano',
#  'vicuna',
#  'pid',
#  'timelapse',
#  'wns',
#  'cast',
#  'airplay',
#  'portability',
#  'ebay',
#  'portable',
#  'freelancer',
#  'esp8266arduino',
#  'uniqueid',
#  'awsorganizations',
#  'snowflaketwitter',
#  'kubernetesrbac',
#  'twsapi',
#  'predictivemaintenance',
#  'multicamera',
#  'ghas',
#  'psvita',
#  'notice',
#  'bigquery',
#  'azurevirtualnetworks',
#  'efficiency',
#  'offensivescripts',
#  'remix',
#  'sentence',
#  'rhythm',
#  'es2015',
#  'videoplayer',
#  'agricultureresearch',
#  'imagery',
#  'cpumonitoring',
#  'matlab',
#  'softskills',
#  'rstats',
#  'dockerimage',
#  'water',
#  'developers',
#  'chemistry',
#  'orchestration',
#  'jetsontx1',
#  'a4988steppermotordriver',
#  'twc',
#  'germany',
#  'elasticache',
#  'deeplink',
#  'raspberrypicamera',
#  'chef',
#  'vehicledetectionandtracking',
#  'githubpages',
#  'ggplot2',
#  'emailnotification',
#  'djangoadmin',
#  'reflectedxssvulnerabilities',
#  'blinkdetectionalgorithm',
#  'zlib',
#  'unrealengine5',
#  'rce',
#  'graphqlclient',
#  'p2p',
#  'ziglang',
#  'roi',
#  'bestpractice',
#  'dcgan',
#  'iterativedeepeningsearch',
#  'fileserver',
#  'mtcnnfacedetection',
#  'jetson',
#  'failover',
#  'pipe',
#  'paseto',
#  'adventure',
#  'malaysia',
#  'microbialgenomics',
#  'invest',
#  'springsecurityoauth2',
#  'topic',
#  'pycbc',
#  'torrenttracker',
#  'uptimerobot',
#  'automatedtrading',
#  'skincancer',
#  'tvm',
#  'activationfunctions',
#  'economics',
#  'summary',
#  'altcoin',
#  'ohmyzsh',
#  'fullstackwebdevelopment',
#  'unlimited',
#  'xrp',
#  'sentenceembeddings',
#  'epicreactdev',
#  'ban',
#  'icinga2',
#  'biomedicalapplications',
#  'messengerbot',
#  'wordembedding',
#  'programsynthesis',
#  'artisan',
#  'gitflow',
#  'terraformaws',
#  'pose',
#  'oss',
#  'frameworkagnostic',
#  'prestashopmodule',
#  'skeletonbasedactionrecognition',
#  'ctid',
#  'spv3',
#  'structuralvariation',
#  'artifactory',
#  'explainableartificialintelligence',
#  'quantitativefinance',
#  'bsdpuppetmodule',
#  'optimization',
#  'alignment',
#  'oldschoolrunescape',
#  'randomizer',
#  'androiddevelopment',
#  'geometry',
#  'fsharp',
#  'pnpm',
#  'osdetection',
#  'onewire',
#  'layui',
#  'languageclassification',
#  'workers',
#  'ansiblecollections',
#  'ipmi',
#  'passiveliveness',
#  'cascadeclassifier',
#  'waveletanalysis',
#  'barcodedetection',
#  'drift',
#  'napariplugin',
#  'azuresdk',
#  'awsssm',
#  'distanceestimationopencv',
#  'ciphersuites',
#  'colonoscopy',
#  'evaluationframework',
#  'pthreads',
#  'vulnerabilityscanners',
#  'symbols',
#  'ztfii',
#  'wordpressphplibrary',
#  'mtproto',
#  'modelicalibrary',
#  'citypersons',
#  'aerialrobotics',
#  'barcodescanner',
#  'azuremonitormetrics',
#  'opencore',
#  'salientobjectdetection',
#  'btrfs',
#  'noty',
#  'aop',
#  'jack',
#  'aespmacsiv',
#  'bbcode',
#  'apimonitoring',
#  'notesapp',
#  'wled',
#  'amazon',
#  'wine',
#  'ssdmobilenetv2',
#  'jni',
#  'ds',
#  'aaai2021',
#  'iepextendedbanters',
#  'satelliteimagery',
#  'hashingalgorithm',
#  'rawsockets',
#  'encrypt',
#  'crowdstrike',
#  'dbscanclustering',
#  'multer',
#  'influxdata',
#  'homeautomation',
#  'pupiltracking',
#  'compliance',
#  'soundboard',
#  'attacker',
#  'edi',
#  'bayesiannetworks',
#  'emergency',
#  'rectangle',
#  'malwaredataset',
#  'jpush',
#  'wow',
#  'milvus',
#  'cssframework',
#  'digitalimageprocessing',
#  'obstacleavoidance',
#  'currencyexchangerates',
#  'vuerouter',
#  'uicomponents',
#  'sqldatabase',
#  'userregistration',
#  'udp',
#  'transliteration',
#  'quantumalgorithms',
#  'actixweb',
#  'unitsofmeasure',
#  'aqara',
#  'faulttolerant',
#  'examples',
#  'sidebar',
#  'rnntensorflow',
#  'signlanguagerecognitionsystem',
#  'testnet',
#  'angularapplications',
#  'configmanagement',
#  'lowcodeframework',
#  'keras',
#  'cloudwatchevents',
#  'remoteshell',
#  'packertemplate',
#  'ekscluster',
#  'es7',
#  'serialization',
#  'awssqs',
#  'samd21',
#  'nexus',
#  'stressdetection',
#  'poseestimation',
#  'gameboycolor',
#  'faceimages',
#  'retinalfundusimages',
#  'aurora',
#  'minecraftmod',
#  'filemanager',
#  'readinglist',
#  'libbpf',
#  'emailvalidation',
#  'signaldetection',
#  'remoteadmintool',
#  'mediapipefacemesh',
#  'aspnet',
#  'npc',
#  'fakenewsdetection',
#  'anomalylocalization',
#  'opensetrecognition',
#  'arduinoplatform',
#  'notifier',
#  'secops',
#  'azurevirtualmachine',
#  'asterisk',
#  'rxjs',
#  'aerialimagedetection',
#  'forextrading',
#  'duplicatedetection',
#  'mvcframework',
#  'attackdetection',
#  'acousticscenes',
#  'automotive',
#  'cleaner',
#  'batterystatus',
#  'unixcommand',
#  'msbuild',
#  'devopspipeline',
#  'xps',
#  'glpi',
#  'c3d',
#  'secdevops',
#  'humancellatlas',
#  'enterprisearchitect',
#  'ansiblerole',
#  'openapispecification',
#  'pinia',
#  'fluid',
#  'finalyearproject',
#  'bzip2',
#  'deepconvolutionalnetworks',
#  'higherorderstatistics',
#  'webots',
#  'macosapp',
#  'toolset',
#  'vulnerabilityidentification',
#  'mae',
#  'dataaugmentation',
#  'detectanomalies',
#  'awstranscribe',
#  'position',
#  'antivm',
#  'weaklysupervisedobjectdetection',
#  'htmlparser',
#  'flutterplugin',
#  'datalineage',
#  'geospatialanalytics',
#  'qbus',
#  'threadpool',
#  'handlepermissionpopups',
#  'websocketserver',
#  'postagging',
#  'prophet',
#  'xarray',
#  'smtpserver',
#  'candlestickpatternsdetection',
#  'pbr',
#  'snps',
#  'tellodrone',
#  'codesigning',
#  'msi',
#  'siri',
#  'menu',
#  'intrusiondetection',
#  'basketball',
#  'optics',
#  'gateway',
#  'securityorchestration',
#  'telco',
#  'offlineflow',
#  'xception',
#  'dojo',
#  'fft',
#  'cost',
#  'opsec',
#  'googlehome',
#  'arfoundation',
#  'stenciljs',
#  'numberplaterecognition',
#  'jade',
#  'neptune',
#  'consensus',
#  'plasma',
#  'fun',
#  'azurestorageaccount',
#  'textpattern',
#  '2022',
#  'collegeproject',
#  'final',
#  'minerproxy',
#  'remoteaccess',
#  'production',
#  'tail',
#  'gpuacceleration',
#  'emacsinitialization',
#  'backpropagation',
#  'reverseshell',
#  'packetanalyser',
#  'interviewprep',
#  'p4',
#  'boto',
#  'ransac',
#  'wpasupplicant',
#  'nist80053',
#  'vnet',
#  'pubnub',
#  'automatic1111',
#  'track',
#  'windows7',
#  'push',
#  'sde',
#  'reliabilityengineering',
#  'linearalgebra',
#  'drone',
#  'breakpoint',
#  'camerax',
#  'atlas',
#  'vocabulary',
#  'parkingmanagement',
#  'stt',
#  'mp3',
#  'bitcoinpayment',
#  'sbtplugin',
#  'radiology',
#  'apollo',
#  'saml2',
#  'coinmarketcap',
#  'graphattentionnetworks',
#  'tokens',
#  'i3d',
#  'gpu',
#  'okhttp3',
#  'computervision',
#  'apptemplates',
#  'termux',
#  'code4ro',
#  'wearabledevices',
#  'hackthebox',
#  'chess',
#  'dataviz',
#  'wafdetection',
#  'firebaseauth',
#  'deepfakedetection',
#  'pytorchmodels',
#  'blackbox',
#  'snyk',
#  'qrs',
#  'alexavoiceservice',
#  'computerscienceeducation',
#  'raspberrypi3b',
#  'relay',
#  'capsulenetwork',
#  'hacktoberfest2022',
#  'stereomatching',
#  'httpproxy',
#  'hactoberfestaccepted',
#  'shufflenetv2',
#  'servicenowapi',
#  'cip',
#  'markerless',
#  'csharplibrary',
#  'binpacking',
#  'remoteaccesstrojan',
#  'dvwa',
#  'bamfiles',
#  'buildpacks',
#  'vrchattool',
#  'pymongo',
#  'deeplearning',
#  'scientificpuppetmodule',
#  'facemask',
#  'indonesia',
#  'pf',
#  'annotations',
#  'packet',
#  'biosignals',
#  'daq',
#  'anilist',
#  'saliencymaps',
#  'yoloxnano',
#  'prompttoolkit',
#  'ethersjs',
#  'reactdashboard',
#  'mailbox',
#  'lidarmeasurements',
#  'lab',
#  'hackernews',
#  'adc',
#  'fusefilesystem',
#  'zap',
#  'tflearn',
#  'retropie',
#  'carbon',
#  'co2sensor',
#  'substrate',
#  'wandb',
#  'anomalies',
#  'intersystemsiris',
#  'delphi',
#  'country',
#  'rnaseq',
#  'tf2',
#  'llms',
#  'floatingwindow',
#  'china',
#  'magisk',
#  'workmanager',
#  'cgal',
#  'racket',
#  'smali',
#  'erlang',
#  'atompackage',
#  'tcpproxy',
#  'discordrat',
#  'computationalsocialscience',
#  'gitpod',
#  'bcrypt',
#  'cypress',
#  'dennycheatsheets',
#  'parallax',
#  'pathfinder',
#  'editorjs',
#  'tvos',
#  'googleteachablemachine',
#  'pacbio',
#  'renovate',
#  'androiddevelopers',
#  'nvme',
#  'patients',
#  'stealerbuilder',
#  'siemens',
#  'idm',
#  'kubeflow',
#  'repositorymanagement',
#  'sleepanalysis',
#  'directx',
#  'csf',
#  'malwarepackers',
#  'zabbixtemplates',
#  'apm',
#  'multisig',
#  'pmm',
#  'facedetectionrealtime',
#  'socialdistancing',
#  'vulnerabilityresearch',
#  'freak',
#  'quake',
#  'nox',
#  'carve',
#  'storageservice',
#  'loss',
#  'ransomwarebuilder',
#  'sequencealignment',
#  'powersystems',
#  'avx',
#  'paper',
#  'ipaddress',
#  'pulumi',
#  'steal',
#  'store',
#  'unity3dgames',
#  'uacbypass',
#  'iclr2020',
#  'b2b',
#  'iframe',
#  'webui',
#  'powerconversion',
#  'bioconductor',
#  'todomvc',
#  'rollup',
#  'swaggerspec',
#  'vuejs',
#  'portfoliosite',
#  'loremipsum',
#  'influxdb',
#  'seanpm2001',
#  'stockdata',
#  'videos',
#  'apache',
#  'openvpnserver',
#  'lowlightvision',
#  'drive',
#  'scam',
#  'pagerank',
#  'tensorflowgpu',
#  'twemoji',
#  'semeval',
#  'eve',
#  'nginxserver',
#  'svmclassifier',
#  'bugbountyhunting',
#  'selection',
#  'businessprocessmanagement',
#  'osm',
#  'serviceworker',
#  'antispoofing',
#  'swift',
#  'tenant',
#  'quantummachinelearning',
#  'recruit',
#  'wikipediaapi',
#  'bugbountytips',
#  'prisma',
#  'prisma2',
#  'malicious',
#  'neurosciencemethods',
#  'sqli',
#  'ethicalhacking',
#  'paddlelite',
#  'lof',
#  'montecarlosimulation',
#  'trafficlights',
#  'swc',
#  'androidstudio',
#  'teensy41',
#  'vectors',
#  'dns',
#  'telegramapi',
#  'next',
#  'dino',
#  'summarization',
#  'securityaudit',
#  'cyberattack',
#  '125khz',
#  'batchnormalization',
#  'cbir',
#  'fileformat',
#  'googlekubernetesengine',
#  'crawlingpython',
#  'free',
#  'machinelearningprojects',
#  'buildtools',
#  'tesla',
#  'mpegts',
#  'timers',
#  'altair',
#  'disasterrecovery',
#  'bookmarklets',
#  'breakout',
#  'anticheat',
#  'dataextraction',
#  'deepnetworks',
#  'icon',
#  'electra',
#  'mongodbdatabase',
#  'hibernate',
#  'ethash',
#  'ecgqrsdetection',
#  'modpack',
#  'bim',
#  'drug',
#  'cube',
#  'whisper',
#  'agegenderestimation',
#  'opensea',
#  'serverlessfunctions',
#  'aceeditor',
#  'newsletter',
#  'nikto',
#  'mybatis',
#  'pcapparser',
#  'gas',
#  'sveltecomponents',
#  'zbar',
#  'administration',
#  'wizardsteps',
#  'firmwaretools',
#  'fat32',
#  'sprites',
#  'ipsymcon',
#  'devicedetection',
#  'wrk',
#  'reidentification',
#  'facepose',
#  'wifinetwork',
#  'bestof',
#  'sol',
#  'neurips2021',
#  'breastcancerprediction',
#  'space',
#  'firsttimers',
#  'monitoringapplication',
#  'springcloudeureka',
#  'draw',
#  'dataqualitymonitoring',
#  'speechprocessing',
#  'eagle',
#  'iforest',
#  'firstroboticscompetition',
#  'fullstack',
#  'modularity',
#  'dfu',
#  'diskusage',
#  'pointcloudsegmentation',
#  'multidomainlearning',
#  'seriesdata',
#  'awsemr',
#  'amsi',
#  'coroutines',
#  'shellcodeinjector',
#  'glass',
#  'framerate',
#  'generativeart',
#  'phaserjs',
#  'firmwareupdate',
#  'gpt2',
#  'cognitiveservices',
#  'asn',
#  'dbi',
#  'highdimensionaldata',
#  'mse',
#  'idle',
#  'pyautogui',
#  'spacyextension',
#  'stockprices',
#  'cli',
#  'websitechangemonitor',
#  'lightgbm',
#  'ioslibrary',
#  'political',
#  'rnn',
#  'dnsresolver',
#  'course',
#  'galaxy',
#  'pcidss',
#  'sidechannel',
#  'pigo',
#  'tensorrtinference',
#  'sslpinning',
#  'koreannlp',
#  'plutus',
#  'rack',
#  'phpcsstandard',
#  'nodeexporter',
#  'postgraphile',
#  'mq',
#  'soar',
#  'rtl',
#  'xpdeveloper',
#  'gprs',
#  'facebook',
#  'passwordstrength',
#  'smokedetection',
#  'napari',
#  'btree',
#  'swiftlibrary',
#  'aggressorscripts',
#  'asm',
#  'coredns',
#  'androiddialog',
#  'prostatecancer',
#  'pathplanning',
#  'live',
#  'meltdown',
#  'tuner',
#  'wechatminiprogram',
#  'indoor',
#  'zkp',
#  'camelyon16',
#  'uialertview',
#  'sketchapp',
#  'flyway',
#  'semisupervisedlearning',
#  'handshake',
#  'minimalist',
#  'standards',
#  'v2ray',
#  'metagenomics',
#  'mongodbatlas',
#  'components',
#  'quasar',
#  'figmaplugin',
#  'employee',
#  'pwa',
#  'autoit',
#  'lzma',
#  'jwtauth',
#  'texttoimage',
#  'telemetrycollection',
#  'apiclient',
#  'vbaexcel',
#  'ubc',
#  'htmltemplate',
#  'cve202145046',
#  'timeseriesforecasting',
#  'pythontelegrambot',
#  'openra',
#  'flaskdashboard',
#  'cam',
#  'operators',
#  'sharedpreferences',
#  'opendata',
#  'scannet',
#  'work',
#  'powershellmodule',
#  'spatiotemporalanalysis',
#  'fortran',
#  'featurevectors',
#  'rundeck',
#  'codeinjection',
#  'particlefilter',
#  'imagematching',
#  'facebookmessenger',
#  ...]

# %%
def myclnfunction(x):
    return preprocess_text(x, lem=True, token_list = topics_combined_full, do_composition=True)

# %%
t1 = github_data_df['name'].apply(lambda x: myclnfunction(x))

# %%
t1_cnt = Counter(t1.explode())
t1_cnt.most_common()
# Out:
# [(nan, 193576),
#  ('js', 873),
#  ('microsoft', 482),
#  ('io', 343),
#  ('github', 310),
#  ('ibm', 206),
#  ('jquery', 194),
#  ('azure', 186),
#  ('linuxserver', 172),
#  ('google', 165),
#  ('pytorch', 154),
#  ('facedetection', 151),
#  ('uboot', 147),
#  ('net', 138),
#  ('awesome', 129),
#  ('awesomepython', 117),
#  ('objectdetection', 115),
#  ('intel', 114),
#  ('googlecloudplatform', 111),
#  ('publicapis', 111),
#  ('iobroker', 107),
#  ('anomalydetection', 100),
#  ('apache', 98),
#  ('awesomemachinelearning', 96),
#  ('newrelic', 88),
#  ('aws', 86),
#  ('1', 84),
#  ('jenkinsci', 83),
#  ('project', 78),
#  ('machinelearning', 77),
#  ('mozilla', 74),
#  ('facerecognition', 74),
#  ('computervision', 71),
#  ('creditcardfrauddetection', 68),
#  ('openpilot', 68),
#  ('fakenewsdetection', 67),
#  ('vim', 66),
#  ('core', 65),
#  ('deeplearning', 64),
#  ('prometheus', 64),
#  ('facemaskdetection', 63),
#  ('alert', 62),
#  ('docker', 59),
#  ('dotfiles', 58),
#  ('ai', 58),
#  ('splunk', 58),
#  ('infineon', 57),
#  ('seanpm2001', 57),
#  ('oracle', 55),
#  ('homeassistantconfig', 55),
#  ('docs', 54),
#  ('bootstrap', 53),
#  ('paper', 53),
#  ('openshift', 53),
#  ('awesomestars', 52),
#  ('grafana', 51),
#  ('tool', 50),
#  ('shopify', 50),
#  ('resources', 50),
#  ('tensorflow', 49),
#  ('codacy', 46),
#  ('yararules', 46),
#  ('script', 45),
#  ('darknet', 43),
#  ('frauddetection', 43),
#  ('tutorials', 43),
#  ('vehicledetection', 43),
#  ('sh', 42),
#  ('sparkfun', 41),
#  ('cnn', 41),
#  ('misp', 41),
#  ('monitor', 40),
#  ('lanedetection', 39),
#  ('opencv', 38),
#  ('falldetection', 38),
#  ('mmdetection', 38),
#  ('blog', 37),
#  ('ids', 37),
#  ('examples', 37),
#  ('datadog', 37),
#  ('owasp', 37),
#  ('javascript', 36),
#  ('codeofconduct', 36),
#  ('python', 36),
#  ('udacity', 36),
#  ('algorithms', 36),
#  ('machinelearningtutorials', 36),
#  ('paloaltonetworks', 35),
#  ('salesforce', 35),
#  ('x', 35),
#  ('transformers', 35),
#  ('model', 34),
#  ('note', 34),
#  ('yara', 34),
#  ('pedestriandetection', 34),
#  ('emotiondetection', 34),
#  ('adafruit', 34),
#  ('yolov3', 33),
#  ('crowdstrike', 33),
#  ('nasa', 32),
#  ('threathunting', 32),
#  ('security', 32),
#  ('learn', 32),
#  ('community', 32),
#  ('detection', 32),
#  ('adobe', 32),
#  ('api', 31),
#  ('osquery', 31),
#  ('aliyun', 31),
#  ('communitydetection', 31),
#  ('azuread', 30),
#  ('elastic', 30),
#  ('openmmlab', 30),
#  ('6', 30),
#  ('edgedetection', 30),
#  ('marlin', 30),
#  ('mono', 29),
#  ('react', 29),
#  ('mitre', 29),
#  ('systemdesigninterview', 29),
#  ('ctftools', 29),
#  ('hashicorp', 29),
#  ('sap', 29),
#  ('app', 28),
#  ('yolov5', 28),
#  ('apns', 28),
#  ('backbone', 28),
#  ('datascience', 28),
#  ('log', 28),
#  ('homeassistant', 28),
#  ('git', 28),
#  ('javascript30', 28),
#  ('facedetect', 28),
#  ('deepfakedetection', 28),
#  ('demo', 28),
#  ('nvim', 28),
#  ('book', 27),
#  ('vision', 27),
#  ('ui', 27),
#  ('trafficsigndetection', 27),
#  ('cloudfoundry', 27),
#  ('fasterrcnn', 26),
#  ('autoware', 26),
#  ('yahoo', 26),
#  ('covid19', 26),
#  ('roboflow', 25),
#  ('documentation', 25),
#  ('game', 25),
#  ('html5boilerplate', 25),
#  ('hackingtool', 25),
#  ('leetcode', 25),
#  ('uptime', 25),
#  ('swift', 25),
#  ('ips', 25),
#  ('nsm', 24),
#  ('selfdrivingcar', 24),
#  ('mapbox', 24),
#  ('apollo', 24),
#  ('maskdetection', 24),
#  ('imageprocessing', 24),
#  ('alibaba', 24),
#  ('dialog', 24),
#  ('fiware', 24),
#  ('esri', 24),
#  ('vmware', 24),
#  ('springboot', 23),
#  ('data', 23),
#  ('plugins', 23),
#  ('php', 23),
#  ('intrusiondetectionsystem', 23),
#  ('dev', 23),
#  ('xamarin', 23),
#  ('web', 23),
#  ('guardian', 23),
#  ('ipinfo', 23),
#  ('reveal', 23),
#  ('openra', 23),
#  ('android', 22),
#  ('cran', 22),
#  ('cv', 22),
#  ('website', 22),
#  ('framework', 22),
#  ('r', 22),
#  ('yelp', 22),
#  ('firedetection', 22),
#  ('openpose', 22),
#  ('mediapipe', 22),
#  ('designpatternsforhumans', 22),
#  ('betaflight', 22),
#  ('star', 22),
#  ('sqlmap', 22),
#  ('snyk', 22),
#  ('empire', 22),
#  ('ray', 21),
#  ('diabeticretinopathydetection', 21),
#  ('wireshark', 21),
#  ('dynatrace', 21),
#  ('antivirus', 21),
#  ('boot', 21),
#  ('serverless', 21),
#  ('facemaskdetector', 21),
#  ('carbonblack', 21),
#  ('bsc', 21),
#  ('breastcancerdetection', 21),
#  ('potholedetection', 21),
#  ('airbnb', 21),
#  ('upptime', 21),
#  ('status', 21),
#  ('mtcnn', 21),
#  ('phpflasher', 21),
#  ('espressif', 20),
#  ('cpuminer', 20),
#  ('node', 20),
#  ('nvidia', 20),
#  ('whitepaper', 20),
#  ('sensuplugins', 20),
#  ('classifier', 20),
#  ('cli', 20),
#  ('facedetector', 20),
#  ('devsecops', 20),
#  ('gpuimage', 20),
#  ('ctf', 20),
#  ('zeek', 20),
#  ('vad', 20),
#  ('discord', 20),
#  ('motiondetection', 20),
#  ('sample', 20),
#  ('drowsinessdetection', 20),
#  ('cloudflare', 19),
#  ('emacs', 19),
#  ('resume', 19),
#  ('box', 19),
#  ('malwaredetection', 19),
#  ('malware', 19),
#  ('highlight', 19),
#  ('redis', 19),
#  ('dotnet', 19),
#  ('realtimeobjectdetection', 19),
#  ('plugin', 19),
#  ('tencent', 19),
#  ('socket', 19),
#  ('detectron2', 19),
#  ('server', 19),
#  ('list', 19),
#  ('arduino', 19),
#  ('heroku', 18),
#  ('plantdiseasedetection', 18),
#  ('matlabdeeplearning', 18),
#  ('dashboard', 18),
#  ('yolo', 18),
#  ('head', 18),
#  ('chess', 18),
#  ('lungcancerdetection', 18),
#  ('gamehacking', 18),
#  ('javascriptinterviewquestions', 18),
#  ('jetbrains', 18),
#  ('openstack', 18),
#  ('datasets', 18),
#  ('whisper', 18),
#  ('ctfwriteups', 18),
#  ('face', 18),
#  ('detectron', 18),
#  ('wazuh', 18),
#  ('licenseplatedetection', 18),
#  ('engine', 17),
#  ('twitter', 17),
#  ('ocr', 17),
#  ('magento2', 17),
#  ('textdetection', 17),
#  ('toolbox', 17),
#  ('twilio', 17),
#  ('5', 17),
#  ('pagerduty', 17),
#  ('portfolio', 17),
#  ('bind', 17),
#  ('objectdetector', 17),
#  ('ssd', 17),
#  ('nlp', 17),
#  ('cyberark', 17),
#  ('cybersecurity', 17),
#  ('presentations', 17),
#  ('retroarch', 17),
#  ('notify', 16),
#  ('ebay', 16),
#  ('springcloud', 16),
#  ('ibmcloud', 16),
#  ('target', 16),
#  ('validator', 16),
#  ('istio', 16),
#  ('covid19detection', 16),
#  ('fileuploader', 16),
#  ('alerta', 16),
#  ('reverseengineering', 16),
#  ('barcodescanner', 16),
#  ('ts', 16),
#  ('lidarobstacledetection', 16),
#  ('notebooks', 16),
#  ('openface', 16),
#  ('paddlepaddle', 16),
#  ('devops', 16),
#  ('languagedetection', 16),
#  ('go', 16),
#  ('jfrog', 16),
#  ('netflix', 16),
#  ('wallet', 16),
#  ('aspnetcore', 16),
#  ('workshop', 16),
#  ('readinglist', 16),
#  ('phonegap', 16),
#  ('xilinx', 16),
#  ('nicehash', 16),
#  ('tensorflow2', 16),
#  ('kubernetes', 16),
#  ('virustotal', 16),
#  ('c', 16),
#  ('facebook', 16),
#  ('ml', 16),
#  ('service', 16),
#  ('facenet', 16),
#  ('androidmalwaredetection', 16),
#  ('ansible', 15),
#  ('dell', 15),
#  ('claranet', 15),
#  ('ftcrobotcontroller', 15),
#  ('siemens', 15),
#  ('outlierdetection', 15),
#  ('ios', 15),
#  ('link', 15),
#  ('nodejs', 15),
#  ('router', 15),
#  ('braintumordetection', 15),
#  ('flash', 15),
#  ('json', 15),
#  ('algolia', 15),
#  ('thehiveproject', 15),
#  ('fingerprintjs', 15),
#  ('network', 15),
#  ('avast', 15),
#  ('pubnub', 15),
#  ('kde', 15),
#  ('driverdrowsinessdetection', 15),
#  ('licenseplaterecognition', 15),
#  ('threatintel', 15),
#  ('appdynamics', 15),
#  ('handdetection', 15),
#  ('suse', 15),
#  ('openhab', 15),
#  ('autogpt', 15),
#  ('auth0', 15),
#  ('pentesttools', 15),
#  ('thesis', 15),
#  ('bcc', 15),
#  ('talk', 15),
#  ('sgminer', 15),
#  ('networkintrusiondetection', 15),
#  ('agent', 15),
#  ('dart', 15),
#  ('sherlock', 15),
#  ('sumologic', 15),
#  ('defectdetection', 15),
#  ('influxdata', 15),
#  ('kong', 14),
#  ('opendistroforelasticsearch', 14),
#  ('hashids', 14),
#  ('callforcode', 14),
#  ('watchdog', 14),
#  ('tictactoe', 14),
#  ('client', 14),
#  ('leaflet', 14),
#  ('yolact', 14),
#  ('gensim', 14),
#  ('base', 14),
#  ('paperreading', 14),
#  ('advancedsecurity', 14),
#  ('competitiveprogramming', 14),
#  ('nextcloud', 14),
#  ('image', 14),
#  ('bitcoin', 14),
#  ('spotify', 14),
#  ('sarcasmdetection', 14),
#  ('linkedin', 14),
#  ('magisk', 14),
#  ('sdk', 14),
#  ('100daysofcode', 14),
#  ('zoneminder', 14),
#  ('armadito', 14),
#  ('emotionrecognition', 14),
#  ('snap', 14),
#  ('spamdetection', 14),
#  ('bugbounty', 14),
#  ('async', 14),
#  ('home', 14),
#  ('tc39', 14),
#  ('code', 14),
#  ('logger', 14),
#  ('frontend', 14),
#  ('percona', 14),
#  ('infrastructure', 14),
#  ('form', 14),
#  ('opsgenie', 14),
#  ('jarvis', 13),
#  ('dataset', 13),
#  ('phishingdetection', 13),
#  ('tendermint', 13),
#  ('alertmanager', 13),
#  ('eclipse', 13),
#  ('asterisk', 13),
#  ('computerscience', 13),
#  ('sweetalert', 13),
#  ('labelimg', 13),
#  ('machine1337', 13),
#  ('changedetection', 13),
#  ('track', 13),
#  ('nagiosplugins', 13),
#  ('rollbar', 13),
#  ('hrnet', 13),
#  ('gmail', 13),
#  ('sensu', 13),
#  ('samsung', 13),
#  ('akamai', 13),
#  ('dubbo', 13),
#  ('systemdesign', 13),
#  ('motiondetector', 13),
#  ('loremipsum', 13),
#  ('ipset', 13),
#  ('secp256k1', 13),
#  ('hatespeechdetection', 13),
#  ('fastly', 13),
#  ('platform', 13),
#  ('charmve', 13),
#  ('train', 12),
#  ('uber', 12),
#  ('maskrcnn', 12),
#  ('ip2location', 12),
#  ('lua', 12),
#  ('rcnn', 12),
#  ('chameleon', 12),
#  ('azuresentinel', 12),
#  ('hawkular', 12),
#  ('rule', 12),
#  ('pusher', 12),
#  ('intro', 12),
#  ('phoenix', 12),
#  ('ring', 12),
#  ('signalfx', 12),
#  ('libretro', 12),
#  ('templates', 12),
#  ('openeew', 12),
#  ('clamav', 12),
#  ('browser', 12),
#  ('cilium', 12),
#  ('apple', 12),
#  ('botnetdetection', 12),
#  ('anomaly', 12),
#  ('digitalocean', 12),
#  ('cacti', 12),
#  ('rest', 12),
#  ('nebula', 12),
#  ('watchtower', 12),
#  ('caffe', 12),
#  ('datascienceportfolio', 12),
#  ('ethereum', 12),
#  ('uploadcare', 12),
#  ('smarthome', 12),
#  ('ransomware', 12),
#  ('cat', 12),
#  ('blockchain', 12),
#  ('forum', 12),
#  ('smoke', 12),
#  ('events', 12),
#  ('pneumoniadetection', 12),
#  ('shipdetection', 12),
#  ('imageforgerydetection', 12),
#  ('handbook', 12),
#  ('objectdetectionandtracking', 12),
#  ('mpv', 12),
#  ('course', 12),
#  ('slide', 12),
#  ('retinanet', 12),
#  ('reactnativecomponent', 11),
#  ('airflow', 11),
#  ('ace', 11),
#  ('iris', 11),
#  ('cookieconsent', 11),
#  ('intrusiondetection', 11),
#  ('weather', 11),
#  ('redalert', 11),
#  ('afl', 11),
#  ('wiki', 11),
#  ('sysmonconfig', 11),
#  ('cs231n', 11),
#  ('incidentresponse', 11),
#  ('facialexpressionrecognition', 11),
#  ('documentscanner', 11),
#  ('objecttracking', 11),
#  ('chat', 11),
#  ('timeseriesanomalydetection', 11),
#  ('sophos', 11),
#  ('hack', 11),
#  ('databricksindustrysolutions', 11),
#  ('timer', 11),
#  ('flow', 11),
#  ('coinbase', 11),
#  ('ansiblecollections', 11),
#  ('wordpress', 11),
#  ('jamf', 11),
#  ('homelab', 11),
#  ('redteam', 11),
#  ('aircrackng', 11),
#  ('bot', 11),
#  ('gnosis', 11),
#  ('openvinotoolkit', 11),
#  ('read', 11),
#  ('java', 11),
#  ('cheatsheets', 11),
#  ('ultralytics', 11),
#  ('crackdetection', 11),
#  ('kubesphere', 11),
#  ('alerter', 11),
#  ('imagestitching', 11),
#  ('treblle', 11),
#  ('rook', 11),
#  ('webviewjavascriptbridge', 11),
#  ('research', 11),
#  ('public', 11),
#  ('feature', 11),
#  ('toolkit', 11),
#  ('forensics', 11),
#  ('osx', 11),
#  ('example', 11),
#  ('colordetection', 11),
#  ('malariadetection', 11),
#  ('helmetdetection', 11),
#  ('3dobjectdetection', 11),
#  ('swaggerui', 11),
#  ('ncnn', 11),
#  ('pacman', 11),
#  ('ipstack', 11),
#  ('store', 11),
#  ('meraki', 11),
#  ('catalyst', 11),
#  ('transferlearning', 11),
#  ('ripple', 11),
#  ('blurdetection', 11),
#  ('threatintelligence', 11),
#  ('line', 11),
#  ('violencedetection', 11),
#  ('cloudera', 10),
#  ('hunt', 10),
#  ('ahk', 10),
#  ('dropbox', 10),
#  ('cardetection', 10),
#  ('mobilenetv2', 10),
#  ('lighthouse', 10),
#  ('mobiledetect', 10),
#  ('toast', 10),
#  ('mitreattack', 10),
#  ('nfcore', 10),
#  ('edge', 10),
#  ('backend', 10),
#  ('googlecoral', 10),
#  ('paddleocr', 10),
#  ('es6', 10),
#  ('nanodet', 10),
#  ('computerpointercontroller', 10),
#  ('camera', 10),
#  ('q', 10),
#  ('mattermost', 10),
#  ('browserdetection', 10),
#  ('insightface', 10),
#  ('keylogger', 10),
#  ('100daysofmlcode', 10),
#  ('angular', 10),
#  ('crypto', 10),
#  ('heimdall', 10),
#  ('i18next', 10),
#  ('bookmarks', 10),
#  ('vehicledetectionandtracking', 10),
#  ('raspberrypi', 10),
#  ('interview', 10),
#  ('device', 10),
#  ('cloud', 10),
#  ('mongodb', 10),
#  ('capstone', 10),
#  ('pulse', 10),
#  ('red', 10),
#  ('lab', 10),
#  ('openwisp', 10),
#  ('tutorial', 10),
#  ('clip', 10),
#  ('netdata', 10),
#  ('thefatrat', 10),
#  ('package', 10),
#  ('cs50', 10),
#  ('sift', 10),
#  ('swintransformer', 10),
#  ('nemo', 10),
#  ('cncf', 10),
#  ('utils', 10),
#  ('nmap', 10),
#  ('pythonprojects', 10),
#  ('info', 10),
#  ('map', 10),
#  ('loki', 10),
#  ('qrcode', 10),
#  ('huggingface', 10),
#  ('console', 9),
#  ('netcore', 9),
#  ('detect', 9),
#  ('bootstrap4', 9),
#  ('vehicletracking', 9),
#  ('spec', 9),
#  ('rocketmq', 9),
#  ('cheatsheet', 9),
#  ('rail', 9),
#  ('cvat', 9),
#  ('sleuthkit', 9),
#  ('push', 9),
#  ('maliciousurldetection', 9),
#  ('pycaret', 9),
#  ('voiceactivitydetection', 9),
#  ('athena', 9),
#  ('trafficlightdetection', 9),
#  ('realtimefacedetection', 9),
#  ('roadmap', 9),
#  ('glfw', 9),
#  ('sigma', 9),
#  ('util', 9),
#  ('slack', 9),
#  ('writeups', 9),
#  ('forcedotcom', 9),
#  ('knowledgebase', 9),
#  ('protobuf', 9),
#  ('godaddy', 9),
#  ('maskdetector', 9),
#  ('tasmota', 9),
#  ('mr', 9),
#  ('openapigenerator', 9),
#  ('h2oai', 9),
#  ('aruco', 9),
#  ('predictivemaintenance', 9),
#  ('asp', 9),
#  ('hassioaddons', 9),
#  ('meta', 9),
#  ('iossdk', 9),
#  ('test', 9),
#  ('persondetection', 9),
#  ('silverstripe', 9),
#  ('eosio', 9),
#  ('markdown', 9),
#  ('modelzoo', 9),
#  ('ossec', 9),
#  ('efficientdet', 9),
#  ('ncbi', 9),
#  ('selfdrivingcars', 9),
#  ('tuya', 9),
#  ('consul', 9),
#  ('guide', 9),
#  ('mvc', 9),
#  ('elastalert', 9),
#  ('pipeline', 9),
#  ('vonage', 9),
#  ('component', 9),
#  ('collision', 9),
#  ('request', 9),
#  ('w3c', 9),
#  ('hermes', 9),
#  ('ksuid', 9),
#  ('xss', 9),
#  ('utilities', 9),
#  ('exploit', 9),
#  ('syntaxtree', 9),
#  ('east', 9),
#  ('fast', 9),
#  ('elasticsearch', 9),
#  ('playground', 9),
#  ('gesturedetection', 9),
#  ('vault', 9),
#  ('system', 9),
#  ('openai', 9),
#  ('http', 9),
#  ('article', 9),
#  ('ipsum', 9),
#  ('roaddetection', 9),
#  ('devise', 9),
#  ('detections', 9),
#  ('snippets', 9),
#  ('facialdetection', 9),
#  ('firebase', 9),
#  ('forge', 9),
#  ('polkadot', 9),
#  ('apigee', 9),
#  ('ideas', 9),
#  ('hackerrank', 9),
#  ('stakater', 9),
#  ('tail', 9),
#  ('ecommerce', 9),
#  ('icinga', 9),
#  ('lazyload', 8),
#  ('download', 8),
#  ('stellar', 8),
#  ('mailserver', 8),
#  ('googletranslateapi', 8),
#  ('dfir', 8),
#  ('modsecurity', 8),
#  ('changepointdetection', 8),
#  ('loginradius', 8),
#  ('powershell', 8),
#  ('next', 8),
#  ('oscp', 8),
#  ('deeplearningpapers', 8),
#  ('opensuse', 8),
#  ('history', 8),
#  ('kerasretinanet', 8),
#  ('okta', 8),
#  ('facialrecognition', 8),
#  ('pytorchyolov3', 8),
#  ('styleguide', 8),
#  ('finalproject', 8),
#  ('explorer', 8),
#  ('craft', 8),
#  ('domoticz', 8),
#  ('homeassistantconfiguration', 8),
#  ('quic', 8),
#  ('bitshares', 8),
#  ('falcon', 8),
#  ('amphp', 8),
#  ('ctpn', 8),
#  ('openzeppelin', 8),
#  ('diseasedetection', 8),
#  ('facelivenessdetection', 8),
#  ('codeigniter', 8),
#  ('awesomelist', 8),
#  ('cloudinary', 8),
#  ('todo', 8),
#  ('survey', 8),
#  ('machinelearningcoursera', 8),
#  ('prism', 8),
#  ('iot', 8),
#  ('worker', 8),
#  ('nifi', 8),
#  ('slim', 8),
#  ('hls', 8),
#  ('unity', 8),
#  ('bridge', 8),
#  ('detectlanguage', 8),
#  ('jpush', 8),
#  ('piratestealer', 8),
#  ('ghost', 8),
#  ('eureka', 8),
#  ('phpcompatibility', 8),
#  ('faq', 8),
#  ('ipscanner', 8),
#  ('linux', 8),
#  ('riscv', 8),
#  ('hackintosh', 8),
#  ('weatherapp', 8),
#  ('apriltag', 8),
#  ('mtcnnpytorch', 8),
#  ('italia', 8),
#  ('100daysofpython', 8),
#  ('gettingstarted', 8),
#  ('pagerank', 8),
#  ('axios', 8),
#  ('deepface', 8),
#  ('phpmailer', 8),
#  ('weatherstation', 8),
#  ('mobile', 8),
#  ('zappa', 8),
#  ('guard', 8),
#  ('pygame', 8),
#  ('metrics', 8),
#  ('volatility', 8),
#  ('alienvaultotx', 8),
#  ('components', 8),
#  ('facerecognizer', 8),
#  ('tensorflowobjectdetection', 8),
#  ('miscreant', 8),
#  ('phd', 8),
#  ('iocs', 8),
#  ('cancerdetection', 8),
#  ('labelme', 8),
#  ('pitchdetection', 8),
#  ('sensor', 8),
#  ('meteor', 8),
#  ('machinelearningprojects', 8),
#  ('graph', 8),
#  ('ovh', 8),
#  ('puppeteer', 8),
#  ('swipe', 8),
#  ('forensicanalysis', 8),
#  ('paddledetection', 8),
#  ('twittersentimentanalysis', 8),
#  ('library', 8),
#  ('document', 8),
#  ('paperlist', 8),
#  ('rancher', 8),
#  ('capstoneproject', 8),
#  ('make', 8),
#  ('focalloss', 8),
#  ('microsoftgraph', 8),
#  ('runc', 8),
#  ('stealth', 8),
#  ('digitalimageprocessing', 8),
#  ('lyft', 8),
#  ('translate', 8),
#  ('fasterr', 8),
#  ('suricata', 8),
#  ('asteroids', 8),
#  ('deeplearningspecialization', 8),
#  ('timeline', 8),
#  ('prometheusoperator', 8),
#  ('citrix', 8),
#  ('cisco', 8),
#  ('shapedetection', 8),
#  ('facemask', 8),
#  ('dojo', 8),
#  ('css', 8),
#  ('notifier', 8),
#  ('faceapi', 8),
#  ('imageforensics', 8),
#  ('dosbox', 8),
#  ('maxmind', 8),
#  ('rpi', 8),
#  ('wolfssl', 8),
#  ('livenessdetection', 7),
#  ('mobilenetssd', 7),
#  ('webview', 7),
#  ('orbit', 7),
#  ('algorand', 7),
#  ('alfred', 7),
#  ('detectionrules', 7),
#  ('facerecognitionattendancesystem', 7),
#  ('atlas', 7),
#  ('echo', 7),
#  ('bro', 7),
#  ('anpr', 7),
#  ('tf', 7),
#  ('movenet', 7),
#  ('peoplecounter', 7),
#  ('handgesturerecognition', 7),
#  ('cordova', 7),
#  ('creditcardfraud', 7),
#  ('devicedetection', 7),
#  ('finalyearproject', 7),
#  ('reference', 7),
#  ('redash', 7),
#  ('modal', 7),
#  ('synapse', 7),
#  ('theme', 7),
#  ('ailframework', 7),
#  ('alpr', 7),
#  ('mmsegmentation', 7),
#  ('plagiarismdetector', 7),
#  ('eve', 7),
#  ('minio', 7),
#  ('checklist', 7),
#  ('patrowl', 7),
#  ('drop', 7),
#  ('movingobjectdetection', 7),
#  ('rocketchat', 7),
#  ('common', 7),
#  ('sandbox', 7),
#  ('team', 7),
#  ('awscli', 7),
#  ('cuid', 7),
#  ('recon', 7),
#  ('eagle', 7),
#  ('widget', 7),
#  ('numberplatedetection', 7),
#  ('nuttx', 7),
#  ('facetracking', 7),
#  ('yolov2', 7),
#  ('perception', 7),
#  ('zsh', 7),
#  ('smartthings', 7),
#  ('imagecaptioning', 7),
#  ('user', 7),
#  ('airsim', 7),
#  ('quadtree', 7),
#  ('shop', 7),
#  ('challenge', 7),
#  ('proximity', 7),
#  ('inception', 7),
#  ('humanposeestimation', 7),
#  ('depressiondetection', 7),
#  ('message', 7),
#  ('zabbix', 7),
#  ('humancellatlas', 7),
#  ('fastrcnn', 7),
#  ('trafficsignrecognition', 7),
#  ('masterthesis', 7),
#  ('pentest', 7),
#  ('vercel', 7),
#  ('memgraph', 7),
#  ('fakenews', 7),
#  ('centernet', 7),
#  ('humandetection', 7),
#  ('noty', 7),
#  ('cosmos', 7),
#  ('useragent', 7),
#  ('nexmo', 7),
#  ('courseramachinelearning', 7),
#  ('cpp', 7),
#  ('sigstore', 7),
#  ('plagiarismdetection', 7),
#  ('host', 7),
#  ('bugsnag', 7),
#  ('gradcam', 7),
#  ('bytetrack', 7),
#  ('res2net', 7),
#  ('p5', 7),
#  ('gesture', 7),
#  ('minesweeper', 7),
#  ('securitycamera', 7),
#  ('chatgpt', 7),
#  ('laravel5', 7),
#  ('hackerranksolutions', 7),
#  ('libinput', 7),
#  ('countdown', 7),
#  ('nova', 7),
#  ('wechat', 7),
#  ('darkflow', 7),
#  ('template', 7),
#  ('materialui', 7),
#  ('snowboy', 7),
#  ('leetcodesolutions', 7),
#  ('springcloudgateway', 7),
#  ('torch', 7),
#  ('localstack', 7),
#  ('advancedlanefinding', 7),
#  ('jittor', 7),
#  ('malwareanalysis', 7),
#  ('webapp', 7),
#  ('apiclient', 7),
#  ('site', 7),
#  ('celery', 7),
#  ('microservices', 7),
#  ('mirror', 7),
#  ('radare2', 7),
#  ('gateway', 7),
#  ('cryptopals', 7),
#  ('osintframework', 7),
#  ('aerospike', 7),
#  ('hook', 7),
#  ('helmcharts', 7),
#  ('microservice', 7),
#  ('fastapi', 7),
#  ('cyberbullyingdetection', 7),
#  ('videoobjectdetection', 7),
#  ('expo', 7),
#  ('html', 7),
#  ('baidu', 7),
#  ('hatespeech', 7),
#  ('databricks', 7),
#  ('ice', 7),
#  ('cameracalibration', 7),
#  ('shuffle', 7),
#  ('hackathon', 7),
#  ('lib', 7),
#  ('protocolbuffers', 7),
#  ('flame', 7),
#  ('coreos', 7),
#  ('chart', 6),
#  ('kaggle', 6),
#  ('netapp', 6),
#  ('hed', 6),
#  ('upload', 6),
#  ('opencvjs', 6),
#  ('transition', 6),
#  ('trojan', 6),
#  ('opencvfacedetection', 6),
#  ('snake', 6),
#  ('crackingthecodinginterview', 6),
#  ('signlanguagerecognition', 6),
#  ('xray', 6),
#  ('report', 6),
#  ('benchmark', 6),
#  ('spot', 6),
#  ('aryiabehroziuan', 6),
#  ('audit', 6),
#  ('hardware', 6),
#  ('detectsecrets', 6),
#  ('poseestimation', 6),
#  ('coursera', 6),
#  ('fcos', 6),
#  ('faceantispoofing', 6),
#  ('sms', 6),
#  ('healthcheck', 6),
#  ('cti', 6),
#  ('todolist', 6),
#  ('cc', 6),
#  ('hackthebox', 6),
#  ('2022', 6),
#  ('ranger', 6),
#  ('tron', 6),
#  ('devicedetector', 6),
#  ('cvpr2019', 6),
#  ('signal', 6),
#  ('netbears', 6),
#  ...]

# %%
t2 = github_data_df['topics'].apply(lambda x: myclnfunction(x))

# %%
t2_cnt = Counter(t2.explode())
t2_cnt.most_common()
# Out:
# [(nan, 153668),
#  ('python', 6323),
#  ('deeplearning', 5300),
#  ('machinelearning', 4665),
#  ('computervision', 3010),
#  ('javascript', 2744),
#  ('security', 2657),
#  ('objectdetection', 2617),
#  ('pytorch', 2166),
#  ('tensorflow', 2125),
#  ('opencv', 2055),
#  ('hacktoberfest', 2010),
#  ('python3', 1781),
#  ('android', 1676),
#  ('docker', 1658),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1373),
#  ('monitor', 1285),
#  ('aws', 1264),
#  ('golang', 1252),
#  ('kubernetes', 1223),
#  ('awesomelist', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('imageprocessing', 1000),
#  ('facedetection', 987),
#  ('typescript', 971),
#  ('keras', 871),
#  ('windows', 848),
#  ('datascience', 836),
#  ('nlp', 823),
#  ('cybersecurity', 819),
#  ('api', 802),
#  ('go', 783),
#  ('artificialintelligence', 738),
#  ('anomalydetection', 738),
#  ('alert', 737),
#  ('raspberrypi', 736),
#  ('hack', 727),
#  ('swift', 721),
#  ('convolutionalneuralnetworks', 704),
#  ('cnn', 698),
#  ('ai', 672),
#  ('cpp', 660),
#  ('neuralnetwork', 653),
#  ('securitytools', 653),
#  ('facerecognition', 647),
#  ('automation', 637),
#  ('terraform', 615),
#  ('opensource', 609),
#  ('prometheus', 600),
#  ('dataset', 598),
#  ('azure', 584),
#  ('iot', 580),
#  ('naturallanguageprocessing', 579),
#  ('html', 575),
#  ('csharp', 574),
#  ('rust', 561),
#  ('yolo', 557),
#  ('macos', 551),
#  ('flask', 547),
#  ('network', 541),
#  ('deepneuralnetworks', 538),
#  ('blockchain', 536),
#  ('css', 527),
#  ('classification', 526),
#  ('game', 522),
#  ('reactjs', 520),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 501),
#  ('bot', 498),
#  ('springboot', 498),
#  ('reactnative', 483),
#  ('c', 469),
#  ('cli', 464),
#  ('cryptography', 461),
#  ('yolov3', 457),
#  ('homeassistant', 454),
#  ('opencvpython', 453),
#  ('segmentation', 452),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 432),
#  ('vue', 427),
#  ('library', 415),
#  ('tool', 414),
#  ('imageclassification', 412),
#  ('cloud', 411),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('realtime', 406),
#  ('django', 403),
#  ('covid19', 403),
#  ('database', 399),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('log', 387),
#  ('bugbounty', 383),
#  ('mongodb', 372),
#  ('cryptocurrency', 372),
#  ('ruby', 371),
#  ('web', 367),
#  ('cplusplus', 365),
#  ('neuralnetworks', 360),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('ocr', 349),
#  ('timeseries', 348),
#  ('elasticsearch', 344),
#  ('matlab', 334),
#  ('penetrationtesting', 333),
#  ('test', 331),
#  ('yolov5', 331),
#  ('ansible', 330),
#  ('threathunting', 330),
#  ('plugin', 329),
#  ('postgresql', 328),
#  ('restapi', 326),
#  ('bootstrap', 323),
#  ('paper', 322),
#  ('malwareanalysis', 321),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('antivirus', 319),
#  ('cluster', 319),
#  ('mysql', 317),
#  ('discord', 317),
#  ('metrics', 315),
#  ('reverseengineering', 311),
#  ('threatintelligence', 311),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('json', 308),
#  ('list', 305),
#  ('notifications', 304),
#  ('r', 303),
#  ('jupyternotebook', 302),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('dotnet', 297),
#  ('framework', 295),
#  ('incidentresponse', 292),
#  ('redteam', 286),
#  ('github', 286),
#  ('audio', 284),
#  ('firebase', 278),
#  ('osint', 275),
#  ('dockercompose', 274),
#  ('sql', 273),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('transferlearning', 267),
#  ('bash', 266),
#  ('visualization', 259),
#  ('track', 259),
#  ('semanticsegmentation', 257),
#  ('dfir', 257),
#  ('encryption', 256),
#  ('graph', 253),
#  ('html5', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 248),
#  ('microservices', 246),
#  ('image', 245),
#  ('gui', 245),
#  ('autonomousdriving', 245),
#  ('homeautomation', 244),
#  ('dataanalysis', 244),
#  ('unity', 244),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('lstm', 239),
#  ('ui', 239),
#  ('jquery', 238),
#  ('redis', 237),
#  ('stream', 236),
#  ('pointcloud', 236),
#  ('algorithms', 231),
#  ('js', 231),
#  ('awslambda', 231),
#  ('vuejs', 227),
#  ('poseestimation', 227),
#  ('http', 225),
#  ('exploit', 225),
#  ('sdk', 221),
#  ('gamedevelopment', 221),
#  ('machinelearningalgorithms', 219),
#  ('frontend', 219),
#  ('kerastensorflow', 217),
#  ('tensorflow2', 217),
#  ('datavisualization', 215),
#  ('selfdrivingcar', 215),
#  ('fasterrcnn', 212),
#  ('imagesegmentation', 210),
#  ('telegrambot', 209),
#  ('authentication', 209),
#  ('containers', 208),
#  ('ml', 207),
#  ('redux', 204),
#  ('scikitlearn', 203),
#  ('dart', 202),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('git', 199),
#  ('objectivec', 197),
#  ('webapp', 197),
#  ('scanner', 197),
#  ('spark', 196),
#  ('blueteam', 196),
#  ('unsupervisedlearning', 195),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('data', 194),
#  ('face', 194),
#  ('ids', 194),
#  ('learn', 193),
#  ('githubactions', 193),
#  ('script', 192),
#  ('transformer', 191),
#  ('express', 191),
#  ('discordbot', 190),
#  ('slack', 190),
#  ('remotesensing', 190),
#  ('mobile', 190),
#  ('yolov4', 189),
#  ('pandas', 186),
#  ('analytics', 186),
#  ('crossplatform', 186),
#  ('esp8266', 185),
#  ('speechrecognition', 185),
#  ('malwaredetection', 185),
#  ('datamining', 183),
#  ('rest', 183),
#  ('reinforcementlearning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentimentanalysis', 182),
#  ('slam', 181),
#  ('imagerecognition', 181),
#  ('observability', 179),
#  ('instancesegmentation', 178),
#  ('darknet', 178),
#  ('chatgpt', 178),
#  ('gin', 178),
#  ('graphql', 177),
#  ('wifi', 177),
#  ('resources', 177),
#  ('dns', 177),
#  ('staticanalysis', 176),
#  ('trade', 176),
#  ('lidar', 175),
#  ('server', 174),
#  ('spring', 174),
#  ('chromeextension', 173),
#  ('devsecops', 173),
#  ('yara', 172),
#  ('twitter', 172),
#  ('vulnerability', 171),
#  ('lanedetection', 170),
#  ('email', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('chatbot', 168),
#  ('map', 167),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('objecttracking', 163),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('signalprocessing', 161),
#  ('medicalimaging', 160),
#  ('template', 160),
#  ('cloudnative', 160),
#  ('electron', 159),
#  ('scala', 159),
#  ('smarthome', 158),
#  ('autonomousvehicles', 158),
#  ('securityaudit', 158),
#  ('randomforest', 157),
#  ('androidapplication', 157),
#  ('cuda', 157),
#  ('maskrcnn', 156),
#  ('ssd', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('tailwindcss', 155),
#  ('opengl', 155),
#  ('commandline', 155),
#  ('bigdata', 154),
#  ('browser', 154),
#  ('smartcontracts', 154),
#  ('microservice', 154),
#  ('malwareresearch', 153),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('wordpressplugin', 151),
#  ('networkanalysis', 151),
#  ('dockerimage', 151),
#  ('terminal', 150),
#  ('unity3d', 149),
#  ('outlierdetection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('textclassification', 148),
#  ('3d', 148),
#  ('onnx', 147),
#  ('threatintel', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('expressjs', 145),
#  ('apple', 145),
#  ('selenium', 145),
#  ('rail', 144),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('edgedetection', 144),
#  ('dotnetcore', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('datastructures', 143),
#  ('frauddetection', 143),
#  ('embed', 143),
#  ('cicd', 142),
#  ('css3', 141),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('hook', 140),
#  ('gameengine', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('windows10', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('package', 138),
#  ('intrusiondetection', 138),
#  ('openapi', 137),
#  ('siem', 137),
#  ('generativeadversarialnetwork', 137),
#  ('phishing', 137),
#  ('project', 136),
#  ('deployment', 136),
#  ('hackingtool', 136),
#  ('inference', 136),
#  ('swiftui', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('heroku', 134),
#  ('videoprocessing', 134),
#  ('dlib', 134),
#  ('nlpmachinelearning', 133),
#  ('selfhosted', 133),
#  ('websocket', 132),
#  ('vision', 132),
#  ('vscode', 132),
#  ('terraformmodule', 132),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('springcloud', 130),
#  ('androidlibrary', 130),
#  ('augmentedreality', 129),
#  ('backup', 129),
#  ('bootstrap4', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheusexporter', 128),
#  ('alertmanager', 128),
#  ('boilerplate', 127),
#  ('recognition', 127),
#  ('chrome', 126),
#  ('openai', 125),
#  ('form', 125),
#  ('demo', 125),
#  ('webrtc', 124),
#  ('tensorflowlite', 124),
#  ('3dobjectdetection', 124),
#  ('npm', 124),
#  ('client', 124),
#  ('audit', 123),
#  ('theme', 123),
#  ('benchmark', 123),
#  ('app', 122),
#  ('gamedev', 122),
#  ('filter', 122),
#  ('textdetection', 122),
#  ('vim', 122),
#  ('backend', 122),
#  ('infrastructure', 122),
#  ('statuspage', 122),
#  ('cnnkeras', 121),
#  ('distributedsystems', 121),
#  ('ssl', 121),
#  ('autoencoder', 121),
#  ('program', 121),
#  ('jenkins', 121),
#  ('kibana', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('service', 120),
#  ('vulnerabilitydetection', 120),
#  ('tls', 120),
#  ('workflow', 119),
#  ('selfsupervisedlearning', 119),
#  ('graphneuralnetworks', 119),
#  ('featureextraction', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('mlops', 118),
#  ('language', 117),
#  ('tensorflowjs', 117),
#  ('mediapipe', 117),
#  ('materialdesign', 117),
#  ('ecommerce', 117),
#  ('web3', 117),
#  ('vpn', 116),
#  ('model', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('resnet', 115),
#  ('optimization', 114),
#  ('unet', 114),
#  ('module', 114),
#  ('changedetection', 114),
#  ('book', 114),
#  ('emotionrecognition', 114),
#  ('googlecloud', 113),
#  ('pushnotifications', 113),
#  ('developertools', 113),
#  ('scan', 113),
#  ('uptimemonitor', 113),
#  ('uikit', 112),
#  ('sklearn', 112),
#  ('networksecurity', 111),
#  ('bluetooth', 111),
#  ('digitalforensics', 111),
#  ('education', 111),
#  ('crawler', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfestaccepted', 110),
#  ('streamlit', 109),
#  ('debug', 109),
#  ('compliance', 109),
#  ('awesomelists', 109),
#  ('webassembly', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('finance', 107),
#  ('hardware', 107),
#  ('translation', 107),
#  ('securityautomation', 107),
#  ('hash', 107),
#  ('androidapp', 107),
#  ('rnn', 106),
#  ('vulnerabilities', 106),
#  ('communitydetection', 105),
#  ('bestpractices', 105),
#  ('hackingtools', 105),
#  ('message', 105),
#  ('pwa', 105),
#  ('search', 105),
#  ('vscodeextension', 105),
#  ('sqlite', 105),
#  ('terraformmodules', 105),
#  ('springsecurity', 105),
#  ('intel', 105),
#  ('apigateway', 104),
#  ('vehicledetection', 104),
#  ('arduinolibrary', 104),
#  ('vulnerabilityscanners', 104),
#  ('collisiondetection', 104),
#  ('cache', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('fingerprint', 103),
#  ('computerscience', 103),
#  ('pretrainedmodels', 103),
#  ('aspnetcore', 103),
#  ('animation', 102),
#  ('edgecomputing', 102),
#  ('csv', 101),
#  ('logisticregression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('edge', 101),
#  ('genomics', 101),
#  ('trace', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('blog', 100),
#  ('attack', 100),
#  ('commandlinetool', 100),
#  ('googlecloudplatform', 99),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('emotiondetection', 99),
#  ('postgres', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('hacktoberfest2021', 98),
#  ('drone', 98),
#  ('fastapi', 98),
#  ('infrastructureascode', 97),
#  ('satelliteimagery', 97),
#  ('cheatsheet', 97),
#  ('audioprocessing', 97),
#  ('cnnclassification', 97),
#  ('interview', 97),
#  ('owasp', 96),
#  ('kalilinux', 96),
#  ('openshift', 95),
#  ('hacktoberfest2020', 95),
#  ('kotlinandroid', 95),
#  ('facemaskdetection', 95),
#  ('cocoapods', 95),
#  ('sample', 95),
#  ('nmap', 95),
#  ('mobilenet', 95),
#  ('timeseriesanalysis', 95),
#  ('yolov2', 94),
#  ('validation', 94),
#  ('svmclassifier', 94),
#  ('uicomponents', 94),
#  ('materialui', 94),
#  ('tflite', 94),
#  ('influxdb', 94),
#  ('interviewquestions', 94),
#  ('regression', 93),
#  ('physics', 93),
#  ('imagenet', 93),
#  ('async', 93),
#  ('filesystem', 93),
#  ('websockets', 93),
#  ('rstats', 93),
#  ('hacktoberfest2022', 93),
#  ('speech', 92),
#  ('mobilenetv2', 92),
#  ('cv', 92),
#  ('gitops', 92),
#  ('chat', 92),
#  ('sass', 91),
#  ('apiclient', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentesttool', 90),
#  ('guide', 90),
#  ('scraper', 90),
#  ('speechtotext', 90),
#  ('webapplication', 90),
#  ('supervisedlearning', 89),
#  ('container', 89),
#  ('cloudformation', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attentionmechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('motiondetection', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('tradingbot', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('action', 88),
#  ('imageanalysis', 88),
#  ('pytorchimplementation', 88),
#  ('firefox', 88),
#  ('tcp', 88),
#  ('bypass', 87),
#  ('coursera', 87),
#  ('extension', 87),
#  ('wallet', 87),
#  ('chart', 87),
#  ('coco', 87),
#  ('svelte', 87),
#  ('mitreattack', 87),
#  ('awss3', 87),
#  ('amazon', 86),
#  ('humanposeestimation', 86),
#  ('middleware', 86),
#  ('webdevelopment', 86),
#  ('xml', 86),
#  ('networkmonitoring', 86),
#  ('informationsecurity', 86),
#  ('securityscanner', 86),
#  ('binance', 86),
#  ('bashscript', 86),
#  ('zabbix', 86),
#  ('train', 86),
#  ('grpc', 85),
#  ('sqlserver', 85),
#  ('clojure', 85),
#  ('webscraping', 85),
#  ('honeypot', 85),
#  ('healthcare', 85),
#  ('activedirectory', 85),
#  ('p2p', 85),
#  ('toast', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('redteaming', 84),
#  ('restfulapi', 84),
#  ('parse', 84),
#  ('recurrentneuralnetworks', 84),
#  ('lightweight', 84),
#  ('coreml', 84),
#  ('ctfwriteups', 84),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flaskapplication', 82),
#  ('webcam', 82),
#  ('homeassistantconfig', 82),
#  ('i18n', 82),
#  ('rat', 82),
#  ('process', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('cloudcomputing', 82),
#  ('retinanet', 82),
#  ('artificialneuralnetworks', 82),
#  ('continuousintegration', 81),
#  ('maven', 81),
#  ('javascriptlibrary', 81),
#  ('popup', 81),
#  ('logger', 81),
#  ('textrecognition', 81),
#  ('monitoringtool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('fakenews', 80),
#  ('php7', 80),
#  ('jetsonnano', 80),
#  ('dataengineering', 80),
#  ('development', 80),
#  ('application', 80),
#  ('file', 80),
#  ('perl', 80),
#  ('forecast', 80),
#  ('pyqt5', 80),
#  ('cyberthreatintelligence', 80),
#  ('gps', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graphalgorithms', 79),
#  ('fullstack', 79),
#  ('angular2', 79),
#  ('nvidia', 79),
#  ('actionrecognition', 79),
#  ('webcomponents', 79),
#  ('languagedetection', 79),
#  ('tutorials', 79),
#  ('cheat', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('pythonscript', 78),
#  ('obfuscation', 78),
#  ('threejs', 78),
#  ('sms', 78),
#  ('internetofthings', 77),
#  ('example', 77),
#  ('convolutionalneuralnetwork', 77),
#  ('certificate', 77),
#  ('xgboost', 77),
#  ('compiler', 77),
#  ('intrusiondetectionsystem', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('nodered', 76),
#  ('searchengine', 76),
#  ('windows11', 76),
#  ('qrcode', 76),
#  ('pythonlibrary', 76),
#  ('scrap', 76),
#  ('ransomware', 75),
#  ('facialrecognition', 75),
#  ('raspberrypi3', 75),
#  ('forensicanalysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('osx', 75),
#  ('cloudsecurity', 75),
#  ('gplv3', 75),
#  ('suricata', 75),
#  ('linearregression', 74),
#  ('backdoor', 74),
#  ('distribute', 74),
#  ('editor', 74),
#  ('dataaugmentation', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('bruteforce', 73),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('cleanarchitecture', 73),
#  ('note', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('prediction', 73),
#  ('androidstudio', 73),
#  ('ble', 73),
#  ('npmpackage', 73),
#  ('gpt3', 73),
#  ('pcap', 73),
#  ('semisupervisedlearning', 72),
#  ('yararules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('gpt', 72),
#  ('securityhardening', 72),
#  ('report', 72),
#  ('lidarpointcloud', 72),
#  ('adversarialattacks', 72),
#  ('3dreconstruction', 72),
#  ('programminglanguage', 72),
#  ('htmlcssjavascript', 72),
#  ('ajax', 71),
#  ('offensivesecurity', 71),
#  ('cti', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('softwareengineering', 71),
#  ('jqueryplugin', 71),
#  ('mac', 71),
#  ('ethicalhacking', 71),
#  ('https', 71),
#  ('course', 71),
#  ('llm', 71),
#  ('multithreading', 71),
#  ('rustlang', 71),
#  ('multiobjecttracking', 71),
#  ('cpu', 71),
#  ('scss', 70),
#  ('stock', 70),
#  ('deepsort', 70),
#  ('sandbox', 70),
#  ('androiddevelopment', 70),
#  ('management', 70),
#  ('visiontransformer', 70),
#  ('integration', 70),
#  ('stm32', 70),
#  ('defi', 70),
#  ('kalmanfilter', 70),
#  ('salientobjectdetection', 70),
#  ('facealignment', 70),
#  ('awsec2', 70),
#  ('virus', 70),
#  ('crud', 69),
#  ('angularjs', 69),
#  ('cms', 69),
#  ('ec2', 69),
#  ('azurefunctions', 69),
#  ('virtualmachine', 69),
#  ('apache', 69),
#  ('radar', 69),
#  ('rnaseq', 69),
#  ('vue3', 69),
#  ('haarcascade', 69),
#  ('jest', 69),
#  ('vgg16', 68),
#  ('streamprocessing', 68),
#  ('vault', 68),
#  ('domainadaptation', 68),
#  ('federatedlearning', 68),
#  ('svg', 68),
#  ('operatingsystem', 68),
#  ('oracle', 68),
#  ('ionic', 68),
#  ('facebook', 68),
#  ('amazonwebservices', 68),
#  ('iobroker', 68),
#  ('control', 67),
#  ('mongoose', 67),
#  ('ioc', 67),
#  ('boundingboxes', 67),
#  ('emulator', 67),
#  ('gpt4', 67),
#  ('graphics', 67),
#  ('qt5', 67),
#  ('automl', 67),
#  ('wrapper', 67),
#  ('utility', 67),
#  ('events', 67),
#  ('facenet', 67),
#  ('promise', 67),
#  ('widget', 67),
#  ('simulator', 67),
#  ('engineer', 66),
#  ('trojan', 66),
#  ('engine', 66),
#  ('antivirusevasion', 66),
#  ('etl', 66),
#  ('orm', 66),
#  ('cpp17', 66),
#  ('socketio', 66),
#  ('encode', 66),
#  ('sensorfusion', 66),
#  ('unix', 66),
#  ('texttospeech', 66),
#  ('configuration', 66),
#  ('navigation', 66),
#  ('article', 66),
#  ('pedestriandetection', 66),
#  ('software', 66),
#  ('gi', 65),
#  ('kubernetescluster', 65),
#  ('gateway', 65),
#  ('admindashboard', 65),
#  ('collection', 65),
#  ('sdr', 65),
#  ('letsencrypt', 65),
#  ('textmining', 65),
#  ('facetracking', 65),
#  ('sort', 65),
#  ('profile', 65),
#  ('edgeai', 65),
#  ('embeddedsystems', 65),
#  ('alarm', 65),
#  ('rpackage', 65),
#  ('googlecolab', 65),
#  ('fast', 64),
#  ('webserver', 64),
#  ('ansiblerole', 64),
#  ('harden', 64),
#  ('steganography', 64),
#  ('bypassantivirus', 64),
#  ('survey', 64),
#  ('system', 64),
#  ('iosapp', 64),
#  ('shellscript', 64),
#  ('websecurity', 64),
#  ('neovim', 64),
#  ('bootstrap5', 64),
#  ('ocrrecognition', 63),
#  ('community', 63),
#  ('composer', 63),
#  ('nosql', 63),
#  ('python2', 63),
#  ('cisco', 63),
#  ('bluetoothlowenergy', 63),
#  ('radio', 63),
#  ('objectrecognition', 63),
#  ('archlinux', 63),
#  ('voice', 63),
#  ('maskdetection', 63),
#  ('tesseract', 63),
#  ('paperlist', 63),
#  ('testingtools', 63),
#  ('prompt', 62),
#  ('label', 62),
#  ('smtp', 62),
#  ('ebpf', 62),
#  ('cdk', 62),
#  ('interviewpreparation', 62),
#  ('usb', 62),
#  ('voiceactivitydetection', 62),
#  ('eeg', 62),
#  ('sre', 62),
#  ('java8', 62),
#  ('chess', 62),
#  ('cnnmodel', 62),
#  ('verilog', 62),
#  ('keyboard', 62),
#  ('pentestingtools', 62),
#  ('config', 61),
#  ('javafx', 61),
#  ('dockercontainer', 61),
#  ('waf', 61),
#  ('telemetry', 61),
#  ('deprecate', 61),
#  ('linter', 61),
#  ('mvvm', 61),
#  ('faciallandmarks', 61),
#  ('reactrouter', 61),
#  ('mine', 61),
#  ('anticheat', 61),
#  ('jetson', 61),
#  ('socialmedia', 61),
#  ('apns', 61),
#  ('kagglecompetition', 61),
#  ('virtualization', 61),
#  ('kmeansclustering', 61),
#  ('attention', 61),
#  ('productivity', 61),
#  ('protection', 61),
#  ('wireless', 60),
#  ('sensors', 60),
#  ('arkit', 60),
#  ('sagemaker', 60),
#  ('memory', 60),
#  ('informationgathering', 60),
#  ('osquery', 60),
#  ('linuxkernel', 60),
#  ('annotations', 60),
#  ('cordovaplugin', 60),
#  ('resnet50', 60),
#  ('virustotal', 60),
#  ('syntaxhighlighting', 60),
#  ('tkinter', 60),
#  ('explainableai', 60),
#  ('socialnetwork', 60),
#  ('color', 60),
#  ('news', 60),
#  ('emotion', 60),
#  ('reactcomponents', 60),
#  ('enumeration', 59),
#  ('purpleteam', 59),
#  ('hackintosh', 59),
#  ('tensorflowobjectdetectionapi', 59),
#  ('agent', 59),
#  ('devopstools', 59),
#  ('native', 59),
#  ('eks', 59),
#  ('clamav', 59),
#  ('dockerfile', 59),
#  ('md', 59),
#  ('puppet', 59),
#  ('cassandra', 59),
#  ('ddos', 59),
#  ('iac', 59),
#  ('cpp11', 59),
#  ('browserextension', 59),
#  ('portfolio', 59),
#  ('udp', 59),
#  ('rcnn', 58),
#  ('onnxruntime', 58),
#  ('mvc', 58),
#  ('iphone', 58),
#  ('operator', 58),
#  ('lstmneuralnetworks', 58),
#  ('stockmarket', 58),
#  ('ensemblelearning', 58),
#  ('multimodal', 58),
#  ('instagram', 58),
#  ('tracker', 58),
#  ('gitlab', 58),
#  ('vagrant', 58),
#  ('designpatterns', 58),
#  ('salesforce', 58),
#  ('pca', 58),
#  ('secure', 57),
#  ('testautomation', 57),
#  ('opencv3', 57),
#  ('regex', 57),
#  ('consul', 57),
#  ('tree', 57),
#  ('geolocation', 57),
#  ('hunt', 57),
#  ...]

# %%
t3 = github_data_df['about'].apply(lambda x: myclnfunction(x))

# %%
t3_cnt = Counter(t3.explode())
t3_cnt.most_common()
# Out:
# [(nan, 33273),
#  ('detection', 25620),
#  ('learn', 11396),
#  ('data', 10783),
#  ('project', 10742),
#  ('tool', 10131),
#  ('code', 9236),
#  ('image', 9042),
#  ('base', 8788),
#  ('1', 8014),
#  ('python', 7972),
#  ('library', 7828),
#  ('list', 7768),
#  ('network', 7280),
#  ('object', 6958),
#  ('set', 6935),
#  ('model', 6785),
#  ('system', 6600),
#  ('api', 6266),
#  ('web', 6129),
#  ('detect', 6015),
#  ('implementation', 5941),
#  ('file', 5867),
#  ('application', 5523),
#  ('simple', 5499),
#  ('app', 5473),
#  ('script', 5352),
#  ('repository', 5332),
#  ('build', 5273),
#  ('https', 5138),
#  ('c', 4920),
#  ('machine', 4848),
#  ('deep', 4808),
#  ('js', 4655),
#  ('plugin', 4633),
#  ('framework', 4614),
#  ('paper', 4547),
#  ('source', 4511),
#  ('security', 4441),
#  ('android', 4430),
#  ('alert', 4395),
#  ('create', 4391),
#  ('face', 4191),
#  ('support', 4170),
#  ('class', 4135),
#  ('monitor', 4100),
#  ('make', 4050),
#  ('github', 4023),
#  ('open', 4004),
#  ('service', 3924),
#  ('resources', 3885),
#  ('analysis', 3870),
#  ('http', 3808),
#  ('awesome', 3777),
#  ('javascript', 3734),
#  ('software', 3670),
#  ('test', 3644),
#  ('feature', 3580),
#  ('process', 3563),
#  ('collection', 3496),
#  ('server', 3494),
#  ('curated', 3350),
#  ('time', 3325),
#  ('function', 3254),
#  ('work', 3187),
#  ('go', 3103),
#  ('program', 3022),
#  ('google', 3014),
#  ('track', 2968),
#  ('write', 2941),
#  ('recognition', 2892),
#  ('computer', 2878),
#  ('cloud', 2860),
#  ('react', 2860),
#  ('windows', 2792),
#  ('text', 2789),
#  ('include', 2779),
#  ('package', 2778),
#  ('dataset', 2741),
#  ('module', 2738),
#  ('get', 2718),
#  ('ios', 2687),
#  ('aws', 2679),
#  ('video', 2661),
#  ('help', 2617),
#  ('design', 2605),
#  ('neural', 2596),
#  ('node', 2539),
#  ('user', 2539),
#  ('train', 2507),
#  ('game', 2490),
#  ('control', 2456),
#  ('vision', 2410),
#  ('opencv', 2387),
#  ('tensorflow', 2384),
#  ('version', 2375),
#  ('platform', 2363),
#  ('applications', 2357),
#  ('client', 2352),
#  ('information', 2305),
#  ('linux', 2277),
#  ('algorithm', 2255),
#  ('java', 2231),
#  ('pytorch', 2182),
#  ('language', 2179),
#  ('realtime', 2155),
#  ('development', 2131),
#  ('type', 2109),
#  ('find', 2100),
#  ('5', 2092),
#  ('php', 2021),
#  ('generate', 2007),
#  ('name', 1994),
#  ('ai', 1992),
#  ('x', 1988),
#  ('io', 1960),
#  ('3d', 1950),
#  ('log', 1949),
#  ('automate', 1928),
#  ('management', 1904),
#  ('sample', 1893),
#  ('change', 1869),
#  ('net', 1865),
#  ('classification', 1837),
#  ('bot', 1829),
#  ('message', 1800),
#  ('manage', 1793),
#  ('command', 1780),
#  ('fast', 1775),
#  ('example', 1775),
#  ('engine', 1765),
#  ('update', 1761),
#  ('easy', 1738),
#  ('libraries', 1725),
#  ('course', 1718),
#  ('link', 1716),
#  ('custom', 1711),
#  ('check', 1694),
#  ('document', 1691),
#  ('docker', 1688),
#  ('mobile', 1683),
#  ('content', 1677),
#  ('algorithms', 1667),
#  ('official', 1640),
#  ('free', 1636),
#  ('segmentation', 1621),
#  ('azure', 1606),
#  ('sdk', 1595),
#  ('native', 1578),
#  ('demo', 1567),
#  ('vue', 1564),
#  ('camera', 1562),
#  ('search', 1556),
#  ('line', 1554),
#  ('database', 1550),
#  ('attack', 1547),
#  ('multiple', 1546),
#  ('etc', 1543),
#  ('ui', 1535),
#  ('interface', 1525),
#  ('task', 1520),
#  ('anomaly', 1494),
#  ('kubernetes', 1485),
#  ('cluster', 1473),
#  ('html', 1470),
#  ('engineer', 1464),
#  ('systems', 1458),
#  ('users', 1455),
#  ('team', 1455),
#  ('page', 1451),
#  ('point', 1450),
#  ('access', 1449),
#  ('extension', 1444),
#  ('stream', 1435),
#  ('display', 1430),
#  ('spring', 1429),
#  ('research', 1425),
#  ('browser', 1420),
#  ('detector', 1416),
#  ('map', 1413),
#  ('apps', 1407),
#  ('graph', 1406),
#  ('guide', 1383),
#  ('solution', 1382),
#  ('number', 1370),
#  ('fork', 1370),
#  ('devices', 1364),
#  ('fix', 1358),
#  ('challenge', 1357),
#  ('ids', 1354),
#  ('integration', 1327),
#  ('deploy', 1318),
#  ('science', 1318),
#  ('read', 1314),
#  ('cod', 1311),
#  ('device', 1300),
#  ('real', 1299),
#  ('action', 1290),
#  ('target', 1287),
#  ('6', 1273),
#  ('email', 1272),
#  ('address', 1272),
#  ('local', 1266),
#  ('method', 1257),
#  ('small', 1249),
#  ('event', 1239),
#  ('wrapper', 1236),
#  ('view', 1234),
#  ('report', 1226),
#  ('id', 1218),
#  ('online', 1217),
#  ('automatic', 1215),
#  ('power', 1215),
#  ('home', 1207),
#  ('smart', 1201),
#  ('lightweight', 1189),
#  ('filter', 1184),
#  ('useful', 1182),
#  ('human', 1172),
#  ('note', 1171),
#  ('study', 1168),
#  ('component', 1163),
#  ('style', 1160),
#  ('website', 1160),
#  ('public', 1159),
#  ('pi', 1151),
#  ('call', 1144),
#  ('remote', 1143),
#  ('scan', 1139),
#  ('malware', 1134),
#  ('opensource', 1130),
#  ('color', 1130),
#  ('store', 1129),
#  ('group', 1121),
#  ('master', 1120),
#  ('input', 1118),
#  ('git', 1112),
#  ('visual', 1107),
#  ('push', 1107),
#  ('advance', 1106),
#  ('configuration', 1098),
#  ('form', 1096),
#  ('performance', 1093),
#  ('request', 1090),
#  ('community', 1087),
#  ('block', 1086),
#  ('raspberry', 1085),
#  ('traffic', 1077),
#  ('key', 1075),
#  ('r', 1074),
#  ('2020', 1072),
#  ('format', 1070),
#  ('best', 1063),
#  ('template', 1060),
#  ('environment', 1060),
#  ('people', 1058),
#  ('publish', 1058),
#  ('book', 1055),
#  ('examples', 1050),
#  ('drive', 1047),
#  ('audio', 1043),
#  ('jquery', 1043),
#  ('live', 1036),
#  ('components', 1034),
#  ('share', 1033),
#  ('rule', 1032),
#  ('host', 1031),
#  ('events', 1031),
#  ('datasets', 1030),
#  ('core', 1023),
#  ('json', 1019),
#  ('question', 1019),
#  ('2021', 1014),
#  ('pipeline', 1007),
#  ('connect', 1005),
#  ('edge', 1003),
#  ('top', 1000),
#  ('intelligence', 995),
#  ('secure', 992),
#  ('css', 992),
#  ('hack', 990),
#  ('basic', 986),
#  ('notifications', 985),
#  ('stack', 976),
#  ('series', 975),
#  ('toolkit', 972),
#  ('extract', 966),
#  ('state', 956),
#  ('structure', 956),
#  ('2019', 956),
#  ('prometheus', 954),
#  ('iot', 953),
#  ('amazon', 950),
#  ('driver', 950),
#  ('account', 947),
#  ('rest', 940),
#  ('frameworks', 928),
#  ('post', 926),
#  ('estimation', 923),
#  ('pattern', 917),
#  ('videos', 916),
#  ('digital', 915),
#  ('architecture', 912),
#  ('ml', 909),
#  ('port', 906),
#  ('case', 904),
#  ('memory', 904),
#  ('mask', 899),
#  ('microsoft', 899),
#  ('2022', 895),
#  ('protocol', 894),
#  ('first', 886),
#  ('aim', 884),
#  ('ruby', 884),
#  ('ip', 883),
#  ('wordpress', 879),
#  ('utility', 876),
#  ('download', 870),
#  ('signal', 866),
#  ('focus', 865),
#  ('query', 863),
#  ('arduino', 862),
#  ('twitter', 862),
#  ('laravel', 859),
#  ('bootstrap', 859),
#  ('issue', 859),
#  ('convert', 859),
#  ('terraform', 858),
#  ('path', 856),
#  ('common', 854),
#  ('automation', 853),
#  ('mirror', 850),
#  ('record', 848),
#  ('media', 848),
#  ('instance', 846),
#  ('label', 844),
#  ('url', 843),
#  ('angular', 842),
#  ('manager', 840),
#  ('notification', 840),
#  ('facial', 840),
#  ('yolo', 838),
#  ('plan', 837),
#  ('frontend', 837),
#  ('cnn', 835),
#  ('tutorial', 834),
#  ('keras', 834),
#  ('dynamic', 830),
#  ('boot', 824),
#  ('sensor', 820),
#  ('generation', 818),
#  ('threat', 817),
#  ('car', 816),
#  ('button', 813),
#  ('documentation', 808),
#  ('reference', 807),
#  ('apis', 804),
#  ('hunt', 804),
#  ('chat', 803),
#  ('interview', 800),
#  ('box', 798),
#  ('os', 797),
#  ('load', 795),
#  ('cli', 792),
#  ('generator', 789),
#  ('match', 783),
#  ('discord', 779),
#  ('practice', 779),
#  ('social', 775),
#  ('swift', 774),
#  ('robot', 774),
#  ('pose', 767),
#  ('distribute', 766),
#  ('ips', 763),
#  ('parse', 760),
#  ('table', 751),
#  ('tutorials', 751),
#  ('solutions', 748),
#  ('status', 746),
#  ('motion', 746),
#  ('matlab', 742),
#  ('2018', 739),
#  ('blog', 738),
#  ('apache', 737),
#  ('active', 736),
#  ('developers', 735),
#  ('move', 734),
#  ('bee', 731),
#  ('release', 730),
#  ('domain', 729),
#  ('card', 728),
#  ('order', 726),
#  ('macos', 724),
#  ('setup', 721),
#  ('job', 720),
#  ('sql', 719),
#  ('play', 718),
#  ('speech', 717),
#  ('light', 715),
#  ('university', 714),
#  ('bug', 711),
#  ('backend', 709),
#  ('embed', 709),
#  ('proxy', 708),
#  ('tree', 704),
#  ('dashboard', 704),
#  ('sign', 704),
#  ('article', 702),
#  ('news', 699),
#  ('background', 698),
#  ('analytics', 697),
#  ('modern', 696),
#  ('vehicle', 696),
#  ('sequence', 695),
#  ('metrics', 694),
#  ('response', 693),
#  ('rail', 693),
#  ('efficient', 690),
#  ('operations', 689),
#  ('admin', 685),
#  ('container', 685),
#  ('transfer', 684),
#  ('upload', 677),
#  ('personal', 676),
#  ('workshop', 672),
#  ('ros', 672),
#  ('controller', 668),
#  ('word', 665),
#  ('install', 662),
#  ('channel', 661),
#  ('telegram', 659),
#  ('rust', 659),
#  ('site', 656),
#  ('scale', 652),
#  ('capture', 650),
#  ('step', 648),
#  ('window', 648),
#  ('powershell', 647),
#  ('2d', 646),
#  ('virtual', 644),
#  ('star', 644),
#  ('cvpr', 642),
#  ('bind', 639),
#  ('trade', 639),
#  ('hide', 638),
#  ('flutter', 633),
#  ('modules', 632),
#  ('authentication', 631),
#  ('storage', 631),
#  ('autonomous', 629),
#  ('cordova', 629),
#  ('scanner', 629),
#  ('string', 626),
#  ('desktop', 624),
#  ('clone', 622),
#  ('roblox', 621),
#  ('chrome', 619),
#  ('contract', 619),
#  ('golang', 618),
#  ('gui', 617),
#  ('experiment', 614),
#  ('do', 613),
#  ('output', 612),
#  ('red', 611),
#  ('hand', 611),
#  ('assistant', 610),
#  ('final', 610),
#  ('voice', 610),
#  ('django', 609),
#  ('svg', 609),
#  ('ansible', 608),
#  ('prediction', 605),
#  ('internet', 605),
#  ('mine', 603),
#  ('compute', 602),
#  ('v', 601),
#  ('private', 597),
#  ('theme', 596),
#  ('nlp', 595),
#  ('extraction', 594),
#  ('facebook', 592),
#  ('vulnerability', 592),
#  ('material', 591),
#  ('infrastructure', 590),
#  ('location', 590),
#  ('rcnn', 588),
#  ('robust', 588),
#  ('space', 587),
#  ('fake', 587),
#  ('knowledge', 583),
#  ('blockchain', 581),
#  ('artificial', 579),
#  ('technology', 578),
#  ('error', 577),
#  ('position', 577),
#  ('license', 577),
#  ('deployment', 576),
#  ('forensics', 575),
#  ('apple', 575),
#  ('remove', 574),
#  ('auto', 573),
#  ('static', 570),
#  ('maintain', 570),
#  ('tag', 570),
#  ('deprecate', 569),
#  ('kit', 568),
#  ('typescript', 568),
#  ('editor', 567),
#  ('exploit', 564),
#  ('shell', 563),
#  ('activity', 562),
#  ('quality', 561),
#  ('lab', 560),
#  ('reverse', 560),
#  ('music', 559),
#  ('flow', 559),
#  ('layer', 558),
#  ('standard', 558),
#  ('hardware', 557),
#  ('lane', 555),
#  ('mode', 554),
#  ('semantic', 553),
#  ('servers', 550),
#  ('plugins', 547),
#  ('eye', 545),
#  ('developer', 541),
#  ('screen', 539),
#  ('talk', 537),
#  ('export', 536),
#  ('profile', 535),
#  ('random', 534),
#  ('natural', 534),
#  ('kernel', 534),
#  ('pdf', 529),
#  ('count', 527),
#  ('board', 527),
#  ('phone', 526),
#  ('communication', 524),
#  ('binary', 524),
#  ('mac', 523),
#  ('edit', 522),
#  ('bypass', 516),
#  ('wifi', 516),
#  ('external', 514),
#  ('mysql', 514),
#  ('dns', 514),
#  ('intrusion', 513),
#  ('archive', 512),
#  ('interactive', 511),
#  ('player', 511),
#  ('patch', 510),
#  ('experience', 508),
#  ('unity', 508),
#  ('click', 507),
#  ('covid19', 507),
#  ('websites', 506),
#  ('devops', 503),
#  ('life', 500),
#  ('password', 497),
#  ('inference', 496),
#  ('classifier', 496),
#  ('sound', 496),
#  ('antivirus', 494),
#  ('tracker', 493),
#  ('disease', 493),
#  ('select', 492),
#  ('html5', 491),
#  ('bitcoin', 490),
#  ('speed', 489),
#  ('visualization', 488),
#  ('adversarial', 488),
#  ('simulation', 488),
#  ('toolbox', 487),
#  ('index', 486),
#  ('benchmark', 486),
#  ('transform', 485),
#  ('crossplatform', 485),
#  ('health', 483),
#  ('next', 483),
#  ('center', 482),
#  ('flask', 482),
#  ('usage', 482),
#  ('mongodb', 481),
#  ('firmware', 479),
#  ('hash', 478),
#  ('agent', 478),
#  ('unsupervised', 477),
#  ('ethereum', 475),
#  ('nodejs', 475),
#  ('serverless', 474),
#  ('yolov3', 472),
#  ('resource', 472),
#  ('slack', 471),
#  ('compare', 466),
#  ('penetration', 465),
#  ('forensic', 465),
#  ('2017', 465),
#  ('templates', 464),
#  ('localization', 462),
#  ('quick', 462),
#  ('fraud', 462),
#  ('cyber', 462),
#  ('role', 461),
#  ('sense', 458),
#  ('company', 456),
#  ('context', 455),
#  ('utilities', 454),
#  ('navigation', 453),
#  ('evaluation', 453),
#  ('malicious', 451),
#  ('accuracy', 451),
#  ('review', 449),
#  ('element', 448),
#  ('commit', 445),
#  ('identification', 444),
#  ('pool', 443),
#  ('sit', 442),
#  ('optimize', 442),
#  ('head', 442),
#  ('intel', 439),
#  ('emotion', 439),
#  ('be', 439),
#  ('road', 438),
#  ('character', 436),
#  ('satellite', 435),
#  ('combine', 433),
#  ('long', 432),
#  ('src', 432),
#  ('directory', 431),
#  ('kaggle', 431),
#  ('daily', 430),
#  ('answer', 430),
#  ('render', 428),
#  ('pretrained', 428),
#  ('import', 428),
#  ('attention', 427),
#  ('fire', 427),
#  ('info', 426),
#  ('dialog', 426),
#  ('incident', 425),
#  ('switch', 424),
#  ('gateway', 421),
#  ('customizable', 421),
#  ('price', 420),
#  ('vulnerabilities', 420),
#  ('date', 420),
#  ('unofficial', 418),
#  ('scene', 416),
#  ('stock', 415),
#  ('mod', 414),
#  ('console', 414),
#  ('injection', 413),
#  ('scalable', 413),
#  ('watch', 412),
#  ('login', 412),
#  ('size', 409),
#  ('parser', 408),
#  ('kafka', 408),
#  ('flexible', 407),
#  ('grafana', 406),
#  ('tiny', 406),
#  ('cmd', 406),
#  ('lidar', 405),
#  ('range', 405),
#  ('token', 405),
#  ('sort', 405),
#  ('yara', 403),
#  ('chain', 403),
#  ('usb', 402),
#  ('spark', 401),
#  ('crypto', 401),
#  ('menu', 400),
#  ('sms', 400),
#  ('frame', 399),
#  ('2023', 399),
#  ('students', 398),
#  ('validation', 396),
#  ('clean', 395),
#  ('runtime', 395),
#  ('weather', 394),
#  ('delete', 392),
#  ('cameras', 391),
#  ('competition', 390),
#  ('copy', 389),
#  ('fee', 388),
#  ('product', 388),
#  ('youtube', 386),
#  ('limit', 386),
#  ('syntax', 386),
#  ('enterprise', 385),
#  ('medical', 384),
#  ('ajax', 384),
#  ('notebooks', 383),
#  ('endtoend', 382),
#  ('progress', 382),
#  ('privacy', 380),
#  ('radio', 380),
#  ('panel', 380),
#  ('collision', 379),
#  ('global', 379),
#  ('sensors', 378),
#  ('pass', 377),
#  ('cancer', 375),
#  ('plate', 375),
#  ('annotation', 374),
#  ('encryption', 373),
#  ('audit', 372),
#  ('config', 372),
#  ('sheet', 372),
#  ('webcam', 371),
#  ('distance', 371),
#  ('bash', 371),
#  ('lambda', 369),
#  ('production', 369),
#  ('market', 369),
#  ('express', 368),
#  ('encrypt', 367),
#  ('wallet', 366),
#  ('helper', 366),
#  ('options', 365),
#  ('starter', 364),
#  ('dev', 364),
#  ('yolov5', 364),
#  ('phishing', 364),
#  ('highlight', 363),
#  ('gesture', 362),
#  ('settings', 362),
#  ('fusion', 361),
#  ('capabilities', 361),
#  ('math', 361),
#  ('hook', 360),
#  ('exchange', 359),
#  ('debug', 359),
#  ('trace', 359),
#  ('addon', 358),
#  ('ocr', 358),
#  ('vehicles', 358),
#  ('tech', 357),
#  ('trigger', 356),
#  ('wiki', 356),
#  ('extensions', 356),
#  ('cpu', 356),
#  ('workflow', 355),
#  ('transformer', 353),
#  ('protect', 352),
#  ('loss', 352),
#  ('ieee', 352),
#  ('score', 351),
#  ('microservices', 350),
#  ('business', 348),
#  ('forest', 348),
#  ('measure', 347),
#  ('bridge', 347),
#  ('experimental', 347),
#  ('warn', 347),
#  ('transactions', 346),
#  ('contact', 345),
#  ('cache', 345),
#  ('discovery', 344),
#  ('notify', 344),
#  ('gpu', 344),
#  ('languages', 343),
#  ('chinese', 342),
#  ('rate', 340),
#  ('q', 339),
#  ('uboot', 339),
#  ('alarm', 337),
#  ('concept', 337),
#  ('compile', 337),
#  ('shiny', 336),
#  ('distribution', 335),
#  ('terminal', 335),
#  ('udacity', 334),
#  ('behavior', 333),
#  ('elasticsearch', 332),
#  ('platforms', 331),
#  ('tcp', 331),
#  ('svm', 331),
#  ('arxiv', 331),
#  ('simulator', 330),
#  ('history', 329),
#  ('markdown', 329),
#  ('universal', 329),
#  ('tv', 329),
#  ('urls', 329),
#  ('encode', 328),
#  ('mail', 328),
#  ('xss', 328),
#  ('surveillance', 326),
#  ('ctf', 326),
#  ('restful', 325),
#  ('drone', 324),
#  ('prototype', 324),
#  ('assets', 324),
#  ('print', 323),
#  ('protection', 322),
#  ('poc', 322),
#  ('vector', 321),
#  ('mqtt', 320),
#  ('regression', 320),
#  ('brain', 319),
#  ('optimization', 319),
#  ('s3', 319),
#  ('safe', 319),
#  ('schedule', 319),
#  ('minimal', 318),
#  ('continuous', 318),
#  ('modular', 318),
#  ('robotics', 315),
#  ('ssh', 315),
#  ('analyse', 314),
#  ('segment', 314),
#  ('exercise', 313),
#  ('fall', 312),
#  ('condition', 311),
#  ('introduction', 310),
#  ('redis', 310),
#  ('chart', 310),
#  ('flash', 310),
#  ('effect', 309),
#  ('keyboard', 309),
#  ('imagery', 309),
#  ('nginx', 307),
#  ('trust', 306),
#  ('certificate', 306),
#  ('esp32', 306),
#  ('firebase', 305),
#  ('gather', 305),
#  ('arm', 304),
#  ('cheat', 304),
#  ('connection', 303),
#  ('boilerplate', 302),
#  ('dependencies', 300),
#  ('rout', 300),
#  ('img', 300),
#  ('interaction', 299),
#  ('comment', 299),
#  ('tweet', 298),
#  ('slide', 298),
#  ('backup', 298),
#  ('ubuntu', 297),
#  ('lead', 296),
#  ('cms', 296),
#  ('xml', 295),
#  ('payload', 295),
#  ('bluetooth', 295),
#  ('csv', 294),
#  ('exam', 293),
#  ('postgresql', 292),
#  ('alternative', 292),
#  ('cookie', 292),
#  ('slam', 291),
#  ('serve', 291),
#  ('adaptive', 291),
#  ('anything', 291),
#  ('multi', 290),
#  ('jupyter', 290),
#  ('nod', 290),
#  ('browsers', 289),
#  ('db', 289),
#  ('forward', 289),
#  ('meta', 289),
#  ('radar', 288),
#  ('plant', 288),
#  ('sentiment', 288),
#  ('spam', 288),
#  ('session', 288),
#  ('elements', 287),
#  ('tip', 287),
#  ('versions', 286),
#  ('selection', 286),
#  ('verify', 285),
#  ('rat', 285),
#  ('thesis', 285),
#  ('drop', 284),
#  ('vim', 284),
#  ('picture', 284),
#  ('crop', 284),
#  ('minecraft', 283),
#  ('commandline', 281),
#  ('functional', 281),
#  ('discover', 281),
#  ('elastic', 280),
#  ('shape', 279),
#  ('exporter', 279),
#  ('future', 279),
#  ('standalone', 278),
#  ('attribute', 278),
#  ('portable', 277),
#  ('esp8266', 277),
#  ('labs', 276),
#  ('scratch', 276),
#  ('region', 276),
#  ('batch', 275),
#  ('hackathon', 275),
#  ('containers', 273),
#  ('notebook', 272),
#  ('tokens', 272),
#  ('metadata', 272),
#  ('fun', 270),
#  ('safety', 270),
#  ('xray', 269),
#  ('raw', 269),
#  ('bite', 269),
#  ('largescale', 268),
#  ('unique', 268),
#  ('nvidia', 268),
#  ('gin', 268),
#  ('prompt', 267),
#  ('fingerprint', 267),
#  ('provider', 266),
#  ('park', 266),
#  ('keycloak', 266),
#  ('surface', 266),
#  ('pack', 265),
#  ('depth', 265),
#  ('split', 265),
#  ('cost', 265),
#  ('school', 265),
#  ('pc', 264),
#  ('operator', 264),
#  ('crack', 264),
#  ('router', 263),
#  ('validate', 263),
#  ('lstm', 262),
#  ('loop', 261),
#  ('verification', 261),
#  ('translation', 261),
#  ('bundle', 261),
#  ('expression', 261),
#  ('splunk', 261),
#  ('array', 260),
#  ('redux', 260),
#  ('wireless', 260),
#  ('root', 259),
#  ('pedestrian', 259),
#  ('energy', 259),
#  ('domains', 259),
#  ('touch', 258),
#  ('landmark', 258),
#  ('hub', 257),
#  ('analyzer', 257),
#  ('reality', 257),
#  ('firewall', 257),
#  ('reactjs', 257),
#  ('water', 257),
#  ('merge', 256),
#  ('ssd', 256),
#  ('black', 256),
#  ('cybersecurity', 256),
#  ('policy', 256),
#  ('ci', 256),
#  ('cryptocurrency', 256),
#  ('statistics', 256),
#  ('generative', 255),
#  ('payment', 254),
#  ('lite', 254),
#  ('attendance', 254),
#  ('listen', 254),
#  ('generic', 254),
#  ('header', 254),
#  ('risk', 253),
#  ('sync', 252),
#  ('contribute', 252),
#  ('phonegap', 252),
#  ('stateoftheart', 252),
#  ('cause', 252),
#  ('physics', 251),
#  ('selfdriving', 251),
#  ('translate', 251),
#  ('lua', 251),
#  ('iphone', 251),
#  ('docs', 251),
#  ('city', 249),
#  ('cars', 249),
#  ('unify', 249),
#  ('databases', 249),
#  ('photo', 249),
#  ('gem', 248),
#  ('offline', 248),
#  ('amp', 248),
#  ('bar', 247),
#  ('transformers', 247),
#  ('gitlab', 247),
#  ('minerproxy', 247),
#  ('matrix', 246),
#  ('identity', 245),
#  ('conference', 245),
#  ('widget', 244),
#  ('baseline', 244),
#  ('topic', 244),
#  ('parameters', 243),
#  ('summary', 243),
#  ('installation', 243),
#  ('angularjs', 243),
#  ('less', 243),
#  ('bank', 243),
#  ('party', 242),
#  ('photos', 242),
#  ('entity', 242),
#  ...]

# %%
t4 = github_data_df['languages'].apply(lambda x: myclnfunction(x))

# %%
t4_cnt = Counter(t4.explode())
t4_cnt.most_common()
# Out:
# [('python', 85119),
#  ('c', 60229),
#  ('shell', 57069),
#  ('javascript', 49677),
#  ('html', 40935),
#  ('css', 29797),
#  (nan, 27065),
#  ('makefile', 24513),
#  ('jupyter', 19789),
#  ('notebook', 19789),
#  ('dockerfile', 19663),
#  ('java', 17412),
#  ('ruby', 10653),
#  ('objectivec', 10510),
#  ('cmake', 10454),
#  ('php', 9441),
#  ('batchfile', 8983),
#  ('typescript', 8785),
#  ('go', 8276),
#  ('matlab', 6311),
#  ('perl', 5473),
#  ('powershell', 4618),
#  ('cuda', 4374),
#  ('swift', 3961),
#  ('assembly', 3892),
#  ('scss', 3615),
#  ('r', 3512),
#  ('kotlin', 2567),
#  ('lua', 2543),
#  ('tex', 2374),
#  ('hcl', 2360),
#  ('rust', 2280),
#  ('vue', 1890),
#  ('scala', 1300),
#  ('dart', 1199),
#  ('coffeescript', 1191),
#  ('glsl', 1181),
#  ('groovy', 1175),
#  ('tcl', 1098),
#  ('awk', 1053),
#  ('lisp', 1047),
#  ('script', 958),
#  ('vim', 942),
#  ('jinja', 907),
#  ('lex', 899),
#  ('cython', 895),
#  ('solidity', 839),
#  ('asp', 810),
#  ('less', 810),
#  ('emacs', 769),
#  ('tsql', 760),
#  ('pascal', 718),
#  ('basic', 676),
#  ('gdb', 627),
#  ('visual', 620),
#  ('clojure', 606),
#  ('yara', 582),
#  ('fortran', 565),
#  ('hack', 543),
#  ('mustache', 542),
#  ('gherkin', 526),
#  ('text', 516),
#  ('format', 515),
#  ('handlebars', 508),
#  ('sed', 488),
#  ('net', 455),
#  ('arduino', 454),
#  ('verilog', 441),
#  ('hlsl', 431),
#  ('nix', 418),
#  ('ejs', 401),
#  ('haskell', 397),
#  ('elixir', 382),
#  ('prolog', 375),
#  ('language', 374),
#  ('blade', 366),
#  ('process', 346),
#  ('erlang', 336),
#  ('setup', 334),
#  ('julia', 333),
#  ('6', 318),
#  ('swig', 313),
#  ('common', 312),
#  ('qml', 302),
#  ('vbscript', 291),
#  ('plsql', 286),
#  ('puppet', 286),
#  ('gnuplot', 279),
#  ('actionscript', 278),
#  ('digital', 275),
#  ('command', 275),
#  ('scheme', 273),
#  ('sourcepawn', 263),
#  ('protocol', 258),
#  ('buffer', 258),
#  ('ocaml', 251),
#  ('raku', 247),
#  ('mathematica', 245),
#  ('vhdl', 242),
#  ('smpl', 235),
#  ('antlr', 234),
#  ('pug', 228),
#  ('jsonnet', 224),
#  ('asl', 223),
#  ('svelte', 212),
#  ('systemverilog', 203),
#  ('standard', 203),
#  ('ml', 203),
#  ('applescript', 184),
#  ('bicep', 183),
#  ('104', 181),
#  ('pawn', 180),
#  ('twig', 173),
#  ('llvm', 169),
#  ('forth', 164),
#  ('autohotkey', 153),
#  ('gap', 145),
#  ('sass', 145),
#  ('haxe', 142),
#  ('sdl', 137),
#  ('ada', 137),
#  ('zeek', 137),
#  ('nextflow', 131),
#  ('vba', 131),
#  ('1', 130),
#  ('markdown', 129),
#  ('module', 123),
#  ('management', 123),
#  ('system', 123),
#  ('42', 122),
#  ('stylus', 120),
#  ('racket', 117),
#  ('stata', 115),
#  ('apex', 111),
#  ('metal', 109),
#  ('thrift', 105),
#  ('coq', 105),
#  ('mdx', 105),
#  ('yaml', 104),
#  ('nginx', 103),
#  ('360', 100),
#  ('gdscript', 97),
#  ('open', 97),
#  ('policy', 97),
#  ('agent', 97),
#  ('cap', 96),
#  ('idl', 94),
#  ('nim', 93),
#  ('json', 93),
#  ('webassembly', 91),
#  ('autoit', 88),
#  ('elm', 88),
#  ('saltstack', 86),
#  ('proto', 85),
#  ('crystal', 85),
#  ('q', 84),
#  ('robotframework', 79),
#  ('supercollider', 78),
#  ('bro', 77),
#  ('gcode', 69),
#  ('classic', 65),
#  ('slim', 59),
#  ('renderscript', 59),
#  ('clean', 57),
#  ('vala', 54),
#  ('rpc', 52),
#  ('p4', 52),
#  ('smali', 49),
#  ('api', 49),
#  ('blueprint', 49),
#  ('vcl', 48),
#  ('eagle', 47),
#  ('zig', 45),
#  ('2017', 43),
#  ('clip', 42),
#  ('v', 41),
#  ('game', 40),
#  ('2020', 40),
#  ('squirrel', 39),
#  ('enterprise', 38),
#  ('2022', 37),
#  ('cobol', 35),
#  ('io', 34),
#  ('mql5', 34),
#  ('mql4', 34),
#  ('workflow', 34),
#  ('fluent', 33),
#  ('jq', 31),
#  ('2023', 31),
#  ('stan', 31),
#  ('2019', 31),
#  ('2018', 30),
#  ('hiveql', 29),
#  ('5', 29),
#  ('peg', 28),
#  ('js', 28),
#  ('2021', 28),
#  ('codeql', 27),
#  ('imagej', 26),
#  ('macro', 26),
#  ('bison', 26),
#  ('xml', 24),
#  ('arc', 23),
#  ('terra', 21),
#  ('singularity', 21),
#  ('kicad', 21),
#  ('red', 20),
#  ('reason', 20),
#  ('cypher', 20),
#  ('template', 19),
#  ('flux', 19),
#  ('layout', 19),
#  ('mermaid', 18),
#  ('mcfunction', 18),
#  ('lasso', 18),
#  ('sieve', 18),
#  ('smt', 18),
#  ('graphviz', 17),
#  ('dot', 17),
#  ('sql', 17),
#  ('host', 17),
#  ('data', 16),
#  ('gcc', 16),
#  ('machine', 16),
#  ('modelica', 15),
#  ('mask', 15),
#  ('jetbrains', 15),
#  ('velocity', 15),
#  ('cairo', 15),
#  ('astro', 14),
#  ('click', 14),
#  ('6502', 11),
#  ('ring', 10),
#  ('alloy', 10),
#  ('web', 10),
#  ('ontology', 10),
#  ('opa', 8),
#  ('component', 8),
#  ('routeros', 8),
#  ('document', 7),
#  ('closure', 7),
#  ('templates', 7),
#  ('8086', 6),
#  ('parrot', 6),
#  ('move', 6),
#  ('adblock', 6),
#  ('filter', 6),
#  ('list', 6),
#  ('framework', 5),
#  ('slice', 5),
#  ('zap', 5),
#  ('pep8', 5),
#  ('lean', 5),
#  ('8051', 5),
#  ('ink', 4),
#  ('kit', 4),
#  ('qt', 4),
#  ('diff', 4),
#  ('ini', 3),
#  ('polar', 3),
#  ('uno', 2),
#  ('cadence', 2),
#  ('score', 2),
#  ('rmarkdown', 2),
#  ('riot', 2),
#  ('gettext', 2),
#  ('catalog', 2),
#  ('form', 1),
#  ('asciidoc', 1),
#  ('expression', 1),
#  ('80211', 1),
#  ('http', 1),
#  ('openapi', 1),
#  ('specification', 1)]

# %%
t5 = github_data_df['readme_clean'].apply(lambda x: myclnfunction(x))

# %%
t5_cnt = Counter(t5.explode())
t5_cnt.most_common()
# Out:
# [('1', 1462653),
#  ('file', 1280296),
#  ('data', 1116929),
#  ('code', 841991),
#  ('test', 757078),
#  ('image', 740513),
#  ('create', 708906),
#  ('build', 706714),
#  ('set', 696386),
#  ('name', 661142),
#  ('support', 614297),
#  ('function', 576514),
#  ('model', 570529),
#  ('project', 569795),
#  ('make', 560286),
#  ('http', 558639),
#  ('c', 530918),
#  ('app', 515640),
#  ('get', 506224),
#  ('learn', 502459),
#  ('python', 496298),
#  ('example', 491264),
#  ('network', 477513),
#  ('js', 467012),
#  ('type', 466813),
#  ('api', 446833),
#  ('server', 444425),
#  ('tool', 444002),
#  ('user', 443096),
#  ('install', 439300),
#  ('object', 435509),
#  ('command', 434523),
#  ('work', 431994),
#  ('list', 431816),
#  ('time', 431029),
#  ('5', 422647),
#  ('service', 415736),
#  ('source', 413675),
#  ('change', 410782),
#  ('x', 406484),
#  ('system', 389516),
#  ('script', 380698),
#  ('include', 379772),
#  ('string', 378714),
#  ('feature', 372346),
#  ('version', 370540),
#  ('library', 368236),
#  ('log', 363241),
#  ('process', 361301),
#  ('number', 352768),
#  ('find', 351278),
#  ('note', 344277),
#  ('web', 343978),
#  ('application', 339141),
#  ('base', 338551),
#  ('open', 332127),
#  ('go', 331816),
#  ('key', 331056),
#  ('javascript', 324864),
#  ('html', 321291),
#  ('update', 320156),
#  ('request', 318671),
#  ('detection', 317468),
#  ('class', 309168),
#  ('write', 307252),
#  ('call', 299025),
#  ('react', 297805),
#  ('page', 296929),
#  ('package', 296148),
#  ('import', 291603),
#  ('environment', 287776),
#  ('information', 286181),
#  ('json', 284967),
#  ('video', 284056),
#  ('6', 283230),
#  ('program', 282693),
#  ('check', 277568),
#  ('message', 267846),
#  ('text', 265534),
#  ('configuration', 264941),
#  ('output', 264091),
#  ('first', 262245),
#  ('train', 261476),
#  ('address', 256823),
#  ('paper', 255880),
#  ('read', 255731),
#  ('github', 253022),
#  ('link', 252281),
#  ('security', 250583),
#  ('machine', 246936),
#  ('path', 246294),
#  ('access', 245132),
#  ('generate', 237700),
#  ('directory', 235924),
#  ('software', 234355),
#  ('id', 233561),
#  ('download', 230610),
#  ('line', 229674),
#  ('load', 229465),
#  ('npm', 224483),
#  ('fix', 224015),
#  ('error', 222001),
#  ('design', 220167),
#  ('host', 219523),
#  ('simple', 218902),
#  ('development', 215745),
#  ('help', 211087),
#  ('case', 210236),
#  ('windows', 209581),
#  ('database', 209129),
#  ('bash', 208483),
#  ('format', 208302),
#  ('linux', 207973),
#  ('license', 207551),
#  ('issue', 206096),
#  ('input', 205999),
#  ('public', 205754),
#  ('config', 205309),
#  ('state', 203286),
#  ('node', 201859),
#  ('content', 201651),
#  ('method', 200734),
#  ('client', 200188),
#  ('search', 197826),
#  ('framework', 196521),
#  ('php', 196190),
#  ('control', 196053),
#  ('local', 195925),
#  ('free', 195187),
#  ('map', 193509),
#  ('java', 192741),
#  ('url', 192446),
#  ('device', 192381),
#  ('step', 192179),
#  ('docker', 192152),
#  ('store', 191819),
#  ('sh', 191506),
#  ('port', 190590),
#  ('point', 188740),
#  ('git', 186859),
#  ('view', 186051),
#  ('users', 186033),
#  ('module', 184326),
#  ('index', 183679),
#  ('memory', 182029),
#  ('language', 181417),
#  ('console', 180271),
#  ('google', 179448),
#  ('options', 179328),
#  ('etc', 178549),
#  ('pdf', 177722),
#  ('instance', 177523),
#  ('component', 177273),
#  ('css', 176425),
#  ('size', 174919),
#  ('android', 172100),
#  ('target', 169416),
#  ('select', 169086),
#  ('mode', 168567),
#  ('dataset', 168470),
#  ('r', 167933),
#  ('src', 164452),
#  ('repository', 162224),
#  ('analysis', 162034),
#  ('deploy', 161972),
#  ('release', 160987),
#  ('display', 160535),
#  ('custom', 159572),
#  ('alert', 159511),
#  ('order', 159361),
#  ('aws', 156857),
#  ('block', 156755),
#  ('multiple', 156244),
#  ('top', 156157),
#  ('deep', 155886),
#  ('table', 155532),
#  ('cloud', 155525),
#  ('array', 153894),
#  ('group', 153805),
#  ('event', 150521),
#  ('interface', 149793),
#  ('button', 149470),
#  ('task', 149180),
#  ('remove', 149075),
#  ('implementation', 149013),
#  ('applications', 147911),
#  ('sample', 147281),
#  ('action', 145955),
#  ('account', 145353),
#  ('net', 144103),
#  ('components', 144042),
#  ('pass', 143491),
#  ('document', 142923),
#  ('detect', 142459),
#  ('click', 142385),
#  ('plugin', 141914),
#  ('usage', 141786),
#  ('browser', 141283),
#  ('report', 140783),
#  ('copy', 139753),
#  ('common', 138887),
#  ('documentation', 138865),
#  ('reference', 138158),
#  ('query', 137618),
#  ('resources', 137390),
#  ('game', 136123),
#  ('structure', 135898),
#  ('setup', 135447),
#  ('root', 135424),
#  ('systems', 135406),
#  ('cache', 135041),
#  ('render', 134294),
#  ('monitor', 133373),
#  ('share', 133273),
#  ('tag', 131186),
#  ('neural', 130303),
#  ('email', 130039),
#  ('connect', 129951),
#  ('filter', 129433),
#  ('post', 128944),
#  ('tree', 128896),
#  ('debug', 128770),
#  ('form', 127113),
#  ('style', 126767),
#  ('examples', 126678),
#  ('settings', 126555),
#  ('match', 125948),
#  ('cluster', 125187),
#  ('password', 125149),
#  ('performance', 125034),
#  ('platform', 124871),
#  ('ip', 124703),
#  ('optional', 124323),
#  ('export', 123446),
#  ('env', 122697),
#  ('label', 122444),
#  ('ios', 121957),
#  ('shell', 121767),
#  ('graph', 121277),
#  ('rule', 120440),
#  ('easy', 120307),
#  ('static', 120064),
#  ('management', 119907),
#  ('parameters', 118853),
#  ('color', 118708),
#  ('installation', 116990),
#  ('io', 116183),
#  ('next', 116143),
#  ('computer', 115662),
#  ('print', 114778),
#  ('txt', 114553),
#  ('bug', 113603),
#  ('do', 112799),
#  ('status', 110498),
#  ('domain', 110077),
#  ('manage', 109423),
#  ('info', 109234),
#  ('guide', 109218),
#  ('clone', 108670),
#  ('delete', 108323),
#  ('useful', 108255),
#  ('arxiv', 107601),
#  ('response', 107434),
#  ('demo', 106742),
#  ('core', 105613),
#  ('fast', 105438),
#  ('track', 105257),
#  ('container', 104544),
#  ('proxy', 103485),
#  ('cd', 100727),
#  ('algorithm', 100643),
#  ('libraries', 99508),
#  ('production', 99183),
#  ('binary', 99030),
#  ('stream', 98813),
#  ('kernel', 98549),
#  ('ui', 98340),
#  ('pattern', 97970),
#  ('storage', 97883),
#  ('architecture', 97423),
#  ('uboot', 97350),
#  ('swift', 97129),
#  ('algorithms', 96374),
#  ('stack', 96274),
#  ('remote', 96240),
#  ('edit', 95440),
#  ('template', 95332),
#  ('collection', 95116),
#  ('course', 94391),
#  ('space', 94299),
#  ('record', 94045),
#  ('global', 93769),
#  ('azure', 93704),
#  ('2019', 93419),
#  ('team', 93055),
#  ('sudo', 92738),
#  ('limit', 92721),
#  ('attack', 92641),
#  ('devices', 92170),
#  ('dependencies', 92046),
#  ('best', 91874),
#  ('apps', 91691),
#  ('date', 91521),
#  ('window', 91372),
#  ('board', 91326),
#  ('events', 90980),
#  ('solution', 90723),
#  ('engine', 90683),
#  ('bin', 89930),
#  ('channel', 89893),
#  ('question', 89846),
#  ('book', 89703),
#  ('star', 89459),
#  ('layer', 89376),
#  ('website', 89120),
#  ('location', 88440),
#  ('standard', 88316),
#  ('visual', 88171),
#  ('job', 87805),
#  ('compile', 87730),
#  ('hash', 87108),
#  ('editor', 86813),
#  ('distribute', 86242),
#  ('v', 86200),
#  ('boot', 86145),
#  ('mit', 85749),
#  ('blog', 85467),
#  ('move', 85380),
#  ('os', 85351),
#  ('2020', 85164),
#  ('3d', 84930),
#  ('home', 84815),
#  ('resource', 84229),
#  ('basic', 83856),
#  ('private', 83427),
#  ('face', 83289),
#  ('token', 83125),
#  ('context', 82089),
#  ('sort', 81712),
#  ('online', 81285),
#  ('attribute', 81251),
#  ('site', 81141),
#  ('videos', 80976),
#  ('header', 80822),
#  ('yaml', 80167),
#  ('native', 80034),
#  ('scale', 79909),
#  ('small', 79824),
#  ('modules', 79792),
#  ('box', 78988),
#  ('deployment', 78961),
#  ('sql', 78874),
#  ('controller', 78789),
#  ('engineer', 78315),
#  ('2018', 77956),
#  ('dynamic', 77733),
#  ('2021', 77685),
#  ('upload', 77641),
#  ('power', 77565),
#  ('properties', 77439),
#  ('scan', 77144),
#  ('microsoft', 76876),
#  ('advance', 76724),
#  ('driver', 76263),
#  ('register', 76078),
#  ('apache', 75955),
#  ('connection', 75909),
#  ('element', 75823),
#  ('word', 75640),
#  ('requirements', 75624),
#  ('count', 75442),
#  ('compute', 75283),
#  ('dev', 75220),
#  ('extension', 75184),
#  ('screen', 74780),
#  ('integration', 74779),
#  ('push', 74402),
#  ('switch', 74377),
#  ('cod', 74233),
#  ('warn', 73364),
#  ('mobile', 73042),
#  ('flow', 72948),
#  ('range', 72749),
#  ('flag', 72730),
#  ('protocol', 72455),
#  ('versions', 72082),
#  ('recognition', 71982),
#  ('vue', 71927),
#  ('cpu', 71753),
#  ('xml', 71717),
#  ('admin', 71710),
#  ('research', 71270),
#  ('sequence', 70572),
#  ('convert', 70463),
#  ('frame', 70378),
#  ('errors', 70368),
#  ('amazon', 69879),
#  ('profile', 69807),
#  ('2022', 69670),
#  ('bind', 69669),
#  ('classification', 69610),
#  ('publish', 69467),
#  ('pip', 69341),
#  ('kubernetes', 69328),
#  ('virtual', 69156),
#  ('character', 68951),
#  ('ai', 68650),
#  ('serve', 68200),
#  ('manager', 67941),
#  ('speed', 67860),
#  ('2017', 67812),
#  ('comment', 67693),
#  ('parse', 67178),
#  ('operations', 67165),
#  ('contribute', 66801),
#  ('hardware', 66735),
#  ('camera', 66570),
#  ('introduction', 66238),
#  ('extract', 66152),
#  ('localhost', 66076),
#  ('long', 66020),
#  ('people', 65800),
#  ('authentication', 65297),
#  ('plan', 65240),
#  ('session', 64535),
#  ('vision', 64517),
#  ('thread', 64494),
#  ('audio', 64372),
#  ('ruby', 64057),
#  ('rest', 63920),
#  ('active', 63884),
#  ('answer', 63729),
#  ('real', 63342),
#  ('community', 63323),
#  ('syntax', 63292),
#  ('developers', 63230),
#  ('cause', 63118),
#  ('random', 63053),
#  ('position', 62769),
#  ('launch', 62699),
#  ('bootstrap', 62681),
#  ('login', 62251),
#  ('datasets', 62247),
#  ('developer', 62105),
#  ('university', 61545),
#  ('flash', 60989),
#  ('product', 60751),
#  ('embed', 60569),
#  ('jest', 60524),
#  ('play', 60356),
#  ('transfer', 60151),
#  ('elements', 60138),
#  ('review', 60114),
#  ('assets', 59950),
#  ('live', 59933),
#  ('terminal', 59864),
#  ('trigger', 59843),
#  ('patch', 59615),
#  ('tensorflow', 59445),
#  ('focus', 59307),
#  ('less', 59182),
#  ('servers', 58971),
#  ('drive', 58897),
#  ('segmentation', 58863),
#  ('article', 58858),
#  ('automate', 58807),
#  ('tutorial', 58761),
#  ('practice', 58738),
#  ('username', 58712),
#  ('series', 58479),
#  ('secure', 58280),
#  ('certificate', 58130),
#  ('exe', 58129),
#  ('macos', 58065),
#  ('cli', 58014),
#  ('realtime', 57878),
#  ('awesome', 57814),
#  ('commit', 57700),
#  ('dns', 57699),
#  ('master', 57654),
#  ('backend', 57530),
#  ('challenge', 57504),
#  ('sign', 57300),
#  ('operation', 57299),
#  ('callback', 57287),
#  ('traffic', 57159),
#  ('bar', 57145),
#  ('pytorch', 57133),
#  ('mac', 57103),
#  ('csv', 56895),
#  ('generation', 56674),
#  ('md', 56323),
#  ('q', 56025),
#  ('effect', 55993),
#  ('background', 55886),
#  ('menu', 55758),
#  ('future', 55184),
#  ('png', 55149),
#  ('card', 55116),
#  ('rout', 54870),
#  ('runtime', 54716),
#  ('bundle', 54592),
#  ('ssh', 54538),
#  ('plugins', 54534),
#  ('readme', 54306),
#  ('docs', 54286),
#  ('sdk', 54248),
#  ('external', 54197),
#  ('experience', 54027),
#  ('contact', 53955),
#  ('condition', 53928),
#  ('prop', 53819),
#  ('apis', 53694),
#  ('nod', 53442),
#  ('queue', 53429),
#  ('yarn', 53285),
#  ('encode', 53242),
#  ('db', 53148),
#  ('metadata', 53093),
#  ('science', 53080),
#  ('dependency', 53046),
#  ('validation', 53044),
#  ('metrics', 53018),
#  ('bite', 52556),
#  ('fetch', 52538),
#  ('buffer', 52429),
#  ('tcp', 52183),
#  ('theme', 52086),
#  ('policy', 52025),
#  ('contract', 51906),
#  ('internet', 51827),
#  ('void', 51824),
#  ('echo', 51428),
#  ('knowledge', 51034),
#  ('watch', 50829),
#  ('hide', 50742),
#  ('lead', 50613),
#  ('facebook', 50360),
#  ('media', 50333),
#  ('bytes', 50284),
#  ('automatic', 50124),
#  ('lecture', 50067),
#  ('score', 50063),
#  ('signal', 49694),
#  ('final', 49539),
#  ('interview', 49520),
#  ('reason', 48691),
#  ('red', 48687),
#  ('https', 48663),
#  ('history', 48358),
#  ('edge', 48330),
#  ('verify', 48287),
#  ('pipeline', 48270),
#  ('chrome', 48172),
#  ('pool', 48156),
#  ('s3', 47765),
#  ('interactive', 47743),
#  ('region', 47605),
#  ('official', 47462),
#  ('twitter', 46957),
#  ('center', 46491),
#  ('mysql', 46448),
#  ('split', 46420),
#  ('compare', 46399),
#  ('role', 46323),
#  ('capture', 46150),
#  ('lib', 45977),
#  ('modern', 45882),
#  ('disk', 45826),
#  ('express', 45746),
#  ('zip', 45724),
#  ('medium', 45644),
#  ('internal', 45610),
#  ('company', 45233),
#  ('unique', 45139),
#  ('exploit', 44958),
#  ('router', 44952),
#  ('spring', 44845),
#  ('clean', 44828),
#  ('promise', 44802),
#  ('yml', 44625),
#  ('prompt', 44589),
#  ('usb', 44579),
#  ('opensource', 44463),
#  ('wrapper', 44436),
#  ('loop', 44355),
#  ('generator', 44239),
#  ('ci', 44164),
#  ('light', 44107),
#  ('efficient', 43941),
#  ('i2c', 43896),
#  ('sensor', 43867),
#  ('reverse', 43450),
#  ('rate', 43430),
#  ('fork', 43170),
#  ('init', 43133),
#  ('lightweight', 43128),
#  ('bot', 43030),
#  ('jpg', 42652),
#  ('merge', 42548),
#  ('behavior', 42503),
#  ('raw', 42378),
#  ('worker', 42339),
#  ('maintain', 42241),
#  ('cvpr', 42108),
#  ('webpack', 41936),
#  ('secret', 41910),
#  ('empty', 41875),
#  ('credentials', 41640),
#  ('infrastructure', 41501),
#  ('human', 41465),
#  ('player', 41370),
#  ('logic', 41334),
#  ('prediction', 41288),
#  ('gpu', 41275),
#  ('desktop', 41245),
#  ('frontend', 41050),
#  ('notification', 40951),
#  ('distribution', 40802),
#  ('price', 40791),
#  ('auto', 40765),
#  ('ubuntu', 40743),
#  ('pair', 40742),
#  ('quick', 40671),
#  ('quality', 40545),
#  ('social', 40488),
#  ('cost', 40447),
#  ('evaluation', 40362),
#  ('experiment', 40331),
#  ('languages', 40134),
#  ('icon', 40039),
#  ('templates', 39980),
#  ('encrypt', 39921),
#  ('head', 39860),
#  ('powershell', 39783),
#  ('slide', 39708),
#  ('containers', 39533),
#  ('partition', 39422),
#  ('firebase', 39421),
#  ('socket', 39232),
#  ('hook', 39184),
#  ('optimize', 39180),
#  ('todo', 39167),
#  ('technology', 39100),
#  ('ram', 39086),
#  ('archive', 39073),
#  ('fit', 39022),
#  ('study', 39008),
#  ('python3', 38871),
#  ('optimization', 38738),
#  ('bus', 38685),
#  ('mask', 38610),
#  ('transform', 38600),
#  ('42', 38570),
#  ('endpoint', 38567),
#  ('apikey', 38560),
#  ('layout', 38412),
#  ('utility', 38403),
#  ('ssl', 38328),
#  ('smart', 38186),
#  ('solutions', 38183),
#  ('payload', 38150),
#  ('forward', 38136),
#  ('hack', 38056),
#  ('analytics', 38053),
#  ('cs', 38042),
#  ('progress', 37955),
#  ('provider', 37892),
#  ('upgrade', 37879),
#  ('redis', 37841),
#  ('robot', 37800),
#  ('youtube', 37508),
#  ('permissions', 37507),
#  ('trace', 37492),
#  ('schedule', 37438),
#  ('copyright', 37390),
#  ('inference', 37345),
#  ('notice', 37315),
#  ('combine', 37296),
#  ('lambda', 37218),
#  ('pi', 37103),
#  ('serial', 37066),
#  ('phone', 37049),
#  ('matrix', 37009),
#  ('batch', 36984),
#  ('mount', 36965),
#  ('topic', 36957),
#  ('digital', 36820),
#  ('volume', 36816),
#  ('vulnerability', 36716),
#  ('business', 36696),
#  ('semantic', 36546),
#  ('apple', 36477),
#  ('loss', 36418),
#  ('fire', 36199),
#  ('chain', 36197),
#  ('vector', 36157),
#  ('communication', 36102),
#  ('conference', 35764),
#  ('nginx', 35753),
#  ('linear', 35734),
#  ('curl', 35675),
#  ('pretrained', 35612),
#  ('malware', 35561),
#  ('news', 35474),
#  ('compiler', 35473),
#  ('notifications', 35311),
#  ('natural', 35272),
#  ('dashboard', 35258),
#  ('lock', 35246),
#  ('ieee', 35218),
#  ('angular', 35199),
#  ('gui', 35188),
#  ('pod', 35122),
#  ('distance', 35065),
#  ('generic', 35051),
#  ('kind', 35042),
#  ('async', 34944),
#  ('protect', 34922),
#  ('expression', 34899),
#  ('dom', 34870),
#  ('schema', 34868),
#  ('listen', 34832),
#  ('firmware', 34800),
#  ('sit', 34779),
#  ('anything', 34738),
#  ('adversarial', 34681),
#  ('shape', 34546),
#  ('intel', 34516),
#  ('namespace', 34444),
#  ('chart', 34411),
#  ('opencv', 34399),
#  ('entity', 34362),
#  ('intelligence', 34324),
#  ('cmd', 34319),
#  ('accuracy', 34291),
#  ('2023', 34274),
#  ('visualization', 34255),
#  ('img', 34135),
#  ('mail', 33993),
#  ('summary', 33925),
#  ('estimation', 33798),
#  ('manual', 33772),
#  ('auth', 33705),
#  ('extensions', 33652),
#  ('pin', 33583),
#  ('drop', 33549),
#  ('agent', 33512),
#  ('alternative', 33395),
#  ('plot', 33340),
#  ('offset', 33289),
#  ('draw', 33275),
#  ('toolkit', 33239),
#  ('workflow', 33165),
#  ('chat', 33071),
#  ('activity', 32972),
#  ('continuous', 32949),
#  ('backup', 32899),
#  ('headers', 32809),
#  ('selection', 32745),
#  ('validate', 32727),
#  ('tutorials', 32708),
#  ('coverage', 32650),
#  ('translation', 32630),
#  ('typescript', 32444),
#  ('sound', 32426),
#  ('transaction', 32337),
#  ('encryption', 32308),
#  ('float', 32302),
#  ('svg', 32296),
#  ('injection', 32238),
#  ('handler', 32216),
#  ('platforms', 32125),
#  ('await', 32041),
#  ('xss', 31989),
#  ('jsx', 31961),
#  ('notebook', 31946),
#  ('gnu', 31873),
#  ('ide', 31843),
#  ('detector', 31772),
#  ('markdown', 31658),
#  ('measure', 31571),
#  ('gateway', 31503),
#  ('depth', 31386),
#  ('delay', 31309),
#  ('flexible', 31287),
#  ('redirect', 31251),
#  ('hub', 31196),
#  ('parallel', 31152),
#  ('mine', 31146),
#  ('cpp', 31136),
#  ('databases', 31054),
#  ('jquery', 31049),
#  ('operator', 31009),
#  ('hand', 30965),
#  ('parser', 30898),
#  ('interfaces', 30850),
#  ('fee', 30788),
#  ('automation', 30786),
#  ('regression', 30736),
#  ('browsers', 30721),
#  ('aim', 30663),
#  ('functional', 30626),
#  ('talk', 30618),
#  ('balance', 30540),
#  ('matlab', 30532),
#  ('ml', 30449),
#  ('wifi', 30445),
#  ('vm', 30391),
#  ('sync', 30320),
#  ('crash', 30285),
#  ('attention', 30126),
#  ('feedback', 30031),
#  ('age', 30022),
#  ('bucket', 29945),
#  ('material', 29930),
#  ('statistics', 29821),
#  ('urls', 29817),
#  ('motion', 29795),
#  ('highlight', 29739),
#  ('cat', 29736),
#  ('music', 29690),
#  ('golang', 29676),
#  ('tar', 29620),
#  ('arm', 29583),
#  ('django', 29439),
#  ('threshold', 29421),
#  ('heroku', 29394),
#  ('iot', 29366),
#  ('exception', 29355),
#  ('terraform', 29308),
#  ('commandline', 29265),
#  ('enzyme', 29264),
#  ('navigation', 29218),
#  ('wiki', 29166),
#  ('permission', 29124),
#  ('risk', 29000),
#  ('drivers', 28967),
#  ('websocket', 28820),
#  ('conda', 28728),
#  ('kubectl', 28639),
#  ('animation', 28580),
#  ('frameworks', 28451),
#  ('transactions', 28441),
#  ('2d', 28379),
#  ('scene', 28346),
#  ('objectivec', 28308),
#  ('math', 28247),
#  ('websites', 28134),
#  ('bypass', 28130),
#  ('bits', 28087),
#  ('robust', 28084),
#  ('compress', 28078),
#  ('tip', 28000),
#  ('tokens', 27948),
#  ('meta', 27927),
#  ('black', 27823),
#  ('jar', 27804),
#  ('rust', 27757),
#  ('exchange', 27732),
#  ('lab', 27638),
#  ('speech', 27633),
#  ('manifest', 27553),
#  ('grid', 27508),
#  ('english', 27425),
#  ('extraction', 27420),
#  ('privacy', 27279),
#  ('clock', 27250),
#  ('market', 27159),
#  ('diff', 27124),
#  ('zone', 27035),
#  ('chip', 27018),
#  ('mention', 26999),
#  ('sheet', 26971),
#  ('keyboard', 26933),
#  ('resolution', 26923),
#  ('tls', 26903),
#  ('pose', 26878),
#  ('strategy', 26870),
#  ('segment', 26814),
#  ('stable', 26803),
#  ('pointer', 26731),
#  ('personal', 26580),
#  ('health', 26579),
#  ('ec2', 26576),
#  ('inject', 26475),
#  ('prometheus', 26446),
#  ('dump', 26431),
#  ('scroll', 26284),
#  ('mongodb', 26227),
#  ('compression', 26150),
#  ('vim', 26090),
#  ('safe', 26026),
#  ('lua', 25995),
#  ('frequency', 25981),
#  ('dll', 25944),
#  ('packet', 25850),
#  ('party', 25822),
#  ('identity', 25820),
#  ('blockchain', 25702),
#  ('registry', 25666),
#  ('rat', 25580),
#  ('discover', 25476),
#  ('oauth', 25462),
#  ('compatibility', 25418),
#  ('trust', 25409),
#  ('organization', 25394),
#  ('benchmark', 25344),
#  ('unity', 25311),
#  ('icons', 25305),
#  ('generative', 25239),
#  ('ids', 25186),
#  ('capabilities', 25183),
#  ('panel', 25142),
#  ('coordinate', 25107),
#  ('minimal', 25089),
#  ('audit', 25005),
#  ('scanner', 24988),
#  ('scalable', 24956),
#  ('graphics', 24935),
#  ('transformer', 24931),
#  ('html5', 24839),
#  ('raspberry', 24789),
#  ('rename', 24783),
#  ('vulnerabilities', 24749),
#  ('touch', 24680),
#  ('discovery', 24669),
#  ('postgresql', 24613),
#  ('pick', 24504),
#  ('curated', 24460),
#  ('wordpress', 24456),
#  ('snapshot', 24444),
#  ('rail', 24402),
#  ('sense', 24245),
#  ('annotations', 24227),
#  ('complexity', 24205),
#  ('car', 23995),
#  ('spec', 23992),
#  ('crossplatform', 23987),
#  ('es6', 23764),
#  ('secrets', 23755),
#  ('unix', 23676),
#  ('signature', 23629),
#  ('authorization', 23604),
#  ('cmake', 23604),
#  ('adapter', 23562),
#  ('cfg', 23560),
#  ('podcast', 23440),
#  ('verification', 23365),
#  ('threat', 23312),
#  ('annotation', 23282),
#  ('picture', 23272),
#  ('life', 23233),
#  ('serverless', 23161),
#  ('asynchronous', 23029),
#  ('tweak', 22882),
#  ('decode', 22831),
#  ('redux', 22665),
#  ('udp', 22647),
#  ('preview', 22575),
#  ('scheme', 22560),
#  ('ts', 22542),
#  ('logo', 22459),
#  ('accessible', 22436),
#  ('slack', 22332),
#  ('startup', 22312),
#  ('specification', 22235),
#  ('theory', 22163),
#  ('spark', 22144),
#  ('journal', 22121),
#  ('executable', 22100),
#  ('roles', 22039),
#  ('enterprise', 22006),
#  ('transport', 21991),
#  ('cycle', 21989),
#  ('trade', 21952),
#  ('utilities', 21865),
#  ('unsupervised', 21847),
#  ('prototype', 21813),
#  ('dockercompose', 21757),
#  ('provision', 21688),
#  ('asset', 21678),
#  ('font', 21661),
#  ('green', 21600),
#  ('kafka', 21532),
#  ('translate', 21481),
#  ('stock', 21480),
#  ('fonts', 21478),
#  ('counter', 21477),
#  ('homepage', 21423),
#  ('exercise', 21422),
#  ('protection', 21372),
#  ('simulation', 21328),
#  ('paste', 21300),
#  ('standalone', 21297),
#  ('laravel', 21265),
#  ('transition', 21217),
#  ('builder', 21156),
#  ('interval', 21143),
#  ('nlp', 21133),
#  ...]

# %%
t6 = github_data_df['tree'].apply(lambda x: myclnfunction(x))

# %%
t6_cnt = Counter(t6.explode())
t6_cnt.most_common()
# Out:
# [('md', 325331),
#  ('readme', 226553),
#  ('license', 122166),
#  ('json', 76702),
#  ('txt', 72106),
#  ('yml', 54284),
#  ('js', 47756),
#  ('sh', 45016),
#  ('go', 39764),
#  ('src', 38999),
#  ('test', 38897),
#  ('github', 36783),
#  ('c', 35230),
#  ('pdf', 34427),
#  ('png', 32537),
#  ('package', 31035),
#  ('config', 30235),
#  ('ipynb', 26781),
#  ('requirements', 23195),
#  ('docs', 20048),
#  ('makefile', 19489),
#  ('contribute', 18652),
#  ('setup', 18332),
#  ('travis', 18122),
#  ('cpp', 17375),
#  ('gradle', 17296),
#  ('image', 17248),
#  ('php', 17190),
#  ('changelog', 16603),
#  ('yaml', 16327),
#  ('data', 16306),
#  ('xml', 15719),
#  ('build', 15489),
#  ('html', 15164),
#  ('script', 15031),
#  ('lib', 14292),
#  ('dockerfile', 13717),
#  ('lock', 12860),
#  ('index', 12590),
#  ('model', 12531),
#  ('examples', 11218),
#  ('jpg', 10511),
#  ('app', 10330),
#  ('utils', 9517),
#  ('editorconfig', 9067),
#  ('example', 8789),
#  ('tool', 8714),
#  ('bat', 8635),
#  ('assets', 8324),
#  ('cfg', 8289),
#  ('1', 7544),
#  ('bin', 7292),
#  ('toml', 7251),
#  ('manifest', 7044),
#  ('project', 6951),
#  ('csv', 6786),
#  ('demo', 6663),
#  ('vscode', 6606),
#  ('settings', 6582),
#  ('train', 6282),
#  ('properties', 5919),
#  ('dockercompose', 5901),
#  ('public', 5770),
#  ('yarn', 5759),
#  ('tf', 5471),
#  ('install', 5356),
#  ('ini', 5317),
#  ('img', 5052),
#  ('resources', 5047),
#  ('env', 4795),
#  ('sample', 4759),
#  ('security', 4751),
#  ('copy', 4749),
#  ('css', 4740),
#  ('include', 4714),
#  ('zip', 4688),
#  ('mod', 4606),
#  ('composer', 4514),
#  ('server', 4426),
#  ('r', 4314),
#  ('log', 4247),
#  ('cmd', 4192),
#  ('docker', 4079),
#  ('ps1', 4031),
#  ('templates', 3970),
#  ('version', 3877),
#  ('cs', 3620),
#  ('spec', 3556),
#  ('api', 3496),
#  ('ts', 3380),
#  ('gif', 3367),
#  ('common', 3318),
#  ('dataset', 3242),
#  ('configs', 3227),
#  ('sql', 3119),
#  ('webpack', 3091),
#  ('detection', 3032),
#  ('todo', 3020),
#  ('cmake', 2901),
#  ('lua', 2890),
#  ('notice', 2880),
#  ('util', 2878),
#  ('source', 2795),
#  ('android', 2776),
#  ('code', 2764),
#  ('static', 2713),
#  ('cargo', 2676),
#  ('circleci', 2608),
#  ('output', 2585),
#  ('release', 2521),
#  ('screenshots', 2491),
#  ('file', 2373),
#  ('datasets', 2311),
#  ('client', 2273),
#  ('core', 2246),
#  ('network', 2246),
#  ('java', 2233),
#  ('db', 2227),
#  ('web', 2219),
#  ('5', 2179),
#  ('service', 2173),
#  ('exe', 2158),
#  ('notebooks', 2153),
#  ('python', 2136),
#  ('patch', 2093),
#  ('modules', 2029),
#  ('documentation', 2017),
#  ('template', 2014),
#  ('mp4', 1963),
#  ('plugin', 1943),
#  ('bower', 1941),
#  ('media', 1920),
#  ('news', 1915),
#  ('change', 1902),
#  ('environment', 1882),
#  ('cc', 1864),
#  ('report', 1862),
#  ('ios', 1860),
#  ('style', 1844),
#  ('jest', 1820),
#  ('phpunit', 1796),
#  ('deploy', 1740),
#  ('logo', 1739),
#  ('appveyor', 1714),
#  ('misc', 1708),
#  ('dev', 1677),
#  ('svg', 1664),
#  ('tox', 1663),
#  ('learn', 1611),
#  ('screenshot', 1601),
#  ('view', 1559),
#  ('ui', 1556),
#  ('class', 1543),
#  ('paper', 1529),
#  ('metadata', 1528),
#  ('net', 1526),
#  ('6', 1514),
#  ('ml', 1508),
#  ('clangformat', 1494),
#  ('ico', 1488),
#  ('babel', 1487),
#  ('plugins', 1477),
#  ('pkg', 1450),
#  ('type', 1448),
#  ('library', 1425),
#  ('rule', 1390),
#  ('database', 1389),
#  ('markdown', 1372),
#  ('note', 1370),
#  ('rar', 1368),
#  ('ips', 1366),
#  ('gitlabci', 1362),
#  ('mat', 1340),
#  ('init', 1326),
#  ('meta', 1299),
#  ('dll', 1267),
#  ('tslint', 1257),
#  ('msg', 1255),
#  ('bootstrap', 1252),
#  ('experiment', 1245),
#  ('analysis', 1241),
#  ('history', 1231),
#  ('ipset', 1230),
#  ('function', 1197),
#  ('task', 1194),
#  ('read', 1191),
#  ('docx', 1189),
#  ('iml', 1177),
#  ('feature', 1160),
#  ('flake8', 1155),
#  ('etc', 1145),
#  ('ai', 1144),
#  ('hack', 1142),
#  ('user', 1138),
#  ('ci', 1133),
#  ('jenkinsfile', 1130),
#  ('design', 1112),
#  ('windows', 1106),
#  ('jquery', 1085),
#  ('video', 1077),
#  ('filter', 1068),
#  ('detect', 1059),
#  ('rollup', 1050),
#  ('frontend', 1049),
#  ('command', 1048),
#  ('icon', 1047),
#  ('rspec', 1038),
#  ('xlsx', 1035),
#  ('support', 1017),
#  ('namespace', 1017),
#  ('development', 1016),
#  ('application', 1009),
#  ('vagrantfile', 999),
#  ('final', 993),
#  ('system', 990),
#  ('pytest', 987),
#  ('codeofconduct', 985),
#  ('eval', 983),
#  ('jpeg', 972),
#  ('manage', 971),
#  ('backend', 960),
#  ('map', 955),
#  ('internal', 952),
#  ('v', 946),
#  ('tar', 937),
#  ('rout', 933),
#  ('page', 921),
#  ('reference', 919),
#  ('debian', 915),
#  ('yara', 914),
#  ('debug', 913),
#  ('module', 913),
#  ('h5', 906),
#  ('components', 900),
#  ('launch', 899),
#  ('favicon', 896),
#  ('linux', 896),
#  ('swift', 895),
#  ('share', 885),
#  ('program', 885),
#  ('karma', 883),
#  ('list', 877),
#  ('graph', 870),
#  ('local', 866),
#  ('dependencies', 865),
#  ('document', 863),
#  ('poetry', 855),
#  ('update', 851),
#  ('classification', 848),
#  ('husky', 847),
#  ('base', 846),
#  ('storage', 842),
#  ('input', 841),
#  ('preprocessing', 823),
#  ('cli', 822),
#  ('monitor', 812),
#  ('azurepipelines', 805),
#  ('board', 803),
#  ('evaluation', 802),
#  ('renovate', 802),
#  ('icons', 801),
#  ('deployment', 800),
#  ('process', 798),
#  ('mix', 797),
#  ('action', 793),
#  ('gitpod', 790),
#  ('book', 788),
#  ('gui', 784),
#  ('hook', 777),
#  ('drivers', 776),
#  ('versions', 773),
#  ('mkdocs', 773),
#  ('inference', 767),
#  ('info', 766),
#  ('rubocop', 766),
#  ('deep', 761),
#  ('tutorial', 752),
#  ('pc', 751),
#  ('guide', 750),
#  ('configuration', 747),
#  ('object', 747),
#  ('external', 745),
#  ('fonts', 745),
#  ('benchmark', 743),
#  ('translations', 737),
#  ('alert', 735),
#  ('machine', 725),
#  ('helpers', 719),
#  ('sbt', 707),
#  ('terraform', 704),
#  ('metrics', 702),
#  ('nix', 700),
#  ('plot', 697),
#  ('apps', 695),
#  ('presentation', 681),
#  ('make', 680),
#  ('fs', 680),
#  ('key', 677),
#  ('asm', 675),
#  ('bash', 672),
#  ('admin', 671),
#  ('neural', 669),
#  ('runtime', 665),
#  ('prop', 665),
#  ('post', 660),
#  ('jar', 660),
#  ('slide', 659),
#  ('wav', 648),
#  ('search', 643),
#  ('contract', 636),
#  ('arch', 634),
#  ('content', 629),
#  ('copyright', 629),
#  ('cluster', 627),
#  ('mitlicense', 627),
#  ('options', 625),
#  ('videos', 623),
#  ('bmp', 620),
#  ('control', 615),
#  ('cache', 613),
#  ('postcss', 613),
#  ('compile', 612),
#  ('face', 608),
#  ('testdata', 607),
#  ('website', 604),
#  ('theme', 600),
#  ('utilities', 599),
#  ('desktop', 598),
#  ('architecture', 591),
#  ('prediction', 589),
#  ('framework', 589),
#  ('tree', 587),
#  ('logger', 587),
#  ('engine', 585),
#  ('nginx', 583),
#  ('node', 580),
#  ('rc', 578),
#  ('ansible', 575),
#  ('crypto', 572),
#  ('profile', 569),
#  ('faq', 569),
#  ('game', 566),
#  ('libraries', 564),
#  ('benchmarks', 552),
#  ('yolo', 551),
#  ('archive', 550),
#  ('cloud', 547),
#  ('picture', 543),
#  ('target', 541),
#  ('layer', 536),
#  ('help', 535),
#  ('aws', 534),
#  ('cypress', 532),
#  ('detector', 532),
#  ('zone', 531),
#  ('cnn', 530),
#  ('languages', 529),
#  ('disk', 529),
#  ('tutorials', 528),
#  ('nuget', 527),
#  ('plan', 527),
#  ('hardware', 526),
#  ('schema', 524),
#  ('download', 523),
#  ('injection', 521),
#  ('migrations', 520),
#  ('global', 520),
#  ('matlab', 520),
#  ('sort', 520),
#  ('workspace', 517),
#  ('cod', 516),
#  ('text', 515),
#  ('feed', 514),
#  ('track', 513),
#  ('audio', 512),
#  ('uninstall', 509),
#  ('sound', 508),
#  ('installer', 508),
#  ('bot', 508),
#  ('releasenotes', 504),
#  ('chart', 504),
#  ('upload', 498),
#  ('groovy', 491),
#  ('tex', 488),
#  ('angular', 486),
#  ('e2e', 484),
#  ('miner', 481),
#  ('diagram', 481),
#  ('pipeline', 480),
#  ('shell', 479),
#  ('host', 477),
#  ('designer', 471),
#  ('message', 470),
#  ('directory', 466),
#  ('number', 466),
#  ('summary', 465),
#  ('x', 465),
#  ('screen', 464),
#  ('helper', 464),
#  ('algorithm', 462),
#  ('circle', 455),
#  ('mypy', 454),
#  ('attack', 453),
#  ('camera', 453),
#  ('kubernetes', 453),
#  ('label', 450),
#  ('recognition', 450),
#  ('coffee', 448),
#  ('check', 448),
#  ('bundle', 447),
#  ('link', 447),
#  ('malware', 442),
#  ('loss', 441),
#  ('controller', 438),
#  ('events', 435),
#  ('clean', 435),
#  ('platform', 434),
#  ('segmentation', 432),
#  ('header', 432),
#  ('algorithms', 429),
#  ('state', 429),
#  ('tailwind', 426),
#  ('export', 423),
#  ('classifier', 421),
#  ('stack', 421),
#  ('software', 420),
#  ('grafana', 419),
#  ('time', 417),
#  ('notebook', 417),
#  ('dashboard', 415),
#  ('visualization', 412),
#  ('http', 410),
#  ('htm', 404),
#  ('convert', 402),
#  ('roadmap', 401),
#  ('vite', 399),
#  ('publish', 398),
#  ('git', 396),
#  ('keywords', 395),
#  ('custom', 392),
#  ('apk', 391),
#  ('backup', 391),
#  ('firmware', 391),
#  ('resource', 390),
#  ('art', 389),
#  ('flow', 388),
#  ('firebase', 387),
#  ('proxy', 386),
#  ('set', 383),
#  ('tensorflow', 382),
#  ('color', 381),
#  ('bind', 381),
#  ('commit', 381),
#  ('azure', 380),
#  ('site', 380),
#  ('snapshot', 380),
#  ('binary', 378),
#  ('string', 378),
#  ('prometheus', 378),
#  ('os', 375),
#  ('name', 374),
#  ('preview', 372),
#  ('darknet', 371),
#  ('integration', 371),
#  ('neon', 368),
#  ('course', 368),
#  ('pod', 367),
#  ('cpuminer', 366),
#  ('login', 365),
#  ('roles', 362),
#  ('lerna', 362),
#  ('table', 362),
#  ('generate', 362),
#  ('root', 362),
#  ('upgrade', 361),
#  ('mobile', 359),
#  ('vue', 355),
#  ('block', 354),
#  ('arduino', 353),
#  ('utility', 353),
#  ('javascript', 353),
#  ('webapp', 353),
#  ('drone', 351),
#  ('trainer', 351),
#  ('array', 350),
#  ('background', 350),
#  ('tag', 349),
#  ('regression', 347),
#  ('phpcs', 344),
#  ('console', 343),
#  ('query', 342),
#  ('language', 342),
#  ('io', 342),
#  ('form', 341),
#  ('domain', 341),
#  ('home', 340),
#  ('extension', 340),
#  ('proto', 340),
#  ('exploit', 340),
#  ('2020', 338),
#  ('event', 337),
#  ('group', 336),
#  ('stats', 336),
#  ('robots', 335),
#  ('extensions', 335),
#  ('bug', 335),
#  ('ibm', 335),
#  ('session', 332),
#  ('platformio', 331),
#  ('structure', 331),
#  ('agent', 331),
#  ('store', 330),
#  ('sha2', 328),
#  ('manual', 326),
#  ('get', 325),
#  ('work', 324),
#  ('graphics', 323),
#  ('parser', 323),
#  ('kernel', 322),
#  ('find', 321),
#  ('i18n', 321),
#  ('record', 321),
#  ('vision', 319),
#  ('community', 318),
#  ('generator', 318),
#  ('device', 317),
#  ('2018', 314),
#  ('hash', 314),
#  ('applications', 313),
#  ('asciidoc', 311),
#  ('yolov3', 310),
#  ('stream', 310),
#  ('exercise', 310),
#  ('mine', 309),
#  ('opencv', 308),
#  ('production', 308),
#  ('font', 308),
#  ('netlify', 308),
#  ('troubleshoot', 305),
#  ('driver', 305),
#  ('lecture', 304),
#  ('format', 303),
#  ('assignment', 302),
#  ('artisan', 301),
#  ('phpstan', 300),
#  ('perl', 300),
#  ('coveralls', 299),
#  ('svm', 299),
#  ('usage', 298),
#  ('management', 298),
#  ('advance', 297),
#  ('transform', 297),
#  ('auth', 297),
#  ('avi', 297),
#  ('startup', 297),
#  ('introduction', 296),
#  ('menu', 296),
#  ('next', 295),
#  ('parameters', 295),
#  ('research', 295),
#  ('snippets', 294),
#  ('storybook', 292),
#  ('loader', 291),
#  ('secrets', 291),
#  ('case', 291),
#  ('job', 289),
#  ('diff', 289),
#  ('pickle', 289),
#  ('tsv', 289),
#  ('sol', 288),
#  ('mp3', 287),
#  ('pic', 287),
#  ('vhd', 287),
#  ('textile', 286),
#  ('component', 284),
#  ('protocol', 283),
#  ('installation', 282),
#  ('rpc', 282),
#  ('account', 282),
#  ('review', 282),
#  ('google', 281),
#  ('dataloader', 281),
#  ('2019', 280),
#  ('covid', 278),
#  ('context', 277),
#  ('import', 277),
#  ('blog', 277),
#  ('baseline', 275),
#  ('cdk', 275),
#  (nan, 275),
#  ('bro', 275),
#  ('jsp', 274),
#  ('error', 270),
#  ('policy', 270),
#  ('create', 268),
#  ('mac', 267),
#  ('scan', 266),
#  ('boot', 266),
#  ('robot', 265),
#  ('coverage', 265),
#  ('solutions', 265),
#  ('infrastructure', 264),
#  ('status', 264),
#  ('banner', 263),
#  ('email', 263),
#  ('computer', 261),
#  ('editor', 261),
#  ('card', 260),
#  ('https', 259),
#  ('wiki', 257),
#  ('ar', 257),
#  ('microsoft', 256),
#  ('pytorch', 256),
#  ('path', 256),
#  ('playground', 256),
#  ('popup', 255),
#  ('sdk', 255),
#  ('errors', 254),
#  ('engineer', 253),
#  ('kmeans', 252),
#  ('overlay', 252),
#  ('kitchen', 251),
#  ('pattern', 251),
#  ('capture', 251),
#  ('hp', 251),
#  ('interface', 250),
#  ('scss', 249),
#  ('daemon', 249),
#  ('lab', 249),
#  ('annotations', 248),
#  ('statistics', 248),
#  ('doxygen', 248),
#  ('pcap', 248),
#  ('caffe', 248),
#  ('tracker', 246),
#  ('macos', 246),
#  ('lisp', 245),
#  ('issue', 244),
#  ('light', 244),
#  ('addons', 244),
#  ('win32', 243),
#  ('pack', 243),
#  ('team', 243),
#  ('cheatsheet', 242),
#  ('memory', 241),
#  ('extract', 240),
#  ('mask', 240),
#  ('nlp', 239),
#  ('privacy', 238),
#  ('k8s', 238),
#  ('sqlite3', 237),
#  ('forensics', 237),
#  ('ros', 237),
#  ('article', 237),
#  ('basic', 237),
#  ('trace', 236),
#  ('xss', 235),
#  ('aarch64', 235),
#  ('lambda', 234),
#  ('vagrant', 234),
#  ('connect', 233),
#  ('builder', 232),
#  ('hcl', 232),
#  ('cpu', 232),
#  ('md5', 231),
#  ('simple', 231),
#  ('users', 230),
#  ('request', 229),
#  ('win', 228),
#  ('ahk', 228),
#  ('openra', 228),
#  ('2022', 227),
#  ('word', 226),
#  ('matrix', 226),
#  ('prettier', 226),
#  ('chat', 226),
#  ('player', 226),
#  ('sequence', 225),
#  ('private', 225),
#  ('information', 224),
#  ('challenge', 224),
#  ('url', 224),
#  ('formatter', 224),
#  ('asset', 222),
#  ('machinelearning', 222),
#  ('interfaces', 222),
#  ('serverless', 221),
#  ('repository', 221),
#  ('remote', 220),
#  ('workflow', 219),
#  ('validate', 219),
#  ('load', 218),
#  ('audit', 218),
#  ('coco', 217),
#  ('stub', 217),
#  ('validation', 217),
#  ('yolov5', 217),
#  ('discovery', 217),
#  ('helm', 217),
#  ('performance', 215),
#  ('cron', 215),
#  ('layout', 214),
#  ('timer', 214),
#  ('inventory', 214),
#  ('mysql', 214),
#  ('random', 213),
#  ('certificate', 213),
#  ('ssd', 211),
#  ('3d', 211),
#  ('analytics', 211),
#  ('math', 210),
#  ('fee', 210),
#  ('labs', 208),
#  ('recipes', 208),
#  ('locale', 207),
#  ('speech', 207),
#  ('middleware', 207),
#  ('rce', 207),
#  ('visual', 206),
#  ('distribution', 206),
#  ('registry', 206),
#  ('display', 206),
#  ('step', 205),
#  ('glide', 205),
#  ('antivirus', 205),
#  ('question', 205),
#  ('infra', 205),
#  ('collection', 204),
#  ('resnet', 204),
#  ('dockerfiles', 204),
#  ('apache', 204),
#  ('checkpoint', 203),
#  ('split', 203),
#  ('embed', 202),
#  ('reverse', 202),
#  ('snyk', 202),
#  ('syntax', 202),
#  ('edge', 202),
#  ('scrypt', 202),
#  ('dashboards', 201),
#  ('2017', 200),
#  ('hex', 200),
#  ('jenkins', 200),
#  ('cheat', 200),
#  ('calibration', 200),
#  ('xaml', 200),
#  ('experimental', 199),
#  ('simulation', 199),
#  ('vim', 198),
#  ('line', 198),
#  ('anomaly', 198),
#  ('githooks', 198),
#  ('open', 197),
#  ('sheet', 197),
#  ('fraud', 197),
#  ('generators', 196),
#  ('browser', 195),
#  ('intro', 195),
#  ('caffemodel', 194),
#  ('snap', 194),
#  ('legacy', 194),
#  ('sandbox', 194),
#  ('orange', 194),
#  ('worker', 193),
#  ('presentations', 193),
#  ('redis', 192),
#  ('spark', 192),
#  ('solution', 192),
#  ('queue', 191),
#  ('parse', 191),
#  ('dump', 191),
#  ('eda', 191),
#  ('ocr', 191),
#  ('study', 190),
#  ('react', 190),
#  ('cleanup', 190),
#  ('chrome', 188),
#  ('layouts', 188),
#  ('smart', 188),
#  ('box', 187),
#  ('awesome', 187),
#  ('checkstyle', 187),
#  ('hacs', 187),
#  ('compiler', 186),
#  ('jsdoc', 186),
#  ('launcher', 185),
#  ('powershell', 185),
#  ('ops', 185),
#  ('facedetection', 185),
#  ('render', 184),
#  ('linear', 184),
#  ('amazon', 183),
#  ('ftcrobotcontroller', 183),
#  ('nod', 182),
#  ('tcl', 182),
#  ('schedule', 181),
#  ('pipelines', 181),
#  ('price', 180),
#  ('attribute', 180),
#  ('match', 180),
#  ('dns', 180),
#  ('mock', 180),
#  ('wrapper', 180),
#  ('systems', 179),
#  ('scanner', 178),
#  ('writeup', 178),
#  ('ids', 178),
#  ('sync', 178),
#  ('master', 178),
#  ('contact', 177),
#  ('progress', 177),
#  ('devops', 176),
#  ('stylesheets', 176),
#  ('artifacts', 176),
#  ('password', 176),
#  ('addon', 176),
#  ('gpu', 176),
#  ('cloudformation', 175),
#  ('score', 175),
#  ('deeplearning', 175),
#  ('twitter', 175),
#  ('deb', 175),
#  ('gitbook', 174),
#  ('graphql', 174),
#  ('transfer', 174),
#  ('manager', 174),
#  ('swiftpm', 174),
#  ('credentials', 174),
#  ('dl', 174),
#  ('power', 174),
#  ('2021', 172),
#  ('gitlab', 172),
#  ('platforms', 172),
#  ('container', 172),
#  ('eclipse', 171),
#  ('mit', 170),
#  ('ssh', 170),
#  ('frame', 170),
#  ('register', 169),
#  ('deprecate', 169),
#  ('count', 169),
#  ('toc', 169),
#  ('ip', 169),
#  ('webcam', 167),
#  ('governance', 167),
#  ('proposal', 167),
#  ('iot', 167),
#  ('sign', 167),
#  ('operations', 166),
#  ('automation', 165),
#  ('hardhat', 165),
#  ('practice', 165),
#  ('nodemon', 165),
#  ('localization', 165),
#  ('wifi', 165),
#  ('elasticsearch', 164),
#  ('sketch', 164),
#  ('native', 164),
#  ('pcb', 164),
#  ('exp', 164),
#  ('mail', 163),
#  ('protractor', 163),
#  ('rviz', 163),
#  ('hunt', 163),
#  ('csl', 163),
#  ('pool', 163),
#  ('raw', 163),
#  ('domains', 163),
#  ('button', 163),
#  ('product', 162),
#  ('poster', 162),
#  ('quickstart', 162),
#  ('playbooks', 161),
#  ('social', 160),
#  ('provider', 160),
#  ('router', 160),
#  ('sensor', 160),
#  ('s3', 159),
#  ('traffic', 159),
#  ('draw', 159),
#  ('cv', 159),
#  ('push', 159),
#  ('binaries', 158),
#  ('panel', 158),
#  ('car', 158),
#  ('metro', 157),
#  ('fake', 157),
#  ('tip', 157),
#  ('best', 156),
#  ('pca', 156),
#  ('signal', 156),
#  ('base64', 156),
#  ('notification', 155),
#  ('less', 155),
#  ('lstm', 155),
#  ('swagger', 155),
#  ('handler', 155),
#  ('access', 154),
#  ('implementation', 154),
#  ('42', 154),
#  ('science', 154),
#  ('prompt', 153),
#  ('solver', 153),
#  ('q', 153),
#  ('encode', 152),
#  ('databases', 152),
#  ('lane', 152),
#  ('auto', 152),
#  ('threat', 152),
#  ('thread', 151),
#  ('rpm', 151),
#  ('rest', 151),
#  ('exchange', 150),
#  ('flag', 150),
#  ('print', 150),
#  ('sqlite', 150),
#  ('nse', 150),
#  ('response', 149),
#  ('bypass', 149),
#  ('objectdetection', 149),
#  ('x64', 149),
#  ('keras', 148),
#  ('bazel', 148),
#  ('stl', 148),
#  ('webserver', 148),
#  ('osint', 148),
#  ('runner', 148),
#  ('cms', 147),
#  ('heroku', 147),
#  ('port', 147),
#  ('systemd', 146),
#  ('ionic', 146),
#  ('extraction', 146),
#  ('serve', 146),
#  ('recovery', 146),
#  ('mods', 145),
#  ('osx', 145),
#  ('comment', 145),
#  ('channel', 145),
#  ('awk', 145),
#  ('policies', 144),
#  ('hdf5', 144),
#  ('schemas', 144),
#  ('helloworld', 144),
#  ('english', 144),
#  ('qa', 143),
#  ('payloads', 143),
#  ('xls', 143),
#  ('backbone', 143),
#  ('date', 142),
#  ('generation', 142),
#  ('fuzz', 142),
#  ('provision', 142),
#  ('dot', 142),
#  ('gateway', 141),
#  ('merge', 141),
#  ('kibana', 141),
#  ('migration', 141),
#  ('token', 141),
#  ('conda', 141),
#  ('optimization', 140),
#  ('wsgi', 140),
#  ('predictions', 140),
#  ('persistence', 140),
#  ('cascade', 140),
#  ('blockchain', 140),
#  ('renderer', 140),
#  ('ubuntu', 139),
#  ('collector', 139),
#  ('unet', 139),
#  ('apis', 139),
#  ('devices', 139),
#  ('quantum', 138),
#  ('lint', 138),
#  ('buildtools', 138),
#  ('bluetooth', 138),
#  ('iam', 137),
#  ('point', 137),
#  ('pretrained', 137),
#  ('zsh', 137),
#  ('openapi', 137),
#  ('yolo3', 136),
#  ('distance', 136),
#  ('seed', 136),
#  ('containers', 136),
#  ('blob', 136),
#  ('intelligence', 135),
#  ('material', 135),
#  ('alarm', 134),
#  ('jupyter', 134),
#  ('coin', 134),
#  ('payload', 134),
#  ('mnist', 134),
#  ('nms', 134),
#  ('ruleset', 133),
#  ('annotation', 133),
#  ('people', 133),
#  ('alertmanager', 133),
#  ('interview', 133),
#  ('realtime', 133),
#  ...]

# %% [markdown]
# ### testset 2.3.1(s)
# takes all 2.3 readme_clean extracted topics as set

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t5
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.1')
# Out:
# total repos 218335
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.1.pkl

# %%
ghd_exp['topics'] = ghd_exp['topics'].apply(lambda x: ' '.join(set(x)))

# %%
to_disk(ghd_exp, 't2.3.1s')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.1s.pkl

# %% [markdown]
# ### testset 2.3.2
# takes all 2.3 about extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t3 #+t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.2')
# Out:
# total repos 188698
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.2.pkl

# %% [markdown]
# ### testset 2.3.3
# takes all 2.5 tree extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t6
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.3')
# Out:
# total repos 221696
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.3.pkl

# %% [markdown]
# ### testset 2.3.4
# takes all 2.5 topics extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.4')
# Out:
# total repos 68303
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.4.pkl

# %% [markdown]
# ### testset 2.3.5
# takes all 2.5 languages extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t4
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.5')
# Out:
# total repos 194906
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.5.pkl

# %% [markdown]
# ### testset 2.3.6
# takes all 2.3 title extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t1
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.3.6')
# Out:
# total repos 28395
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.6.pkl

# %% [markdown]
# ## Testset 2.4 (Part of D_C3)
# The best performing 1 set was 1.2; so we do the same we did with 1.2 on readme and about
#
# we set a **min_thres** here, that means this topic has to be at least in 4 repos

# %%
total_repos_with_topics*0.001
# Out:
# 69.81700000000001

# %%
topics_combined_full24 = []
min_thres = total_repos_with_topics*0.001
for i in topic_counter.items():
    t = i[0]
    o = i[1]
    t = str(t)
    if t == 'nan':
        continue
    newt = preprocess_text(t, lem=True, do_composition=True)
    if newt not in topics_combined_full24:
        if o >= min_thres:
            topics_combined_full24 += newt

# %%
len(set(topics_combined_full24))
# Out:
# 743

# %%
len(topics_combined_full24)
# Out:
# 773

# %%
topics_combined_full24 = list(set(topics_combined_full24))

# %%
def myclnfunction(x):
    return preprocess_text(x, lem=True, token_list = topics_combined_full24, do_composition=True)

# %%
t1 = github_data_df['name'].apply(lambda x: myclnfunction(x))

# %%
t1_cnt = Counter(t1.explode())
t1_cnt.most_common()
# Out:
# [(nan, 212929),
#  ('js', 873),
#  ('microsoft', 482),
#  ('github', 310),
#  ('jquery', 194),
#  ('azure', 186),
#  ('google', 165),
#  ('pytorch', 154),
#  ('facedetection', 151),
#  ('awesome', 129),
#  ('objectdetection', 115),
#  ('intel', 114),
#  ('googlecloudplatform', 111),
#  ('anomalydetection', 100),
#  ('aws', 86),
#  ('project', 78),
#  ('machinelearning', 77),
#  ('facerecognition', 74),
#  ('computervision', 71),
#  ('vim', 66),
#  ('deeplearning', 64),
#  ('prometheus', 64),
#  ('alert', 62),
#  ('docker', 59),
#  ('ai', 58),
#  ('splunk', 58),
#  ('bootstrap', 53),
#  ('paper', 53),
#  ('openshift', 53),
#  ('grafana', 51),
#  ('tool', 50),
#  ('resources', 50),
#  ('tensorflow', 49),
#  ('yararules', 46),
#  ('script', 45),
#  ('darknet', 43),
#  ('frauddetection', 43),
#  ('tutorials', 43),
#  ('vehicledetection', 43),
#  ('cnn', 41),
#  ('misp', 41),
#  ('monitor', 40),
#  ('lanedetection', 39),
#  ('opencv', 38),
#  ('blog', 37),
#  ('ids', 37),
#  ('owasp', 37),
#  ('javascript', 36),
#  ('python', 36),
#  ('udacity', 36),
#  ('algorithms', 36),
#  ('transformers', 35),
#  ('yara', 34),
#  ('emotiondetection', 34),
#  ('yolov3', 33),
#  ('threathunting', 32),
#  ('security', 32),
#  ('learn', 32),
#  ('detection', 32),
#  ('api', 31),
#  ('communitydetection', 31),
#  ('edgedetection', 30),
#  ('react', 29),
#  ('app', 28),
#  ('yolov5', 28),
#  ('datascience', 28),
#  ('log', 28),
#  ('homeassistant', 28),
#  ('git', 28),
#  ('demo', 28),
#  ('vision', 27),
#  ('ui', 27),
#  ('fasterrcnn', 26),
#  ('covid19', 26),
#  ('documentation', 25),
#  ('game', 25),
#  ('hackingtool', 25),
#  ('swift', 25),
#  ('ips', 25),
#  ('selfdrivingcar', 24),
#  ('imageprocessing', 24),
#  ('dialog', 24),
#  ('springboot', 23),
#  ('data', 23),
#  ('php', 23),
#  ('intrusiondetectionsystem', 23),
#  ('web', 23),
#  ('android', 22),
#  ('cv', 22),
#  ('website', 22),
#  ('framework', 22),
#  ('r', 22),
#  ('mediapipe', 22),
#  ('antivirus', 21),
#  ('serverless', 21),
#  ('upptime', 21),
#  ('mtcnn', 21),
#  ('node', 20),
#  ('nvidia', 20),
#  ('cli', 20),
#  ('devsecops', 20),
#  ('ctf', 20),
#  ('discord', 20),
#  ('motiondetection', 20),
#  ('cloudflare', 19),
#  ('emacs', 19),
#  ('malwaredetection', 19),
#  ('malware', 19),
#  ('redis', 19),
#  ('dotnet', 19),
#  ('plugin', 19),
#  ('detectron2', 19),
#  ('server', 19),
#  ('list', 19),
#  ('arduino', 19),
#  ('heroku', 18),
#  ('dashboard', 18),
#  ('yolo', 18),
#  ('datasets', 18),
#  ('ctfwriteups', 18),
#  ('face', 18),
#  ('twitter', 17),
#  ('ocr', 17),
#  ('textdetection', 17),
#  ('ssd', 17),
#  ('nlp', 17),
#  ('cybersecurity', 17),
#  ('springcloud', 16),
#  ('reverseengineering', 16),
#  ('devops', 16),
#  ('languagedetection', 16),
#  ('go', 16),
#  ('wallet', 16),
#  ('workshop', 16),
#  ('tensorflow2', 16),
#  ('kubernetes', 16),
#  ('c', 16),
#  ('ml', 16),
#  ('ansible', 15),
#  ('outlierdetection', 15),
#  ('ios', 15),
#  ('nodejs', 15),
#  ('router', 15),
#  ('json', 15),
#  ('network', 15),
#  ('threatintel', 15),
#  ('dart', 15),
#  ('client', 14),
#  ('image', 14),
#  ('bitcoin', 14),
#  ('sdk', 14),
#  ('emotionrecognition', 14),
#  ('bugbounty', 14),
#  ('async', 14),
#  ('code', 14),
#  ('logger', 14),
#  ('frontend', 14),
#  ('infrastructure', 14),
#  ('dataset', 13),
#  ('alertmanager', 13),
#  ('computerscience', 13),
#  ('changedetection', 13),
#  ('track', 13),
#  ('train', 12),
#  ('maskrcnn', 12),
#  ('lua', 12),
#  ('browser', 12),
#  ('apple', 12),
#  ('rest', 12),
#  ('caffe', 12),
#  ('ethereum', 12),
#  ('smarthome', 12),
#  ('ransomware', 12),
#  ('blockchain', 12),
#  ('retinanet', 12),
#  ('intrusiondetection', 11),
#  ('weather', 11),
#  ('incidentresponse', 11),
#  ('objecttracking', 11),
#  ('chat', 11),
#  ('hack', 11),
#  ('wordpress', 11),
#  ('redteam', 11),
#  ('bot', 11),
#  ('java', 11),
#  ('research', 11),
#  ('forensics', 11),
#  ('osx', 11),
#  ('example', 11),
#  ('3dobjectdetection', 11),
#  ('ncnn', 11),
#  ('transferlearning', 11),
#  ('threatintelligence', 11),
#  ('mobilenetv2', 10),
#  ('toast', 10),
#  ('mitreattack', 10),
#  ('edge', 10),
#  ('backend', 10),
#  ('es6', 10),
#  ('camera', 10),
#  ('angular', 10),
#  ('crypto', 10),
#  ('raspberrypi', 10),
#  ('interview', 10),
#  ('cloud', 10),
#  ('mongodb', 10),
#  ('tutorial', 10),
#  ('package', 10),
#  ('nmap', 10),
#  ('console', 9),
#  ('bootstrap4', 9),
#  ('cheatsheet', 9),
#  ('rail', 9),
#  ('slack', 9),
#  ('test', 9),
#  ('markdown', 9),
#  ('guide', 9),
#  ('pipeline', 9),
#  ('component', 9),
#  ('xss', 9),
#  ('exploit', 9),
#  ('elasticsearch', 9),
#  ('openai', 9),
#  ('http', 9),
#  ('firebase', 9),
#  ('ecommerce', 9),
#  ('dfir', 8),
#  ('powershell', 8),
#  ('facialrecognition', 8),
#  ('awesomelist', 8),
#  ('iot', 8),
#  ('unity', 8),
#  ('linux', 8),
#  ('mobile', 8),
#  ('metrics', 8),
#  ('components', 8),
#  ('sensor', 8),
#  ('graph', 8),
#  ('puppeteer', 8),
#  ('forensicanalysis', 8),
#  ('library', 8),
#  ('suricata', 8),
#  ('css', 8),
#  ('cordova', 7),
#  ('modal', 7),
#  ('theme', 7),
#  ('sandbox', 7),
#  ('recon', 7),
#  ('yolov2', 7),
#  ('humanposeestimation', 7),
#  ('message', 7),
#  ('zabbix', 7),
#  ('pentest', 7),
#  ('cpp', 7),
#  ('chatgpt', 7),
#  ('template', 7),
#  ('materialui', 7),
#  ('malwareanalysis', 7),
#  ('webapp', 7),
#  ('apiclient', 7),
#  ('microservices', 7),
#  ('hook', 7),
#  ('microservice', 7),
#  ('fastapi', 7),
#  ('html', 7),
#  ('hackathon', 7),
#  ('kaggle', 6),
#  ('benchmark', 6),
#  ('audit', 6),
#  ('hardware', 6),
#  ('poseestimation', 6),
#  ('coursera', 6),
#  ('sms', 6),
#  ('cti', 6),
#  ('hacktoberfest2021', 6),
#  ('spark', 6),
#  ('proxy', 6),
#  ('detector', 6),
#  ('streamlit', 6),
#  ('sql', 6),
#  ('rust', 6),
#  ('wordpressplugin', 6),
#  ('speechtotext', 6),
#  ('finance', 6),
#  ('vue', 6),
#  ('penetrationtesting', 6),
#  ('autonomousdriving', 6),
#  ('video', 6),
#  ('imagesegmentation', 6),
#  ('osint', 6),
#  ('collisiondetection', 6),
#  ('notification', 6),
#  ('yolov4', 6),
#  ('design', 6),
#  ('blueteam', 6),
#  ('ajax', 6),
#  ('analytics', 6),
#  ('laravel', 6),
#  ('kotlin', 6),
#  ('mqtt', 6),
#  ('semanticsegmentation', 6),
#  ('robotics', 6),
#  ('webrtc', 6),
#  ('spring', 6),
#  ('webassembly', 6),
#  ('database', 6),
#  ('siem', 5),
#  ('dataengineering', 5),
#  ('filesystem', 5),
#  ('fpga', 5),
#  ('coco', 5),
#  ('education', 5),
#  ('reactjs', 5),
#  ('rabbitmq', 5),
#  ('pentesting', 5),
#  ('securitytools', 5),
#  ('timeseries', 5),
#  ('hackingtools', 5),
#  ('i18n', 5),
#  ('artificialintelligence', 5),
#  ('youtube', 5),
#  ('gui', 5),
#  ('homeautomation', 5),
#  ('cryptography', 5),
#  ('management', 5),
#  ('language', 5),
#  ('yolov8', 5),
#  ('vulnerability', 5),
#  ('analysis', 5),
#  ('mysql', 5),
#  ('ruby', 5),
#  ('flutter', 5),
#  ('automation', 5),
#  ('jenkins', 5),
#  ('bash', 5),
#  ('filter', 5),
#  ('slam', 5),
#  ('terminal', 5),
#  ('electron', 5),
#  ('protocol', 5),
#  ('cpu', 5),
#  ('matlab', 5),
#  ('telegrambot', 5),
#  ('firewall', 5),
#  ('poc', 5),
#  ('architecture', 5),
#  ('ble', 5),
#  ('segmentation', 5),
#  ('lambda', 5),
#  ('opensource', 5),
#  ('phishing', 5),
#  ('dnn', 5),
#  ('vulnerabilities', 5),
#  ('reactnative', 4),
#  ('qt', 4),
#  ('validation', 4),
#  ('gradle', 4),
#  ('logstash', 4),
#  ('interviewquestions', 4),
#  ('websockets', 4),
#  ('yolov7', 4),
#  ('datamining', 4),
#  ('textclassification', 4),
#  ('compliance', 4),
#  ('symfony', 4),
#  ('convolutionalneuralnetworks', 4),
#  ('statuspage', 4),
#  ('sentimentanalysis', 4),
#  ('openapi', 4),
#  ('expressjs', 4),
#  ('admin', 4),
#  ('cache', 4),
#  ('health', 4),
#  ('robot', 4),
#  ('ci', 4),
#  ('imageanalysis', 4),
#  ('web3', 4),
#  ('chrome', 4),
#  ('chatbot', 4),
#  ('salientobjectdetection', 4),
#  ('inference', 4),
#  ('boilerplate', 4),
#  ('kalilinux', 4),
#  ('csharp', 4),
#  ('graphalgorithms', 4),
#  ('virus', 4),
#  ('cluster', 4),
#  ('imageclassification', 4),
#  ('dataaugmentation', 4),
#  ('bigdata', 4),
#  ('ssl', 4),
#  ('container', 4),
#  ('gcp', 4),
#  ('popup', 4),
#  ('cloudformation', 4),
#  ('swiftui', 4),
#  ('scanner', 4),
#  ('hacktoberfest2020', 4),
#  ('timeseriesanalysis', 4),
#  ('augmentedreality', 4),
#  ('ubuntu', 4),
#  ('firmware', 4),
#  ('terraform', 4),
#  ('awesomelists', 3),
#  ('uptimemonitor', 3),
#  ('k8s', 3),
#  ('bestpractices', 3),
#  ('embed', 3),
#  ('mxnet', 3),
#  ('mobilenet', 3),
#  ('lidar', 3),
#  ('application', 3),
#  ('desktop', 3),
#  ('graphql', 3),
#  ('bert', 3),
#  ('selenium', 3),
#  ('uicomponents', 3),
#  ('speech', 3),
#  ('search', 3),
#  ('pointcloud', 3),
#  ('tensorrt', 3),
#  ('helm', 3),
#  ('androidlibrary', 3),
#  ('extension', 3),
#  ('canvas', 3),
#  ('gameengine', 3),
#  ('pdf', 3),
#  ('imagerecognition', 3),
#  ('gitops', 3),
#  ('tls', 3),
#  ('bypass', 3),
#  ('machinelearningalgorithms', 3),
#  ('pythonlibrary', 3),
#  ('graphneuralnetworks', 3),
#  ('notifications', 3),
#  ('hacktoberfest', 3),
#  ('websocket', 3),
#  ('bluetooth', 3),
#  ('3dreconstruction', 3),
#  ('observability', 3),
#  ('smartcontracts', 3),
#  ('sqlite', 3),
#  ('middleware', 3),
#  ('honeypot', 3),
#  ('ecs', 3),
#  ('webhook', 3),
#  ('debian', 3),
#  ('informationsecurity', 3),
#  ('backdoor', 3),
#  ('restapi', 3),
#  ('convolutionalneuralnetwork', 3),
#  ('pwa', 3),
#  ('encryption', 3),
#  ('containers', 3),
#  ('realtime', 3),
#  ('shell', 3),
#  ('vscode', 3),
#  ('instancesegmentation', 3),
#  ('reinforcementlearning', 3),
#  ('malwareresearch', 3),
#  ('privacy', 3),
#  ('naturallanguageprocessing', 3),
#  ('influxdb', 3),
#  ('jupyter', 3),
#  ('visiontransformer', 3),
#  ('webgl', 3),
#  ('swagger', 3),
#  ('dataanalysis', 3),
#  ('scraper', 3),
#  ('algorithm', 3),
#  ('ros2', 3),
#  ('s3', 3),
#  ('selfhosted', 3),
#  ('windows', 3),
#  ('authentication', 3),
#  ('parser', 3),
#  ('digitalforensics', 3),
#  ('vulnerabilitydetection', 3),
#  ('password', 2),
#  ('cve', 2),
#  ('surveillance', 2),
#  ('ros', 2),
#  ('minecraft', 2),
#  ('medicalimaging', 2),
#  ('onnx', 2),
#  ('hacktoberfest2022', 2),
#  ('tflite', 2),
#  ('compiler', 2),
#  ('npm', 2),
#  ('webcam', 2),
#  ('androidapp', 2),
#  ('svelte', 2),
#  ('physics', 2),
#  ('randomforest', 2),
#  ('tor', 2),
#  ('express', 2),
#  ('html5', 2),
#  ('jwt', 2),
#  ('postgres', 2),
#  ('staticanalysis', 2),
#  ('accessibility', 2),
#  ('discordbot', 2),
#  ('workflow', 2),
#  ('flask', 2),
#  ('dns', 2),
#  ('reconnaissance', 2),
#  ('neuralnetworks', 2),
#  ('signalprocessing', 2),
#  ('fuzzing', 2),
#  ('integration', 2),
#  ('textrecognition', 2),
#  ('debug', 2),
#  ('terraformmodules', 2),
#  ('infosec', 2),
#  ('golang', 2),
#  ('metadata', 2),
#  ('telegram', 2),
#  ('storage', 2),
#  ('php7', 2),
#  ('keras', 2),
#  ('wasm', 2),
#  ('postgresql', 2),
#  ('eslint', 2),
#  ('editor', 2),
#  ('amazon', 2),
#  ('kotlinandroid', 2),
#  ('mlops', 2),
#  ('androidapplication', 2),
#  ('trade', 2),
#  ('crawler', 2),
#  ('mod', 2),
#  ('unet', 2),
#  ('speechrecognition', 2),
#  ('featureextraction', 2),
#  ('unsupervisedlearning', 2),
#  ('recognition', 2),
#  ('kafka', 2),
#  ('actionrecognition', 2),
#  ('defi', 2),
#  ('deployment', 2),
#  ('3d', 2),
#  ('vscodeextension', 2),
#  ('neuralnetwork', 2),
#  ('arm', 2),
#  ('assembly', 2),
#  ('classification', 2),
#  ('uikit', 2),
#  ('vpn', 2),
#  ('audioprocessing', 2),
#  ('mac', 2),
#  ('prometheusexporter', 2),
#  ('stream', 2),
#  ('statistics', 1),
#  ('typescript', 1),
#  ('distribute', 1),
#  ('svm', 1),
#  ('lstm', 1),
#  ('autonomousvehicles', 1),
#  ('email', 1),
#  ('pytorchimplementation', 1),
#  ('astronomy', 1),
#  ('gps', 1),
#  ('driver', 1),
#  ('css3', 1),
#  ('gin', 1),
#  ('coronavirus', 1),
#  ('pandas', 1),
#  ('module', 1),
#  ('django', 1),
#  ('oauth2', 1),
#  ('nlpmachinelearning', 1),
#  ('music', 1),
#  ('videoprocessing', 1),
#  ('python3', 1),
#  ('perl', 1),
#  ('cnnkeras', 1),
#  ('restfulapi', 1),
#  ('softwareengineering', 1),
#  ('macos', 1),
#  ('sass', 1),
#  ('raspberrypi3', 1),
#  ('objectivec', 1),
#  ('vuejs', 1),
#  ('grpc', 1),
#  ('scala', 1),
#  ('datavisualization', 1),
#  ('authorization', 1),
#  ('springsecurity', 1),
#  ('networkanalysis', 1),
#  ('ssh', 1),
#  ('cocoapods', 1),
#  ('githubactions', 1),
#  ('securityaudit', 1),
#  ('remotesensing', 1),
#  ('jqueryplugin', 1),
#  ('tensorflowjs', 1),
#  ('linearregression', 1),
#  ('opengl', 1),
#  ('stm32', 1),
#  ('cloudcomputing', 1),
#  ('csv', 1),
#  ('apigateway', 1),
#  ('cmake', 1),
#  ('gpu', 1),
#  ('logisticregression', 1),
#  ('kibana', 1),
#  ('backup', 1),
#  ('free', 1),
#  ('awss3', 1),
#  ('autoencoder', 1),
#  ('jupyternotebook', 1),
#  ('edgecomputing', 1),
#  ('numpy', 1),
#  ('cloudnative', 1),
#  ('genomics', 1),
#  ('clojure', 1),
#  ('pcap', 1),
#  ('securityautomation', 1),
#  ('webapplication', 1),
#  ('bioinformatics', 1),
#  ('audio', 1),
#  ('infrastructureascode', 1),
#  ('cyberthreatintelligence', 1),
#  ('chromeextension', 1),
#  ('ip', 1),
#  ('distributedsystems', 1),
#  ('kernel', 1),
#  ('internetofthings', 1),
#  ('prediction', 1),
#  ('pushnotifications', 1),
#  ('imagenet', 1),
#  ('tradingbot', 1),
#  ('cuda', 1),
#  ('cryptocurrency', 1),
#  ('windows10', 1),
#  ('nginx', 1),
#  ('program', 1),
#  ('kalmanfilter', 1),
#  ('cicd', 1),
#  ('webpack', 1),
#  ('searchengine', 1),
#  ('binance', 1),
#  ('elixir', 1),
#  ('opencvpython', 1),
#  ('monitoringtool', 1),
#  ('unity3d', 1),
#  ('solidity', 1),
#  ('awslambda', 1),
#  ('obfuscation', 1),
#  ('datastructures', 1),
#  ('attack', 1)]

# %%
t2 = github_data_df['topics'].apply(lambda x: myclnfunction(x))

# %%
t2_cnt = Counter(t2.explode())
t2_cnt.most_common()
# Out:
# [(nan, 161626),
#  ('python', 6323),
#  ('deeplearning', 5300),
#  ('machinelearning', 4665),
#  ('computervision', 3010),
#  ('javascript', 2744),
#  ('security', 2657),
#  ('objectdetection', 2617),
#  ('pytorch', 2166),
#  ('tensorflow', 2125),
#  ('opencv', 2055),
#  ('hacktoberfest', 2010),
#  ('python3', 1781),
#  ('android', 1676),
#  ('docker', 1658),
#  ('java', 1523),
#  ('react', 1463),
#  ('nodejs', 1373),
#  ('monitor', 1285),
#  ('aws', 1264),
#  ('golang', 1252),
#  ('kubernetes', 1223),
#  ('awesomelist', 1220),
#  ('detection', 1214),
#  ('awesome', 1139),
#  ('linux', 1097),
#  ('ios', 1059),
#  ('php', 1015),
#  ('imageprocessing', 1000),
#  ('facedetection', 987),
#  ('typescript', 971),
#  ('keras', 871),
#  ('windows', 848),
#  ('datascience', 836),
#  ('nlp', 823),
#  ('cybersecurity', 819),
#  ('api', 802),
#  ('go', 783),
#  ('artificialintelligence', 738),
#  ('anomalydetection', 738),
#  ('alert', 737),
#  ('raspberrypi', 736),
#  ('hack', 727),
#  ('swift', 721),
#  ('convolutionalneuralnetworks', 704),
#  ('cnn', 698),
#  ('ai', 672),
#  ('cpp', 660),
#  ('neuralnetwork', 653),
#  ('securitytools', 653),
#  ('facerecognition', 647),
#  ('automation', 637),
#  ('terraform', 615),
#  ('opensource', 609),
#  ('prometheus', 600),
#  ('dataset', 598),
#  ('azure', 584),
#  ('iot', 580),
#  ('naturallanguageprocessing', 579),
#  ('html', 575),
#  ('csharp', 574),
#  ('rust', 561),
#  ('yolo', 557),
#  ('macos', 551),
#  ('flask', 547),
#  ('network', 541),
#  ('deepneuralnetworks', 538),
#  ('blockchain', 536),
#  ('css', 527),
#  ('classification', 526),
#  ('game', 522),
#  ('reactjs', 520),
#  ('arduino', 516),
#  ('forensics', 511),
#  ('malware', 502),
#  ('devops', 501),
#  ('bot', 498),
#  ('springboot', 498),
#  ('reactnative', 483),
#  ('c', 469),
#  ('cli', 464),
#  ('cryptography', 461),
#  ('yolov3', 457),
#  ('homeassistant', 454),
#  ('opencvpython', 453),
#  ('segmentation', 452),
#  ('angular', 440),
#  ('ethereum', 437),
#  ('pentesting', 432),
#  ('vue', 427),
#  ('library', 415),
#  ('tool', 414),
#  ('imageclassification', 412),
#  ('cloud', 411),
#  ('flutter', 408),
#  ('laravel', 408),
#  ('realtime', 406),
#  ('django', 403),
#  ('covid19', 403),
#  ('database', 399),
#  ('ros', 394),
#  ('video', 390),
#  ('robotics', 388),
#  ('log', 387),
#  ('bugbounty', 383),
#  ('mongodb', 372),
#  ('cryptocurrency', 372),
#  ('ruby', 371),
#  ('web', 367),
#  ('cplusplus', 365),
#  ('neuralnetworks', 360),
#  ('kotlin', 359),
#  ('grafana', 357),
#  ('ocr', 349),
#  ('timeseries', 348),
#  ('elasticsearch', 344),
#  ('matlab', 334),
#  ('penetrationtesting', 333),
#  ('test', 331),
#  ('yolov5', 331),
#  ('ansible', 330),
#  ('threathunting', 330),
#  ('plugin', 329),
#  ('postgresql', 328),
#  ('restapi', 326),
#  ('bootstrap', 323),
#  ('paper', 322),
#  ('malwareanalysis', 321),
#  ('privacy', 321),
#  ('tutorial', 320),
#  ('powershell', 320),
#  ('antivirus', 319),
#  ('cluster', 319),
#  ('mysql', 317),
#  ('discord', 317),
#  ('metrics', 315),
#  ('reverseengineering', 311),
#  ('threatintelligence', 311),
#  ('serverless', 311),
#  ('infosec', 310),
#  ('json', 308),
#  ('list', 305),
#  ('notifications', 304),
#  ('r', 303),
#  ('jupyternotebook', 302),
#  ('bitcoin', 300),
#  ('camera', 300),
#  ('dotnet', 297),
#  ('framework', 295),
#  ('incidentresponse', 292),
#  ('redteam', 286),
#  ('github', 286),
#  ('audio', 284),
#  ('firebase', 278),
#  ('osint', 275),
#  ('dockercompose', 274),
#  ('sql', 273),
#  ('kafka', 271),
#  ('bioinformatics', 270),
#  ('wordpress', 267),
#  ('transferlearning', 267),
#  ('bash', 266),
#  ('visualization', 259),
#  ('track', 259),
#  ('semanticsegmentation', 257),
#  ('dfir', 257),
#  ('encryption', 256),
#  ('graph', 253),
#  ('html5', 252),
#  ('numpy', 251),
#  ('crypto', 251),
#  ('telegram', 249),
#  ('dashboard', 248),
#  ('microservices', 246),
#  ('image', 245),
#  ('gui', 245),
#  ('autonomousdriving', 245),
#  ('homeautomation', 244),
#  ('dataanalysis', 244),
#  ('unity', 244),
#  ('shell', 242),
#  ('mqtt', 242),
#  ('node', 241),
#  ('esp32', 241),
#  ('lstm', 239),
#  ('ui', 239),
#  ('jquery', 238),
#  ('redis', 237),
#  ('stream', 236),
#  ('pointcloud', 236),
#  ('algorithms', 231),
#  ('js', 231),
#  ('awslambda', 231),
#  ('vuejs', 227),
#  ('poseestimation', 227),
#  ('http', 225),
#  ('exploit', 225),
#  ('sdk', 221),
#  ('gamedevelopment', 221),
#  ('machinelearningalgorithms', 219),
#  ('frontend', 219),
#  ('kerastensorflow', 217),
#  ('tensorflow2', 217),
#  ('datavisualization', 215),
#  ('selfdrivingcar', 215),
#  ('fasterrcnn', 212),
#  ('imagesegmentation', 210),
#  ('telegrambot', 209),
#  ('authentication', 209),
#  ('containers', 208),
#  ('ml', 207),
#  ('redux', 204),
#  ('scikitlearn', 203),
#  ('dart', 202),
#  ('algorithm', 202),
#  ('ctf', 201),
#  ('git', 199),
#  ('objectivec', 197),
#  ('webapp', 197),
#  ('scanner', 197),
#  ('spark', 196),
#  ('blueteam', 196),
#  ('unsupervisedlearning', 195),
#  ('nginx', 195),
#  ('simulation', 195),
#  ('data', 194),
#  ('face', 194),
#  ('ids', 194),
#  ('learn', 193),
#  ('githubactions', 193),
#  ('script', 192),
#  ('transformer', 191),
#  ('express', 191),
#  ('discordbot', 190),
#  ('slack', 190),
#  ('remotesensing', 190),
#  ('mobile', 190),
#  ('yolov4', 189),
#  ('pandas', 186),
#  ('analytics', 186),
#  ('crossplatform', 186),
#  ('esp8266', 185),
#  ('speechrecognition', 185),
#  ('malwaredetection', 185),
#  ('datamining', 183),
#  ('rest', 183),
#  ('reinforcementlearning', 182),
#  ('lua', 182),
#  ('analysis', 182),
#  ('lambda', 182),
#  ('sentimentanalysis', 182),
#  ('slam', 181),
#  ('imagerecognition', 181),
#  ('observability', 179),
#  ('instancesegmentation', 178),
#  ('darknet', 178),
#  ('chatgpt', 178),
#  ('gin', 178),
#  ('graphql', 177),
#  ('wifi', 177),
#  ('resources', 177),
#  ('dns', 177),
#  ('staticanalysis', 176),
#  ('trade', 176),
#  ('lidar', 175),
#  ('server', 174),
#  ('spring', 174),
#  ('chromeextension', 173),
#  ('devsecops', 173),
#  ('yara', 172),
#  ('twitter', 172),
#  ('vulnerability', 171),
#  ('lanedetection', 170),
#  ('email', 170),
#  ('solidity', 169),
#  ('proxy', 169),
#  ('markdown', 168),
#  ('google', 168),
#  ('chatbot', 168),
#  ('ubuntu', 167),
#  ('minecraft', 166),
#  ('pipeline', 166),
#  ('k8s', 165),
#  ('music', 165),
#  ('research', 165),
#  ('objecttracking', 163),
#  ('jwt', 162),
#  ('pentest', 161),
#  ('documentation', 161),
#  ('signalprocessing', 161),
#  ('medicalimaging', 160),
#  ('template', 160),
#  ('cloudnative', 160),
#  ('electron', 159),
#  ('scala', 159),
#  ('smarthome', 158),
#  ('autonomousvehicles', 158),
#  ('securityaudit', 158),
#  ('randomforest', 157),
#  ('androidapplication', 157),
#  ('cuda', 157),
#  ('maskrcnn', 156),
#  ('ssd', 156),
#  ('swagger', 155),
#  ('caffe', 155),
#  ('tailwindcss', 155),
#  ('opengl', 155),
#  ('commandline', 155),
#  ('bigdata', 154),
#  ('browser', 154),
#  ('smartcontracts', 154),
#  ('microservice', 154),
#  ('malwareresearch', 153),
#  ('tensorrt', 152),
#  ('gpu', 152),
#  ('wordpressplugin', 151),
#  ('networkanalysis', 151),
#  ('dockerimage', 151),
#  ('terminal', 150),
#  ('unity3d', 149),
#  ('outlierdetection', 149),
#  ('firewall', 149),
#  ('performance', 149),
#  ('textclassification', 148),
#  ('3d', 148),
#  ('onnx', 147),
#  ('threatintel', 147),
#  ('gcp', 146),
#  ('webpack', 146),
#  ('statistics', 146),
#  ('openvino', 146),
#  ('expressjs', 145),
#  ('apple', 145),
#  ('selenium', 145),
#  ('rail', 144),
#  ('datasets', 144),
#  ('transformers', 144),
#  ('edgedetection', 144),
#  ('dotnetcore', 143),
#  ('nextjs', 143),
#  ('sensor', 143),
#  ('datastructures', 143),
#  ('frauddetection', 143),
#  ('embed', 143),
#  ('cicd', 142),
#  ('css3', 141),
#  ('component', 141),
#  ('microsoft', 141),
#  ('dialog', 141),
#  ('hook', 140),
#  ('gameengine', 140),
#  ('bert', 139),
#  ('ssh', 139),
#  ('windows10', 139),
#  ('website', 139),
#  ('helm', 138),
#  ('package', 138),
#  ('intrusiondetection', 138),
#  ('openapi', 137),
#  ('siem', 137),
#  ('generativeadversarialnetwork', 137),
#  ('phishing', 137),
#  ('project', 136),
#  ('deployment', 136),
#  ('hackingtool', 136),
#  ('inference', 136),
#  ('swiftui', 136),
#  ('svm', 135),
#  ('ffmpeg', 135),
#  ('parser', 135),
#  ('heroku', 134),
#  ('videoprocessing', 134),
#  ('dlib', 134),
#  ('nlpmachinelearning', 133),
#  ('selfhosted', 133),
#  ('websocket', 132),
#  ('vision', 132),
#  ('vscode', 132),
#  ('terraformmodule', 132),
#  ('kaggle', 131),
#  ('kernel', 131),
#  ('springcloud', 130),
#  ('androidlibrary', 130),
#  ('augmentedreality', 129),
#  ('backup', 129),
#  ('bootstrap4', 128),
#  ('debian', 128),
#  ('architecture', 128),
#  ('prometheusexporter', 128),
#  ('alertmanager', 128),
#  ('boilerplate', 127),
#  ('recognition', 127),
#  ('chrome', 126),
#  ('openai', 125),
#  ('demo', 125),
#  ('webrtc', 124),
#  ('tensorflowlite', 124),
#  ('3dobjectdetection', 124),
#  ('npm', 124),
#  ('client', 124),
#  ('audit', 123),
#  ('theme', 123),
#  ('benchmark', 123),
#  ('app', 122),
#  ('gamedev', 122),
#  ('filter', 122),
#  ('textdetection', 122),
#  ('vim', 122),
#  ('backend', 122),
#  ('infrastructure', 122),
#  ('statuspage', 122),
#  ('cnnkeras', 121),
#  ('distributedsystems', 121),
#  ('ssl', 121),
#  ('autoencoder', 121),
#  ('program', 121),
#  ('jenkins', 121),
#  ('kibana', 120),
#  ('xss', 120),
#  ('oauth2', 120),
#  ('vulnerabilitydetection', 120),
#  ('tls', 120),
#  ('workflow', 119),
#  ('selfsupervisedlearning', 119),
#  ('graphneuralnetworks', 119),
#  ('featureextraction', 119),
#  ('free', 118),
#  ('fuzzing', 118),
#  ('mlops', 118),
#  ('language', 117),
#  ('tensorflowjs', 117),
#  ('mediapipe', 117),
#  ('materialdesign', 117),
#  ('ecommerce', 117),
#  ('web3', 117),
#  ('vpn', 116),
#  ('cordova', 116),
#  ('reconnaissance', 115),
#  ('cve', 115),
#  ('localization', 115),
#  ('resnet', 115),
#  ('optimization', 114),
#  ('unet', 114),
#  ('module', 114),
#  ('changedetection', 114),
#  ('emotionrecognition', 114),
#  ('googlecloud', 113),
#  ('pushnotifications', 113),
#  ('developertools', 113),
#  ('uptimemonitor', 113),
#  ('uikit', 112),
#  ('sklearn', 112),
#  ('networksecurity', 111),
#  ('bluetooth', 111),
#  ('digitalforensics', 111),
#  ('education', 111),
#  ('crawler', 110),
#  ('storage', 110),
#  ('elixir', 110),
#  ('hacktoberfestaccepted', 110),
#  ('streamlit', 109),
#  ('debug', 109),
#  ('compliance', 109),
#  ('awesomelists', 109),
#  ('webassembly', 108),
#  ('components', 108),
#  ('s3', 108),
#  ('finance', 107),
#  ('hardware', 107),
#  ('translation', 107),
#  ('securityautomation', 107),
#  ('androidapp', 107),
#  ('rnn', 106),
#  ('vulnerabilities', 106),
#  ('communitydetection', 105),
#  ('bestpractices', 105),
#  ('hackingtools', 105),
#  ('message', 105),
#  ('pwa', 105),
#  ('search', 105),
#  ('vscodeextension', 105),
#  ('sqlite', 105),
#  ('terraformmodules', 105),
#  ('springsecurity', 105),
#  ('intel', 105),
#  ('apigateway', 104),
#  ('vehicledetection', 104),
#  ('arduinolibrary', 104),
#  ('vulnerabilityscanners', 104),
#  ('collisiondetection', 104),
#  ('cache', 104),
#  ('coronavirus', 103),
#  ('webgl', 103),
#  ('computerscience', 103),
#  ('pretrainedmodels', 103),
#  ('animation', 102),
#  ('edgecomputing', 102),
#  ('csv', 101),
#  ('logisticregression', 101),
#  ('webhook', 101),
#  ('robot', 101),
#  ('edge', 101),
#  ('genomics', 101),
#  ('es6', 101),
#  ('matplotlib', 101),
#  ('blog', 100),
#  ('attack', 100),
#  ('commandlinetool', 100),
#  ('googlecloudplatform', 99),
#  ('youtube', 99),
#  ('authorization', 99),
#  ('weather', 99),
#  ('emotiondetection', 99),
#  ('postgres', 99),
#  ('notification', 99),
#  ('wasm', 99),
#  ('hacktoberfest2021', 98),
#  ('fastapi', 98),
#  ('infrastructureascode', 97),
#  ('satelliteimagery', 97),
#  ('cheatsheet', 97),
#  ('audioprocessing', 97),
#  ('cnnclassification', 97),
#  ('interview', 97),
#  ('owasp', 96),
#  ('kalilinux', 96),
#  ('openshift', 95),
#  ('hacktoberfest2020', 95),
#  ('kotlinandroid', 95),
#  ('cocoapods', 95),
#  ('nmap', 95),
#  ('mobilenet', 95),
#  ('timeseriesanalysis', 95),
#  ('yolov2', 94),
#  ('validation', 94),
#  ('svmclassifier', 94),
#  ('uicomponents', 94),
#  ('materialui', 94),
#  ('tflite', 94),
#  ('influxdb', 94),
#  ('interviewquestions', 94),
#  ('regression', 93),
#  ('physics', 93),
#  ('imagenet', 93),
#  ('async', 93),
#  ('filesystem', 93),
#  ('websockets', 93),
#  ('rstats', 93),
#  ('hacktoberfest2022', 93),
#  ('speech', 92),
#  ('mobilenetv2', 92),
#  ('cv', 92),
#  ('gitops', 92),
#  ('chat', 92),
#  ('sass', 91),
#  ('apiclient', 91),
#  ('pdf', 91),
#  ('hackathon', 91),
#  ('generator', 91),
#  ('fpga', 91),
#  ('pentesttool', 90),
#  ('guide', 90),
#  ('scraper', 90),
#  ('speechtotext', 90),
#  ('webapplication', 90),
#  ('supervisedlearning', 89),
#  ('container', 89),
#  ('cloudformation', 89),
#  ('mod', 89),
#  ('mtcnn', 89),
#  ('attentionmechanism', 89),
#  ('firmware', 89),
#  ('symfony', 89),
#  ('yolov8', 89),
#  ('jupyter', 89),
#  ('motiondetection', 89),
#  ('upptime', 89),
#  ('recon', 88),
#  ('tradingbot', 88),
#  ('modal', 88),
#  ('emacs', 88),
#  ('imageanalysis', 88),
#  ('pytorchimplementation', 88),
#  ('firefox', 88),
#  ('tcp', 88),
#  ('bypass', 87),
#  ('coursera', 87),
#  ('extension', 87),
#  ('wallet', 87),
#  ('coco', 87),
#  ('svelte', 87),
#  ('mitreattack', 87),
#  ('awss3', 87),
#  ('amazon', 86),
#  ('humanposeestimation', 86),
#  ('middleware', 86),
#  ('xml', 86),
#  ('networkmonitoring', 86),
#  ('informationsecurity', 86),
#  ('securityscanner', 86),
#  ('binance', 86),
#  ('bashscript', 86),
#  ('zabbix', 86),
#  ('train', 86),
#  ('grpc', 85),
#  ('clojure', 85),
#  ('honeypot', 85),
#  ('healthcare', 85),
#  ('p2p', 85),
#  ('toast', 85),
#  ('driver', 85),
#  ('astronomy', 85),
#  ('detector', 85),
#  ('code', 84),
#  ('restfulapi', 84),
#  ('recurrentneuralnetworks', 84),
#  ('lightweight', 84),
#  ('coreml', 84),
#  ('ctfwriteups', 84),
#  ('workshop', 83),
#  ('exploitation', 83),
#  ('ip', 83),
#  ('arm', 83),
#  ('splunk', 83),
#  ('udacity', 83),
#  ('flaskapplication', 82),
#  ('webcam', 82),
#  ('i18n', 82),
#  ('assembly', 82),
#  ('xcode', 82),
#  ('yolov7', 82),
#  ('detectron2', 82),
#  ('cloudcomputing', 82),
#  ('retinanet', 82),
#  ('artificialneuralnetworks', 82),
#  ('continuousintegration', 81),
#  ('maven', 81),
#  ('javascriptlibrary', 81),
#  ('popup', 81),
#  ('logger', 81),
#  ('textrecognition', 81),
#  ('monitoringtool', 81),
#  ('logstash', 81),
#  ('twitch', 81),
#  ('cloudflare', 81),
#  ('qt', 81),
#  ('php7', 80),
#  ('jetsonnano', 80),
#  ('dataengineering', 80),
#  ('development', 80),
#  ('application', 80),
#  ('perl', 80),
#  ('pyqt5', 80),
#  ('cyberthreatintelligence', 80),
#  ('gps', 80),
#  ('cmake', 80),
#  ('ecs', 80),
#  ('eslint', 80),
#  ('graphalgorithms', 79),
#  ('nvidia', 79),
#  ('actionrecognition', 79),
#  ('languagedetection', 79),
#  ('tutorials', 79),
#  ('password', 78),
#  ('console', 78),
#  ('protocol', 78),
#  ('ips', 78),
#  ('elk', 78),
#  ('admin', 78),
#  ('mxnet', 78),
#  ('pythonscript', 78),
#  ('obfuscation', 78),
#  ('sms', 78),
#  ('internetofthings', 77),
#  ('example', 77),
#  ('convolutionalneuralnetwork', 77),
#  ('xgboost', 77),
#  ('compiler', 77),
#  ('intrusiondetectionsystem', 77),
#  ('yaml', 77),
#  ('design', 77),
#  ('gradle', 76),
#  ('misp', 76),
#  ('rabbitmq', 76),
#  ('canvas', 76),
#  ('dnn', 76),
#  ('ros2', 76),
#  ('searchengine', 76),
#  ('pythonlibrary', 76),
#  ('ransomware', 75),
#  ('facialrecognition', 75),
#  ('raspberrypi3', 75),
#  ('forensicanalysis', 75),
#  ('poc', 75),
#  ('ci', 75),
#  ('osx', 75),
#  ('gplv3', 75),
#  ('suricata', 75),
#  ('linearregression', 74),
#  ('backdoor', 74),
#  ('distribute', 74),
#  ('editor', 74),
#  ('dataaugmentation', 74),
#  ('surveillance', 74),
#  ('accessibility', 74),
#  ('desktop', 73),
#  ('ncnn', 73),
#  ('metadata', 73),
#  ('gdpr', 73),
#  ('prediction', 73),
#  ('ble', 73),
#  ('npmpackage', 73),
#  ('pcap', 73),
#  ('yararules', 72),
#  ('tor', 72),
#  ('router', 72),
#  ('gpt', 72),
#  ('securityhardening', 72),
#  ('lidarpointcloud', 72),
#  ('adversarialattacks', 72),
#  ('3dreconstruction', 72),
#  ('programminglanguage', 72),
#  ('htmlcssjavascript', 72),
#  ('ajax', 71),
#  ('cti', 71),
#  ('puppeteer', 71),
#  ('health', 71),
#  ('softwareengineering', 71),
#  ('jqueryplugin', 71),
#  ('mac', 71),
#  ('https', 71),
#  ('llm', 71),
#  ('cpu', 71),
#  ('scss', 70),
#  ('sandbox', 70),
#  ('management', 70),
#  ('visiontransformer', 70),
#  ('integration', 70),
#  ('stm32', 70),
#  ('defi', 70),
#  ('kalmanfilter', 70),
#  ('salientobjectdetection', 70),
#  ('awsec2', 70),
#  ('virus', 70)]

# %%
t3 = github_data_df['about'].apply(lambda x: myclnfunction(x))

# %%
t3_cnt = Counter(t3.explode())
t3_cnt.most_common()
# Out:
# [(nan, 53413),
#  ('detection', 25620),
#  ('learn', 11396),
#  ('data', 10783),
#  ('project', 10742),
#  ('tool', 10131),
#  ('code', 9236),
#  ('image', 9042),
#  ('python', 7972),
#  ('library', 7828),
#  ('list', 7768),
#  ('network', 7280),
#  ('api', 6266),
#  ('web', 6129),
#  ('application', 5523),
#  ('app', 5473),
#  ('script', 5352),
#  ('https', 5138),
#  ('c', 4920),
#  ('js', 4655),
#  ('plugin', 4633),
#  ('framework', 4614),
#  ('paper', 4547),
#  ('security', 4441),
#  ('android', 4430),
#  ('alert', 4395),
#  ('face', 4191),
#  ('monitor', 4100),
#  ('github', 4023),
#  ('resources', 3885),
#  ('analysis', 3870),
#  ('http', 3808),
#  ('awesome', 3777),
#  ('javascript', 3734),
#  ('test', 3644),
#  ('server', 3494),
#  ('go', 3103),
#  ('program', 3022),
#  ('google', 3014),
#  ('track', 2968),
#  ('recognition', 2892),
#  ('cloud', 2860),
#  ('react', 2860),
#  ('windows', 2792),
#  ('package', 2778),
#  ('dataset', 2741),
#  ('module', 2738),
#  ('ios', 2687),
#  ('aws', 2679),
#  ('video', 2661),
#  ('design', 2605),
#  ('node', 2539),
#  ('train', 2507),
#  ('game', 2490),
#  ('vision', 2410),
#  ('opencv', 2387),
#  ('tensorflow', 2384),
#  ('client', 2352),
#  ('linux', 2277),
#  ('algorithm', 2255),
#  ('java', 2231),
#  ('pytorch', 2182),
#  ('language', 2179),
#  ('realtime', 2155),
#  ('development', 2131),
#  ('php', 2021),
#  ('ai', 1992),
#  ('3d', 1950),
#  ('log', 1949),
#  ('management', 1904),
#  ('classification', 1837),
#  ('bot', 1829),
#  ('message', 1800),
#  ('example', 1775),
#  ('docker', 1688),
#  ('mobile', 1683),
#  ('algorithms', 1667),
#  ('free', 1636),
#  ('segmentation', 1621),
#  ('azure', 1606),
#  ('sdk', 1595),
#  ('demo', 1567),
#  ('vue', 1564),
#  ('camera', 1562),
#  ('search', 1556),
#  ('database', 1550),
#  ('attack', 1547),
#  ('ui', 1535),
#  ('kubernetes', 1485),
#  ('cluster', 1473),
#  ('html', 1470),
#  ('extension', 1444),
#  ('stream', 1435),
#  ('spring', 1429),
#  ('research', 1425),
#  ('browser', 1420),
#  ('detector', 1416),
#  ('graph', 1406),
#  ('guide', 1383),
#  ('ids', 1354),
#  ('integration', 1327),
#  ('email', 1272),
#  ('lightweight', 1189),
#  ('filter', 1184),
#  ('component', 1163),
#  ('website', 1160),
#  ('malware', 1134),
#  ('opensource', 1130),
#  ('git', 1112),
#  ('performance', 1093),
#  ('r', 1074),
#  ('template', 1060),
#  ('audio', 1043),
#  ('jquery', 1043),
#  ('components', 1034),
#  ('datasets', 1030),
#  ('json', 1019),
#  ('pipeline', 1007),
#  ('edge', 1003),
#  ('css', 992),
#  ('hack', 990),
#  ('notifications', 985),
#  ('prometheus', 954),
#  ('iot', 953),
#  ('amazon', 950),
#  ('driver', 950),
#  ('rest', 940),
#  ('architecture', 912),
#  ('ml', 909),
#  ('microsoft', 899),
#  ('protocol', 894),
#  ('ruby', 884),
#  ('ip', 883),
#  ('wordpress', 879),
#  ('arduino', 862),
#  ('twitter', 862),
#  ('laravel', 859),
#  ('bootstrap', 859),
#  ('terraform', 858),
#  ('automation', 853),
#  ('angular', 842),
#  ('notification', 840),
#  ('yolo', 838),
#  ('frontend', 837),
#  ('cnn', 835),
#  ('tutorial', 834),
#  ('keras', 834),
#  ('sensor', 820),
#  ('documentation', 808),
#  ('chat', 803),
#  ('interview', 800),
#  ('cli', 792),
#  ('generator', 789),
#  ('discord', 779),
#  ('swift', 774),
#  ('robot', 774),
#  ('distribute', 766),
#  ('ips', 763),
#  ('tutorials', 751),
#  ('matlab', 742),
#  ('blog', 738),
#  ('macos', 724),
#  ('sql', 719),
#  ('speech', 717),
#  ('backend', 709),
#  ('embed', 709),
#  ('proxy', 708),
#  ('dashboard', 704),
#  ('analytics', 697),
#  ('metrics', 694),
#  ('rail', 693),
#  ('admin', 685),
#  ('container', 685),
#  ('workshop', 672),
#  ('ros', 672),
#  ('telegram', 659),
#  ('rust', 659),
#  ('powershell', 647),
#  ('trade', 639),
#  ('flutter', 633),
#  ('authentication', 631),
#  ('storage', 631),
#  ('cordova', 629),
#  ('scanner', 629),
#  ('desktop', 624),
#  ('chrome', 619),
#  ('golang', 618),
#  ('gui', 617),
#  ('django', 609),
#  ('ansible', 608),
#  ('prediction', 605),
#  ('theme', 596),
#  ('nlp', 595),
#  ('vulnerability', 592),
#  ('infrastructure', 590),
#  ('blockchain', 581),
#  ('deployment', 576),
#  ('forensics', 575),
#  ('apple', 575),
#  ('typescript', 568),
#  ('editor', 567),
#  ('exploit', 564),
#  ('shell', 563),
#  ('music', 559),
#  ('hardware', 557),
#  ('kernel', 534),
#  ('pdf', 529),
#  ('mac', 523),
#  ('bypass', 516),
#  ('wifi', 516),
#  ('mysql', 514),
#  ('dns', 514),
#  ('unity', 508),
#  ('covid19', 507),
#  ('devops', 503),
#  ('password', 497),
#  ('inference', 496),
#  ('antivirus', 494),
#  ('html5', 491),
#  ('bitcoin', 490),
#  ('visualization', 488),
#  ('simulation', 488),
#  ('benchmark', 486),
#  ('crossplatform', 485),
#  ('health', 483),
#  ('flask', 482),
#  ('mongodb', 481),
#  ('firmware', 479),
#  ('ethereum', 475),
#  ('nodejs', 475),
#  ('serverless', 474),
#  ('yolov3', 472),
#  ('slack', 471),
#  ('localization', 462),
#  ('intel', 439),
#  ('kaggle', 431),
#  ('dialog', 426),
#  ('vulnerabilities', 420),
#  ('mod', 414),
#  ('console', 414),
#  ('parser', 408),
#  ('kafka', 408),
#  ('grafana', 406),
#  ('lidar', 405),
#  ('yara', 403),
#  ('spark', 401),
#  ('crypto', 401),
#  ('sms', 400),
#  ('validation', 396),
#  ('weather', 394),
#  ('youtube', 386),
#  ('ajax', 384),
#  ('privacy', 380),
#  ('encryption', 373),
#  ('audit', 372),
#  ('webcam', 371),
#  ('bash', 371),
#  ('lambda', 369),
#  ('express', 368),
#  ('wallet', 366),
#  ('yolov5', 364),
#  ('phishing', 364),
#  ('hook', 360),
#  ('debug', 359),
#  ('ocr', 358),
#  ('cpu', 356),
#  ('workflow', 355),
#  ('transformer', 353),
#  ('microservices', 350),
#  ('cache', 345),
#  ('gpu', 344),
#  ('terminal', 335),
#  ('udacity', 334),
#  ('elasticsearch', 332),
#  ('tcp', 331),
#  ('svm', 331),
#  ('markdown', 329),
#  ('xss', 328),
#  ('surveillance', 326),
#  ('ctf', 326),
#  ('poc', 322),
#  ('mqtt', 320),
#  ('regression', 320),
#  ('optimization', 319),
#  ('s3', 319),
#  ('robotics', 315),
#  ('ssh', 315),
#  ('redis', 310),
#  ('nginx', 307),
#  ('esp32', 306),
#  ('firebase', 305),
#  ('arm', 304),
#  ('boilerplate', 302),
#  ('backup', 298),
#  ('ubuntu', 297),
#  ('xml', 295),
#  ('bluetooth', 295),
#  ('csv', 294),
#  ('postgresql', 292),
#  ('slam', 291),
#  ('jupyter', 290),
#  ('vim', 284),
#  ('minecraft', 283),
#  ('commandline', 281),
#  ('esp8266', 277),
#  ('hackathon', 275),
#  ('containers', 273),
#  ('metadata', 272),
#  ('nvidia', 268),
#  ('gin', 268),
#  ('router', 263),
#  ('lstm', 262),
#  ('translation', 261),
#  ('splunk', 261),
#  ('redux', 260),
#  ('firewall', 257),
#  ('reactjs', 257),
#  ('ssd', 256),
#  ('cybersecurity', 256),
#  ('ci', 256),
#  ('cryptocurrency', 256),
#  ('statistics', 256),
#  ('physics', 251),
#  ('lua', 251),
#  ('transformers', 247),
#  ('virus', 242),
#  ('vpn', 239),
#  ('exploitation', 239),
#  ('firefox', 236),
#  ('microservice', 233),
#  ('jenkins', 233),
#  ('kotlin', 227),
#  ('graphql', 226),
#  ('osint', 225),
#  ('websocket', 225),
#  ('cv', 225),
#  ('ecommerce', 221),
#  ('zabbix', 220),
#  ('caffe', 216),
#  ('darknet', 216),
#  ('tls', 214),
#  ('canvas', 210),
#  ('middleware', 210),
#  ('opengl', 209),
#  ('webhook', 209),
#  ('electron', 206),
#  ('ssl', 203),
#  ('coursera', 201),
#  ('assembly', 199),
#  ('gps', 199),
#  ('chatgpt', 198),
#  ('deeplearning', 197),
#  ('async', 196),
#  ('authorization', 195),
#  ('pentesting', 194),
#  ('bert', 192),
#  ('modal', 192),
#  ('objectivec', 191),
#  ('python3', 189),
#  ('debian', 187),
#  ('scala', 185),
#  ('fpga', 185),
#  ('yolov4', 181),
#  ('animation', 178),
#  ('tensorrt', 178),
#  ('autoencoder', 177),
#  ('solidity', 177),
#  ('cloudflare', 176),
#  ('compliance', 176),
#  ('cloudformation', 175),
#  ('gcp', 175),
#  ('compiler', 175),
#  ('webrtc', 174),
#  ('swagger', 173),
#  ('openshift', 170),
#  ('sandbox', 165),
#  ('qt', 165),
#  ('clojure', 165),
#  ('grpc', 164),
#  ('timeseries', 164),
#  ('ransomware', 163),
#  ('selenium', 163),
#  ('helm', 163),
#  ('coco', 161),
#  ('heroku', 160),
#  ('fuzzing', 160),
#  ('emacs', 159),
#  ('oauth2', 159),
#  ('reactnative', 159),
#  ('openapi', 158),
#  ('twitch', 158),
#  ('webapp', 157),
#  ('alertmanager', 156),
#  ('logger', 155),
#  ('toast', 154),
#  ('cuda', 154),
#  ('onnx', 153),
#  ('filesystem', 153),
#  ('unet', 151),
#  ('siem', 151),
#  ('ecs', 150),
#  ('dlib', 147),
#  ('nmap', 147),
#  ('elixir', 147),
#  ('webpack', 145),
#  ('k8s', 145),
#  ('scikitlearn', 145),
#  ('backdoor', 144),
#  ('ble', 144),
#  ('chatbot', 143),
#  ('npm', 143),
#  ('springboot', 140),
#  ('dart', 139),
#  ('sqlite', 139),
#  ('binance', 139),
#  ('perl', 139),
#  ('popup', 137),
#  ('cloudnative', 136),
#  ('pentest', 136),
#  ('selfhosted', 135),
#  ('mediapipe', 134),
#  ('suricata', 134),
#  ('crawler', 133),
#  ('education', 133),
#  ('jwt', 133),
#  ('numpy', 133),
#  ('mtcnn', 132),
#  ('osx', 132),
#  ('cryptography', 132),
#  ('tor', 131),
#  ('symfony', 129),
#  ('openai', 128),
#  ('dnn', 127),
#  ('healthcare', 127),
#  ('honeypot', 124),
#  ('rnn', 123),
#  ('openvino', 123),
#  ('mobilenet', 121),
#  ('observability', 121),
#  ('elk', 121),
#  ('yaml', 120),
#  ('kibana', 119),
#  ('tflite', 118),
#  ('swiftui', 118),
#  ('owasp', 118),
#  ('ffmpeg', 117),
#  ('recon', 117),
#  ('webgl', 116),
#  ('accessibility', 116),
#  ('cve', 116),
#  ('vscode', 115),
#  ('retinanet', 115),
#  ('coreml', 111),
#  ('webassembly', 108),
#  ('es6', 107),
#  ('finance', 106),
#  ('pandas', 105),
#  ('influxdb', 104),
#  ('mxnet', 104),
#  ('streamlit', 102),
#  ('postgres', 101),
#  ('pwa', 100),
#  ('reconnaissance', 100),
#  ('fastapi', 99),
#  ('sass', 97),
#  ('cheatsheet', 97),
#  ('xcode', 97),
#  ('fasterrcnn', 95),
#  ('yolov8', 94),
#  ('websockets', 93),
#  ('dockercompose', 92),
#  ('gradle', 91),
#  ('misp', 91),
#  ('obfuscation', 91),
#  ('dfir', 89),
#  ('scraper', 89),
#  ('ncnn', 88),
#  ('detectron2', 88),
#  ('yolov2', 82),
#  ('resnet', 82),
#  ('yolov7', 80),
#  ('svelte', 80),
#  ('maven', 80),
#  ('p2p', 79),
#  ('pcap', 79),
#  ('bioinformatics', 78),
#  ('logstash', 76),
#  ('stm32', 75),
#  ('machinelearning', 75),
#  ('infosec', 74),
#  ('maskrcnn', 72),
#  ('vuejs', 71),
#  ('eslint', 70),
#  ('i18n', 69),
#  ('web3', 69),
#  ('raspberrypi', 69),
#  ('devsecops', 68),
#  ('gitops', 66),
#  ('coronavirus', 66),
#  ('rabbitmq', 64),
#  ('css3', 64),
#  ('mlops', 63),
#  ('imagenet', 62),
#  ('ros2', 60),
#  ('upptime', 60),
#  ('cmake', 59),
#  ('defi', 56),
#  ('homeassistant', 56),
#  ('matplotlib', 56),
#  ('mobilenetv2', 55),
#  ('xgboost', 55),
#  ('uikit', 54),
#  ('genomics', 52),
#  ('gdpr', 51),
#  ('facedetection', 51),
#  ('unity3d', 51),
#  ('tensorflow2', 48),
#  ('llm', 46),
#  ('tailwindcss', 44),
#  ('objectdetection', 43),
#  ('wasm', 41),
#  ('puppeteer', 39),
#  ('cpp', 39),
#  ('pointcloud', 38),
#  ('gpt', 38),
#  ('cti', 35),
#  ('materialui', 34),
#  ('astronomy', 34),
#  ('scss', 33),
#  ('sklearn', 33),
#  ('nextjs', 32),
#  ('bugbounty', 32),
#  ('redteam', 31),
#  ('webapplication', 30),
#  ('dotnet', 30),
#  ('csharp', 27),
#  ('speechtotext', 24),
#  ('hacktoberfest', 23),
#  ('gplv3', 22),
#  ('expressjs', 21),
#  ('computervision', 21),
#  ('penetrationtesting', 20),
#  ('tensorflowlite', 19),
#  ('pyqt5', 19),
#  ('springcloud', 19),
#  ('cicd', 18),
#  ('opencvpython', 17),
#  ('pythonscript', 17),
#  ('bigdata', 16),
#  ('bestpractices', 16),
#  ('infrastructureascode', 15),
#  ('tensorflowjs', 15),
#  ('datascience', 14),
#  ('facerecognition', 14),
#  ('reverseengineering', 13),
#  ('smarthome', 12),
#  ('imageprocessing', 11),
#  ('anomalydetection', 11),
#  ('bootstrap4', 11),
#  ('restapi', 10),
#  ('datastructures', 10),
#  ('php7', 10),
#  ('blueteam', 9),
#  ('springsecurity', 9),
#  ('languagedetection', 8),
#  ('neuralnetwork', 8),
#  ('motiondetection', 7),
#  ('statuspage', 7),
#  ('googlecloudplatform', 6),
#  ('raspberrypi3', 6),
#  ('poseestimation', 5),
#  ('gameengine', 5),
#  ('edgedetection', 5),
#  ('kerastensorflow', 5),
#  ('randomforest', 5),
#  ('neuralnetworks', 5),
#  ('gamedev', 5),
#  ('threatintelligence', 4),
#  ('selfdrivingcar', 4),
#  ('objecttracking', 4),
#  ('apigateway', 4),
#  ('sentimentanalysis', 4),
#  ('gamedevelopment', 4),
#  ('datamining', 4),
#  ('threathunting', 4),
#  ('yararules', 4),
#  ('pushnotifications', 4),
#  ('windows10', 3),
#  ('googlecloud', 3),
#  ('restfulapi', 3),
#  ('homeautomation', 3),
#  ('tradingbot', 3),
#  ('jetsonnano', 3),
#  ('speechrecognition', 3),
#  ('telegrambot', 3),
#  ('textdetection', 3),
#  ('jupyternotebook', 3),
#  ('cocoapods', 3),
#  ('internetofthings', 3),
#  ('collisiondetection', 3),
#  ('edgecomputing', 3),
#  ('rstats', 3),
#  ('lanedetection', 2),
#  ('materialdesign', 2),
#  ('imageclassification', 2),
#  ('communitydetection', 2),
#  ('kalmanfilter', 2),
#  ('frauddetection', 2),
#  ('vehicledetection', 2),
#  ('threatintel', 2),
#  ('semanticsegmentation', 2),
#  ('transferlearning', 2),
#  ('dotnetcore', 2),
#  ('uicomponents', 2),
#  ('augmentedreality', 2),
#  ('searchengine', 2),
#  ('dataanalysis', 2),
#  ('kalilinux', 1),
#  ('featureextraction', 1),
#  ('imagerecognition', 1),
#  ('instancesegmentation', 1),
#  ('smartcontracts', 1),
#  ('networkanalysis', 1),
#  ('jqueryplugin', 1),
#  ('unsupervisedlearning', 1),
#  ('signalprocessing', 1),
#  ('bashscript', 1),
#  ('apiclient', 1),
#  ('intrusiondetection', 1),
#  ('outlierdetection', 1),
#  ('commandlinetool', 1),
#  ('textclassification', 1),
#  ('androidlibrary', 1),
#  ('malwareanalysis', 1),
#  ('awslambda', 1),
#  ('incidentresponse', 1),
#  ('awsec2', 1),
#  ('imagesegmentation', 1),
#  ('emotionrecognition', 1),
#  ('npmpackage', 1),
#  ('programminglanguage', 1),
#  ('digitalforensics', 1),
#  ('githubactions', 1),
#  ('cplusplus', 1),
#  ('chromeextension', 1),
#  ('remotesensing', 1),
#  ('htmlcssjavascript', 1),
#  ('hackingtool', 1),
#  ('forensicanalysis', 1),
#  ('intrusiondetectionsystem', 1),
#  ('hacktoberfest2021', 1),
#  ('3dreconstruction', 1),
#  ('supervisedlearning', 1),
#  ('autonomousdriving', 1)]

# %%
t4 = github_data_df['languages'].apply(lambda x: myclnfunction(x))

# %%
t4_cnt = Counter(t4.explode())
t4_cnt.most_common()
# Out:
# [('python', 85119),
#  ('c', 60229),
#  ('shell', 57069),
#  ('javascript', 49677),
#  ('html', 40935),
#  (nan, 30353),
#  ('css', 29797),
#  ('jupyter', 19789),
#  ('java', 17412),
#  ('ruby', 10653),
#  ('objectivec', 10510),
#  ('cmake', 10454),
#  ('php', 9441),
#  ('typescript', 8785),
#  ('go', 8276),
#  ('matlab', 6311),
#  ('perl', 5473),
#  ('powershell', 4618),
#  ('cuda', 4374),
#  ('swift', 3961),
#  ('assembly', 3892),
#  ('scss', 3615),
#  ('r', 3512),
#  ('kotlin', 2567),
#  ('lua', 2543),
#  ('rust', 2280),
#  ('vue', 1890),
#  ('scala', 1300),
#  ('dart', 1199),
#  ('script', 958),
#  ('vim', 942),
#  ('solidity', 839),
#  ('emacs', 769),
#  ('clojure', 606),
#  ('yara', 582),
#  ('hack', 543),
#  ('arduino', 454),
#  ('elixir', 382),
#  ('language', 374),
#  ('protocol', 258),
#  ('svelte', 212),
#  ('ml', 203),
#  ('sass', 145),
#  ('markdown', 129),
#  ('module', 123),
#  ('management', 123),
#  ('yaml', 104),
#  ('nginx', 103),
#  ('json', 93),
#  ('webassembly', 91),
#  ('api', 49),
#  ('game', 40),
#  ('workflow', 34),
#  ('js', 28),
#  ('xml', 24),
#  ('template', 19),
#  ('sql', 17),
#  ('data', 16),
#  ('web', 10),
#  ('component', 8),
#  ('filter', 6),
#  ('list', 6),
#  ('framework', 5),
#  ('qt', 4),
#  ('http', 1),
#  ('openapi', 1)]

# %%
t5 = github_data_df['readme_clean'].apply(lambda x: myclnfunction(x))

# %%
t5_cnt = Counter(t5.explode())
t5_cnt.most_common()
# Out:
# [('1', 1462653),
#  ('file', 1280296),
#  ('data', 1116929),
#  ('code', 841991),
#  ('test', 757078),
#  ('image', 740513),
#  ('create', 708906),
#  ('build', 706714),
#  ('set', 696386),
#  ('name', 661142),
#  ('support', 614297),
#  ('function', 576514),
#  ('model', 570529),
#  ('project', 569795),
#  ('make', 560286),
#  ('http', 558639),
#  ('c', 530918),
#  ('app', 515640),
#  ('get', 506224),
#  ('learn', 502459),
#  ('python', 496298),
#  ('example', 491264),
#  ('network', 477513),
#  ('js', 467012),
#  ('type', 466813),
#  ('api', 446833),
#  ('server', 444425),
#  ('tool', 444002),
#  ('user', 443096),
#  ('install', 439300),
#  ('object', 435509),
#  ('command', 434523),
#  ('work', 431994),
#  ('list', 431816),
#  ('time', 431029),
#  ('5', 422647),
#  ('service', 415736),
#  ('source', 413675),
#  ('change', 410782),
#  ('x', 406484),
#  ('system', 389516),
#  ('script', 380698),
#  ('include', 379772),
#  ('string', 378714),
#  ('feature', 372346),
#  ('version', 370540),
#  ('library', 368236),
#  ('log', 363241),
#  ('process', 361301),
#  ('number', 352768),
#  ('find', 351278),
#  ('note', 344277),
#  ('web', 343978),
#  ('application', 339141),
#  ('base', 338551),
#  ('open', 332127),
#  ('go', 331816),
#  ('key', 331056),
#  ('javascript', 324864),
#  ('html', 321291),
#  ('update', 320156),
#  ('request', 318671),
#  ('detection', 317468),
#  ('class', 309168),
#  ('write', 307252),
#  ('call', 299025),
#  ('react', 297805),
#  ('page', 296929),
#  ('package', 296148),
#  ('import', 291603),
#  ('environment', 287776),
#  ('information', 286181),
#  ('json', 284967),
#  ('video', 284056),
#  ('6', 283230),
#  ('program', 282693),
#  ('check', 277568),
#  ('message', 267846),
#  ('text', 265534),
#  ('configuration', 264941),
#  ('output', 264091),
#  ('first', 262245),
#  ('train', 261476),
#  ('address', 256823),
#  ('paper', 255880),
#  ('read', 255731),
#  ('github', 253022),
#  ('link', 252281),
#  ('security', 250583),
#  ('machine', 246936),
#  ('path', 246294),
#  ('access', 245132),
#  ('generate', 237700),
#  ('directory', 235924),
#  ('software', 234355),
#  ('id', 233561),
#  ('download', 230610),
#  ('line', 229674),
#  ('load', 229465),
#  ('npm', 224483),
#  ('fix', 224015),
#  ('error', 222001),
#  ('design', 220167),
#  ('host', 219523),
#  ('simple', 218902),
#  ('development', 215745),
#  ('help', 211087),
#  ('case', 210236),
#  ('windows', 209581),
#  ('database', 209129),
#  ('bash', 208483),
#  ('format', 208302),
#  ('linux', 207973),
#  ('license', 207551),
#  ('issue', 206096),
#  ('input', 205999),
#  ('public', 205754),
#  ('config', 205309),
#  ('state', 203286),
#  ('node', 201859),
#  ('content', 201651),
#  ('method', 200734),
#  ('client', 200188),
#  ('search', 197826),
#  ('framework', 196521),
#  ('php', 196190),
#  ('control', 196053),
#  ('local', 195925),
#  ('free', 195187),
#  ('map', 193509),
#  ('java', 192741),
#  ('url', 192446),
#  ('device', 192381),
#  ('step', 192179),
#  ('docker', 192152),
#  ('store', 191819),
#  ('sh', 191506),
#  ('port', 190590),
#  ('point', 188740),
#  ('git', 186859),
#  ('view', 186051),
#  ('users', 186033),
#  ('module', 184326),
#  ('index', 183679),
#  ('memory', 182029),
#  ('language', 181417),
#  ('console', 180271),
#  ('google', 179448),
#  ('options', 179328),
#  ('etc', 178549),
#  ('pdf', 177722),
#  ('instance', 177523),
#  ('component', 177273),
#  ('css', 176425),
#  ('size', 174919),
#  ('android', 172100),
#  ('target', 169416),
#  ('select', 169086),
#  ('mode', 168567),
#  ('dataset', 168470),
#  ('r', 167933),
#  ('src', 164452),
#  ('repository', 162224),
#  ('analysis', 162034),
#  ('deploy', 161972),
#  ('release', 160987),
#  ('display', 160535),
#  ('custom', 159572),
#  ('alert', 159511),
#  ('order', 159361),
#  ('aws', 156857),
#  ('block', 156755),
#  ('multiple', 156244),
#  ('top', 156157),
#  ('deep', 155886),
#  ('table', 155532),
#  ('cloud', 155525),
#  ('array', 153894),
#  ('group', 153805),
#  ('event', 150521),
#  ('interface', 149793),
#  ('button', 149470),
#  ('task', 149180),
#  ('remove', 149075),
#  ('implementation', 149013),
#  ('applications', 147911),
#  ('sample', 147281),
#  ('action', 145955),
#  ('account', 145353),
#  ('net', 144103),
#  ('components', 144042),
#  ('pass', 143491),
#  ('document', 142923),
#  ('detect', 142459),
#  ('click', 142385),
#  ('plugin', 141914),
#  ('usage', 141786),
#  ('browser', 141283),
#  ('report', 140783),
#  ('copy', 139753),
#  ('common', 138887),
#  ('documentation', 138865),
#  ('reference', 138158),
#  ('query', 137618),
#  ('resources', 137390),
#  ('game', 136123),
#  ('structure', 135898),
#  ('setup', 135447),
#  ('root', 135424),
#  ('systems', 135406),
#  ('cache', 135041),
#  ('render', 134294),
#  ('monitor', 133373),
#  ('share', 133273),
#  ('tag', 131186),
#  ('neural', 130303),
#  ('email', 130039),
#  ('connect', 129951),
#  ('filter', 129433),
#  ('post', 128944),
#  ('tree', 128896),
#  ('debug', 128770),
#  ('form', 127113),
#  ('style', 126767),
#  ('examples', 126678),
#  ('settings', 126555),
#  ('match', 125948),
#  ('cluster', 125187),
#  ('password', 125149),
#  ('performance', 125034),
#  ('platform', 124871),
#  ('ip', 124703),
#  ('optional', 124323),
#  ('export', 123446),
#  ('env', 122697),
#  ('label', 122444),
#  ('ios', 121957),
#  ('shell', 121767),
#  ('graph', 121277),
#  ('rule', 120440),
#  ('easy', 120307),
#  ('static', 120064),
#  ('management', 119907),
#  ('parameters', 118853),
#  ('color', 118708),
#  ('installation', 116990),
#  ('io', 116183),
#  ('next', 116143),
#  ('computer', 115662),
#  ('print', 114778),
#  ('txt', 114553),
#  ('bug', 113603),
#  ('do', 112799),
#  ('status', 110498),
#  ('domain', 110077),
#  ('manage', 109423),
#  ('info', 109234),
#  ('guide', 109218),
#  ('clone', 108670),
#  ('delete', 108323),
#  ('useful', 108255),
#  ('arxiv', 107601),
#  ('response', 107434),
#  ('demo', 106742),
#  ('core', 105613),
#  ('fast', 105438),
#  ('track', 105257),
#  ('container', 104544),
#  ('proxy', 103485),
#  ('cd', 100727),
#  ('algorithm', 100643),
#  ('libraries', 99508),
#  ('production', 99183),
#  ('binary', 99030),
#  ('stream', 98813),
#  ('kernel', 98549),
#  ('ui', 98340),
#  ('pattern', 97970),
#  ('storage', 97883),
#  ('architecture', 97423),
#  ('uboot', 97350),
#  ('swift', 97129),
#  ('algorithms', 96374),
#  ('stack', 96274),
#  ('remote', 96240),
#  ('edit', 95440),
#  ('template', 95332),
#  ('collection', 95116),
#  ('course', 94391),
#  ('space', 94299),
#  ('record', 94045),
#  ('global', 93769),
#  ('azure', 93704),
#  ('2019', 93419),
#  ('team', 93055),
#  ('sudo', 92738),
#  ('limit', 92721),
#  ('attack', 92641),
#  ('devices', 92170),
#  ('dependencies', 92046),
#  ('best', 91874),
#  ('apps', 91691),
#  ('date', 91521),
#  ('window', 91372),
#  ('board', 91326),
#  ('events', 90980),
#  ('solution', 90723),
#  ('engine', 90683),
#  ('bin', 89930),
#  ('channel', 89893),
#  ('question', 89846),
#  ('book', 89703),
#  ('star', 89459),
#  ('layer', 89376),
#  ('website', 89120),
#  ('location', 88440),
#  ('standard', 88316),
#  ('visual', 88171),
#  ('job', 87805),
#  ('compile', 87730),
#  ('hash', 87108),
#  ('editor', 86813),
#  ('distribute', 86242),
#  ('v', 86200),
#  ('boot', 86145),
#  ('mit', 85749),
#  ('blog', 85467),
#  ('move', 85380),
#  ('os', 85351),
#  ('2020', 85164),
#  ('3d', 84930),
#  ('home', 84815),
#  ('resource', 84229),
#  ('basic', 83856),
#  ('private', 83427),
#  ('face', 83289),
#  ('token', 83125),
#  ('context', 82089),
#  ('sort', 81712),
#  ('online', 81285),
#  ('attribute', 81251),
#  ('site', 81141),
#  ('videos', 80976),
#  ('header', 80822),
#  ('yaml', 80167),
#  ('native', 80034),
#  ('scale', 79909),
#  ('small', 79824),
#  ('modules', 79792),
#  ('box', 78988),
#  ('deployment', 78961),
#  ('sql', 78874),
#  ('controller', 78789),
#  ('engineer', 78315),
#  ('2018', 77956),
#  ('dynamic', 77733),
#  ('2021', 77685),
#  ('upload', 77641),
#  ('power', 77565),
#  ('properties', 77439),
#  ('scan', 77144),
#  ('microsoft', 76876),
#  ('advance', 76724),
#  ('driver', 76263),
#  ('register', 76078),
#  ('apache', 75955),
#  ('connection', 75909),
#  ('element', 75823),
#  ('word', 75640),
#  ('requirements', 75624),
#  ('count', 75442),
#  ('compute', 75283),
#  ('dev', 75220),
#  ('extension', 75184),
#  ('screen', 74780),
#  ('integration', 74779),
#  ('push', 74402),
#  ('switch', 74377),
#  ('cod', 74233),
#  ('warn', 73364),
#  ('mobile', 73042),
#  ('flow', 72948),
#  ('range', 72749),
#  ('flag', 72730),
#  ('protocol', 72455),
#  ('versions', 72082),
#  ('recognition', 71982),
#  ('vue', 71927),
#  ('cpu', 71753),
#  ('xml', 71717),
#  ('admin', 71710),
#  ('research', 71270),
#  ('sequence', 70572),
#  ('convert', 70463),
#  ('frame', 70378),
#  ('errors', 70368),
#  ('amazon', 69879),
#  ('profile', 69807),
#  ('2022', 69670),
#  ('bind', 69669),
#  ('classification', 69610),
#  ('publish', 69467),
#  ('pip', 69341),
#  ('kubernetes', 69328),
#  ('virtual', 69156),
#  ('character', 68951),
#  ('ai', 68650),
#  ('serve', 68200),
#  ('manager', 67941),
#  ('speed', 67860),
#  ('2017', 67812),
#  ('comment', 67693),
#  ('parse', 67178),
#  ('operations', 67165),
#  ('contribute', 66801),
#  ('hardware', 66735),
#  ('camera', 66570),
#  ('introduction', 66238),
#  ('extract', 66152),
#  ('localhost', 66076),
#  ('long', 66020),
#  ('people', 65800),
#  ('authentication', 65297),
#  ('plan', 65240),
#  ('session', 64535),
#  ('vision', 64517),
#  ('thread', 64494),
#  ('audio', 64372),
#  ('ruby', 64057),
#  ('rest', 63920),
#  ('active', 63884),
#  ('answer', 63729),
#  ('real', 63342),
#  ('community', 63323),
#  ('syntax', 63292),
#  ('developers', 63230),
#  ('cause', 63118),
#  ('random', 63053),
#  ('position', 62769),
#  ('launch', 62699),
#  ('bootstrap', 62681),
#  ('login', 62251),
#  ('datasets', 62247),
#  ('developer', 62105),
#  ('university', 61545),
#  ('flash', 60989),
#  ('product', 60751),
#  ('embed', 60569),
#  ('jest', 60524),
#  ('play', 60356),
#  ('transfer', 60151),
#  ('elements', 60138),
#  ('review', 60114),
#  ('assets', 59950),
#  ('live', 59933),
#  ('terminal', 59864),
#  ('trigger', 59843),
#  ('patch', 59615),
#  ('tensorflow', 59445),
#  ('focus', 59307),
#  ('less', 59182),
#  ('servers', 58971),
#  ('drive', 58897),
#  ('segmentation', 58863),
#  ('article', 58858),
#  ('automate', 58807),
#  ('tutorial', 58761),
#  ('practice', 58738),
#  ('username', 58712),
#  ('series', 58479),
#  ('secure', 58280),
#  ('certificate', 58130),
#  ('exe', 58129),
#  ('macos', 58065),
#  ('cli', 58014),
#  ('realtime', 57878),
#  ('awesome', 57814),
#  ('commit', 57700),
#  ('dns', 57699),
#  ('master', 57654),
#  ('backend', 57530),
#  ('challenge', 57504),
#  ('sign', 57300),
#  ('operation', 57299),
#  ('callback', 57287),
#  ('traffic', 57159),
#  ('bar', 57145),
#  ('pytorch', 57133),
#  ('mac', 57103),
#  ('csv', 56895),
#  ('generation', 56674),
#  ('md', 56323),
#  ('q', 56025),
#  ('effect', 55993),
#  ('background', 55886),
#  ('menu', 55758),
#  ('future', 55184),
#  ('png', 55149),
#  ('card', 55116),
#  ('rout', 54870),
#  ('runtime', 54716),
#  ('bundle', 54592),
#  ('ssh', 54538),
#  ('plugins', 54534),
#  ('readme', 54306),
#  ('docs', 54286),
#  ('sdk', 54248),
#  ('external', 54197),
#  ('experience', 54027),
#  ('contact', 53955),
#  ('condition', 53928),
#  ('prop', 53819),
#  ('apis', 53694),
#  ('nod', 53442),
#  ('queue', 53429),
#  ('yarn', 53285),
#  ('encode', 53242),
#  ('db', 53148),
#  ('metadata', 53093),
#  ('science', 53080),
#  ('dependency', 53046),
#  ('validation', 53044),
#  ('metrics', 53018),
#  ('bite', 52556),
#  ('fetch', 52538),
#  ('buffer', 52429),
#  ('tcp', 52183),
#  ('theme', 52086),
#  ('policy', 52025),
#  ('contract', 51906),
#  ('internet', 51827),
#  ('void', 51824),
#  ('echo', 51428),
#  ('knowledge', 51034),
#  ('watch', 50829),
#  ('hide', 50742),
#  ('lead', 50613),
#  ('facebook', 50360),
#  ('media', 50333),
#  ('bytes', 50284),
#  ('automatic', 50124),
#  ('lecture', 50067),
#  ('score', 50063),
#  ('signal', 49694),
#  ('final', 49539),
#  ('interview', 49520),
#  ('reason', 48691),
#  ('red', 48687),
#  ('https', 48663),
#  ('history', 48358),
#  ('edge', 48330),
#  ('verify', 48287),
#  ('pipeline', 48270),
#  ('chrome', 48172),
#  ('pool', 48156),
#  ('s3', 47765),
#  ('interactive', 47743),
#  ('region', 47605),
#  ('official', 47462),
#  ('twitter', 46957),
#  ('center', 46491),
#  ('mysql', 46448),
#  ('split', 46420),
#  ('compare', 46399),
#  ('role', 46323),
#  ('capture', 46150),
#  ('lib', 45977),
#  ('modern', 45882),
#  ('disk', 45826),
#  ('express', 45746),
#  ('zip', 45724),
#  ('medium', 45644),
#  ('internal', 45610),
#  ('company', 45233),
#  ('unique', 45139),
#  ('exploit', 44958),
#  ('router', 44952),
#  ('spring', 44845),
#  ('clean', 44828),
#  ('promise', 44802),
#  ('yml', 44625),
#  ('prompt', 44589),
#  ('usb', 44579),
#  ('opensource', 44463),
#  ('wrapper', 44436),
#  ('loop', 44355),
#  ('generator', 44239),
#  ('ci', 44164),
#  ('light', 44107),
#  ('efficient', 43941),
#  ('i2c', 43896),
#  ('sensor', 43867),
#  ('reverse', 43450),
#  ('rate', 43430),
#  ('fork', 43170),
#  ('init', 43133),
#  ('lightweight', 43128),
#  ('bot', 43030),
#  ('jpg', 42652),
#  ('merge', 42548),
#  ('behavior', 42503),
#  ('raw', 42378),
#  ('worker', 42339),
#  ('maintain', 42241),
#  ('cvpr', 42108),
#  ('webpack', 41936),
#  ('secret', 41910),
#  ('empty', 41875),
#  ('credentials', 41640),
#  ('infrastructure', 41501),
#  ('human', 41465),
#  ('player', 41370),
#  ('logic', 41334),
#  ('prediction', 41288),
#  ('gpu', 41275),
#  ('desktop', 41245),
#  ('frontend', 41050),
#  ('notification', 40951),
#  ('distribution', 40802),
#  ('price', 40791),
#  ('auto', 40765),
#  ('ubuntu', 40743),
#  ('pair', 40742),
#  ('quick', 40671),
#  ('quality', 40545),
#  ('social', 40488),
#  ('cost', 40447),
#  ('evaluation', 40362),
#  ('experiment', 40331),
#  ('languages', 40134),
#  ('icon', 40039),
#  ('templates', 39980),
#  ('encrypt', 39921),
#  ('head', 39860),
#  ('powershell', 39783),
#  ('slide', 39708),
#  ('containers', 39533),
#  ('partition', 39422),
#  ('firebase', 39421),
#  ('socket', 39232),
#  ('hook', 39184),
#  ('optimize', 39180),
#  ('todo', 39167),
#  ('technology', 39100),
#  ('ram', 39086),
#  ('archive', 39073),
#  ('fit', 39022),
#  ('study', 39008),
#  ('python3', 38871),
#  ('optimization', 38738),
#  ('bus', 38685),
#  ('mask', 38610),
#  ('transform', 38600),
#  ('42', 38570),
#  ('endpoint', 38567),
#  ('apikey', 38560),
#  ('layout', 38412),
#  ('utility', 38403),
#  ('ssl', 38328),
#  ('smart', 38186),
#  ('solutions', 38183),
#  ('payload', 38150),
#  ('forward', 38136),
#  ('hack', 38056),
#  ('analytics', 38053),
#  ('cs', 38042),
#  ('progress', 37955),
#  ('provider', 37892),
#  ('upgrade', 37879),
#  ('redis', 37841),
#  ('robot', 37800),
#  ('youtube', 37508),
#  ('permissions', 37507),
#  ('trace', 37492),
#  ('schedule', 37438),
#  ('copyright', 37390),
#  ('inference', 37345),
#  ('notice', 37315),
#  ('combine', 37296),
#  ('lambda', 37218),
#  ('pi', 37103),
#  ('serial', 37066),
#  ('phone', 37049),
#  ('matrix', 37009),
#  ('batch', 36984),
#  ('mount', 36965),
#  ('topic', 36957),
#  ('digital', 36820),
#  ('volume', 36816),
#  ('vulnerability', 36716),
#  ('business', 36696),
#  ('semantic', 36546),
#  ('apple', 36477),
#  ('loss', 36418),
#  ('fire', 36199),
#  ('chain', 36197),
#  ('vector', 36157),
#  ('communication', 36102),
#  ('conference', 35764),
#  ('nginx', 35753),
#  ('linear', 35734),
#  ('curl', 35675),
#  ('pretrained', 35612),
#  ('malware', 35561),
#  ('news', 35474),
#  ('compiler', 35473),
#  ('notifications', 35311),
#  ('natural', 35272),
#  ('dashboard', 35258),
#  ('lock', 35246),
#  ('ieee', 35218),
#  ('angular', 35199),
#  ('gui', 35188),
#  ('pod', 35122),
#  ('distance', 35065),
#  ('generic', 35051),
#  ('kind', 35042),
#  ('async', 34944),
#  ('protect', 34922),
#  ('expression', 34899),
#  ('dom', 34870),
#  ('schema', 34868),
#  ('listen', 34832),
#  ('firmware', 34800),
#  ('sit', 34779),
#  ('anything', 34738),
#  ('adversarial', 34681),
#  ('shape', 34546),
#  ('intel', 34516),
#  ('namespace', 34444),
#  ('chart', 34411),
#  ('opencv', 34399),
#  ('entity', 34362),
#  ('intelligence', 34324),
#  ('cmd', 34319),
#  ('accuracy', 34291),
#  ('2023', 34274),
#  ('visualization', 34255),
#  ('img', 34135),
#  ('mail', 33993),
#  ('summary', 33925),
#  ('estimation', 33798),
#  ('manual', 33772),
#  ('auth', 33705),
#  ('extensions', 33652),
#  ('pin', 33583),
#  ('drop', 33549),
#  ('agent', 33512),
#  ('alternative', 33395),
#  ('plot', 33340),
#  ('offset', 33289),
#  ('draw', 33275),
#  ('toolkit', 33239),
#  ('workflow', 33165),
#  ('chat', 33071),
#  ('activity', 32972),
#  ('continuous', 32949),
#  ('backup', 32899),
#  ('headers', 32809),
#  ('selection', 32745),
#  ('validate', 32727),
#  ('tutorials', 32708),
#  ('coverage', 32650),
#  ('translation', 32630),
#  ('typescript', 32444),
#  ('sound', 32426),
#  ('transaction', 32337),
#  ('encryption', 32308),
#  ('float', 32302),
#  ('svg', 32296),
#  ('injection', 32238),
#  ('handler', 32216),
#  ('platforms', 32125),
#  ('await', 32041),
#  ('xss', 31989),
#  ('jsx', 31961),
#  ('notebook', 31946),
#  ('gnu', 31873),
#  ('ide', 31843),
#  ('detector', 31772),
#  ('markdown', 31658),
#  ('measure', 31571),
#  ('gateway', 31503),
#  ('depth', 31386),
#  ('delay', 31309),
#  ('flexible', 31287),
#  ('redirect', 31251),
#  ('hub', 31196),
#  ('parallel', 31152),
#  ('mine', 31146),
#  ('cpp', 31136),
#  ('databases', 31054),
#  ('jquery', 31049),
#  ('operator', 31009),
#  ('hand', 30965),
#  ('parser', 30898),
#  ('interfaces', 30850),
#  ('fee', 30788),
#  ('automation', 30786),
#  ('regression', 30736),
#  ('browsers', 30721),
#  ('aim', 30663),
#  ('functional', 30626),
#  ('talk', 30618),
#  ('balance', 30540),
#  ('matlab', 30532),
#  ('ml', 30449),
#  ('wifi', 30445),
#  ('vm', 30391),
#  ('sync', 30320),
#  ('crash', 30285),
#  ('attention', 30126),
#  ('feedback', 30031),
#  ('age', 30022),
#  ('bucket', 29945),
#  ('material', 29930),
#  ('statistics', 29821),
#  ('urls', 29817),
#  ('motion', 29795),
#  ('highlight', 29739),
#  ('cat', 29736),
#  ('music', 29690),
#  ('golang', 29676),
#  ('tar', 29620),
#  ('arm', 29583),
#  ('django', 29439),
#  ('threshold', 29421),
#  ('heroku', 29394),
#  ('iot', 29366),
#  ('exception', 29355),
#  ('terraform', 29308),
#  ('commandline', 29265),
#  ('enzyme', 29264),
#  ('navigation', 29218),
#  ('wiki', 29166),
#  ('permission', 29124),
#  ('risk', 29000),
#  ('drivers', 28967),
#  ('websocket', 28820),
#  ('conda', 28728),
#  ('kubectl', 28639),
#  ('animation', 28580),
#  ('frameworks', 28451),
#  ('transactions', 28441),
#  ('2d', 28379),
#  ('scene', 28346),
#  ('objectivec', 28308),
#  ('math', 28247),
#  ('websites', 28134),
#  ('bypass', 28130),
#  ('bits', 28087),
#  ('robust', 28084),
#  ('compress', 28078),
#  ('tip', 28000),
#  ('tokens', 27948),
#  ('meta', 27927),
#  ('black', 27823),
#  ('jar', 27804),
#  ('rust', 27757),
#  ('exchange', 27732),
#  ('lab', 27638),
#  ('speech', 27633),
#  ('manifest', 27553),
#  ('grid', 27508),
#  ('english', 27425),
#  ('extraction', 27420),
#  ('privacy', 27279),
#  ('clock', 27250),
#  ('market', 27159),
#  ('diff', 27124),
#  ('zone', 27035),
#  ('chip', 27018),
#  ('mention', 26999),
#  ('sheet', 26971),
#  ('keyboard', 26933),
#  ('resolution', 26923),
#  ('tls', 26903),
#  ('pose', 26878),
#  ('strategy', 26870),
#  ('segment', 26814),
#  ('stable', 26803),
#  ('pointer', 26731),
#  ('personal', 26580),
#  ('health', 26579),
#  ('ec2', 26576),
#  ('inject', 26475),
#  ('prometheus', 26446),
#  ('dump', 26431),
#  ('scroll', 26284),
#  ('mongodb', 26227),
#  ('compression', 26150),
#  ('vim', 26090),
#  ('safe', 26026),
#  ('lua', 25995),
#  ('frequency', 25981),
#  ('dll', 25944),
#  ('packet', 25850),
#  ('party', 25822),
#  ('identity', 25820),
#  ('blockchain', 25702),
#  ('registry', 25666),
#  ('rat', 25580),
#  ('discover', 25476),
#  ('oauth', 25462),
#  ('compatibility', 25418),
#  ('trust', 25409),
#  ('organization', 25394),
#  ('benchmark', 25344),
#  ('unity', 25311),
#  ('icons', 25305),
#  ('generative', 25239),
#  ('ids', 25186),
#  ('capabilities', 25183),
#  ('panel', 25142),
#  ('coordinate', 25107),
#  ('minimal', 25089),
#  ('audit', 25005),
#  ('scanner', 24988),
#  ('scalable', 24956),
#  ('graphics', 24935),
#  ('transformer', 24931),
#  ('html5', 24839),
#  ('raspberry', 24789),
#  ('rename', 24783),
#  ('vulnerabilities', 24749),
#  ('touch', 24680),
#  ('discovery', 24669),
#  ('postgresql', 24613),
#  ('pick', 24504),
#  ('curated', 24460),
#  ('wordpress', 24456),
#  ('snapshot', 24444),
#  ('rail', 24402),
#  ('sense', 24245),
#  ('annotations', 24227),
#  ('complexity', 24205),
#  ('car', 23995),
#  ('spec', 23992),
#  ('crossplatform', 23987),
#  ('es6', 23764),
#  ('secrets', 23755),
#  ('unix', 23676),
#  ('signature', 23629),
#  ('authorization', 23604),
#  ('cmake', 23604),
#  ('adapter', 23562),
#  ('cfg', 23560),
#  ('podcast', 23440),
#  ('verification', 23365),
#  ('threat', 23312),
#  ('annotation', 23282),
#  ('picture', 23272),
#  ('life', 23233),
#  ('serverless', 23161),
#  ('asynchronous', 23029),
#  ('tweak', 22882),
#  ('decode', 22831),
#  ('redux', 22665),
#  ('udp', 22647),
#  ('preview', 22575),
#  ('scheme', 22560),
#  ('ts', 22542),
#  ('logo', 22459),
#  ('accessible', 22436),
#  ('slack', 22332),
#  ('startup', 22312),
#  ('specification', 22235),
#  ('theory', 22163),
#  ('spark', 22144),
#  ('journal', 22121),
#  ('executable', 22100),
#  ('roles', 22039),
#  ('enterprise', 22006),
#  ('transport', 21991),
#  ('cycle', 21989),
#  ('trade', 21952),
#  ('utilities', 21865),
#  ('unsupervised', 21847),
#  ('prototype', 21813),
#  ('dockercompose', 21757),
#  ('provision', 21688),
#  ('asset', 21678),
#  ('font', 21661),
#  ('green', 21600),
#  ('kafka', 21532),
#  ('translate', 21481),
#  ('stock', 21480),
#  ('fonts', 21478),
#  ('counter', 21477),
#  ('homepage', 21423),
#  ('exercise', 21422),
#  ('protection', 21372),
#  ('simulation', 21328),
#  ('paste', 21300),
#  ('standalone', 21297),
#  ('laravel', 21265),
#  ('transition', 21217),
#  ('builder', 21156),
#  ('interval', 21143),
#  ('nlp', 21133),
#  ...]

# %%
t6 = github_data_df['tree'].apply(lambda x: myclnfunction(x))

# %%
t6_cnt = Counter(t6.explode())
t6_cnt.most_common()
# Out:
# [('md', 325331),
#  ('readme', 226553),
#  ('license', 122166),
#  ('json', 76702),
#  ('txt', 72106),
#  ('yml', 54284),
#  ('js', 47756),
#  ('sh', 45016),
#  ('go', 39764),
#  ('src', 38999),
#  ('test', 38897),
#  ('github', 36783),
#  ('c', 35230),
#  ('pdf', 34427),
#  ('png', 32537),
#  ('package', 31035),
#  ('config', 30235),
#  ('ipynb', 26781),
#  ('requirements', 23195),
#  ('docs', 20048),
#  ('makefile', 19489),
#  ('contribute', 18652),
#  ('setup', 18332),
#  ('travis', 18122),
#  ('cpp', 17375),
#  ('gradle', 17296),
#  ('image', 17248),
#  ('php', 17190),
#  ('changelog', 16603),
#  ('yaml', 16327),
#  ('data', 16306),
#  ('xml', 15719),
#  ('build', 15489),
#  ('html', 15164),
#  ('script', 15031),
#  ('lib', 14292),
#  ('dockerfile', 13717),
#  ('lock', 12860),
#  ('index', 12590),
#  ('model', 12531),
#  ('examples', 11218),
#  ('jpg', 10511),
#  ('app', 10330),
#  ('utils', 9517),
#  ('editorconfig', 9067),
#  ('example', 8789),
#  ('tool', 8714),
#  ('bat', 8635),
#  ('assets', 8324),
#  ('cfg', 8289),
#  ('1', 7544),
#  ('bin', 7292),
#  ('toml', 7251),
#  ('manifest', 7044),
#  ('project', 6951),
#  ('csv', 6786),
#  ('demo', 6663),
#  ('vscode', 6606),
#  ('settings', 6582),
#  ('train', 6282),
#  ('properties', 5919),
#  ('dockercompose', 5901),
#  ('public', 5770),
#  ('yarn', 5759),
#  ('tf', 5471),
#  ('install', 5356),
#  ('ini', 5317),
#  ('img', 5052),
#  ('resources', 5047),
#  ('env', 4795),
#  ('sample', 4759),
#  ('security', 4751),
#  ('copy', 4749),
#  ('css', 4740),
#  ('include', 4714),
#  ('zip', 4688),
#  ('mod', 4606),
#  ('composer', 4514),
#  ('server', 4426),
#  ('r', 4314),
#  ('log', 4247),
#  ('cmd', 4192),
#  ('docker', 4079),
#  ('ps1', 4031),
#  ('templates', 3970),
#  ('version', 3877),
#  ('cs', 3620),
#  ('spec', 3556),
#  ('api', 3496),
#  ('ts', 3380),
#  ('gif', 3367),
#  ('common', 3318),
#  ('dataset', 3242),
#  ('configs', 3227),
#  ('sql', 3119),
#  ('webpack', 3091),
#  ('detection', 3032),
#  ('todo', 3020),
#  ('cmake', 2901),
#  ('lua', 2890),
#  ('notice', 2880),
#  ('util', 2878),
#  ('source', 2795),
#  ('android', 2776),
#  ('code', 2764),
#  ('static', 2713),
#  ('cargo', 2676),
#  ('circleci', 2608),
#  ('output', 2585),
#  ('release', 2521),
#  ('screenshots', 2491),
#  ('file', 2373),
#  ('datasets', 2311),
#  ('client', 2273),
#  ('core', 2246),
#  ('network', 2246),
#  ('java', 2233),
#  ('db', 2227),
#  ('web', 2219),
#  ('5', 2179),
#  ('service', 2173),
#  ('exe', 2158),
#  ('notebooks', 2153),
#  ('python', 2136),
#  ('patch', 2093),
#  ('modules', 2029),
#  ('documentation', 2017),
#  ('template', 2014),
#  ('mp4', 1963),
#  ('plugin', 1943),
#  ('bower', 1941),
#  ('media', 1920),
#  ('news', 1915),
#  ('change', 1902),
#  ('environment', 1882),
#  ('cc', 1864),
#  ('report', 1862),
#  ('ios', 1860),
#  ('style', 1844),
#  ('jest', 1820),
#  ('phpunit', 1796),
#  ('deploy', 1740),
#  ('logo', 1739),
#  ('appveyor', 1714),
#  ('misc', 1708),
#  ('dev', 1677),
#  ('svg', 1664),
#  ('tox', 1663),
#  ('learn', 1611),
#  ('screenshot', 1601),
#  ('view', 1559),
#  ('ui', 1556),
#  ('class', 1543),
#  ('paper', 1529),
#  ('metadata', 1528),
#  ('net', 1526),
#  ('6', 1514),
#  ('ml', 1508),
#  ('clangformat', 1494),
#  ('ico', 1488),
#  ('babel', 1487),
#  ('plugins', 1477),
#  ('pkg', 1450),
#  ('type', 1448),
#  ('library', 1425),
#  ('rule', 1390),
#  ('database', 1389),
#  ('markdown', 1372),
#  ('note', 1370),
#  ('rar', 1368),
#  ('ips', 1366),
#  ('gitlabci', 1362),
#  ('mat', 1340),
#  ('init', 1326),
#  ('meta', 1299),
#  ('dll', 1267),
#  ('tslint', 1257),
#  ('msg', 1255),
#  ('bootstrap', 1252),
#  ('experiment', 1245),
#  ('analysis', 1241),
#  ('history', 1231),
#  ('ipset', 1230),
#  ('function', 1197),
#  ('task', 1194),
#  ('read', 1191),
#  ('docx', 1189),
#  ('iml', 1177),
#  ('feature', 1160),
#  ('flake8', 1155),
#  ('etc', 1145),
#  ('ai', 1144),
#  ('hack', 1142),
#  ('user', 1138),
#  ('ci', 1133),
#  ('jenkinsfile', 1130),
#  ('design', 1112),
#  ('windows', 1106),
#  ('jquery', 1085),
#  ('video', 1077),
#  ('filter', 1068),
#  ('detect', 1059),
#  ('rollup', 1050),
#  ('frontend', 1049),
#  ('command', 1048),
#  ('icon', 1047),
#  ('rspec', 1038),
#  ('xlsx', 1035),
#  ('support', 1017),
#  ('namespace', 1017),
#  ('development', 1016),
#  ('application', 1009),
#  ('vagrantfile', 999),
#  ('final', 993),
#  ('system', 990),
#  ('pytest', 987),
#  ('codeofconduct', 985),
#  ('eval', 983),
#  ('jpeg', 972),
#  ('manage', 971),
#  ('backend', 960),
#  ('map', 955),
#  ('internal', 952),
#  ('v', 946),
#  ('tar', 937),
#  ('rout', 933),
#  ('page', 921),
#  ('reference', 919),
#  ('debian', 915),
#  ('yara', 914),
#  ('debug', 913),
#  ('module', 913),
#  ('h5', 906),
#  ('components', 900),
#  ('launch', 899),
#  ('favicon', 896),
#  ('linux', 896),
#  ('swift', 895),
#  ('share', 885),
#  ('program', 885),
#  ('karma', 883),
#  ('list', 877),
#  ('graph', 870),
#  ('local', 866),
#  ('dependencies', 865),
#  ('document', 863),
#  ('poetry', 855),
#  ('update', 851),
#  ('classification', 848),
#  ('husky', 847),
#  ('base', 846),
#  ('storage', 842),
#  ('input', 841),
#  ('preprocessing', 823),
#  ('cli', 822),
#  ('monitor', 812),
#  ('azurepipelines', 805),
#  ('board', 803),
#  ('evaluation', 802),
#  ('renovate', 802),
#  ('icons', 801),
#  ('deployment', 800),
#  ('process', 798),
#  ('mix', 797),
#  ('action', 793),
#  ('gitpod', 790),
#  ('book', 788),
#  ('gui', 784),
#  ('hook', 777),
#  ('drivers', 776),
#  ('versions', 773),
#  ('mkdocs', 773),
#  ('inference', 767),
#  ('info', 766),
#  ('rubocop', 766),
#  ('deep', 761),
#  ('tutorial', 752),
#  ('pc', 751),
#  ('guide', 750),
#  ('configuration', 747),
#  ('object', 747),
#  ('external', 745),
#  ('fonts', 745),
#  ('benchmark', 743),
#  ('translations', 737),
#  ('alert', 735),
#  ('machine', 725),
#  ('helpers', 719),
#  ('sbt', 707),
#  ('terraform', 704),
#  ('metrics', 702),
#  ('nix', 700),
#  ('plot', 697),
#  ('apps', 695),
#  ('presentation', 681),
#  ('make', 680),
#  ('fs', 680),
#  ('key', 677),
#  ('asm', 675),
#  ('bash', 672),
#  ('admin', 671),
#  ('neural', 669),
#  ('runtime', 665),
#  ('prop', 665),
#  ('post', 660),
#  ('jar', 660),
#  ('slide', 659),
#  ('wav', 648),
#  ('search', 643),
#  ('contract', 636),
#  ('arch', 634),
#  ('content', 629),
#  ('copyright', 629),
#  ('cluster', 627),
#  ('mitlicense', 627),
#  ('options', 625),
#  ('videos', 623),
#  ('bmp', 620),
#  ('control', 615),
#  ('cache', 613),
#  ('postcss', 613),
#  ('compile', 612),
#  ('face', 608),
#  ('testdata', 607),
#  ('website', 604),
#  ('theme', 600),
#  ('utilities', 599),
#  ('desktop', 598),
#  ('architecture', 591),
#  ('prediction', 589),
#  ('framework', 589),
#  ('tree', 587),
#  ('logger', 587),
#  ('engine', 585),
#  ('nginx', 583),
#  ('node', 580),
#  ('rc', 578),
#  ('ansible', 575),
#  ('crypto', 572),
#  ('profile', 569),
#  ('faq', 569),
#  ('game', 566),
#  ('libraries', 564),
#  ('benchmarks', 552),
#  ('yolo', 551),
#  ('archive', 550),
#  ('cloud', 547),
#  ('picture', 543),
#  ('target', 541),
#  ('layer', 536),
#  ('help', 535),
#  ('aws', 534),
#  ('cypress', 532),
#  ('detector', 532),
#  ('zone', 531),
#  ('cnn', 530),
#  ('languages', 529),
#  ('disk', 529),
#  ('tutorials', 528),
#  ('nuget', 527),
#  ('plan', 527),
#  ('hardware', 526),
#  ('schema', 524),
#  ('download', 523),
#  ('injection', 521),
#  ('migrations', 520),
#  ('global', 520),
#  ('matlab', 520),
#  ('sort', 520),
#  ('workspace', 517),
#  ('cod', 516),
#  ('text', 515),
#  ('feed', 514),
#  ('track', 513),
#  ('audio', 512),
#  ('uninstall', 509),
#  ('sound', 508),
#  ('installer', 508),
#  ('bot', 508),
#  ('releasenotes', 504),
#  ('chart', 504),
#  ('upload', 498),
#  ('groovy', 491),
#  ('tex', 488),
#  ('angular', 486),
#  ('e2e', 484),
#  ('miner', 481),
#  ('diagram', 481),
#  ('pipeline', 480),
#  ('shell', 479),
#  ('host', 477),
#  ('designer', 471),
#  ('message', 470),
#  ('directory', 466),
#  ('number', 466),
#  ('summary', 465),
#  ('x', 465),
#  ('screen', 464),
#  ('helper', 464),
#  ('algorithm', 462),
#  ('circle', 455),
#  ('mypy', 454),
#  ('attack', 453),
#  ('camera', 453),
#  ('kubernetes', 453),
#  ('label', 450),
#  ('recognition', 450),
#  ('coffee', 448),
#  ('check', 448),
#  ('bundle', 447),
#  ('link', 447),
#  ('malware', 442),
#  ('loss', 441),
#  ('controller', 438),
#  ('events', 435),
#  ('clean', 435),
#  ('platform', 434),
#  ('segmentation', 432),
#  ('header', 432),
#  ('algorithms', 429),
#  ('state', 429),
#  ('tailwind', 426),
#  ('export', 423),
#  ('classifier', 421),
#  ('stack', 421),
#  ('software', 420),
#  ('grafana', 419),
#  ('time', 417),
#  ('notebook', 417),
#  ('dashboard', 415),
#  ('visualization', 412),
#  ('http', 410),
#  ('htm', 404),
#  ('convert', 402),
#  ('roadmap', 401),
#  ('vite', 399),
#  ('publish', 398),
#  ('git', 396),
#  ('keywords', 395),
#  ('custom', 392),
#  ('apk', 391),
#  ('backup', 391),
#  ('firmware', 391),
#  ('resource', 390),
#  ('art', 389),
#  ('flow', 388),
#  ('firebase', 387),
#  ('proxy', 386),
#  ('set', 383),
#  ('tensorflow', 382),
#  ('color', 381),
#  ('bind', 381),
#  ('commit', 381),
#  ('azure', 380),
#  ('site', 380),
#  ('snapshot', 380),
#  ('binary', 378),
#  ('string', 378),
#  ('prometheus', 378),
#  ('os', 375),
#  ('name', 374),
#  ('preview', 372),
#  ('darknet', 371),
#  ('integration', 371),
#  ('neon', 368),
#  ('course', 368),
#  ('pod', 367),
#  ('cpuminer', 366),
#  ('login', 365),
#  ('roles', 362),
#  ('lerna', 362),
#  ('table', 362),
#  ('generate', 362),
#  ('root', 362),
#  ('upgrade', 361),
#  ('mobile', 359),
#  ('vue', 355),
#  ('block', 354),
#  ('arduino', 353),
#  ('utility', 353),
#  ('javascript', 353),
#  ('webapp', 353),
#  ('drone', 351),
#  ('trainer', 351),
#  ('array', 350),
#  ('background', 350),
#  ('tag', 349),
#  ('regression', 347),
#  ('phpcs', 344),
#  ('console', 343),
#  ('query', 342),
#  ('language', 342),
#  ('io', 342),
#  ('form', 341),
#  ('domain', 341),
#  ('home', 340),
#  ('extension', 340),
#  ('proto', 340),
#  ('exploit', 340),
#  ('2020', 338),
#  ('event', 337),
#  ('group', 336),
#  ('stats', 336),
#  ('robots', 335),
#  ('extensions', 335),
#  ('bug', 335),
#  ('ibm', 335),
#  ('session', 332),
#  ('platformio', 331),
#  ('structure', 331),
#  ('agent', 331),
#  ('store', 330),
#  ('sha2', 328),
#  ('manual', 326),
#  ('get', 325),
#  ('work', 324),
#  ('graphics', 323),
#  ('parser', 323),
#  ('kernel', 322),
#  ('find', 321),
#  ('i18n', 321),
#  ('record', 321),
#  ('vision', 319),
#  ('community', 318),
#  ('generator', 318),
#  ('device', 317),
#  ('2018', 314),
#  ('hash', 314),
#  ('applications', 313),
#  ('asciidoc', 311),
#  ('yolov3', 310),
#  ('stream', 310),
#  ('exercise', 310),
#  ('mine', 309),
#  ('opencv', 308),
#  ('production', 308),
#  ('font', 308),
#  ('netlify', 308),
#  ('troubleshoot', 305),
#  ('driver', 305),
#  ('lecture', 304),
#  ('format', 303),
#  ('assignment', 302),
#  ('artisan', 301),
#  ('phpstan', 300),
#  ('perl', 300),
#  ('coveralls', 299),
#  ('svm', 299),
#  ('usage', 298),
#  ('management', 298),
#  ('advance', 297),
#  ('transform', 297),
#  ('auth', 297),
#  ('avi', 297),
#  ('startup', 297),
#  ('introduction', 296),
#  ('menu', 296),
#  ('next', 295),
#  ('parameters', 295),
#  ('research', 295),
#  ('snippets', 294),
#  ('storybook', 292),
#  ('loader', 291),
#  ('secrets', 291),
#  ('case', 291),
#  ('job', 289),
#  ('diff', 289),
#  ('pickle', 289),
#  ('tsv', 289),
#  ('sol', 288),
#  ('mp3', 287),
#  ('pic', 287),
#  ('vhd', 287),
#  ('textile', 286),
#  ('component', 284),
#  ('protocol', 283),
#  ('installation', 282),
#  ('rpc', 282),
#  ('account', 282),
#  ('review', 282),
#  ('google', 281),
#  ('dataloader', 281),
#  ('2019', 280),
#  ('covid', 278),
#  ('context', 277),
#  ('import', 277),
#  ('blog', 277),
#  ('baseline', 275),
#  ('cdk', 275),
#  (nan, 275),
#  ('bro', 275),
#  ('jsp', 274),
#  ('error', 270),
#  ('policy', 270),
#  ('create', 268),
#  ('mac', 267),
#  ('scan', 266),
#  ('boot', 266),
#  ('robot', 265),
#  ('coverage', 265),
#  ('solutions', 265),
#  ('infrastructure', 264),
#  ('status', 264),
#  ('banner', 263),
#  ('email', 263),
#  ('computer', 261),
#  ('editor', 261),
#  ('card', 260),
#  ('https', 259),
#  ('wiki', 257),
#  ('ar', 257),
#  ('microsoft', 256),
#  ('pytorch', 256),
#  ('path', 256),
#  ('playground', 256),
#  ('popup', 255),
#  ('sdk', 255),
#  ('errors', 254),
#  ('engineer', 253),
#  ('kmeans', 252),
#  ('overlay', 252),
#  ('kitchen', 251),
#  ('pattern', 251),
#  ('capture', 251),
#  ('hp', 251),
#  ('interface', 250),
#  ('scss', 249),
#  ('daemon', 249),
#  ('lab', 249),
#  ('annotations', 248),
#  ('statistics', 248),
#  ('doxygen', 248),
#  ('pcap', 248),
#  ('caffe', 248),
#  ('tracker', 246),
#  ('macos', 246),
#  ('lisp', 245),
#  ('issue', 244),
#  ('light', 244),
#  ('addons', 244),
#  ('win32', 243),
#  ('pack', 243),
#  ('team', 243),
#  ('cheatsheet', 242),
#  ('memory', 241),
#  ('extract', 240),
#  ('mask', 240),
#  ('nlp', 239),
#  ('privacy', 238),
#  ('k8s', 238),
#  ('sqlite3', 237),
#  ('forensics', 237),
#  ('ros', 237),
#  ('article', 237),
#  ('basic', 237),
#  ('trace', 236),
#  ('xss', 235),
#  ('aarch64', 235),
#  ('lambda', 234),
#  ('vagrant', 234),
#  ('connect', 233),
#  ('builder', 232),
#  ('hcl', 232),
#  ('cpu', 232),
#  ('md5', 231),
#  ('simple', 231),
#  ('users', 230),
#  ('request', 229),
#  ('win', 228),
#  ('ahk', 228),
#  ('openra', 228),
#  ('2022', 227),
#  ('word', 226),
#  ('matrix', 226),
#  ('prettier', 226),
#  ('chat', 226),
#  ('player', 226),
#  ('sequence', 225),
#  ('private', 225),
#  ('information', 224),
#  ('challenge', 224),
#  ('url', 224),
#  ('formatter', 224),
#  ('asset', 222),
#  ('machinelearning', 222),
#  ('interfaces', 222),
#  ('serverless', 221),
#  ('repository', 221),
#  ('remote', 220),
#  ('workflow', 219),
#  ('validate', 219),
#  ('load', 218),
#  ('audit', 218),
#  ('coco', 217),
#  ('stub', 217),
#  ('validation', 217),
#  ('yolov5', 217),
#  ('discovery', 217),
#  ('helm', 217),
#  ('performance', 215),
#  ('cron', 215),
#  ('layout', 214),
#  ('timer', 214),
#  ('inventory', 214),
#  ('mysql', 214),
#  ('random', 213),
#  ('certificate', 213),
#  ('ssd', 211),
#  ('3d', 211),
#  ('analytics', 211),
#  ('math', 210),
#  ('fee', 210),
#  ('labs', 208),
#  ('recipes', 208),
#  ('locale', 207),
#  ('speech', 207),
#  ('middleware', 207),
#  ('rce', 207),
#  ('visual', 206),
#  ('distribution', 206),
#  ('registry', 206),
#  ('display', 206),
#  ('step', 205),
#  ('glide', 205),
#  ('antivirus', 205),
#  ('question', 205),
#  ('infra', 205),
#  ('collection', 204),
#  ('resnet', 204),
#  ('dockerfiles', 204),
#  ('apache', 204),
#  ('checkpoint', 203),
#  ('split', 203),
#  ('embed', 202),
#  ('reverse', 202),
#  ('snyk', 202),
#  ('syntax', 202),
#  ('edge', 202),
#  ('scrypt', 202),
#  ('dashboards', 201),
#  ('2017', 200),
#  ('hex', 200),
#  ('jenkins', 200),
#  ('cheat', 200),
#  ('calibration', 200),
#  ('xaml', 200),
#  ('experimental', 199),
#  ('simulation', 199),
#  ('vim', 198),
#  ('line', 198),
#  ('anomaly', 198),
#  ('githooks', 198),
#  ('open', 197),
#  ('sheet', 197),
#  ('fraud', 197),
#  ('generators', 196),
#  ('browser', 195),
#  ('intro', 195),
#  ('caffemodel', 194),
#  ('snap', 194),
#  ('legacy', 194),
#  ('sandbox', 194),
#  ('orange', 194),
#  ('worker', 193),
#  ('presentations', 193),
#  ('redis', 192),
#  ('spark', 192),
#  ('solution', 192),
#  ('queue', 191),
#  ('parse', 191),
#  ('dump', 191),
#  ('eda', 191),
#  ('ocr', 191),
#  ('study', 190),
#  ('react', 190),
#  ('cleanup', 190),
#  ('chrome', 188),
#  ('layouts', 188),
#  ('smart', 188),
#  ('box', 187),
#  ('awesome', 187),
#  ('checkstyle', 187),
#  ('hacs', 187),
#  ('compiler', 186),
#  ('jsdoc', 186),
#  ('launcher', 185),
#  ('powershell', 185),
#  ('ops', 185),
#  ('facedetection', 185),
#  ('render', 184),
#  ('linear', 184),
#  ('amazon', 183),
#  ('ftcrobotcontroller', 183),
#  ('nod', 182),
#  ('tcl', 182),
#  ('schedule', 181),
#  ('pipelines', 181),
#  ('price', 180),
#  ('attribute', 180),
#  ('match', 180),
#  ('dns', 180),
#  ('mock', 180),
#  ('wrapper', 180),
#  ('systems', 179),
#  ('scanner', 178),
#  ('writeup', 178),
#  ('ids', 178),
#  ('sync', 178),
#  ('master', 178),
#  ('contact', 177),
#  ('progress', 177),
#  ('devops', 176),
#  ('stylesheets', 176),
#  ('artifacts', 176),
#  ('password', 176),
#  ('addon', 176),
#  ('gpu', 176),
#  ('cloudformation', 175),
#  ('score', 175),
#  ('deeplearning', 175),
#  ('twitter', 175),
#  ('deb', 175),
#  ('gitbook', 174),
#  ('graphql', 174),
#  ('transfer', 174),
#  ('manager', 174),
#  ('swiftpm', 174),
#  ('credentials', 174),
#  ('dl', 174),
#  ('power', 174),
#  ('2021', 172),
#  ('gitlab', 172),
#  ('platforms', 172),
#  ('container', 172),
#  ('eclipse', 171),
#  ('mit', 170),
#  ('ssh', 170),
#  ('frame', 170),
#  ('register', 169),
#  ('deprecate', 169),
#  ('count', 169),
#  ('toc', 169),
#  ('ip', 169),
#  ('webcam', 167),
#  ('governance', 167),
#  ('proposal', 167),
#  ('iot', 167),
#  ('sign', 167),
#  ('operations', 166),
#  ('automation', 165),
#  ('hardhat', 165),
#  ('practice', 165),
#  ('nodemon', 165),
#  ('localization', 165),
#  ('wifi', 165),
#  ('elasticsearch', 164),
#  ('sketch', 164),
#  ('native', 164),
#  ('pcb', 164),
#  ('exp', 164),
#  ('mail', 163),
#  ('protractor', 163),
#  ('rviz', 163),
#  ('hunt', 163),
#  ('csl', 163),
#  ('pool', 163),
#  ('raw', 163),
#  ('domains', 163),
#  ('button', 163),
#  ('product', 162),
#  ('poster', 162),
#  ('quickstart', 162),
#  ('playbooks', 161),
#  ('social', 160),
#  ('provider', 160),
#  ('router', 160),
#  ('sensor', 160),
#  ('s3', 159),
#  ('traffic', 159),
#  ('draw', 159),
#  ('cv', 159),
#  ('push', 159),
#  ('binaries', 158),
#  ('panel', 158),
#  ('car', 158),
#  ('metro', 157),
#  ('fake', 157),
#  ('tip', 157),
#  ('best', 156),
#  ('pca', 156),
#  ('signal', 156),
#  ('base64', 156),
#  ('notification', 155),
#  ('less', 155),
#  ('lstm', 155),
#  ('swagger', 155),
#  ('handler', 155),
#  ('access', 154),
#  ('implementation', 154),
#  ('42', 154),
#  ('science', 154),
#  ('prompt', 153),
#  ('solver', 153),
#  ('q', 153),
#  ('encode', 152),
#  ('databases', 152),
#  ('lane', 152),
#  ('auto', 152),
#  ('threat', 152),
#  ('thread', 151),
#  ('rpm', 151),
#  ('rest', 151),
#  ('exchange', 150),
#  ('flag', 150),
#  ('print', 150),
#  ('sqlite', 150),
#  ('nse', 150),
#  ('response', 149),
#  ('bypass', 149),
#  ('objectdetection', 149),
#  ('x64', 149),
#  ('keras', 148),
#  ('bazel', 148),
#  ('stl', 148),
#  ('webserver', 148),
#  ('osint', 148),
#  ('runner', 148),
#  ('cms', 147),
#  ('heroku', 147),
#  ('port', 147),
#  ('systemd', 146),
#  ('ionic', 146),
#  ('extraction', 146),
#  ('serve', 146),
#  ('recovery', 146),
#  ('mods', 145),
#  ('osx', 145),
#  ('comment', 145),
#  ('channel', 145),
#  ('awk', 145),
#  ('policies', 144),
#  ('hdf5', 144),
#  ('schemas', 144),
#  ('helloworld', 144),
#  ('english', 144),
#  ('qa', 143),
#  ('payloads', 143),
#  ('xls', 143),
#  ('backbone', 143),
#  ('date', 142),
#  ('generation', 142),
#  ('fuzz', 142),
#  ('provision', 142),
#  ('dot', 142),
#  ('gateway', 141),
#  ('merge', 141),
#  ('kibana', 141),
#  ('migration', 141),
#  ('token', 141),
#  ('conda', 141),
#  ('optimization', 140),
#  ('wsgi', 140),
#  ('predictions', 140),
#  ('persistence', 140),
#  ('cascade', 140),
#  ('blockchain', 140),
#  ('renderer', 140),
#  ('ubuntu', 139),
#  ('collector', 139),
#  ('unet', 139),
#  ('apis', 139),
#  ('devices', 139),
#  ('quantum', 138),
#  ('lint', 138),
#  ('buildtools', 138),
#  ('bluetooth', 138),
#  ('iam', 137),
#  ('point', 137),
#  ('pretrained', 137),
#  ('zsh', 137),
#  ('openapi', 137),
#  ('yolo3', 136),
#  ('distance', 136),
#  ('seed', 136),
#  ('containers', 136),
#  ('blob', 136),
#  ('intelligence', 135),
#  ('material', 135),
#  ('alarm', 134),
#  ('jupyter', 134),
#  ('coin', 134),
#  ('payload', 134),
#  ('mnist', 134),
#  ('nms', 134),
#  ('ruleset', 133),
#  ('annotation', 133),
#  ('people', 133),
#  ('alertmanager', 133),
#  ('interview', 133),
#  ('realtime', 133),
#  ...]

# %% [markdown]
# ### testset 2.4.1s
# takes all 2.4 readme_clean extracted topics as set

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t5
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.1')
# Out:
# total repos 217922
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.1.pkl

# %%
ghd_exp['topics'] = ghd_exp['topics'].apply(lambda x: ' '.join(set(x)))

# %%
to_disk(ghd_exp, 't2.4.1s')
# Out:
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.1s.pkl

# %% [markdown]
# ### testset 2.4.2
# takes all 2.4 about extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t3 #+t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.2')
# Out:
# total repos 168558
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.2.pkl

# %% [markdown]
# ### testset 2.4.3
# takes all 2.4 tree extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t6
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.3')
# Out:
# total repos 167102
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.3.pkl

# %% [markdown]
# ### testset 2.4.4
# takes all 2.4 topics extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t2
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.4')
# Out:
# total repos 60345
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.4.pkl

# %% [markdown]
# ### testset 2.4.5
# takes all 2.5 languages extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t4
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.5')
# Out:
# total repos 191618
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.5.pkl

# %% [markdown]
# ### testset 2.4.6
# takes all 2.4 title extracted topics

# %%
ghd_exp = pd.DataFrame()
ghd_exp['name'] = github_data_df['name'].copy()
ghd_exp['topics'] = t1
print(f"total repos {len(ghd_exp[ghd_exp['topics'].str.len() > 0])}")
ghd_exp = ghd_exp[ghd_exp['topics'].str.len() > 0]
#ghd_exp = github_data_df[github_data_df['topics'].str.len() > 0][['name', 'topics']].copy()
#ghd_exp
to_disk(ghd_exp, 't2.4.6')
# Out:
# total repos 9042
# /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.4.6.pkl
