# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar1/"
use_tfidfvectorizer = True
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 30
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.3.1s"
merge_list = ["t2.3.2", "t2.3.4", "t2.3.6"]

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.1s.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 218335

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)
# Out:
# t2.3.1s+2.3.2+2.3.4+2.3.6

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.2.pkl
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.4.pkl
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.6.pkl

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 218335

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 218335
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 14.478011846542358

# %%
word_doc_matrix
# Out:
# <218335x14611 sparse matrix of type '<class 'numpy.float64'>'
# 	with 29666627 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 795 edges.
# It has only fully disconnected 16 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 1h 30min 52s, sys: 4min 47s, total: 1h 35min 39s
# Wall time: 19min 1s

# %%
print(runtime_umap)
# Out:
# 1141.2668962478638

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 3h 8min 41s, sys: 21.2 s, total: 3h 9min 2s
# Wall time: 3h 5min 25s

# %%
print(runtime_umap_transform)
# Out:
# 11125.166414737701

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//umap_embedding_t2.3.1s+2.3.2+2.3.4+2.3.6.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//umap_clusterable_embedding_t2.3.1s+2.3.2+2.3.4+2.3.6.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type                    testset  version      name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss50cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
# 5  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5          300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
# 5  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs50            50
# 6  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5          300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6          350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
# 5  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs50            50
# 6  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs50            50
# 7  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5          300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6          350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7          400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
# 5  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs50            50
# 6  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs50            50
# 7  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs50            50
# 8  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs50            50
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5          300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6          350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7          400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8          450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#   type                    testset  version       name  hdb_minclust  \
# 0  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs50            50
# 1  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs50            50
# 2  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs50            50
# 3  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs50            50
# 4  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs50            50
# 5  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs50            50
# 6  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs50            50
# 7  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs50            50
# 8  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs50            50
# 9  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss50cs100           100
#
#    hdb_minsamp   runtime                                                tdf  \
# 0           50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1          100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2          150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3          200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4          250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5          300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6          350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7          400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8          450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9           50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
# 15  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 15          350  7.965879  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 15  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
# 15  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs100           100
# 16  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 15          350  7.965879  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 16          400  8.435007  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 15  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 16  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
# 15  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs100           100
# 16  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs100           100
# 17  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs100           100
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 15          350  7.965879  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 16          400  8.435007  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 17          450  9.056561  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 15  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 16  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 17  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
# 15  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs100           100
# 16  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs100           100
# 17  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs100           100
# 18  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs150           150
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 15          350  7.965879  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 16          400  8.435007  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 17          450  9.056561  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 18           50  4.698397  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 15  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 16  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 17  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 18  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# 5   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss300cs50            50
# 6   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss350cs50            50
# 7   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss400cs50            50
# 8   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss450cs50            50
# 9   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs100           100
# 10  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs100           100
# 11  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs100           100
# 12  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs100           100
# 13  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs100           100
# 14  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs100           100
# 15  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs100           100
# 16  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs100           100
# 17  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs100           100
# 18  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs150           150
# 19  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs150           150
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 5           300  7.339701  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 6           350  7.976511  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 7           400  8.458377  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 8           450  9.019182  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 9            50  4.384872  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 10          100  4.884819  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 11          150  5.349063  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 12          200  5.998422  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 13          250  6.712877  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 14          300  7.233389  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 15          350  7.965879  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 16          400  8.435007  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 17          450  9.056561  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 18           50  4.698397  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 19          100  4.914289  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 5   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 6   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 7   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 8   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 9   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 10  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 11  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 12  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 13  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 14  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 15  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 16  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 17  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 18  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 19  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# ...
# 74          150  5.615252  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 71  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 72  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 73  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 74  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [75 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 71  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs400           400
# 72  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs450           450
# 73  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs450           450
# 74  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs450           450
# 75  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 71          450  9.137754  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 72           50  4.427539  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 73          100  4.962124  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 74          150  5.615252  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 75          200  6.010156  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 72  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 73  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 74  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 75  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [76 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 72  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss50cs450           450
# 73  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs450           450
# 74  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs450           450
# 75  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs450           450
# 76  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 72           50  4.427539  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 73          100  4.962124  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 74          150  5.615252  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 75          200  6.010156  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 76          250  7.096891  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 73  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 74  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 75  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 76  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [77 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 73  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss100cs450           450
# 74  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs450           450
# 75  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs450           450
# 76  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs450           450
# 77  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 73          100  4.962124  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 74          150  5.615252  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 75          200  6.010156  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 76          250  7.096891  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 77          300  7.556918  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 74  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 75  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 76  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 77  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [78 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 74  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss150cs450           450
# 75  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs450           450
# 76  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs450           450
# 77  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs450           450
# 78  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 74          150  5.615252  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 75          200  6.010156  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 76          250  7.096891  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 77          300  7.556918  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 78          350  8.333987  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 75  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 76  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 77  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 78  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [79 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 75  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss200cs450           450
# 76  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs450           450
# 77  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs450           450
# 78  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs450           450
# 79  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 75          200  6.010156  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 76          250  7.096891  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 77          300  7.556918  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 78          350  8.333987  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 79          400  8.707509  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 76  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 77  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 78  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 79  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [80 rows x 9 columns]
#    type                    testset  version        name  hdb_minclust  \
# 0   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1    ss50cs50            50
# 1   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss100cs50            50
# 2   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss150cs50            50
# 3   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss200cs50            50
# 4   hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1   ss250cs50            50
# ..  ...                        ...      ...         ...           ...
# 76  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss250cs450           450
# 77  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss300cs450           450
# 78  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss350cs450           450
# 79  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss400cs450           450
# 80  hdb  t2.3.1s+2.3.2+2.3.4+2.3.6        1  ss450cs450           450
#
#     hdb_minsamp   runtime                                                tdf  \
# 0            50  5.311795  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 1           100  4.994434  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 2           150  5.402676  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 3           200  5.959788  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 4           250  6.672489  rt_vect: 14.478011846542358, min_df: 4, max_df...
# ..          ...       ...                                                ...
# 76          250  7.096891  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 77          300  7.556918  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 78          350  8.333987  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 79          400  8.707509  rt_vect: 14.478011846542358, min_df: 4, max_df...
# 80          450  9.228392  rt_vect: 14.478011846542358, min_df: 4, max_df...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 1   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 2   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 3   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 4   hellinger, rt_umap_tf: 11125.166414737701, rt_...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 77  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 78  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 79  hellinger, rt_umap_tf: 11125.166414737701, rt_...
# 80  hellinger, rt_umap_tf: 11125.166414737701, rt_...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                  name  ss50cs50  ss100cs50  ss150cs50  \
# 0            technopagan/mss-saliency        52         23         17
# 1          snmnmin12/selective-search       139        108         84
# 2                  google/chaps-linux       197        160        121
# 3            lukasolson/speech-router       223        111         77
# 4               XavierTecBr/qbr-admin        -1         -1         -1
# ...                               ...       ...        ...        ...
# 218330  bhagatabhijeet/bhagatabhijeet        -1         -1         -1
# 218331  LandGrey/SpringBootVulExploit        55         -1         -1
# 218332    mucomplex/Pentest_checklist       164        115         75
# 218333            bigsen/Vision_Track        -1         -1         -1
# 218334             ivanol55/cka-notes        -1         -1         -1
#
#         ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  ss450cs50  ...  \
# 0              12         10          9          7         -1         -1  ...
# 1              10          8          6          1          0          0  ...
# 2              60         47         42         10          8         11  ...
# 3              41         32         33         10          8         11  ...
# 4              -1         -1         -1         10          8         -1  ...
# ...           ...        ...        ...        ...        ...        ...  ...
# 218330         -1         -1         -1         -1         -1         -1  ...
# 218331          5         -1         -1         -1         -1         -1  ...
# 218332         42         29         26         10          8          6  ...
# 218333         10          8          6          1          0          0  ...
# 218334         -1         -1         -1         10          8         11  ...
#
#         ss450cs400  ss50cs450  ss100cs450  ss150cs450  ss200cs450  ss250cs450  \
# 0               -1          2          -1          -1           4           4
# 1                0          4           4          15          12           2
# 2               10         16          28          25          25          10
# 3               10         16          22          20          20          10
# 4               -1         -1          -1          -1          -1          -1
# ...            ...        ...         ...         ...         ...         ...
# 218330          -1         -1          -1          -1          -1          -1
# 218331          -1         -1          -1          -1           0          -1
# 218332           5         16          21          21          21          10
# 218333           0          4           4          -1          -1           2
# 218334          10         16          -1          25          -1          10
#
#         ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0                4           5          -1          -1
# 1                2           0           0           0
# 2               20           7           5          10
# 3               18           7           5          10
# 4               -1           7           5          -1
# ...            ...         ...         ...         ...
# 218330          -1          -1          -1          -1
# 218331          -1          -1          -1          -1
# 218332          16           7           5           5
# 218333           2           0           0           0
# 218334          20           7           5          10
#
# [218335 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_labels_results_t2.3.1s+2.3.2+2.3.4+2.3.6.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16      16   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.588948
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 2  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16      16   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19      16   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.588948
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.878972
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 2  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 3  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16      16   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19      16   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22      16   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.588948
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.878972
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  2.443111
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 2  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 3  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 4  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16      16   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19      16   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22      16   22
# 5  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    25      16   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.588948
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.878972
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  2.443111
# 5  rt_vect: 14.478011846542358, min_df: 4, max_df...  2.719070
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 2  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 3  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 4  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 5  (hellinger, rt_umap_tf: 11125.166414737701, rt...
#            type                    testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10      16   10
# 1  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13      16   13
# 2  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16      16   16
# 3  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19      16   19
# 4  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22      16   22
# 5  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    25      16   25
# 6  kmeans-umapt  t2.3.1s+2.3.2+2.3.4+2.3.6        1    28      16   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.138122
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.318120
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.588948
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  1.878972
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  2.443111
# 5  rt_vect: 14.478011846542358, min_df: 4, max_df...  2.719070
# 6  rt_vect: 14.478011846542358, min_df: 4, max_df...  3.029030
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 1  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 2  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 3  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 4  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 5  (hellinger, rt_umap_tf: 11125.166414737701, rt...
# 6  (hellinger, rt_umap_tf: 11125.166414737701, rt...

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28
# 0            technopagan/mss-saliency   3   8   3   7  12   6   3
# 1          snmnmin12/selective-search   1   3   9  11  14   1  10
# 2                  google/chaps-linux   0  10   0  18  20  18  27
# 3            lukasolson/speech-router   3   8   3   7   6  16  25
# 4               XavierTecBr/qbr-admin   2   5   8  10   0   7   0
# ...                               ...  ..  ..  ..  ..  ..  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   5   2   2   4   3  10   5
# 218331  LandGrey/SpringBootVulExploit   5   6   7   2   5   2   9
# 218332    mucomplex/Pentest_checklist   5  10   0   5   9   3   5
# 218333            bigsen/Vision_Track   1   3   9  11  14   1  10
# 218334             ivanol55/cka-notes   0   6   7   2   5   2   1
#
# [218319 rows x 8 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_labels_results_t2.3.1s+2.3.2+2.3.4+2.3.6.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16   16
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  351.445661
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19   19
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  351.445661
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  388.699830
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22   22
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  351.445661
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  388.699830
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  517.606732
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22   22
# 5  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    25   25
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  351.445661
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  388.699830
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  517.606732
# 5  rt_vect: 14.478011846542358, min_df: 4, max_df...  567.854586
#      type                    testset  version  size name  \
# 0  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    10   10
# 1  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    13   13
# 2  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    16   16
# 3  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    19   19
# 4  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    22   22
# 5  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    25   25
# 6  kmeans  t2.3.1s+2.3.2+2.3.4+2.3.6        1    28   28
#
#                                                  tdf     runtime
# 0  rt_vect: 14.478011846542358, min_df: 4, max_df...  172.710389
# 1  rt_vect: 14.478011846542358, min_df: 4, max_df...  198.945348
# 2  rt_vect: 14.478011846542358, min_df: 4, max_df...  351.445661
# 3  rt_vect: 14.478011846542358, min_df: 4, max_df...  388.699830
# 4  rt_vect: 14.478011846542358, min_df: 4, max_df...  517.606732
# 5  rt_vect: 14.478011846542358, min_df: 4, max_df...  567.854586
# 6  rt_vect: 14.478011846542358, min_df: 4, max_df...  618.790319

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28
# 0            technopagan/mss-saliency   6   2  13   5   3  15  14
# 1          snmnmin12/selective-search   0  10   9  11   0  21  27
# 2                  google/chaps-linux   2  12   1  13  21  18  21
# 3            lukasolson/speech-router   7  11  10  10  12   9  10
# 4               XavierTecBr/qbr-admin   0   3   2  11   0  21  27
# ...                               ...  ..  ..  ..  ..  ..  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   0   4   8  16  18   1   6
# 218331  LandGrey/SpringBootVulExploit   8   1   4  18  16   3   9
# 218332    mucomplex/Pentest_checklist   8   1   7   0  19  18  21
# 218333            bigsen/Vision_Track   0   3   2  11   0  21  27
# 218334             ivanol55/cka-notes   8   1   4  12  13  23   9
#
# [218335 rows x 8 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_labels_results_t2.3.1s+2.3.2+2.3.4+2.3.6.pkl
