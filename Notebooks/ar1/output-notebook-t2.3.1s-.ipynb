# %%
# prepare data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json
import glob
import operator
from IPython.display import display, HTML

# %%
# %load_ext autoreload
# %autoreload 1

from shared_globals_functions import *
# %aimport shared_globals_functions

# %%
t_name='t1'
merge_list=['t1.1', 't1.2', 't1.3', 't1.4']

cust_dir = 'test'

tdidf_max_df=1.0 # defaults to 1.0 (float), can be an int too
tdidf_min_df=4
use_tfidfvectorizer = True
use_stopwords = True
use_extended_stopwords = False

umap_metric='hellinger'
umap_ncomponents=2
umap_random_state=42
umap_min_dist=0 #0.1
umap_n_neighbors=30 #10, 30

min_cluster=10
max_cluster=30
clust_int=3

ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50

#tf-idf vectorizer
#max_df=0.3
#min_df=

#kmeans
#n_clusters
#n_init
#max_iter

# %%
# Parameters
cust_dir = "ar1/"
use_tfidfvectorizer = True
tdidf_max_df = 1.0
tdidf_min_df = 4
use_stopwords = True
use_extended_stopwords = False
umap_metric = "hellinger"
umap_ncomponents = 2
umap_random_state = 42
umap_min_dist = 0
umap_n_neighbors = 30
min_cluster = 10
max_cluster = 30
clust_int = 3
ss_min = 50
ss_max = 500
ss_int = 50
cs_min = 50
cs_max = 500
cs_int = 50
t_name = "t2.3.1s"
merge_list = ""

# %%
testset = from_disk(t_name)
# Out:
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/t2.3.1s.pkl

# %%
len(testset[testset['topics'].str.len() > 0])
# Out:
# 218335

# %%
if len(merge_list)>0:
    t_name = f'{t_name}+{"+".join([re.sub(r"t", "", tid) for tid in merge_list])}'
    print(t_name)

# %%
testset_merge = create_merge(testset, merge_list, merge_to_one=True)

# %%
len(testset_merge[testset_merge['topics'].str.len() > 0])
# Out:
# 218335

# %%
df = testset_merge.merge(testset, on=['name'], how='left', indicator=True)

# %%
df[df['_merge']!='both']
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
df[df['topics_x'].str.len() == 0]
# Out:
# Empty DataFrame
# Columns: [name, topics_x, topics_y, _merge]
# Index: []

# %%
if len(merge_list)>0:
    testset = testset_merge

# %%
import pandas as pd
import umap
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
orig_testset = testset

# %%
my_stop_words=None
if use_stopwords:
    my_stop_words='english'
    if use_extended_stopwords:
        print("todo")

if use_tfidfvectorizer:
    vectorizer = TfidfVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)
else:
    vectorizer = CountVectorizer(min_df=tdidf_min_df, max_df=tdidf_max_df, stop_words=my_stop_words)

print(f"total repos {len(testset[testset['topics'].str.len() > 0])}")
testset = testset[testset['topics'].str.len() > 0].reset_index()

if isinstance(testset['topics'][0], list):
    testset['topics'] = testset['topics'].apply(lambda x: ' '.join(x))
    print("topics came as list ... consider joining it before")

cr_start()
word_doc_matrix = vectorizer.fit_transform(testset['topics'])
runtime_vectorizer = cr_getrt()
# Out:
# total repos 218335
# topics came as list ... consider joining it before

# %%
runtime_vectorizer
# Out:
# 15.95009994506836

# %%
word_doc_matrix
# Out:
# <218335x11147 sparse matrix of type '<class 'numpy.float64'>'
# 	with 29331201 stored elements in Compressed Sparse Row format>

# %%
class ProgressWriter:
    def write(self, text):
        print("custom progress", n, total)

    def flush(self):
        pass

#tqdm_kwds = {"file": "progress_writer", "disable": False }
tqdm_kwds = {"disable": False }

# %%
# %%time
# try also with default parameters for n_neighbors and min_dist

cr_start()

embedding = umap.UMAP(
    n_neighbors=umap_n_neighbors,
    min_dist=umap_min_dist,
    n_components=umap_ncomponents, metric=umap_metric,
    tqdm_kwds=tqdm_kwds,
    random_state=umap_random_state,
).fit(word_doc_matrix)

runtime_umap = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/umap/umap_.py:125: UserWarning: A few of your vertices were disconnected from the manifold.  This shouldn't cause problems.
# Disconnection_distance = 1 has removed 1062 edges.
# It has only fully disconnected 17 vertices.
# Use umap.utils.disconnected_vertices() to identify them.
#   warn(
# Epochs completed:   0%|            0/200 [00:00]
# CPU times: user 1h 24min 59s, sys: 1min 21s, total: 1h 26min 20s
# Wall time: 14min 13s

# %%
print(runtime_umap)
# Out:
# 853.0154831409454

# %%
# %%time

cr_start()
clusterable_embedding = embedding.transform(word_doc_matrix)
runtime_umap_transform = cr_getrt()
# Out:
# /home/manuel/d3tect-tools/venv/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_arrayXarray(i, j, x)
# Epochs completed:   0%|            0/30 [00:00]
# CPU times: user 3h 4min 56s, sys: 11 s, total: 3h 5min 7s
# Wall time: 3h 1min 34s

# %%
print(runtime_umap_transform)
# Out:
# 10894.858936071396

# %%
umap_embedding = pd.DataFrame(embedding.embedding_, columns=['x', 'y']) # (umap_t)
umap_clusterable_embedding = pd.DataFrame(clusterable_embedding, columns=['x', 'y']) # (umap_t)

umap_embedding['name'] = testset['name']
umap_clusterable_embedding['name'] = testset['name']

to_disk_results(umap_embedding, f'umap_embedding_{t_name}', subdir=f"{cust_dir}")
to_disk_results(umap_clusterable_embedding, f'umap_clusterable_embedding_{t_name}', subdir=f"{cust_dir}")
# Out:
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//umap_embedding_t2.3.1s.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//umap_clusterable_embedding_t2.3.1s.pkl

# %% [markdown]
# https://hdbscan.readthedocs.io/en/latest/parameter_selection.html
#
# Since we have seen that min_samples clearly has a dramatic effect on clustering, the question becomes: how do we select this parameter? The simplest intuition for what min_samples does is provide a measure of how conservative you want you clustering to be. The larger the value of min_samples you provide, the more conservative the clustering – more points will be declared as noise, and clusters will be restricted to progressively more dense areas. We can see this in practice by leaving the min_cluster_size at 60, but reducing min_samples to 1.

# %%
import hdbscan

def clusterapply_hdbscan(hdbscan_min_samples, min_cluster_size, runner_name):
    cr_start()
    labels = hdbscan.HDBSCAN(
        min_samples=hdbscan_min_samples,
        min_cluster_size=min_cluster_size,
    ).fit_predict(clusterable_embedding)
    runtime_hdb = cr_getrt()
    
    stats = {'type': "hdb",
             'testset': t_name,
             'version': td_version,
            }
    
    detail_stats = {'hdb_minclust': min_cluster_size,
                    'hdb_minsamp': hdbscan_min_samples,
                    'runtime': runtime_hdb,
                    'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                    'umap': f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}",
                    #'gtr': grtr,
                    #'gtr_rel': grtr_rt
                   }
    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'tot_anom':no_anomalies, 'no_lab':missing_clabel, 'anom':identified_anom})
    prediction.update(detail_stats)
    res.append(prediction.copy())
    display(pd.DataFrame.from_dict(res))
    return labels

res = []
hdb_labels_results = pd.DataFrame()
hdb_labels_results['name'] = testset['name'].copy()


for cs in range(cs_min, cs_max, cs_int): #50, 500
    for ss in range(ss_min, ss_max, ss_int): #50 500
        runner_name = f'ss{ss}cs{cs}'
        hdb_labels_results[runner_name] = clusterapply_hdbscan(ss, cs, runner_name)

results = pd.DataFrame.from_dict(res)
res = []
# Out:
#   type  testset  version      name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1  ss50cs50            50           50  5.182194
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
# 5  hdb  t2.3.1s        1  ss300cs50            50          300  7.494895
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
# 5  hdb  t2.3.1s        1  ss300cs50            50          300  7.494895
# 6  hdb  t2.3.1s        1  ss350cs50            50          350  8.092790
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
# 5  hdb  t2.3.1s        1  ss300cs50            50          300  7.494895
# 6  hdb  t2.3.1s        1  ss350cs50            50          350  8.092790
# 7  hdb  t2.3.1s        1  ss400cs50            50          400  9.012854
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
# 5  hdb  t2.3.1s        1  ss300cs50            50          300  7.494895
# 6  hdb  t2.3.1s        1  ss350cs50            50          350  8.092790
# 7  hdb  t2.3.1s        1  ss400cs50            50          400  9.012854
# 8  hdb  t2.3.1s        1  ss450cs50            50          450  9.599973
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#   type  testset  version       name  hdb_minclust  hdb_minsamp   runtime  \
# 0  hdb  t2.3.1s        1   ss50cs50            50           50  5.182194
# 1  hdb  t2.3.1s        1  ss100cs50            50          100  5.036180
# 2  hdb  t2.3.1s        1  ss150cs50            50          150  5.605837
# 3  hdb  t2.3.1s        1  ss200cs50            50          200  6.153535
# 4  hdb  t2.3.1s        1  ss250cs50            50          250  6.825358
# 5  hdb  t2.3.1s        1  ss300cs50            50          300  7.494895
# 6  hdb  t2.3.1s        1  ss350cs50            50          350  8.092790
# 7  hdb  t2.3.1s        1  ss400cs50            50          400  9.012854
# 8  hdb  t2.3.1s        1  ss450cs50            50          450  9.599973
# 9  hdb  t2.3.1s        1  ss50cs100           100           50  4.505756
#
#                                                  tdf  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                 umap
# 0  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
# 16  hdb  t2.3.1s        1  ss400cs100           100          400  8.584292
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 16  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 16  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
# 16  hdb  t2.3.1s        1  ss400cs100           100          400  8.584292
# 17  hdb  t2.3.1s        1  ss450cs100           100          450  9.380208
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 16  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 17  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 16  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 17  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
# 16  hdb  t2.3.1s        1  ss400cs100           100          400  8.584292
# 17  hdb  t2.3.1s        1  ss450cs100           100          450  9.380208
# 18  hdb  t2.3.1s        1   ss50cs150           150           50  4.841757
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 16  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 17  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 18  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 16  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 17  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 18  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
# 16  hdb  t2.3.1s        1  ss400cs100           100          400  8.584292
# 17  hdb  t2.3.1s        1  ss450cs100           100          450  9.380208
# 18  hdb  t2.3.1s        1   ss50cs150           150           50  4.841757
# 19  hdb  t2.3.1s        1  ss100cs150           150          100  5.363212
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 16  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 17  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 18  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 19  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 16  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 17  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 18  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 19  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# 5   hdb  t2.3.1s        1   ss300cs50            50          300  7.494895
# 6   hdb  t2.3.1s        1   ss350cs50            50          350  8.092790
# 7   hdb  t2.3.1s        1   ss400cs50            50          400  9.012854
# 8   hdb  t2.3.1s        1   ss450cs50            50          450  9.599973
# 9   hdb  t2.3.1s        1   ss50cs100           100           50  4.505756
# 10  hdb  t2.3.1s        1  ss100cs100           100          100  5.027757
# 11  hdb  t2.3.1s        1  ss150cs100           100          150  5.524972
# 12  hdb  t2.3.1s        1  ss200cs100           100          200  6.024128
# 13  hdb  t2.3.1s        1  ss250cs100           100          250  7.264020
# 14  hdb  t2.3.1s        1  ss300cs100           100          300  7.390927
# 15  hdb  t2.3.1s        1  ss350cs100           100          350  8.151108
# 16  hdb  t2.3.1s        1  ss400cs100           100          400  8.584292
# 17  hdb  t2.3.1s        1  ss450cs100           100          450  9.380208
# 18  hdb  t2.3.1s        1   ss50cs150           150           50  4.841757
# 19  hdb  t2.3.1s        1  ss100cs150           150          100  5.363212
# 20  hdb  t2.3.1s        1  ss150cs150           150          150  5.888068
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 5   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 6   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 7   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 8   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 9   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 10  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 11  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 12  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 13  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 14  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 15  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 16  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 17  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 18  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 19  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 20  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 5   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 6   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 7   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 8   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 9   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 10  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 11  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 12  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 13  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 14  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 15  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 16  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 17  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 18  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 19  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 20  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# ...
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 70  hdb  t2.3.1s        1  ss400cs400           400          400  8.844412
# 71  hdb  t2.3.1s        1  ss450cs400           400          450  9.415612
# 72  hdb  t2.3.1s        1   ss50cs450           450           50  4.804289
# 73  hdb  t2.3.1s        1  ss100cs450           450          100  5.240180
# 74  hdb  t2.3.1s        1  ss150cs450           450          150  5.643117
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 70  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 71  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 72  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 73  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 74  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 70  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 71  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 72  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 73  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 74  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [75 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 71  hdb  t2.3.1s        1  ss450cs400           400          450  9.415612
# 72  hdb  t2.3.1s        1   ss50cs450           450           50  4.804289
# 73  hdb  t2.3.1s        1  ss100cs450           450          100  5.240180
# 74  hdb  t2.3.1s        1  ss150cs450           450          150  5.643117
# 75  hdb  t2.3.1s        1  ss200cs450           450          200  6.375100
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 71  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 72  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 73  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 74  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 75  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 71  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 72  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 73  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 74  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 75  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [76 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 72  hdb  t2.3.1s        1   ss50cs450           450           50  4.804289
# 73  hdb  t2.3.1s        1  ss100cs450           450          100  5.240180
# 74  hdb  t2.3.1s        1  ss150cs450           450          150  5.643117
# 75  hdb  t2.3.1s        1  ss200cs450           450          200  6.375100
# 76  hdb  t2.3.1s        1  ss250cs450           450          250  6.997667
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 72  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 73  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 74  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 75  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 76  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 72  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 73  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 74  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 75  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 76  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [77 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 73  hdb  t2.3.1s        1  ss100cs450           450          100  5.240180
# 74  hdb  t2.3.1s        1  ss150cs450           450          150  5.643117
# 75  hdb  t2.3.1s        1  ss200cs450           450          200  6.375100
# 76  hdb  t2.3.1s        1  ss250cs450           450          250  6.997667
# 77  hdb  t2.3.1s        1  ss300cs450           450          300  7.407706
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 73  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 74  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 75  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 76  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 77  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 73  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 74  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 75  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 76  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 77  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [78 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 74  hdb  t2.3.1s        1  ss150cs450           450          150  5.643117
# 75  hdb  t2.3.1s        1  ss200cs450           450          200  6.375100
# 76  hdb  t2.3.1s        1  ss250cs450           450          250  6.997667
# 77  hdb  t2.3.1s        1  ss300cs450           450          300  7.407706
# 78  hdb  t2.3.1s        1  ss350cs450           450          350  8.272894
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 74  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 75  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 76  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 77  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 78  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 74  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 75  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 76  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 77  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 78  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [79 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 75  hdb  t2.3.1s        1  ss200cs450           450          200  6.375100
# 76  hdb  t2.3.1s        1  ss250cs450           450          250  6.997667
# 77  hdb  t2.3.1s        1  ss300cs450           450          300  7.407706
# 78  hdb  t2.3.1s        1  ss350cs450           450          350  8.272894
# 79  hdb  t2.3.1s        1  ss400cs450           450          400  8.829526
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 75  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 76  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 77  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 78  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 79  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 75  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 76  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 77  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 78  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 79  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [80 rows x 9 columns]
#    type  testset  version        name  hdb_minclust  hdb_minsamp   runtime  \
# 0   hdb  t2.3.1s        1    ss50cs50            50           50  5.182194
# 1   hdb  t2.3.1s        1   ss100cs50            50          100  5.036180
# 2   hdb  t2.3.1s        1   ss150cs50            50          150  5.605837
# 3   hdb  t2.3.1s        1   ss200cs50            50          200  6.153535
# 4   hdb  t2.3.1s        1   ss250cs50            50          250  6.825358
# ..  ...      ...      ...         ...           ...          ...       ...
# 76  hdb  t2.3.1s        1  ss250cs450           450          250  6.997667
# 77  hdb  t2.3.1s        1  ss300cs450           450          300  7.407706
# 78  hdb  t2.3.1s        1  ss350cs450           450          350  8.272894
# 79  hdb  t2.3.1s        1  ss400cs450           450          400  8.829526
# 80  hdb  t2.3.1s        1  ss450cs450           450          450  9.435637
#
#                                                   tdf  \
# 0   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 1   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 2   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 3   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 4   rt_vect: 15.95009994506836, min_df: 4, max_df:...
# ..                                                ...
# 76  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 77  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 78  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 79  rt_vect: 15.95009994506836, min_df: 4, max_df:...
# 80  rt_vect: 15.95009994506836, min_df: 4, max_df:...
#
#                                                  umap
# 0   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 1   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 2   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 3   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 4   hellinger, rt_umap_tf: 10894.858936071396, rt_...
# ..                                                ...
# 76  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 77  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 78  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 79  hellinger, rt_umap_tf: 10894.858936071396, rt_...
# 80  hellinger, rt_umap_tf: 10894.858936071396, rt_...
#
# [81 rows x 9 columns]

# %%
hdb_labels_results
# Out:
#                                  name  ss50cs50  ss100cs50  ss150cs50  \
# 0            technopagan/mss-saliency        63         44         22
# 1          snmnmin12/selective-search        -1         53         19
# 2                  google/chaps-linux        -1         -1         -1
# 3            lukasolson/speech-router        -1         -1         74
# 4               XavierTecBr/qbr-admin        -1         -1         -1
# ...                               ...       ...        ...        ...
# 218330  bhagatabhijeet/bhagatabhijeet        -1         -1         -1
# 218331  LandGrey/SpringBootVulExploit        -1         -1         -1
# 218332    mucomplex/Pentest_checklist        -1         -1         -1
# 218333            bigsen/Vision_Track        -1         53         19
# 218334             ivanol55/cka-notes       273        140        105
#
#         ss200cs50  ss250cs50  ss300cs50  ss350cs50  ss400cs50  ss450cs50  ...  \
# 0              18         16         13         14         -1         -1  ...
# 1               8         11          8         10          2          0  ...
# 2              25         -1         -1         13          7          5  ...
# 3              25         -1         40         13          7          5  ...
# 4              -1         -1         -1         -1         -1         -1  ...
# ...           ...        ...        ...        ...        ...        ...  ...
# 218330         -1         -1         -1         -1         -1         -1  ...
# 218331         -1         -1         -1         -1         -1         -1  ...
# 218332         25         -1         -1         13          7          5  ...
# 218333          8         11          8         10          2          0  ...
# 218334         25         72         61         13          7          5  ...
#
#         ss450cs400  ss50cs450  ss100cs450  ss150cs450  ss200cs450  ss250cs450  \
# 0               -1         -1          -1          -1          -1          -1
# 1                0          8           8           3           0           3
# 2                5         -1          -1           6           8           7
# 3                5         31          20           6           8           7
# 4               -1         -1          -1          -1          -1          -1
# ...            ...        ...         ...         ...         ...         ...
# 218330          -1         -1          -1          -1          -1          -1
# 218331          -1         -1          -1          -1          -1          -1
# 218332           5         -1          18           6           8           7
# 218333           0          8           8           3           0           3
# 218334           5         43          37           6           8           7
#
#         ss300cs450  ss350cs450  ss400cs450  ss450cs450
# 0               -1          -1          -1          -1
# 1                3           3           0           0
# 2                7           8           5           5
# 3                7           8           5           5
# 4               -1          -1          -1          -1
# ...            ...         ...         ...         ...
# 218330          -1          -1          -1          -1
# 218331          -1          -1          -1          -1
# 218332           7           8           5           5
# 218333           3           3           0           0
# 218334           7           8           5           5
#
# [218335 rows x 82 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/hdb_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'hdb_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'hdb_results', subdir=f"{cust_dir}")
to_disk_results(hdb_labels_results, f'hdb_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//hdb_labels_results_t2.3.1s.pkl

# %%
umap_embedding['topics'] = testset['topics']
umap_clusterable_embedding['topics'] = testset['topics']

# %%
import sklearn.cluster as cluster

def clusterapply_kmeans(testset, clustersize, runner_name, opt_comment=""):
    # Perform k-means clustering
    
    kmeans = cluster.KMeans(n_clusters=clustersize, random_state=42)
        
    if('y' in testset.columns):
        #print("assuming umap reduced testset here")
        testset = testset.copy()
        dropping_not_connected = len(testset[testset['y'].isnull()])
        testset = testset[testset['y'].notna()]
        cr_start()
        kmeans.fit(testset[['x', 'y']].to_numpy())
        runtime_kmeans = cr_getrt()
        opt_comment="-umapt"
    else:
        dropping_not_connected = 0
        cr_start()
        kmeans.fit(word_doc_matrix)
        runtime_kmeans = cr_getrt()

    
    stats = {'type': f"kmeans{opt_comment}",
             'testset': t_name,
             'version': td_version,
             'size': clustersize
            }
    
    detail_stats = {'tdf': f"rt_vect: {runtime_vectorizer}, min_df: {tdidf_min_df}, max_df: {tdidf_max_df}, stopwords: {use_stopwords}, extended stopwords: {use_extended_stopwords}",
                'runtime': runtime_kmeans
               }
    
    if('y' in testset.columns):
        detail_stats['umap'] = f"{umap_metric}, rt_umap_tf: {runtime_umap_transform}, rt_umap: {runtime_umap}, ncomp: {umap_ncomponents}, rs: {umap_random_state}, min_dist: {umap_min_dist}, no_neigh: {umap_n_neighbors}", #umap not important here
        stats['no_con'] = dropping_not_connected

    prediction = stats
    prediction['name'] = runner_name
    #prediction.update(max_fscore(my_results[[tag, 'clabel']].apply(tuple, axis=1).to_dict()))
    #prediction.update({'tot_clust': total_clusters, 'no_lab':missing_clabel})
    prediction.update(detail_stats)
    res.append(prediction.copy())
        
    display(pd.DataFrame.from_dict(res))
    return kmeans.labels_
    #testset.drop(['cluster_run'], axis=1)

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = umap_embedding[umap_embedding['y'].notna()]['name'].copy()

for i in range(min_cluster, max_cluster, clust_int): # 10, 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(umap_embedding, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
# 2  kmeans-umapt  t2.3.1s        1    16      17   16
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.602722
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 2  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
# 2  kmeans-umapt  t2.3.1s        1    16      17   16
# 3  kmeans-umapt  t2.3.1s        1    19      17   19
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.602722
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.954129
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 2  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 3  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
# 2  kmeans-umapt  t2.3.1s        1    16      17   16
# 3  kmeans-umapt  t2.3.1s        1    19      17   19
# 4  kmeans-umapt  t2.3.1s        1    22      17   22
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.602722
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.954129
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.451612
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 2  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 3  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 4  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
# 2  kmeans-umapt  t2.3.1s        1    16      17   16
# 3  kmeans-umapt  t2.3.1s        1    19      17   19
# 4  kmeans-umapt  t2.3.1s        1    22      17   22
# 5  kmeans-umapt  t2.3.1s        1    25      17   25
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.602722
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.954129
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.451612
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.828312
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 2  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 3  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 4  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 5  (hellinger, rt_umap_tf: 10894.858936071396, rt...
#            type  testset  version  size  no_con name  \
# 0  kmeans-umapt  t2.3.1s        1    10      17   10
# 1  kmeans-umapt  t2.3.1s        1    13      17   13
# 2  kmeans-umapt  t2.3.1s        1    16      17   16
# 3  kmeans-umapt  t2.3.1s        1    19      17   19
# 4  kmeans-umapt  t2.3.1s        1    22      17   22
# 5  kmeans-umapt  t2.3.1s        1    25      17   25
# 6  kmeans-umapt  t2.3.1s        1    28      17   28
#
#                                                  tdf   runtime  \
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.257621
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.396671
# 2  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.602722
# 3  rt_vect: 15.95009994506836, min_df: 4, max_df:...  1.954129
# 4  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.451612
# 5  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.828312
# 6  rt_vect: 15.95009994506836, min_df: 4, max_df:...  2.927205
#
#                                                 umap
# 0  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 1  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 2  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 3  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 4  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 5  (hellinger, rt_umap_tf: 10894.858936071396, rt...
# 6  (hellinger, rt_umap_tf: 10894.858936071396, rt...

# %%
kmeans_labels_results
# Out:
#                                  name  10  13  16  19  22  25  28
# 0            technopagan/mss-saliency   6   0  15  13  12   8  12
# 1          snmnmin12/selective-search   5   1   1   7  16  10  16
# 2                  google/chaps-linux   2   2   0  18  17   5  17
# 3            lukasolson/speech-router   6   8   3   4   1  21  27
# 4               XavierTecBr/qbr-admin   2   2   7   6   7  19   7
# ...                               ...  ..  ..  ..  ..  ..  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   3   4   2  10  21   9  21
# 218331  LandGrey/SpringBootVulExploit   8  10  14  15   9  14   9
# 218332    mucomplex/Pentest_checklist   2   2   7   6   7  19   7
# 218333            bigsen/Vision_Track   5   1   1   7  16  10  16
# 218334             ivanol55/cka-notes   8  10  14  15   9  14   9
#
# [218318 rows x 8 columns]

# %%
print("saving results to disk")
try:
    old_results = from_disk(f'results/{cust_dir}/kmeans-umap_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans-umap_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans-umap_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans-umap_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans-umap_labels_results_t2.3.1s.pkl

# %%
res = []

kmeans_labels_results = pd.DataFrame()
kmeans_labels_results['name'] = testset['name'].copy()


for i in range(10, 16, 3): # 10 60
    runner_name = f'{i}'
    kmeans_labels_results[runner_name] = clusterapply_kmeans(testset, i, runner_name)

results = pd.DataFrame.from_dict(res)
res = []

#k_means_df[['x', 'y']].to_numpy(), 
#word_doc_matrix
# Out:
#      type  testset  version  size name  \
# 0  kmeans  t2.3.1s        1    10   10
#
#                                                  tdf    runtime
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  149.06347
#      type  testset  version  size name  \
# 0  kmeans  t2.3.1s        1    10   10
# 1  kmeans  t2.3.1s        1    13   13
#
#                                                  tdf     runtime
# 0  rt_vect: 15.95009994506836, min_df: 4, max_df:...  149.063470
# 1  rt_vect: 15.95009994506836, min_df: 4, max_df:...  222.543931

# %%
kmeans_labels_results
# Out:
#                                  name  10  13
# 0            technopagan/mss-saliency   1   0
# 1          snmnmin12/selective-search   0   3
# 2                  google/chaps-linux   3   4
# 3            lukasolson/speech-router   4   8
# 4               XavierTecBr/qbr-admin   0   3
# ...                               ...  ..  ..
# 218330  bhagatabhijeet/bhagatabhijeet   0   2
# 218331  LandGrey/SpringBootVulExploit   9   1
# 218332    mucomplex/Pentest_checklist   9   1
# 218333            bigsen/Vision_Track   0   3
# 218334             ivanol55/cka-notes   9   1
#
# [218335 rows x 3 columns]

# %%
print("saving results to disk")

try:
    old_results = from_disk(f'results/{cust_dir}/kmeans_results')
    concat_results = pd.concat([old_results, results])
    concat_results.drop_duplicates(inplace=True)
    to_disk_results(concat_results, f'kmeans_results', subdir=f"{cust_dir}")
except FileNotFoundError:
    to_disk_results(results, f'kmeans_results', subdir=f"{cust_dir}")
    
to_disk_results(kmeans_labels_results, f'kmeans_labels_results_{t_name}', subdir=f"{cust_dir}")
# Out:
# saving results to disk
# reading /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_results.pkl
# writing /home/manuel/d3tect-tools/Notebooks/raw_testdata_v1/results/ar1//kmeans_labels_results_t2.3.1s.pkl
